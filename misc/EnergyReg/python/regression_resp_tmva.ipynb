# %%
import sys, os
import ROOT
import numpy as np
import xgboost as xgb
import pandas as pd
from CMS_lumi import CMS_lumi
from colorPrint import *
from ROOT import RooFit

ROOT.RooMsgService.instance().setSilentMode(True)
ROOT.gROOT.LoadMacro("../interface/tdrstyle.C")
ROOT.gROOT.ProcessLine("setTDRStyle();")
# Out:
# Welcome to JupyROOT 6.24/02
# /home/chenghan/.conda/envs/hdalitz2/lib/python3.8/site-packages/ROOT/_facade.py:150: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   return _orig_ihook(name, *args, **kwds)
# /home/chenghan/.conda/envs/hdalitz2/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# RooFit v3.60 -- Developed by Wouter Verkerke and David Kirkby
#                 Copyright (C) 2000-2013 NIKHEF, University of California & Stanford University
#                 All rights reserved, please read http://roofit.sourceforge.net/license.txt
# 0

# %%
from pprint import pprint

iBE = 1 # 0 for EB and 1 for EE
nthreads = 5
region = "EB" if iBE == 0 else "EE"
inpath = "../reg_results/TMVARegression_DeepNetAndBDTG_{}/weights".format(region)

# TMVA::Experimental::RReader reader("{}/TMVARegression_BDTG.weights.xml");
ROOT.EnableImplicitMT(nthreads)
ROOT.gInterpreter.ProcessLine('''
    TMVA::Experimental::RReader reader("{}/TMVARegression_BDTG.weights.xml");               
'''.format(inpath))

features = ROOT.reader.GetVariableNames()
print("[INFO] {} features are used for training".format(len(features)))
print(features)
# Out:
# [INFO] 23 features are used for training
# { "rho", "nVtx", "eleSCEta_Lead", "eleSCPhi_Lead", "eleSCRawEn_Lead", "eleCalibPt_Lead", "eledEtaAtVtx_Lead", "eledPhiAtVtx_Lead", "elePtError_Lead", "eleHoverE_Lead", "eleEoverP_Lead", "eleEoverPout_Lead", "eleEoverPInv_Lead", "eleSCEtaWidth_Lead", "eleSCPhiWidth_Lead", "eleSigmaIEtaIEtaFull5x5_Lead", "eleSigmaIPhiIPhiFull5x5_Lead", "eleR9Full5x5_Lead", "eleBrem_Lead", "gsfPtSum_Lead", "gsfPtRatio_Lead", "diTrk.Pt()", "gsfDeltaR_Lead" }

# %%
featuresF = []
for f in features:
    fread = ""
    
    # type cast
    if f == "nVtx":
        fread = "nVtxF"
    elif f == "gsfPtSum_Lead":
        fread = "gsfPtSumF_Lead"
    elif f == "gsfPtRatio_Lead":
        fread = "gsfPtRatioF_Lead"
    elif f == "diTrk.Pt()":
        fread = "diTrkPt"
    elif f == "gsfDeltaR_Lead":
        fread = "gsfDeltaRF_Lead"
    else:
        fread = str(f)
    
    featuresF.append(fread)
pprint(featuresF)
featuresF_str = ", ".join(featuresF)

ROOT.gInterpreter.ProcessLine('''
    compute = TMVA::Experimental::Compute<{}, float>(reader);
'''.format(len(featuresF)))

# preselection
cut_base = "elePresel_Lead == 1 && eleCalibPt_Lead > 25 && category == 2"
cut_region = "fabs(eleSCEta_Lead) < 1.479"
if iBE == 1:
    cut_region = "fabs(eleSCEta_Lead) >= 1.479 && fabs(eleSCEta_Lead) < 2.5"
cut_target = "target < 2 && target > 0"

# convert RDataFrame to dataframe
data = ROOT.RDataFrame("miniTree", "../reg_signal.root")\
           .Define("target",    
                #    "diGenEle.Pt()/eleCalibPt_Lead"
                   "dilheEle.Pt()/elePt_Lead"
            )\
           .Define("diTrkPt",           "(float) diTrk.Pt()")\
           .Define("nVtxF",             "(float) nVtx")\
           .Define("gsfPtSumF_Lead",    "(float) gsfPtSum_Lead")\
           .Define("gsfPtRatioF_Lead",  "(float) gsfPtRatio_Lead")\
           .Define("gsfDeltaRF_Lead",   "(float) gsfDeltaR_Lead")\
           .Define("RatioRL",           "(eleEright_Lead - eleEleft_Lead)/(eleEright_Lead + eleEleft_Lead)")\
           .Define("RatioBT",           "(eleEtop_Lead - eleEbottom_Lead)/(eleEtop_Lead + eleEbottom_Lead)")\
           .Define("diTrkPtToRawE",     "diTrkPt/eleSCRawEn_Lead")\
           .Define("eleEmaxToRawE",     "eleEmax_Lead/eleSCRawEn_Lead")\
           .Define("eleE2ndToRawE",     "eleE2nd_Lead/eleSCRawEn_Lead")\
           .Define("eleE2x2ToRawE",     "eleE2x2Full5x5_Lead/eleSCRawEn_Lead")\
           .Define("eleE2x5ToRawE",     "eleE2x5Full5x5_Lead/eleSCRawEn_Lead")\
           .Define("eleE1x3ToRawE",     "eleE1x3Full5x5_Lead/eleSCRawEn_Lead")\
           .Define("genPt",             "diGenEle.Pt()")\
           .Define("regSF",             "compute({})[0]".format(featuresF_str))\
           .Filter("{} && {}".format(cut_base, cut_region))\
           .AsNumpy(columns=featuresF+["regSF", "instwei", "target", "mcwei", "genwei", "puwei", "genPt", "elePt_Lead", "eleCalibPt_Lead"])
                     
df = pd.DataFrame(data)
df
# Out:
# ['rho',
#  'nVtxF',
#  'eleSCEta_Lead',
#  'eleSCPhi_Lead',
#  'eleSCRawEn_Lead',
#  'eleCalibPt_Lead',
#  'eledEtaAtVtx_Lead',
#  'eledPhiAtVtx_Lead',
#  'elePtError_Lead',
#  'eleHoverE_Lead',
#  'eleEoverP_Lead',
#  'eleEoverPout_Lead',
#  'eleEoverPInv_Lead',
#  'eleSCEtaWidth_Lead',
#  'eleSCPhiWidth_Lead',
#  'eleSigmaIEtaIEtaFull5x5_Lead',
#  'eleSigmaIPhiIPhiFull5x5_Lead',
#  'eleR9Full5x5_Lead',
#  'eleBrem_Lead',
#  'gsfPtSumF_Lead',
#  'gsfPtRatioF_Lead',
#  'diTrkPt',
#  'gsfDeltaRF_Lead']
#                rho  nVtxF  eleSCEta_Lead  eleSCPhi_Lead  eleSCRawEn_Lead  \
# 0        14.999523   26.0      -2.026267       0.752340       178.644379
# 1        27.392809   35.0       1.910286      -1.041402       412.505096
# 2        12.107013   16.0       1.786753       0.314079       329.372833
# 3        14.651574   16.0       1.654634       0.823223       104.443230
# 4        32.241436   41.0      -2.165726       1.997939       221.648560
# ...            ...    ...            ...            ...              ...
# 2928336  19.941242   20.0      -2.045621       2.574764       147.239899
# 2928337  19.705475   24.0      -1.958987      -1.285115       581.879272
# 2928338  16.310019   20.0      -2.303794       0.052822       145.615524
# 2928339  20.997568   29.0       2.070329       2.877687       182.294724
# 2928340  37.640064   35.0       2.150474       0.537923       229.337143
#
#          eleCalibPt_Lead  eledEtaAtVtx_Lead  eledPhiAtVtx_Lead  \
# 0              54.641090          -0.001021          -0.001404
# 1             132.407166           0.002726           0.018688
# 2             118.462090           0.000190           0.007506
# 3              44.546276           0.001407          -0.039971
# 4              54.059025           0.006510           0.068691
# ...                  ...                ...                ...
# 2928336        41.718342          -0.000739          -0.009170
# 2928337       174.739777           0.000483           0.009274
# 2928338        34.617832          -0.003749          -0.075728
# 2928339        53.534107           0.002132          -0.021227
# 2928340        54.767456          -0.000893          -0.020582
#
#          elePtError_Lead  eleHoverE_Lead  ...     diTrkPt  gsfDeltaRF_Lead  \
# 0               1.270103        0.000000  ...   91.546585         0.019061
# 1               2.308383        0.017359  ...   45.272739         0.027266
# 2               1.948070        0.002981  ...  120.490692         0.001301
# 3               1.149450        0.007040  ...   29.011034         0.035025
# 4               1.387893        0.013935  ...   64.290215         0.005454
# ...                  ...             ...  ...         ...              ...
# 2928336         1.178673        0.030731  ...   55.834938         0.003340
# 2928337         2.269882        0.007534  ...  248.205612         0.000608
# 2928338         0.920866        0.015021  ...   24.104965         0.007783
# 2928339         1.228276        0.002420  ...   48.160290         0.002313
# 2928340         1.009507        0.012608  ...   27.273220         0.005329
#
#             regSF   instwei    target     mcwei  genwei     puwei       genPt  \
# 0        1.108644  0.010438  0.963976  0.000006     1.0  0.998303   54.615597
# 1        1.061597  0.010438  1.094698  0.000006    -1.0  0.986672  129.315216
# 2        1.017857  0.010438  1.018506  0.000006     1.0  0.983275  116.230545
# 3        1.029768  0.010438  1.472429  0.000006    -1.0  0.934941   46.182442
# 4        1.056031  0.010438  0.922941  0.000006    -1.0  0.973201   52.886925
# ...           ...       ...       ...       ...     ...       ...         ...
# 2928336  1.055901  0.018195  1.023842  0.000012     1.0  0.986530   43.723537
# 2928337  1.075596  0.018195  1.064408  0.000012     1.0  0.979761  175.052200
# 2928338  1.025126  0.018195  1.068980  0.000012     1.0  1.037169   36.421474
# 2928339  1.089184  0.018195  0.969921  0.000012     1.0  1.020131   39.301716
# 2928340  1.109143  0.018195  1.064028  0.000012     1.0  1.016172   57.231850
#
#          elePt_Lead
# 0         53.611691
# 1        130.177002
# 2        114.999214
# 3         44.933357
# 4         52.250473
# ...             ...
# 2928336   42.630165
# 2928337  169.806519
# 2928338   34.611046
# 2928339   51.653427
# 2928340   55.726242
#
# [2928341 rows x 31 columns]

# %%
import matplotlib.pyplot as plt

preds = df["regSF"].to_numpy()

df["wei"] = df["mcwei"] * df["genwei"] * df["puwei"]
weights = df["wei"].to_numpy()

df["eleHDALRegPt_Lead"] = df["regSF"] * df["elePt_Lead"]

binContent, binEdge, _ = plt.hist(df["genPt"]/df["eleHDALRegPt_Lead"], bins=100, range=(0.8, 1.2), histtype="step", weights=weights, color="#008891", linewidth=2, label="eleHDALRegPt")
binContent, binEdge, _ = plt.hist(df["target"], bins=100, range=(0.8, 1.2), histtype="step", weights=weights, linewidth=2, label="elePt", color="#EC524B")

plt.legend(loc="best", fontsize=13, edgecolor="none")

# %%
def pltSty(ax, xName="x-axis", yName="y-axis", TitleSize=15, LabelSize=15, TickSize=13, yAuto=True):
    from matplotlib.ticker import AutoLocator, AutoMinorLocator
    ax.set_xlabel(xName, fontsize=LabelSize, loc="right")
    ax.set_ylabel(yName, fontsize=LabelSize, loc="top")
    ax.text(1, 1, "(13 TeV)", horizontalalignment="right", verticalalignment="bottom", transform=ax.transAxes, fontsize=TitleSize)
    ax.text(0, 1, "CMS", horizontalalignment="left", verticalalignment="bottom", transform=ax.transAxes, fontsize=TitleSize * 1.2, fontweight="bold")
    ax.text(TitleSize * 0.009 + 0.025, 1, "Simulation Preliminary", horizontalalignment="left", verticalalignment="bottom", transform=ax.transAxes, fontsize=TitleSize)

    ax.xaxis.set_major_locator(AutoLocator())
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    if (yAuto):
        ax.yaxis.set_major_locator(AutoLocator())
        ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.tick_params(direction="in", length=7, labelsize=TickSize, top=True, right=True)
    ax.tick_params(direction="in", length=4, which="minor", labelsize=TickSize, top=True, right=True)

pltSty(plt.gca(), xName="$p_{T}$ GeV", yName="a.u.")
binContent, binEdge, _ = plt.hist(df["eleHDALRegPt_Lead"], bins=50, range=(25, 150), histtype="step", density=True, color="#008891", linewidth=2, label="eleHDALRegPt")
binContent, binEdge, _ = plt.hist(df["elePt_Lead"],        bins=50, range=(25, 150), histtype="step", density=True, color="#EC524B", linewidth=2, label="elePt")
binContent, binEdge, _ = plt.hist(df["genPt"],             bins=50, range=(25, 150), histtype="step", density=True, color="#005792", linewidth=2, label="diGenElePt")
plt.legend(loc="best", fontsize=13, edgecolor="none")
plt.tight_layout()

# %%
df["resp_XGB"] = df["eleHDALRegPt_Lead"]/df["genPt"]
df["resp_EGM"] = df["elePt_Lead"]/df["genPt"]

genPt = df["genPt"].to_numpy()
resp_XGB = df["resp_XGB"].to_numpy()
resp_EGM = df["resp_EGM"].to_numpy()

bins = 350 if iBE == 0 else 300
hist2D_XGB = ROOT.TH2D("hist2D_XGB", "", 13, 25, 155, bins, 0, 2)
hist2D_EGM = ROOT.TH2D("hist2D_EGM", "", 13, 25, 155, bins, 0, 2)

for i in range(len(resp_XGB)):
    hist2D_XGB.Fill(genPt[i], resp_XGB[i], weights[i])
    hist2D_EGM.Fill(genPt[i], resp_EGM[i], weights[i])
    
hist2D_XGB.Print("all")
# Out:
# TH1.Print Name  = hist2D_XGB, Entries= 2928341, Total sum= 114.95
#  fSumw[0][0]=0, x=20, y=-0.00333333, error=0
#  fSumw[1][0]=0, x=30, y=-0.00333333, error=0
#  fSumw[2][0]=0, x=40, y=-0.00333333, error=0
#  fSumw[3][0]=0, x=50, y=-0.00333333, error=0
#  fSumw[4][0]=0, x=60, y=-0.00333333, error=0
#  fSumw[5][0]=0, x=70, y=-0.00333333, error=0
#  fSumw[6][0]=0, x=80, y=-0.00333333, error=0
#  fSumw[7][0]=0, x=90, y=-0.00333333, error=0
#  fSumw[8][0]=0, x=100, y=-0.00333333, error=0
#  fSumw[9][0]=0, x=110, y=-0.00333333, error=0
#  fSumw[10][0]=0, x=120, y=-0.00333333, error=0
#  fSumw[11][0]=0, x=130, y=-0.00333333, error=0
#  fSumw[12][0]=0, x=140, y=-0.00333333, error=0
#  fSumw[13][0]=0, x=150, y=-0.00333333, error=0
#  fSumw[14][0]=0, x=160, y=-0.00333333, error=0
#  fSumw[0][1]=0, x=20, y=0.00333333, error=0
#  fSumw[1][1]=0, x=30, y=0.00333333, error=0
#  fSumw[2][1]=0, x=40, y=0.00333333, error=0
#  fSumw[3][1]=0, x=50, y=0.00333333, error=0
#  fSumw[4][1]=0, x=60, y=0.00333333, error=0
#  fSumw[5][1]=0, x=70, y=0.00333333, error=0
#  fSumw[6][1]=0, x=80, y=0.00333333, error=0
#  fSumw[7][1]=0, x=90, y=0.00333333, error=0
#  fSumw[8][1]=0, x=100, y=0.00333333, error=0
#  fSumw[9][1]=0, x=110, y=0.00333333, error=0
#  fSumw[10][1]=0, x=120, y=0.00333333, error=0
#  fSumw[11][1]=0, x=130, y=0.00333333, error=0
#  fSumw[12][1]=0, x=140, y=0.00333333, error=0
#  fSumw[13][1]=0, x=150, y=0.00333333, error=0
#  fSumw[14][1]=0, x=160, y=0.00333333, error=0
#  fSumw[0][2]=0, x=20, y=0.01, error=0
#  fSumw[1][2]=0, x=30, y=0.01, error=0
#  fSumw[2][2]=0, x=40, y=0.01, error=0
#  fSumw[3][2]=0, x=50, y=0.01, error=0
#  fSumw[4][2]=0, x=60, y=0.01, error=0
#  fSumw[5][2]=0, x=70, y=0.01, error=0
#  fSumw[6][2]=0, x=80, y=0.01, error=0
#  fSumw[7][2]=0, x=90, y=0.01, error=0
#  fSumw[8][2]=0, x=100, y=0.01, error=0
#  fSumw[9][2]=0, x=110, y=0.01, error=0
#  fSumw[10][2]=0, x=120, y=0.01, error=0
#  fSumw[11][2]=0, x=130, y=0.01, error=0
#  fSumw[12][2]=0, x=140, y=0.01, error=0
#  fSumw[13][2]=0, x=150, y=0.01, error=0
#  fSumw[14][2]=0, x=160, y=0.01, error=0
#  fSumw[0][3]=0, x=20, y=0.0166667, error=0
#  fSumw[1][3]=0, x=30, y=0.0166667, error=0
#  fSumw[2][3]=0, x=40, y=0.0166667, error=0
#  fSumw[3][3]=0, x=50, y=0.0166667, error=0
#  fSumw[4][3]=0, x=60, y=0.0166667, error=0
#  fSumw[5][3]=0, x=70, y=0.0166667, error=0
#  fSumw[6][3]=0, x=80, y=0.0166667, error=0
#  fSumw[7][3]=0, x=90, y=0.0166667, error=0
#  fSumw[8][3]=0, x=100, y=0.0166667, error=0
#  fSumw[9][3]=0, x=110, y=0.0166667, error=0
#  fSumw[10][3]=0, x=120, y=0.0166667, error=0
#  fSumw[11][3]=0, x=130, y=0.0166667, error=0
#  fSumw[12][3]=0, x=140, y=0.0166667, error=0
#  fSumw[13][3]=0, x=150, y=0.0166667, error=0
#  fSumw[14][3]=0, x=160, y=0.0166667, error=0
#  fSumw[0][4]=0, x=20, y=0.0233333, error=0
#  fSumw[1][4]=0, x=30, y=0.0233333, error=0
#  fSumw[2][4]=0, x=40, y=0.0233333, error=0
#  fSumw[3][4]=0, x=50, y=0.0233333, error=0
#  fSumw[4][4]=0, x=60, y=0.0233333, error=0
#  fSumw[5][4]=0, x=70, y=0.0233333, error=0
#  fSumw[6][4]=0, x=80, y=0.0233333, error=0
#  fSumw[7][4]=0, x=90, y=0.0233333, error=0
#  fSumw[8][4]=0, x=100, y=0.0233333, error=0
#  fSumw[9][4]=0, x=110, y=0.0233333, error=0
#  fSumw[10][4]=0, x=120, y=0.0233333, error=0
#  fSumw[11][4]=0, x=130, y=0.0233333, error=0
#  fSumw[12][4]=0, x=140, y=0.0233333, error=0
#  fSumw[13][4]=0, x=150, y=0.0233333, error=0
#  fSumw[14][4]=0, x=160, y=0.0233333, error=0
#  fSumw[0][5]=0, x=20, y=0.03, error=0
#  fSumw[1][5]=0, x=30, y=0.03, error=0
#  fSumw[2][5]=0, x=40, y=0.03, error=0
#  fSumw[3][5]=0, x=50, y=0.03, error=0
#  fSumw[4][5]=0, x=60, y=0.03, error=0
#  fSumw[5][5]=0, x=70, y=0.03, error=0
#  fSumw[6][5]=0, x=80, y=0.03, error=0
#  fSumw[7][5]=0, x=90, y=0.03, error=0
#  fSumw[8][5]=0, x=100, y=0.03, error=0
#  fSumw[9][5]=0, x=110, y=0.03, error=0
#  fSumw[10][5]=0, x=120, y=0.03, error=0
#  fSumw[11][5]=0, x=130, y=0.03, error=0
#  fSumw[12][5]=0, x=140, y=0.03, error=0
#  fSumw[13][5]=0, x=150, y=0.03, error=0
#  fSumw[14][5]=0, x=160, y=0.03, error=0
#  fSumw[0][6]=0, x=20, y=0.0366667, error=0
#  fSumw[1][6]=0, x=30, y=0.0366667, error=0
#  fSumw[2][6]=0, x=40, y=0.0366667, error=0
#  fSumw[3][6]=0, x=50, y=0.0366667, error=0
#  fSumw[4][6]=0, x=60, y=0.0366667, error=0
#  fSumw[5][6]=0, x=70, y=0.0366667, error=0
#  fSumw[6][6]=0, x=80, y=0.0366667, error=0
#  fSumw[7][6]=0, x=90, y=0.0366667, error=0
#  fSumw[8][6]=0, x=100, y=0.0366667, error=0
#  fSumw[9][6]=0, x=110, y=0.0366667, error=0
#  fSumw[10][6]=0, x=120, y=0.0366667, error=0
#  fSumw[11][6]=0, x=130, y=0.0366667, error=0
#  fSumw[12][6]=0, x=140, y=0.0366667, error=0
#  fSumw[13][6]=0, x=150, y=0.0366667, error=0
#  fSumw[14][6]=0, x=160, y=0.0366667, error=0
#  fSumw[0][7]=0, x=20, y=0.0433333, error=0
#  fSumw[1][7]=0, x=30, y=0.0433333, error=0
#  fSumw[2][7]=0, x=40, y=0.0433333, error=0
#  fSumw[3][7]=0, x=50, y=0.0433333, error=0
#  fSumw[4][7]=0, x=60, y=0.0433333, error=0
#  fSumw[5][7]=0, x=70, y=0.0433333, error=0
#  fSumw[6][7]=0, x=80, y=0.0433333, error=0
#  fSumw[7][7]=0, x=90, y=0.0433333, error=0
#  fSumw[8][7]=0, x=100, y=0.0433333, error=0
#  fSumw[9][7]=0, x=110, y=0.0433333, error=0
#  fSumw[10][7]=0, x=120, y=0.0433333, error=0
#  fSumw[11][7]=0, x=130, y=0.0433333, error=0
#  fSumw[12][7]=0, x=140, y=0.0433333, error=0
#  fSumw[13][7]=0, x=150, y=0.0433333, error=0
#  fSumw[14][7]=0, x=160, y=0.0433333, error=0
#  fSumw[0][8]=0, x=20, y=0.05, error=0
#  fSumw[1][8]=0, x=30, y=0.05, error=0
#  fSumw[2][8]=0, x=40, y=0.05, error=0
#  fSumw[3][8]=0, x=50, y=0.05, error=0
#  fSumw[4][8]=0, x=60, y=0.05, error=0
#  fSumw[5][8]=0, x=70, y=0.05, error=0
#  fSumw[6][8]=0, x=80, y=0.05, error=0
#  fSumw[7][8]=0, x=90, y=0.05, error=0
#  fSumw[8][8]=0, x=100, y=0.05, error=0
#  fSumw[9][8]=0, x=110, y=0.05, error=0
#  fSumw[10][8]=0, x=120, y=0.05, error=0
#  fSumw[11][8]=0, x=130, y=0.05, error=0
#  fSumw[12][8]=0, x=140, y=0.05, error=0
#  fSumw[13][8]=0, x=150, y=0.05, error=0
#  fSumw[14][8]=0, x=160, y=0.05, error=0
#  fSumw[0][9]=0, x=20, y=0.0566667, error=0
#  fSumw[1][9]=0, x=30, y=0.0566667, error=0
#  fSumw[2][9]=0, x=40, y=0.0566667, error=0
#  fSumw[3][9]=0, x=50, y=0.0566667, error=0
#  fSumw[4][9]=0, x=60, y=0.0566667, error=0
#  fSumw[5][9]=0, x=70, y=0.0566667, error=0
#  fSumw[6][9]=0, x=80, y=0.0566667, error=0
#  fSumw[7][9]=0, x=90, y=0.0566667, error=0
#  fSumw[8][9]=0, x=100, y=0.0566667, error=0
#  fSumw[9][9]=0, x=110, y=0.0566667, error=0
#  fSumw[10][9]=0, x=120, y=0.0566667, error=0
#  fSumw[11][9]=0, x=130, y=0.0566667, error=0
#  fSumw[12][9]=0, x=140, y=0.0566667, error=0
#  fSumw[13][9]=0, x=150, y=0.0566667, error=0
#  fSumw[14][9]=0, x=160, y=0.0566667, error=0
#  fSumw[0][10]=0, x=20, y=0.0633333, error=0
#  fSumw[1][10]=0, x=30, y=0.0633333, error=0
#  fSumw[2][10]=0, x=40, y=0.0633333, error=0
#  fSumw[3][10]=0, x=50, y=0.0633333, error=0
#  fSumw[4][10]=0, x=60, y=0.0633333, error=0
#  fSumw[5][10]=0, x=70, y=0.0633333, error=0
#  fSumw[6][10]=0, x=80, y=0.0633333, error=0
#  fSumw[7][10]=0, x=90, y=0.0633333, error=0
#  fSumw[8][10]=0, x=100, y=0.0633333, error=0
#  fSumw[9][10]=0, x=110, y=0.0633333, error=0
#  fSumw[10][10]=0, x=120, y=0.0633333, error=0
#  fSumw[11][10]=0, x=130, y=0.0633333, error=0
#  fSumw[12][10]=0, x=140, y=0.0633333, error=0
#  fSumw[13][10]=0, x=150, y=0.0633333, error=0
#  fSumw[14][10]=0, x=160, y=0.0633333, error=0
#  fSumw[0][11]=0, x=20, y=0.07, error=0
#  fSumw[1][11]=0, x=30, y=0.07, error=0
#  fSumw[2][11]=0, x=40, y=0.07, error=0
#  fSumw[3][11]=0, x=50, y=0.07, error=0
#  fSumw[4][11]=0, x=60, y=0.07, error=0
#  fSumw[5][11]=0, x=70, y=0.07, error=0
#  fSumw[6][11]=0, x=80, y=0.07, error=0
#  fSumw[7][11]=0, x=90, y=0.07, error=0
#  fSumw[8][11]=0, x=100, y=0.07, error=0
#  fSumw[9][11]=0, x=110, y=0.07, error=0
#  fSumw[10][11]=0, x=120, y=0.07, error=0
#  fSumw[11][11]=0, x=130, y=0.07, error=0
#  fSumw[12][11]=0, x=140, y=0.07, error=0
#  fSumw[13][11]=0, x=150, y=0.07, error=0
#  fSumw[14][11]=0, x=160, y=0.07, error=0
#  fSumw[0][12]=0, x=20, y=0.0766667, error=0
#  fSumw[1][12]=0, x=30, y=0.0766667, error=0
#  fSumw[2][12]=0, x=40, y=0.0766667, error=0
#  fSumw[3][12]=0, x=50, y=0.0766667, error=0
#  fSumw[4][12]=0, x=60, y=0.0766667, error=0
#  fSumw[5][12]=0, x=70, y=0.0766667, error=0
#  fSumw[6][12]=0, x=80, y=0.0766667, error=0
#  fSumw[7][12]=0, x=90, y=0.0766667, error=0
#  fSumw[8][12]=0, x=100, y=0.0766667, error=0
#  fSumw[9][12]=0, x=110, y=0.0766667, error=0
#  fSumw[10][12]=0, x=120, y=0.0766667, error=0
#  fSumw[11][12]=0, x=130, y=0.0766667, error=0
#  fSumw[12][12]=0, x=140, y=0.0766667, error=0
#  fSumw[13][12]=0, x=150, y=0.0766667, error=0
#  fSumw[14][12]=0, x=160, y=0.0766667, error=0
#  fSumw[0][13]=0, x=20, y=0.0833333, error=0
#  fSumw[1][13]=0, x=30, y=0.0833333, error=0
#  fSumw[2][13]=0, x=40, y=0.0833333, error=0
#  fSumw[3][13]=0, x=50, y=0.0833333, error=0
#  fSumw[4][13]=0, x=60, y=0.0833333, error=0
#  fSumw[5][13]=0, x=70, y=0.0833333, error=0
#  fSumw[6][13]=0, x=80, y=0.0833333, error=0
#  fSumw[7][13]=0, x=90, y=0.0833333, error=0
#  fSumw[8][13]=0, x=100, y=0.0833333, error=0
#  fSumw[9][13]=0, x=110, y=0.0833333, error=0
#  fSumw[10][13]=0, x=120, y=0.0833333, error=0
#  fSumw[11][13]=0, x=130, y=0.0833333, error=0
#  fSumw[12][13]=0, x=140, y=0.0833333, error=0
#  fSumw[13][13]=0, x=150, y=0.0833333, error=0
#  fSumw[14][13]=0, x=160, y=0.0833333, error=0
#  fSumw[0][14]=0, x=20, y=0.09, error=0
#  fSumw[1][14]=0, x=30, y=0.09, error=0
#  fSumw[2][14]=0, x=40, y=0.09, error=0
#  fSumw[3][14]=0, x=50, y=0.09, error=0
#  fSumw[4][14]=0, x=60, y=0.09, error=0
#  fSumw[5][14]=0, x=70, y=0.09, error=0
#  fSumw[6][14]=0, x=80, y=0.09, error=0
#  fSumw[7][14]=0, x=90, y=0.09, error=0
#  fSumw[8][14]=0, x=100, y=0.09, error=0
#  fSumw[9][14]=0, x=110, y=0.09, error=0
#  fSumw[10][14]=0, x=120, y=0.09, error=0
#  fSumw[11][14]=0, x=130, y=0.09, error=0
#  fSumw[12][14]=0, x=140, y=0.09, error=0
#  fSumw[13][14]=0, x=150, y=0.09, error=0
#  fSumw[14][14]=0, x=160, y=0.09, error=0
#  fSumw[0][15]=0, x=20, y=0.0966667, error=0
#  fSumw[1][15]=0, x=30, y=0.0966667, error=0
#  fSumw[2][15]=0, x=40, y=0.0966667, error=0
#  fSumw[3][15]=0, x=50, y=0.0966667, error=0
#  fSumw[4][15]=0, x=60, y=0.0966667, error=0
#  fSumw[5][15]=0, x=70, y=0.0966667, error=0
#  fSumw[6][15]=0, x=80, y=0.0966667, error=0
#  fSumw[7][15]=0, x=90, y=0.0966667, error=0
#  fSumw[8][15]=0, x=100, y=0.0966667, error=0
#  fSumw[9][15]=4.09406e-05, x=110, y=0.0966667, error=4.09406e-05
#  fSumw[10][15]=0, x=120, y=0.0966667, error=0
#  fSumw[11][15]=0, x=130, y=0.0966667, error=0
#  fSumw[12][15]=0, x=140, y=0.0966667, error=0
#  fSumw[13][15]=0, x=150, y=0.0966667, error=0
#  fSumw[14][15]=0, x=160, y=0.0966667, error=0
#  fSumw[0][16]=0, x=20, y=0.103333, error=0
#  fSumw[1][16]=0, x=30, y=0.103333, error=0
#  fSumw[2][16]=0, x=40, y=0.103333, error=0
#  fSumw[3][16]=0, x=50, y=0.103333, error=0
#  fSumw[4][16]=0, x=60, y=0.103333, error=0
#  fSumw[5][16]=0, x=70, y=0.103333, error=0
#  fSumw[6][16]=0, x=80, y=0.103333, error=0
#  fSumw[7][16]=0, x=90, y=0.103333, error=0
#  fSumw[8][16]=0, x=100, y=0.103333, error=0
#  fSumw[9][16]=0, x=110, y=0.103333, error=0
#  fSumw[10][16]=0, x=120, y=0.103333, error=0
#  fSumw[11][16]=0, x=130, y=0.103333, error=0
#  fSumw[12][16]=0, x=140, y=0.103333, error=0
#  fSumw[13][16]=0, x=150, y=0.103333, error=0
#  fSumw[14][16]=0, x=160, y=0.103333, error=0
#  fSumw[0][17]=0, x=20, y=0.11, error=0
#  fSumw[1][17]=0, x=30, y=0.11, error=0
#  fSumw[2][17]=0, x=40, y=0.11, error=0
#  fSumw[3][17]=0, x=50, y=0.11, error=0
#  fSumw[4][17]=0, x=60, y=0.11, error=0
#  fSumw[5][17]=0, x=70, y=0.11, error=0
#  fSumw[6][17]=0, x=80, y=0.11, error=0
#  fSumw[7][17]=0, x=90, y=0.11, error=0
#  fSumw[8][17]=0, x=100, y=0.11, error=0
#  fSumw[9][17]=0, x=110, y=0.11, error=0
#  fSumw[10][17]=0, x=120, y=0.11, error=0
#  fSumw[11][17]=0, x=130, y=0.11, error=0
#  fSumw[12][17]=0, x=140, y=0.11, error=0
#  fSumw[13][17]=0, x=150, y=0.11, error=0
#  fSumw[14][17]=0, x=160, y=0.11, error=0
#  fSumw[0][18]=0, x=20, y=0.116667, error=0
#  fSumw[1][18]=0, x=30, y=0.116667, error=0
#  fSumw[2][18]=0, x=40, y=0.116667, error=0
#  fSumw[3][18]=0, x=50, y=0.116667, error=0
#  fSumw[4][18]=0, x=60, y=0.116667, error=0
#  fSumw[5][18]=0, x=70, y=0.116667, error=0
#  fSumw[6][18]=0, x=80, y=0.116667, error=0
#  fSumw[7][18]=0, x=90, y=0.116667, error=0
#  fSumw[8][18]=0, x=100, y=0.116667, error=0
#  fSumw[9][18]=0, x=110, y=0.116667, error=0
#  fSumw[10][18]=0, x=120, y=0.116667, error=0
#  fSumw[11][18]=0, x=130, y=0.116667, error=0
#  fSumw[12][18]=0, x=140, y=0.116667, error=0
#  fSumw[13][18]=0, x=150, y=0.116667, error=0
#  fSumw[14][18]=7.64151e-06, x=160, y=0.116667, error=7.64151e-06
#  fSumw[0][19]=0, x=20, y=0.123333, error=0
#  fSumw[1][19]=0, x=30, y=0.123333, error=0
#  fSumw[2][19]=0, x=40, y=0.123333, error=0
#  fSumw[3][19]=0, x=50, y=0.123333, error=0
#  fSumw[4][19]=0, x=60, y=0.123333, error=0
#  fSumw[5][19]=0, x=70, y=0.123333, error=0
#  fSumw[6][19]=0, x=80, y=0.123333, error=0
#  fSumw[7][19]=0, x=90, y=0.123333, error=0
#  fSumw[8][19]=0, x=100, y=0.123333, error=0
#  fSumw[9][19]=0, x=110, y=0.123333, error=0
#  fSumw[10][19]=0, x=120, y=0.123333, error=0
#  fSumw[11][19]=0, x=130, y=0.123333, error=0
#  fSumw[12][19]=0, x=140, y=0.123333, error=0
#  fSumw[13][19]=0, x=150, y=0.123333, error=0
#  fSumw[14][19]=0, x=160, y=0.123333, error=0
#  fSumw[0][20]=0, x=20, y=0.13, error=0
#  fSumw[1][20]=0, x=30, y=0.13, error=0
#  fSumw[2][20]=0, x=40, y=0.13, error=0
#  fSumw[3][20]=0, x=50, y=0.13, error=0
#  fSumw[4][20]=0, x=60, y=0.13, error=0
#  fSumw[5][20]=0, x=70, y=0.13, error=0
#  fSumw[6][20]=0, x=80, y=0.13, error=0
#  fSumw[7][20]=0, x=90, y=0.13, error=0
#  fSumw[8][20]=0, x=100, y=0.13, error=0
#  fSumw[9][20]=0, x=110, y=0.13, error=0
#  fSumw[10][20]=0, x=120, y=0.13, error=0
#  fSumw[11][20]=0, x=130, y=0.13, error=0
#  fSumw[12][20]=0, x=140, y=0.13, error=0
#  fSumw[13][20]=0, x=150, y=0.13, error=0
#  fSumw[14][20]=2.22159e-05, x=160, y=0.13, error=2.22159e-05
#  fSumw[0][21]=0, x=20, y=0.136667, error=0
#  fSumw[1][21]=0, x=30, y=0.136667, error=0
#  fSumw[2][21]=0, x=40, y=0.136667, error=0
#  fSumw[3][21]=0, x=50, y=0.136667, error=0
#  fSumw[4][21]=0, x=60, y=0.136667, error=0
#  fSumw[5][21]=0, x=70, y=0.136667, error=0
#  fSumw[6][21]=0, x=80, y=0.136667, error=0
#  fSumw[7][21]=0, x=90, y=0.136667, error=0
#  fSumw[8][21]=0, x=100, y=0.136667, error=0
#  fSumw[9][21]=0, x=110, y=0.136667, error=0
#  fSumw[10][21]=0, x=120, y=0.136667, error=0
#  fSumw[11][21]=0, x=130, y=0.136667, error=0
#  fSumw[12][21]=0, x=140, y=0.136667, error=0
#  fSumw[13][21]=0, x=150, y=0.136667, error=0
#  fSumw[14][21]=0, x=160, y=0.136667, error=0
#  fSumw[0][22]=0, x=20, y=0.143333, error=0
#  fSumw[1][22]=0, x=30, y=0.143333, error=0
#  fSumw[2][22]=0, x=40, y=0.143333, error=0
#  fSumw[3][22]=0, x=50, y=0.143333, error=0
#  fSumw[4][22]=0, x=60, y=0.143333, error=0
#  fSumw[5][22]=0, x=70, y=0.143333, error=0
#  fSumw[6][22]=0, x=80, y=0.143333, error=0
#  fSumw[7][22]=0, x=90, y=0.143333, error=0
#  fSumw[8][22]=0, x=100, y=0.143333, error=0
#  fSumw[9][22]=0, x=110, y=0.143333, error=0
#  fSumw[10][22]=0, x=120, y=0.143333, error=0
#  fSumw[11][22]=0, x=130, y=0.143333, error=0
#  fSumw[12][22]=0, x=140, y=0.143333, error=0
#  fSumw[13][22]=0, x=150, y=0.143333, error=0
#  fSumw[14][22]=6.08784e-05, x=160, y=0.143333, error=4.69336e-05
#  fSumw[0][23]=0, x=20, y=0.15, error=0
#  fSumw[1][23]=0, x=30, y=0.15, error=0
#  fSumw[2][23]=0, x=40, y=0.15, error=0
#  fSumw[3][23]=0, x=50, y=0.15, error=0
#  fSumw[4][23]=0, x=60, y=0.15, error=0
#  fSumw[5][23]=0, x=70, y=0.15, error=0
#  fSumw[6][23]=0, x=80, y=0.15, error=0
#  fSumw[7][23]=0, x=90, y=0.15, error=0
#  fSumw[8][23]=0, x=100, y=0.15, error=0
#  fSumw[9][23]=0, x=110, y=0.15, error=0
#  fSumw[10][23]=0, x=120, y=0.15, error=0
#  fSumw[11][23]=0, x=130, y=0.15, error=0
#  fSumw[12][23]=0, x=140, y=0.15, error=0
#  fSumw[13][23]=0, x=150, y=0.15, error=0
#  fSumw[14][23]=-3.77172e-05, x=160, y=0.15, error=4.47743e-05
#  fSumw[0][24]=0, x=20, y=0.156667, error=0
#  fSumw[1][24]=0, x=30, y=0.156667, error=0
#  fSumw[2][24]=0, x=40, y=0.156667, error=0
#  fSumw[3][24]=0, x=50, y=0.156667, error=0
#  fSumw[4][24]=0, x=60, y=0.156667, error=0
#  fSumw[5][24]=0, x=70, y=0.156667, error=0
#  fSumw[6][24]=0, x=80, y=0.156667, error=0
#  fSumw[7][24]=0, x=90, y=0.156667, error=0
#  fSumw[8][24]=0, x=100, y=0.156667, error=0
#  fSumw[9][24]=0, x=110, y=0.156667, error=0
#  fSumw[10][24]=0, x=120, y=0.156667, error=0
#  fSumw[11][24]=0, x=130, y=0.156667, error=0
#  fSumw[12][24]=0, x=140, y=0.156667, error=0
#  fSumw[13][24]=0, x=150, y=0.156667, error=0
#  fSumw[14][24]=1.18931e-05, x=160, y=0.156667, error=1.18931e-05
#  fSumw[0][25]=0, x=20, y=0.163333, error=0
#  fSumw[1][25]=0, x=30, y=0.163333, error=0
#  fSumw[2][25]=0, x=40, y=0.163333, error=0
#  fSumw[3][25]=0, x=50, y=0.163333, error=0
#  fSumw[4][25]=0, x=60, y=0.163333, error=0
#  fSumw[5][25]=0, x=70, y=0.163333, error=0
#  fSumw[6][25]=0, x=80, y=0.163333, error=0
#  fSumw[7][25]=0, x=90, y=0.163333, error=0
#  fSumw[8][25]=0, x=100, y=0.163333, error=0
#  fSumw[9][25]=0, x=110, y=0.163333, error=0
#  fSumw[10][25]=0, x=120, y=0.163333, error=0
#  fSumw[11][25]=0, x=130, y=0.163333, error=0
#  fSumw[12][25]=0, x=140, y=0.163333, error=0
#  fSumw[13][25]=0, x=150, y=0.163333, error=0
#  fSumw[14][25]=3.55801e-05, x=160, y=0.163333, error=2.60988e-05
#  fSumw[0][26]=0, x=20, y=0.17, error=0
#  fSumw[1][26]=0, x=30, y=0.17, error=0
#  fSumw[2][26]=0, x=40, y=0.17, error=0
#  fSumw[3][26]=0, x=50, y=0.17, error=0
#  fSumw[4][26]=0, x=60, y=0.17, error=0
#  fSumw[5][26]=0, x=70, y=0.17, error=0
#  fSumw[6][26]=0, x=80, y=0.17, error=0
#  fSumw[7][26]=0, x=90, y=0.17, error=0
#  fSumw[8][26]=0, x=100, y=0.17, error=0
#  fSumw[9][26]=0, x=110, y=0.17, error=0
#  fSumw[10][26]=0, x=120, y=0.17, error=0
#  fSumw[11][26]=5.52677e-06, x=130, y=0.17, error=5.52677e-06
#  fSumw[12][26]=0, x=140, y=0.17, error=0
#  fSumw[13][26]=1.12736e-05, x=150, y=0.17, error=1.12736e-05
#  fSumw[14][26]=1.00981e-05, x=160, y=0.17, error=1.00981e-05
#  fSumw[0][27]=0, x=20, y=0.176667, error=0
#  fSumw[1][27]=0, x=30, y=0.176667, error=0
#  fSumw[2][27]=0, x=40, y=0.176667, error=0
#  fSumw[3][27]=0, x=50, y=0.176667, error=0
#  fSumw[4][27]=0, x=60, y=0.176667, error=0
#  fSumw[5][27]=0, x=70, y=0.176667, error=0
#  fSumw[6][27]=0, x=80, y=0.176667, error=0
#  fSumw[7][27]=0, x=90, y=0.176667, error=0
#  fSumw[8][27]=0, x=100, y=0.176667, error=0
#  fSumw[9][27]=0, x=110, y=0.176667, error=0
#  fSumw[10][27]=0, x=120, y=0.176667, error=0
#  fSumw[11][27]=0, x=130, y=0.176667, error=0
#  fSumw[12][27]=0, x=140, y=0.176667, error=0
#  fSumw[13][27]=0, x=150, y=0.176667, error=0
#  fSumw[14][27]=2.93675e-05, x=160, y=0.176667, error=2.93675e-05
#  fSumw[0][28]=0, x=20, y=0.183333, error=0
#  fSumw[1][28]=0, x=30, y=0.183333, error=0
#  fSumw[2][28]=0, x=40, y=0.183333, error=0
#  fSumw[3][28]=0, x=50, y=0.183333, error=0
#  fSumw[4][28]=0, x=60, y=0.183333, error=0
#  fSumw[5][28]=0, x=70, y=0.183333, error=0
#  fSumw[6][28]=0, x=80, y=0.183333, error=0
#  fSumw[7][28]=0, x=90, y=0.183333, error=0
#  fSumw[8][28]=0, x=100, y=0.183333, error=0
#  fSumw[9][28]=0, x=110, y=0.183333, error=0
#  fSumw[10][28]=0, x=120, y=0.183333, error=0
#  fSumw[11][28]=1.2358e-05, x=130, y=0.183333, error=1.2358e-05
#  fSumw[12][28]=0, x=140, y=0.183333, error=0
#  fSumw[13][28]=2.14531e-05, x=150, y=0.183333, error=2.14531e-05
#  fSumw[14][28]=4.81028e-05, x=160, y=0.183333, error=4.6293e-05
#  fSumw[0][29]=0, x=20, y=0.19, error=0
#  fSumw[1][29]=0, x=30, y=0.19, error=0
#  fSumw[2][29]=0, x=40, y=0.19, error=0
#  fSumw[3][29]=0, x=50, y=0.19, error=0
#  fSumw[4][29]=0, x=60, y=0.19, error=0
#  fSumw[5][29]=0, x=70, y=0.19, error=0
#  fSumw[6][29]=0, x=80, y=0.19, error=0
#  fSumw[7][29]=-8.09596e-06, x=90, y=0.19, error=8.09596e-06
#  fSumw[8][29]=0, x=100, y=0.19, error=0
#  fSumw[9][29]=0, x=110, y=0.19, error=0
#  fSumw[10][29]=0, x=120, y=0.19, error=0
#  fSumw[11][29]=0, x=130, y=0.19, error=0
#  fSumw[12][29]=8.57141e-06, x=140, y=0.19, error=8.57141e-06
#  fSumw[13][29]=4.4242e-05, x=150, y=0.19, error=4.4242e-05
#  fSumw[14][29]=2.24623e-05, x=160, y=0.19, error=1.65558e-05
#  fSumw[0][30]=0, x=20, y=0.196667, error=0
#  fSumw[1][30]=0, x=30, y=0.196667, error=0
#  fSumw[2][30]=0, x=40, y=0.196667, error=0
#  fSumw[3][30]=0, x=50, y=0.196667, error=0
#  fSumw[4][30]=0, x=60, y=0.196667, error=0
#  fSumw[5][30]=0, x=70, y=0.196667, error=0
#  fSumw[6][30]=0, x=80, y=0.196667, error=0
#  fSumw[7][30]=0, x=90, y=0.196667, error=0
#  fSumw[8][30]=-4.51858e-05, x=100, y=0.196667, error=4.51858e-05
#  fSumw[9][30]=0, x=110, y=0.196667, error=0
#  fSumw[10][30]=0, x=120, y=0.196667, error=0
#  fSumw[11][30]=0, x=130, y=0.196667, error=0
#  fSumw[12][30]=3.82696e-05, x=140, y=0.196667, error=3.11474e-05
#  fSumw[13][30]=0.000406264, x=150, y=0.196667, error=0.000373323
#  fSumw[14][30]=-0.000252455, x=160, y=0.196667, error=0.000262903
#  fSumw[0][31]=0, x=20, y=0.203333, error=0
#  fSumw[1][31]=0, x=30, y=0.203333, error=0
#  fSumw[2][31]=1.61021e-05, x=40, y=0.203333, error=1.61021e-05
#  fSumw[3][31]=0, x=50, y=0.203333, error=0
#  fSumw[4][31]=0, x=60, y=0.203333, error=0
#  fSumw[5][31]=0, x=70, y=0.203333, error=0
#  fSumw[6][31]=0, x=80, y=0.203333, error=0
#  fSumw[7][31]=1.19696e-05, x=90, y=0.203333, error=1.19696e-05
#  fSumw[8][31]=0, x=100, y=0.203333, error=0
#  fSumw[9][31]=-2.83414e-05, x=110, y=0.203333, error=2.83414e-05
#  fSumw[10][31]=0, x=120, y=0.203333, error=0
#  fSumw[11][31]=4.79659e-05, x=130, y=0.203333, error=4.79659e-05
#  fSumw[12][31]=4.76769e-06, x=140, y=0.203333, error=4.76769e-06
#  fSumw[13][31]=0, x=150, y=0.203333, error=0
#  fSumw[14][31]=0.000347418, x=160, y=0.203333, error=0.000289201
#  fSumw[0][32]=0, x=20, y=0.21, error=0
#  fSumw[1][32]=0, x=30, y=0.21, error=0
#  fSumw[2][32]=0, x=40, y=0.21, error=0
#  fSumw[3][32]=0, x=50, y=0.21, error=0
#  fSumw[4][32]=0, x=60, y=0.21, error=0
#  fSumw[5][32]=0, x=70, y=0.21, error=0
#  fSumw[6][32]=0.000293727, x=80, y=0.21, error=0.000293727
#  fSumw[7][32]=0, x=90, y=0.21, error=0
#  fSumw[8][32]=0, x=100, y=0.21, error=0
#  fSumw[9][32]=0, x=110, y=0.21, error=0
#  fSumw[10][32]=0, x=120, y=0.21, error=0
#  fSumw[11][32]=3.11047e-05, x=130, y=0.21, error=3.11047e-05
#  fSumw[12][32]=8.18878e-06, x=140, y=0.21, error=8.18878e-06
#  fSumw[13][32]=-5.52174e-06, x=150, y=0.21, error=5.52174e-06
#  fSumw[14][32]=-2.7379e-05, x=160, y=0.21, error=6.52686e-05
#  fSumw[0][33]=0, x=20, y=0.216667, error=0
#  fSumw[1][33]=0, x=30, y=0.216667, error=0
#  fSumw[2][33]=0, x=40, y=0.216667, error=0
#  fSumw[3][33]=0, x=50, y=0.216667, error=0
#  fSumw[4][33]=0, x=60, y=0.216667, error=0
#  fSumw[5][33]=0, x=70, y=0.216667, error=0
#  fSumw[6][33]=0, x=80, y=0.216667, error=0
#  fSumw[7][33]=0, x=90, y=0.216667, error=0
#  fSumw[8][33]=0, x=100, y=0.216667, error=0
#  fSumw[9][33]=0, x=110, y=0.216667, error=0
#  fSumw[10][33]=-3.63504e-06, x=120, y=0.216667, error=9.50193e-06
#  fSumw[11][33]=4.12353e-05, x=130, y=0.216667, error=0.000294415
#  fSumw[12][33]=-3.73259e-05, x=140, y=0.216667, error=3.73259e-05
#  fSumw[13][33]=0.000480584, x=150, y=0.216667, error=0.000293737
#  fSumw[14][33]=-0.00025195, x=160, y=0.216667, error=0.00025195
#  fSumw[0][34]=0, x=20, y=0.223333, error=0
#  fSumw[1][34]=0, x=30, y=0.223333, error=0
#  fSumw[2][34]=0, x=40, y=0.223333, error=0
#  fSumw[3][34]=0, x=50, y=0.223333, error=0
#  fSumw[4][34]=0, x=60, y=0.223333, error=0
#  fSumw[5][34]=0, x=70, y=0.223333, error=0
#  fSumw[6][34]=0, x=80, y=0.223333, error=0
#  fSumw[7][34]=0, x=90, y=0.223333, error=0
#  fSumw[8][34]=0, x=100, y=0.223333, error=0
#  fSumw[9][34]=3.57343e-05, x=110, y=0.223333, error=3.57343e-05
#  fSumw[10][34]=-6.19257e-05, x=120, y=0.223333, error=5.04878e-05
#  fSumw[11][34]=0.000109657, x=130, y=0.223333, error=6.22862e-05
#  fSumw[12][34]=-0.000244529, x=140, y=0.223333, error=0.000281524
#  fSumw[13][34]=2.60486e-05, x=150, y=0.223333, error=2.01092e-05
#  fSumw[14][34]=9.62074e-05, x=160, y=0.223333, error=5.94196e-05
#  fSumw[0][35]=0, x=20, y=0.23, error=0
#  fSumw[1][35]=0, x=30, y=0.23, error=0
#  fSumw[2][35]=0, x=40, y=0.23, error=0
#  fSumw[3][35]=0, x=50, y=0.23, error=0
#  fSumw[4][35]=0, x=60, y=0.23, error=0
#  fSumw[5][35]=0, x=70, y=0.23, error=0
#  fSumw[6][35]=0, x=80, y=0.23, error=0
#  fSumw[7][35]=0, x=90, y=0.23, error=0
#  fSumw[8][35]=0, x=100, y=0.23, error=0
#  fSumw[9][35]=0.000312999, x=110, y=0.23, error=0.000267821
#  fSumw[10][35]=7.51928e-05, x=120, y=0.23, error=4.74581e-05
#  fSumw[11][35]=-5.35142e-05, x=130, y=0.23, error=4.41389e-05
#  fSumw[12][35]=0, x=140, y=0.23, error=0
#  fSumw[13][35]=0, x=150, y=0.23, error=0
#  fSumw[14][35]=3.63849e-05, x=160, y=0.23, error=3.4162e-05
#  fSumw[0][36]=0, x=20, y=0.236667, error=0
#  fSumw[1][36]=0, x=30, y=0.236667, error=0
#  fSumw[2][36]=0, x=40, y=0.236667, error=0
#  fSumw[3][36]=0, x=50, y=0.236667, error=0
#  fSumw[4][36]=0, x=60, y=0.236667, error=0
#  fSumw[5][36]=0, x=70, y=0.236667, error=0
#  fSumw[6][36]=0, x=80, y=0.236667, error=0
#  fSumw[7][36]=0, x=90, y=0.236667, error=0
#  fSumw[8][36]=0, x=100, y=0.236667, error=0
#  fSumw[9][36]=-0.000318485, x=110, y=0.236667, error=0.000318485
#  fSumw[10][36]=-8.80072e-06, x=120, y=0.236667, error=5.21412e-05
#  fSumw[11][36]=0.000524591, x=130, y=0.236667, error=0.000382177
#  fSumw[12][36]=0.000283744, x=140, y=0.236667, error=0.000275368
#  fSumw[13][36]=3.13007e-07, x=150, y=0.236667, error=6.93596e-06
#  fSumw[14][36]=0.000232645, x=160, y=0.236667, error=0.000188119
#  fSumw[0][37]=0, x=20, y=0.243333, error=0
#  fSumw[1][37]=0, x=30, y=0.243333, error=0
#  fSumw[2][37]=0, x=40, y=0.243333, error=0
#  fSumw[3][37]=0, x=50, y=0.243333, error=0
#  fSumw[4][37]=0, x=60, y=0.243333, error=0
#  fSumw[5][37]=0, x=70, y=0.243333, error=0
#  fSumw[6][37]=0, x=80, y=0.243333, error=0
#  fSumw[7][37]=0, x=90, y=0.243333, error=0
#  fSumw[8][37]=5.13837e-05, x=100, y=0.243333, error=5.13837e-05
#  fSumw[9][37]=4.16224e-06, x=110, y=0.243333, error=4.16224e-06
#  fSumw[10][37]=1.2806e-05, x=120, y=0.243333, error=1.68924e-05
#  fSumw[11][37]=0, x=130, y=0.243333, error=0
#  fSumw[12][37]=-3.52788e-05, x=140, y=0.243333, error=4.79784e-05
#  fSumw[13][37]=0, x=150, y=0.243333, error=0
#  fSumw[14][37]=0.000325975, x=160, y=0.243333, error=0.000279492
#  fSumw[0][38]=0, x=20, y=0.25, error=0
#  fSumw[1][38]=-4.54487e-05, x=30, y=0.25, error=4.54487e-05
#  fSumw[2][38]=0, x=40, y=0.25, error=0
#  fSumw[3][38]=0, x=50, y=0.25, error=0
#  fSumw[4][38]=0, x=60, y=0.25, error=0
#  fSumw[5][38]=0.000192821, x=70, y=0.25, error=0.000192821
#  fSumw[6][38]=0, x=80, y=0.25, error=0
#  fSumw[7][38]=0, x=90, y=0.25, error=0
#  fSumw[8][38]=0, x=100, y=0.25, error=0
#  fSumw[9][38]=2.77482e-05, x=110, y=0.25, error=2.09178e-05
#  fSumw[10][38]=7.55501e-05, x=120, y=0.25, error=5.05643e-05
#  fSumw[11][38]=-2.79993e-05, x=130, y=0.25, error=3.11319e-05
#  fSumw[12][38]=-0.000288896, x=140, y=0.25, error=0.000338267
#  fSumw[13][38]=8.09364e-06, x=150, y=0.25, error=8.09364e-06
#  fSumw[14][38]=-8.83481e-07, x=160, y=0.25, error=2.02413e-05
#  fSumw[0][39]=0, x=20, y=0.256667, error=0
#  fSumw[1][39]=0, x=30, y=0.256667, error=0
#  fSumw[2][39]=0, x=40, y=0.256667, error=0
#  fSumw[3][39]=0, x=50, y=0.256667, error=0
#  fSumw[4][39]=0, x=60, y=0.256667, error=0
#  fSumw[5][39]=2.09431e-05, x=70, y=0.256667, error=2.09431e-05
#  fSumw[6][39]=0, x=80, y=0.256667, error=0
#  fSumw[7][39]=0, x=90, y=0.256667, error=0
#  fSumw[8][39]=4.25825e-05, x=100, y=0.256667, error=4.25825e-05
#  fSumw[9][39]=6.00537e-05, x=110, y=0.256667, error=4.2531e-05
#  fSumw[10][39]=1.08858e-05, x=120, y=0.256667, error=1.08858e-05
#  fSumw[11][39]=2.14047e-05, x=130, y=0.256667, error=1.51355e-05
#  fSumw[12][39]=0, x=140, y=0.256667, error=0
#  fSumw[13][39]=0, x=150, y=0.256667, error=0
#  fSumw[14][39]=0.000122417, x=160, y=0.256667, error=6.83651e-05
#  fSumw[0][40]=0, x=20, y=0.263333, error=0
#  fSumw[1][40]=0, x=30, y=0.263333, error=0
#  fSumw[2][40]=-0.000426662, x=40, y=0.263333, error=0.000426662
#  fSumw[3][40]=0, x=50, y=0.263333, error=0
#  fSumw[4][40]=5.82898e-06, x=60, y=0.263333, error=5.82898e-06
#  fSumw[5][40]=0.000206893, x=70, y=0.263333, error=0.000206893
#  fSumw[6][40]=-0.000316421, x=80, y=0.263333, error=0.000316421
#  fSumw[7][40]=0, x=90, y=0.263333, error=0
#  fSumw[8][40]=-0.000221163, x=100, y=0.263333, error=0.000231218
#  fSumw[9][40]=0.000337785, x=110, y=0.263333, error=0.000280077
#  fSumw[10][40]=0.000229801, x=120, y=0.263333, error=0.000226588
#  fSumw[11][40]=-4.99068e-05, x=130, y=0.263333, error=5.10415e-05
#  fSumw[12][40]=0.000326503, x=140, y=0.263333, error=0.000245045
#  fSumw[13][40]=0, x=150, y=0.263333, error=0
#  fSumw[14][40]=7.25235e-05, x=160, y=0.263333, error=4.93137e-05
#  fSumw[0][41]=0, x=20, y=0.27, error=0
#  fSumw[1][41]=0, x=30, y=0.27, error=0
#  fSumw[2][41]=8.3359e-06, x=40, y=0.27, error=8.3359e-06
#  fSumw[3][41]=0, x=50, y=0.27, error=0
#  fSumw[4][41]=0, x=60, y=0.27, error=0
#  fSumw[5][41]=3.15497e-05, x=70, y=0.27, error=3.15497e-05
#  fSumw[6][41]=1.00709e-05, x=80, y=0.27, error=1.00709e-05
#  fSumw[7][41]=1.28546e-05, x=90, y=0.27, error=1.28546e-05
#  fSumw[8][41]=-3.14599e-05, x=100, y=0.27, error=4.13839e-05
#  fSumw[9][41]=9.41368e-05, x=110, y=0.27, error=5.21414e-05
#  fSumw[10][41]=1.63153e-05, x=120, y=0.27, error=6.24511e-05
#  fSumw[11][41]=0, x=130, y=0.27, error=0
#  fSumw[12][41]=2.43338e-05, x=140, y=0.27, error=1.45448e-05
#  fSumw[13][41]=0, x=150, y=0.27, error=0
#  fSumw[14][41]=-0.000116012, x=160, y=0.27, error=0.000234697
#  fSumw[0][42]=0, x=20, y=0.276667, error=0
#  fSumw[1][42]=0, x=30, y=0.276667, error=0
#  fSumw[2][42]=0, x=40, y=0.276667, error=0
#  fSumw[3][42]=0.0001946, x=50, y=0.276667, error=0.0001946
#  fSumw[4][42]=2.72044e-05, x=60, y=0.276667, error=2.48675e-05
#  fSumw[5][42]=2.09476e-05, x=70, y=0.276667, error=2.09476e-05
#  fSumw[6][42]=0, x=80, y=0.276667, error=0
#  fSumw[7][42]=-8.3988e-05, x=90, y=0.276667, error=0.000136935
#  fSumw[8][42]=0.000212429, x=100, y=0.276667, error=0.000252101
#  fSumw[9][42]=0.000365252, x=110, y=0.276667, error=0.000259468
#  fSumw[10][42]=2.63542e-05, x=120, y=0.276667, error=1.99715e-05
#  fSumw[11][42]=2.42519e-05, x=130, y=0.276667, error=1.25828e-05
#  fSumw[12][42]=0.000145842, x=140, y=0.276667, error=0.000145842
#  fSumw[13][42]=2.36977e-05, x=150, y=0.276667, error=3.07031e-05
#  fSumw[14][42]=0.000238429, x=160, y=0.276667, error=0.000198641
#  fSumw[0][43]=0, x=20, y=0.283333, error=0
#  fSumw[1][43]=0, x=30, y=0.283333, error=0
#  fSumw[2][43]=0, x=40, y=0.283333, error=0
#  fSumw[3][43]=0, x=50, y=0.283333, error=0
#  fSumw[4][43]=-2.0022e-05, x=60, y=0.283333, error=4.30519e-05
#  fSumw[5][43]=0, x=70, y=0.283333, error=0
#  fSumw[6][43]=0, x=80, y=0.283333, error=0
#  fSumw[7][43]=8.68992e-05, x=90, y=0.283333, error=7.21919e-05
#  fSumw[8][43]=-0.000201633, x=100, y=0.283333, error=0.000264735
#  fSumw[9][43]=0.000745336, x=110, y=0.283333, error=0.000525772
#  fSumw[10][43]=3.69294e-06, x=120, y=0.283333, error=4.18595e-05
#  fSumw[11][43]=-0.000235372, x=130, y=0.283333, error=0.000259763
#  fSumw[12][43]=4.3411e-05, x=140, y=0.283333, error=4.3411e-05
#  fSumw[13][43]=0.000184126, x=150, y=0.283333, error=0.000169982
#  fSumw[14][43]=0.000468522, x=160, y=0.283333, error=0.000280205
#  fSumw[0][44]=0, x=20, y=0.29, error=0
#  fSumw[1][44]=0, x=30, y=0.29, error=0
#  fSumw[2][44]=0, x=40, y=0.29, error=0
#  fSumw[3][44]=0, x=50, y=0.29, error=0
#  fSumw[4][44]=0, x=60, y=0.29, error=0
#  fSumw[5][44]=-1.45605e-06, x=70, y=0.29, error=1.45605e-06
#  fSumw[6][44]=0, x=80, y=0.29, error=0
#  fSumw[7][44]=4.60352e-05, x=90, y=0.29, error=3.48744e-05
#  fSumw[8][44]=0.000369864, x=100, y=0.29, error=0.000331899
#  fSumw[9][44]=-3.152e-05, x=110, y=0.29, error=4.34157e-05
#  fSumw[10][44]=0.000330321, x=120, y=0.29, error=0.000330321
#  fSumw[11][44]=5.37329e-05, x=130, y=0.29, error=2.94443e-05
#  fSumw[12][44]=5.05261e-06, x=140, y=0.29, error=2.17806e-05
#  fSumw[13][44]=2.5194e-05, x=150, y=0.29, error=1.61131e-05
#  fSumw[14][44]=3.78874e-05, x=160, y=0.29, error=3.78331e-05
#  fSumw[0][45]=0, x=20, y=0.296667, error=0
#  fSumw[1][45]=0, x=30, y=0.296667, error=0
#  fSumw[2][45]=0, x=40, y=0.296667, error=0
#  fSumw[3][45]=0, x=50, y=0.296667, error=0
#  fSumw[4][45]=0.000249872, x=60, y=0.296667, error=0.000249872
#  fSumw[5][45]=-1.59937e-05, x=70, y=0.296667, error=1.59937e-05
#  fSumw[6][45]=0, x=80, y=0.296667, error=0
#  fSumw[7][45]=0.000143472, x=90, y=0.296667, error=0.000198465
#  fSumw[8][45]=0.000112692, x=100, y=0.296667, error=7.90722e-05
#  fSumw[9][45]=0.000261981, x=110, y=0.296667, error=0.000311085
#  fSumw[10][45]=0.000112861, x=120, y=0.296667, error=6.62484e-05
#  fSumw[11][45]=1.43601e-06, x=130, y=0.296667, error=8.22938e-06
#  fSumw[12][45]=6.59839e-05, x=140, y=0.296667, error=4.85287e-05
#  fSumw[13][45]=0, x=150, y=0.296667, error=0
#  fSumw[14][45]=-0.000119262, x=160, y=0.296667, error=0.000137911
#  fSumw[0][46]=0, x=20, y=0.303333, error=0
#  fSumw[1][46]=0, x=30, y=0.303333, error=0
#  fSumw[2][46]=0, x=40, y=0.303333, error=0
#  fSumw[3][46]=1.04425e-05, x=50, y=0.303333, error=1.04425e-05
#  fSumw[4][46]=0.000353404, x=60, y=0.303333, error=0.000353404
#  fSumw[5][46]=0.000339758, x=70, y=0.303333, error=0.000339758
#  fSumw[6][46]=0, x=80, y=0.303333, error=0
#  fSumw[7][46]=0.000284396, x=90, y=0.303333, error=0.000200329
#  fSumw[8][46]=7.43986e-05, x=100, y=0.303333, error=4.87533e-05
#  fSumw[9][46]=0.000192779, x=110, y=0.303333, error=0.000190466
#  fSumw[10][46]=4.27661e-05, x=120, y=0.303333, error=4.27661e-05
#  fSumw[11][46]=0.000317109, x=130, y=0.303333, error=0.000297203
#  fSumw[12][46]=0, x=140, y=0.303333, error=0
#  fSumw[13][46]=0, x=150, y=0.303333, error=0
#  fSumw[14][46]=-2.07659e-05, x=160, y=0.303333, error=0.000326875
#  fSumw[0][47]=0, x=20, y=0.31, error=0
#  fSumw[1][47]=0, x=30, y=0.31, error=0
#  fSumw[2][47]=0, x=40, y=0.31, error=0
#  fSumw[3][47]=0, x=50, y=0.31, error=0
#  fSumw[4][47]=-9.47878e-06, x=60, y=0.31, error=6.1416e-05
#  fSumw[5][47]=9.95953e-06, x=70, y=0.31, error=9.95953e-06
#  fSumw[6][47]=-0.000307699, x=80, y=0.31, error=0.000266391
#  fSumw[7][47]=-3.37348e-05, x=90, y=0.31, error=4.09525e-05
#  fSumw[8][47]=0.000117549, x=100, y=0.31, error=5.88711e-05
#  fSumw[9][47]=0.000100572, x=110, y=0.31, error=7.31443e-05
#  fSumw[10][47]=0.000230463, x=120, y=0.31, error=0.000177909
#  fSumw[11][47]=9.78677e-05, x=130, y=0.31, error=6.94753e-05
#  fSumw[12][47]=2.64635e-06, x=140, y=0.31, error=4.35355e-05
#  fSumw[13][47]=9.80131e-06, x=150, y=0.31, error=6.77459e-05
#  fSumw[14][47]=0.0003049, x=160, y=0.31, error=0.000255568
#  fSumw[0][48]=0, x=20, y=0.316667, error=0
#  fSumw[1][48]=0, x=30, y=0.316667, error=0
#  fSumw[2][48]=0, x=40, y=0.316667, error=0
#  fSumw[3][48]=0.00033411, x=50, y=0.316667, error=0.000320966
#  fSumw[4][48]=4.97055e-05, x=60, y=0.316667, error=4.97055e-05
#  fSumw[5][48]=0, x=70, y=0.316667, error=0
#  fSumw[6][48]=6.86337e-06, x=80, y=0.316667, error=6.86337e-06
#  fSumw[7][48]=9.26017e-05, x=90, y=0.316667, error=6.00079e-05
#  fSumw[8][48]=-0.000236025, x=100, y=0.316667, error=0.000270888
#  fSumw[9][48]=0.000227657, x=110, y=0.316667, error=0.000212732
#  fSumw[10][48]=1.54893e-05, x=120, y=0.316667, error=1.54893e-05
#  fSumw[11][48]=-6.73432e-06, x=130, y=0.316667, error=6.73432e-06
#  fSumw[12][48]=-3.46324e-05, x=140, y=0.316667, error=3.46324e-05
#  fSumw[13][48]=1.05163e-05, x=150, y=0.316667, error=1.05163e-05
#  fSumw[14][48]=4.62139e-05, x=160, y=0.316667, error=2.4503e-05
#  fSumw[0][49]=0, x=20, y=0.323333, error=0
#  fSumw[1][49]=0, x=30, y=0.323333, error=0
#  fSumw[2][49]=0, x=40, y=0.323333, error=0
#  fSumw[3][49]=0.000246496, x=50, y=0.323333, error=0.00022933
#  fSumw[4][49]=0.000751438, x=60, y=0.323333, error=0.000439697
#  fSumw[5][49]=7.59153e-06, x=70, y=0.323333, error=7.59153e-06
#  fSumw[6][49]=0.000681285, x=80, y=0.323333, error=0.000388785
#  fSumw[7][49]=0.000367024, x=90, y=0.323333, error=0.000356023
#  fSumw[8][49]=0.000428436, x=100, y=0.323333, error=0.00036875
#  fSumw[9][49]=-2.85742e-05, x=110, y=0.323333, error=2.04612e-05
#  fSumw[10][49]=-1.07276e-07, x=120, y=0.323333, error=9.56237e-06
#  fSumw[11][49]=5.47298e-05, x=130, y=0.323333, error=4.76259e-05
#  fSumw[12][49]=6.88884e-05, x=140, y=0.323333, error=4.75326e-05
#  fSumw[13][49]=3.00136e-06, x=150, y=0.323333, error=3.00136e-06
#  fSumw[14][49]=0.00010416, x=160, y=0.323333, error=0.000460718
#  fSumw[0][50]=0, x=20, y=0.33, error=0
#  fSumw[1][50]=0, x=30, y=0.33, error=0
#  fSumw[2][50]=0, x=40, y=0.33, error=0
#  fSumw[3][50]=7.8372e-06, x=50, y=0.33, error=7.8372e-06
#  fSumw[4][50]=1.44721e-05, x=60, y=0.33, error=7.65495e-05
#  fSumw[5][50]=0, x=70, y=0.33, error=0
#  fSumw[6][50]=6.03108e-05, x=80, y=0.33, error=4.81979e-05
#  fSumw[7][50]=0.000294019, x=90, y=0.33, error=0.000424813
#  fSumw[8][50]=-2.76941e-06, x=100, y=0.33, error=4.70601e-05
#  fSumw[9][50]=-5.75849e-06, x=110, y=0.33, error=1.2709e-05
#  fSumw[10][50]=-5.09896e-05, x=120, y=0.33, error=5.92638e-05
#  fSumw[11][50]=0, x=130, y=0.33, error=0
#  fSumw[12][50]=0, x=140, y=0.33, error=0
#  fSumw[13][50]=-1.23066e-05, x=150, y=0.33, error=1.23066e-05
#  fSumw[14][50]=0.000465509, x=160, y=0.33, error=0.000370812
#  fSumw[0][51]=0, x=20, y=0.336667, error=0
#  fSumw[1][51]=0, x=30, y=0.336667, error=0
#  fSumw[2][51]=0, x=40, y=0.336667, error=0
#  fSumw[3][51]=4.52536e-05, x=50, y=0.336667, error=4.52536e-05
#  fSumw[4][51]=0.000323639, x=60, y=0.336667, error=0.000298061
#  fSumw[5][51]=0.000433828, x=70, y=0.336667, error=0.000322809
#  fSumw[6][51]=-0.000180317, x=80, y=0.336667, error=0.000252992
#  fSumw[7][51]=5.81704e-06, x=90, y=0.336667, error=0.000329323
#  fSumw[8][51]=-0.00024073, x=100, y=0.336667, error=0.000225221
#  fSumw[9][51]=4.71403e-06, x=110, y=0.336667, error=1.93302e-05
#  fSumw[10][51]=2.77923e-05, x=120, y=0.336667, error=7.22096e-05
#  fSumw[11][51]=3.48361e-05, x=130, y=0.336667, error=2.05883e-05
#  fSumw[12][51]=0, x=140, y=0.336667, error=0
#  fSumw[13][51]=0, x=150, y=0.336667, error=0
#  fSumw[14][51]=0.000874238, x=160, y=0.336667, error=0.000469102
#  fSumw[0][52]=0, x=20, y=0.343333, error=0
#  fSumw[1][52]=0, x=30, y=0.343333, error=0
#  fSumw[2][52]=0, x=40, y=0.343333, error=0
#  fSumw[3][52]=-0.000195386, x=50, y=0.343333, error=0.000195386
#  fSumw[4][52]=6.22245e-05, x=60, y=0.343333, error=0.000300633
#  fSumw[5][52]=2.50725e-05, x=70, y=0.343333, error=5.36716e-05
#  fSumw[6][52]=-0.000274251, x=80, y=0.343333, error=0.000351003
#  fSumw[7][52]=-0.000523558, x=90, y=0.343333, error=0.000509958
#  fSumw[8][52]=-0.000153413, x=100, y=0.343333, error=0.000376145
#  fSumw[9][52]=0.000483113, x=110, y=0.343333, error=0.000310429
#  fSumw[10][52]=0.000205048, x=120, y=0.343333, error=0.000227601
#  fSumw[11][52]=0.000381833, x=130, y=0.343333, error=0.000304124
#  fSumw[12][52]=1.49467e-05, x=140, y=0.343333, error=1.07019e-05
#  fSumw[13][52]=-0.000279975, x=150, y=0.343333, error=0.000280172
#  fSumw[14][52]=4.17211e-05, x=160, y=0.343333, error=7.51473e-05
#  fSumw[0][53]=0, x=20, y=0.35, error=0
#  fSumw[1][53]=0.000216355, x=30, y=0.35, error=0.000216355
#  fSumw[2][53]=0, x=40, y=0.35, error=0
#  fSumw[3][53]=0.000391565, x=50, y=0.35, error=0.000304333
#  fSumw[4][53]=0.00020444, x=60, y=0.35, error=0.000280452
#  fSumw[5][53]=0.000236935, x=70, y=0.35, error=0.000219213
#  fSumw[6][53]=-1.48128e-05, x=80, y=0.35, error=8.29637e-05
#  fSumw[7][53]=0.00103903, x=90, y=0.35, error=0.000476567
#  fSumw[8][53]=3.2401e-05, x=100, y=0.35, error=5.50738e-05
#  fSumw[9][53]=0.00015778, x=110, y=0.35, error=0.000197434
#  fSumw[10][53]=1.43586e-05, x=120, y=0.35, error=1.76533e-05
#  fSumw[11][53]=0.000305266, x=130, y=0.35, error=0.000280742
#  fSumw[12][53]=5.91893e-05, x=140, y=0.35, error=3.85671e-05
#  fSumw[13][53]=0.000169585, x=150, y=0.35, error=0.000216323
#  fSumw[14][53]=-0.000114578, x=160, y=0.35, error=0.000226156
#  fSumw[0][54]=0, x=20, y=0.356667, error=0
#  fSumw[1][54]=0, x=30, y=0.356667, error=0
#  fSumw[2][54]=0, x=40, y=0.356667, error=0
#  fSumw[3][54]=0.000136711, x=50, y=0.356667, error=0.000122149
#  fSumw[4][54]=0, x=60, y=0.356667, error=0
#  fSumw[5][54]=0.000235259, x=70, y=0.356667, error=0.00020119
#  fSumw[6][54]=0.000884864, x=80, y=0.356667, error=0.000471575
#  fSumw[7][54]=2.22626e-05, x=90, y=0.356667, error=0.000348252
#  fSumw[8][54]=9.38931e-05, x=100, y=0.356667, error=6.49293e-05
#  fSumw[9][54]=1.17889e-05, x=110, y=0.356667, error=4.4374e-05
#  fSumw[10][54]=-0.00011298, x=120, y=0.356667, error=0.00031706
#  fSumw[11][54]=-1.33203e-05, x=130, y=0.356667, error=1.33203e-05
#  fSumw[12][54]=-0.000217174, x=140, y=0.356667, error=0.000229346
#  fSumw[13][54]=0.000275093, x=150, y=0.356667, error=0.000246958
#  fSumw[14][54]=-6.94628e-05, x=160, y=0.356667, error=0.000136787
#  fSumw[0][55]=0, x=20, y=0.363333, error=0
#  fSumw[1][55]=0, x=30, y=0.363333, error=0
#  fSumw[2][55]=5.60303e-06, x=40, y=0.363333, error=5.60303e-06
#  fSumw[3][55]=0, x=50, y=0.363333, error=0
#  fSumw[4][55]=0.000368542, x=60, y=0.363333, error=0.000245338
#  fSumw[5][55]=3.03565e-05, x=70, y=0.363333, error=3.00847e-05
#  fSumw[6][55]=0.000342346, x=80, y=0.363333, error=0.000569216
#  fSumw[7][55]=0.000186661, x=90, y=0.363333, error=0.000354397
#  fSumw[8][55]=4.79129e-05, x=100, y=0.363333, error=4.36063e-05
#  fSumw[9][55]=-2.87047e-05, x=110, y=0.363333, error=7.88394e-05
#  fSumw[10][55]=0, x=120, y=0.363333, error=0
#  fSumw[11][55]=0, x=130, y=0.363333, error=0
#  fSumw[12][55]=0.0003642, x=140, y=0.363333, error=0.000372017
#  fSumw[13][55]=1.46431e-05, x=150, y=0.363333, error=1.03574e-05
#  fSumw[14][55]=0.000316095, x=160, y=0.363333, error=0.000267127
#  fSumw[0][56]=0, x=20, y=0.37, error=0
#  fSumw[1][56]=0, x=30, y=0.37, error=0
#  fSumw[2][56]=0, x=40, y=0.37, error=0
#  fSumw[3][56]=0.000509368, x=50, y=0.37, error=0.000332015
#  fSumw[4][56]=0.000216696, x=60, y=0.37, error=0.000203134
#  fSumw[5][56]=0.000192762, x=70, y=0.37, error=0.000211931
#  fSumw[6][56]=0.000415584, x=80, y=0.37, error=0.000212795
#  fSumw[7][56]=0.000358739, x=90, y=0.37, error=0.000355935
#  fSumw[8][56]=3.54584e-05, x=100, y=0.37, error=3.30091e-05
#  fSumw[9][56]=6.64434e-05, x=110, y=0.37, error=8.52818e-05
#  fSumw[10][56]=-7.02101e-06, x=120, y=0.37, error=7.02101e-06
#  fSumw[11][56]=0, x=130, y=0.37, error=0
#  fSumw[12][56]=2.55543e-07, x=140, y=0.37, error=1.54807e-05
#  fSumw[13][56]=7.64217e-05, x=150, y=0.37, error=0.000248427
#  fSumw[14][56]=1.67366e-05, x=160, y=0.37, error=2.00819e-05
#  fSumw[0][57]=0, x=20, y=0.376667, error=0
#  fSumw[1][57]=0, x=30, y=0.376667, error=0
#  fSumw[2][57]=2.75845e-05, x=40, y=0.376667, error=2.75845e-05
#  fSumw[3][57]=0.000314638, x=50, y=0.376667, error=0.000314638
#  fSumw[4][57]=0.000166057, x=60, y=0.376667, error=0.000314652
#  fSumw[5][57]=-0.000355257, x=70, y=0.376667, error=0.000379347
#  fSumw[6][57]=0.000594429, x=80, y=0.376667, error=0.000364937
#  fSumw[7][57]=7.18115e-05, x=90, y=0.376667, error=0.000340829
#  fSumw[8][57]=-0.0001929, x=100, y=0.376667, error=0.000239441
#  fSumw[9][57]=8.38869e-05, x=110, y=0.376667, error=3.70641e-05
#  fSumw[10][57]=-1.83382e-05, x=120, y=0.376667, error=3.10858e-05
#  fSumw[11][57]=-2.90221e-05, x=130, y=0.376667, error=3.54313e-05
#  fSumw[12][57]=-1.94987e-05, x=140, y=0.376667, error=3.66332e-05
#  fSumw[13][57]=-0.000101098, x=150, y=0.376667, error=0.000213776
#  fSumw[14][57]=2.48742e-05, x=160, y=0.376667, error=0.000358147
#  fSumw[0][58]=0, x=20, y=0.383333, error=0
#  fSumw[1][58]=0, x=30, y=0.383333, error=0
#  fSumw[2][58]=5.6477e-05, x=40, y=0.383333, error=5.6477e-05
#  fSumw[3][58]=0, x=50, y=0.383333, error=0
#  fSumw[4][58]=0.000313857, x=60, y=0.383333, error=0.000560737
#  fSumw[5][58]=0.000857568, x=70, y=0.383333, error=0.000635764
#  fSumw[6][58]=0.00120611, x=80, y=0.383333, error=0.000639055
#  fSumw[7][58]=0.000371046, x=90, y=0.383333, error=0.000303916
#  fSumw[8][58]=0.00115208, x=100, y=0.383333, error=0.000567974
#  fSumw[9][58]=-0.000175632, x=110, y=0.383333, error=0.000261363
#  fSumw[10][58]=-1.16341e-06, x=120, y=0.383333, error=4.28667e-05
#  fSumw[11][58]=3.04754e-05, x=130, y=0.383333, error=2.41306e-05
#  fSumw[12][58]=2.91102e-05, x=140, y=0.383333, error=7.35804e-05
#  fSumw[13][58]=0.00028711, x=150, y=0.383333, error=0.000271215
#  fSumw[14][58]=-0.000196647, x=160, y=0.383333, error=0.000210195
#  fSumw[0][59]=0, x=20, y=0.39, error=0
#  fSumw[1][59]=0, x=30, y=0.39, error=0
#  fSumw[2][59]=0, x=40, y=0.39, error=0
#  fSumw[3][59]=1.90891e-05, x=50, y=0.39, error=1.90891e-05
#  fSumw[4][59]=0.00031922, x=60, y=0.39, error=0.00031922
#  fSumw[5][59]=0.00112647, x=70, y=0.39, error=0.000533544
#  fSumw[6][59]=0.000477902, x=80, y=0.39, error=0.000382545
#  fSumw[7][59]=5.1728e-06, x=90, y=0.39, error=6.79391e-05
#  fSumw[8][59]=0.000346955, x=100, y=0.39, error=0.00029913
#  fSumw[9][59]=8.86343e-05, x=110, y=0.39, error=5.50319e-05
#  fSumw[10][59]=-0.000286119, x=120, y=0.39, error=0.000351456
#  fSumw[11][59]=3.24063e-05, x=130, y=0.39, error=1.83179e-05
#  fSumw[12][59]=-0.00034819, x=140, y=0.39, error=0.000357632
#  fSumw[13][59]=-0.000324547, x=150, y=0.39, error=0.000318543
#  fSumw[14][59]=0.00027252, x=160, y=0.39, error=0.000266819
#  fSumw[0][60]=0, x=20, y=0.396667, error=0
#  fSumw[1][60]=1.1049e-05, x=30, y=0.396667, error=1.1049e-05
#  fSumw[2][60]=0, x=40, y=0.396667, error=0
#  fSumw[3][60]=0.000177363, x=50, y=0.396667, error=0.000196215
#  fSumw[4][60]=-0.000337895, x=60, y=0.396667, error=0.000367618
#  fSumw[5][60]=0.00142606, x=70, y=0.396667, error=0.000546078
#  fSumw[6][60]=-3.5639e-05, x=80, y=0.396667, error=0.000413191
#  fSumw[7][60]=-6.03783e-05, x=90, y=0.396667, error=5.18695e-05
#  fSumw[8][60]=0.000192551, x=100, y=0.396667, error=0.000191708
#  fSumw[9][60]=5.74031e-05, x=110, y=0.396667, error=5.16745e-05
#  fSumw[10][60]=0.000293031, x=120, y=0.396667, error=0.000263384
#  fSumw[11][60]=1.71487e-05, x=130, y=0.396667, error=2.1571e-05
#  fSumw[12][60]=5.15472e-05, x=140, y=0.396667, error=3.37351e-05
#  fSumw[13][60]=0.000164227, x=150, y=0.396667, error=0.000194434
#  fSumw[14][60]=0.000150317, x=160, y=0.396667, error=7.34717e-05
#  fSumw[0][61]=0, x=20, y=0.403333, error=0
#  fSumw[1][61]=0, x=30, y=0.403333, error=0
#  fSumw[2][61]=0, x=40, y=0.403333, error=0
#  fSumw[3][61]=0.000899128, x=50, y=0.403333, error=0.000484058
#  fSumw[4][61]=0.000312273, x=60, y=0.403333, error=0.000327414
#  fSumw[5][61]=0.000665996, x=70, y=0.403333, error=0.000466944
#  fSumw[6][61]=0.00113526, x=80, y=0.403333, error=0.000580704
#  fSumw[7][61]=0.000524652, x=90, y=0.403333, error=0.000249047
#  fSumw[8][61]=-0.00020102, x=100, y=0.403333, error=0.000260978
#  fSumw[9][61]=-6.37378e-05, x=110, y=0.403333, error=6.05527e-05
#  fSumw[10][61]=-0.000388703, x=120, y=0.403333, error=0.000338209
#  fSumw[11][61]=1.05387e-05, x=130, y=0.403333, error=4.70153e-05
#  fSumw[12][61]=1.38531e-05, x=140, y=0.403333, error=9.84638e-06
#  fSumw[13][61]=3.62091e-05, x=150, y=0.403333, error=3.08708e-05
#  fSumw[14][61]=8.56571e-05, x=160, y=0.403333, error=4.97478e-05
#  fSumw[0][62]=0, x=20, y=0.41, error=0
#  fSumw[1][62]=0, x=30, y=0.41, error=0
#  fSumw[2][62]=5.209e-06, x=40, y=0.41, error=5.209e-06
#  fSumw[3][62]=-0.000368853, x=50, y=0.41, error=0.000368719
#  fSumw[4][62]=0.00129104, x=60, y=0.41, error=0.00060004
#  fSumw[5][62]=0.00145947, x=70, y=0.41, error=0.000641444
#  fSumw[6][62]=0.00096767, x=80, y=0.41, error=0.000534965
#  fSumw[7][62]=0.000269496, x=90, y=0.41, error=0.000386879
#  fSumw[8][62]=-0.000110254, x=100, y=0.41, error=8.44612e-05
#  fSumw[9][62]=0.000362027, x=110, y=0.41, error=0.000267613
#  fSumw[10][62]=6.29866e-05, x=120, y=0.41, error=5.37557e-05
#  fSumw[11][62]=0.000213038, x=130, y=0.41, error=0.00019878
#  fSumw[12][62]=4.2669e-05, x=140, y=0.41, error=3.87464e-05
#  fSumw[13][62]=4.31618e-05, x=150, y=0.41, error=6.17828e-05
#  fSumw[14][62]=0.000421941, x=160, y=0.41, error=0.000371483
#  fSumw[0][63]=0, x=20, y=0.416667, error=0
#  fSumw[1][63]=0, x=30, y=0.416667, error=0
#  fSumw[2][63]=4.49226e-05, x=40, y=0.416667, error=3.56423e-05
#  fSumw[3][63]=0.00018444, x=50, y=0.416667, error=0.000229055
#  fSumw[4][63]=0.0002275, x=60, y=0.416667, error=0.000229658
#  fSumw[5][63]=0.000459538, x=70, y=0.416667, error=0.000568453
#  fSumw[6][63]=0.00138211, x=80, y=0.416667, error=0.000645384
#  fSumw[7][63]=0.000253097, x=90, y=0.416667, error=0.000164525
#  fSumw[8][63]=-0.000301228, x=100, y=0.416667, error=0.000276681
#  fSumw[9][63]=2.85764e-05, x=110, y=0.416667, error=1.81543e-05
#  fSumw[10][63]=-8.91096e-06, x=120, y=0.416667, error=1.76833e-05
#  fSumw[11][63]=0.000219195, x=130, y=0.416667, error=0.000230173
#  fSumw[12][63]=-1.57281e-05, x=140, y=0.416667, error=4.77639e-05
#  fSumw[13][63]=6.70151e-05, x=150, y=0.416667, error=5.27683e-05
#  fSumw[14][63]=-0.00029588, x=160, y=0.416667, error=0.000241771
#  fSumw[0][64]=0, x=20, y=0.423333, error=0
#  fSumw[1][64]=2.83414e-05, x=30, y=0.423333, error=2.83414e-05
#  fSumw[2][64]=1.91149e-05, x=40, y=0.423333, error=1.35243e-05
#  fSumw[3][64]=0.000333593, x=50, y=0.423333, error=0.000321332
#  fSumw[4][64]=0.000695051, x=60, y=0.423333, error=0.000462857
# ...
#  fSumw[6][283]=0.000265808, x=80, y=1.88333, error=0.00026577
#  fSumw[7][283]=-3.22873e-05, x=90, y=1.88333, error=4.30553e-05
#  fSumw[8][283]=-3.43864e-05, x=100, y=1.88333, error=3.43864e-05
#  fSumw[9][283]=-5.55963e-05, x=110, y=1.88333, error=4.90406e-05
#  fSumw[10][283]=1.48066e-05, x=120, y=1.88333, error=1.48066e-05
#  fSumw[11][283]=2.43381e-05, x=130, y=1.88333, error=2.43381e-05
#  fSumw[12][283]=-4.79659e-05, x=140, y=1.88333, error=4.79659e-05
#  fSumw[13][283]=0, x=150, y=1.88333, error=0
#  fSumw[14][283]=9.4302e-06, x=160, y=1.88333, error=9.4302e-06
#  fSumw[0][284]=0.000289863, x=20, y=1.89, error=0.000474851
#  fSumw[1][284]=0.000633448, x=30, y=1.89, error=0.000941993
#  fSumw[2][284]=0.000608212, x=40, y=1.89, error=0.000451258
#  fSumw[3][284]=0.000690673, x=50, y=1.89, error=0.000532072
#  fSumw[4][284]=0.000575212, x=60, y=1.89, error=0.000363936
#  fSumw[5][284]=-0.000298203, x=70, y=1.89, error=0.000290785
#  fSumw[6][284]=0.00011503, x=80, y=1.89, error=5.33804e-05
#  fSumw[7][284]=0.000180423, x=90, y=1.89, error=0.000197952
#  fSumw[8][284]=0, x=100, y=1.89, error=0
#  fSumw[9][284]=0.000240837, x=110, y=1.89, error=0.000240837
#  fSumw[10][284]=0, x=120, y=1.89, error=0
#  fSumw[11][284]=0, x=130, y=1.89, error=0
#  fSumw[12][284]=0, x=140, y=1.89, error=0
#  fSumw[13][284]=0, x=150, y=1.89, error=0
#  fSumw[14][284]=8.71086e-06, x=160, y=1.89, error=8.71086e-06
#  fSumw[0][285]=-6.80428e-05, x=20, y=1.89667, error=0.000476724
#  fSumw[1][285]=0.00106388, x=30, y=1.89667, error=0.000556171
#  fSumw[2][285]=0.00192137, x=40, y=1.89667, error=0.000720183
#  fSumw[3][285]=-0.000283985, x=50, y=1.89667, error=0.00051459
#  fSumw[4][285]=0.000125024, x=60, y=1.89667, error=0.000524332
#  fSumw[5][285]=0.000118251, x=70, y=1.89667, error=6.72633e-05
#  fSumw[6][285]=0.000149481, x=80, y=1.89667, error=0.00049154
#  fSumw[7][285]=0.000142057, x=90, y=1.89667, error=0.00022176
#  fSumw[8][285]=0.000274, x=100, y=1.89667, error=0.000247955
#  fSumw[9][285]=-0.000230275, x=110, y=1.89667, error=0.000230275
#  fSumw[10][285]=5.01673e-06, x=120, y=1.89667, error=5.01673e-06
#  fSumw[11][285]=0, x=130, y=1.89667, error=0
#  fSumw[12][285]=0, x=140, y=1.89667, error=0
#  fSumw[13][285]=0, x=150, y=1.89667, error=0
#  fSumw[14][285]=6.2561e-07, x=160, y=1.89667, error=6.2561e-07
#  fSumw[0][286]=0.00176149, x=20, y=1.90333, error=0.000917116
#  fSumw[1][286]=0.00186117, x=30, y=1.90333, error=0.000739243
#  fSumw[2][286]=0.00127334, x=40, y=1.90333, error=0.000708771
#  fSumw[3][286]=0.000429286, x=50, y=1.90333, error=0.000376932
#  fSumw[4][286]=-0.000137058, x=60, y=1.90333, error=0.000528134
#  fSumw[5][286]=0.00013057, x=70, y=1.90333, error=6.56396e-05
#  fSumw[6][286]=-5.4315e-06, x=80, y=1.90333, error=5.4315e-06
#  fSumw[7][286]=5.10714e-05, x=90, y=1.90333, error=0.00039534
#  fSumw[8][286]=5.55037e-05, x=100, y=1.90333, error=4.48197e-05
#  fSumw[9][286]=-2.72368e-05, x=110, y=1.90333, error=3.54824e-05
#  fSumw[10][286]=-4.93696e-06, x=120, y=1.90333, error=1.39307e-05
#  fSumw[11][286]=-5.87932e-06, x=130, y=1.90333, error=5.87932e-06
#  fSumw[12][286]=0, x=140, y=1.90333, error=0
#  fSumw[13][286]=0, x=150, y=1.90333, error=0
#  fSumw[14][286]=0, x=160, y=1.90333, error=0
#  fSumw[0][287]=0.000656317, x=20, y=1.91, error=0.000495282
#  fSumw[1][287]=0.000954249, x=30, y=1.91, error=0.000496105
#  fSumw[2][287]=7.97579e-06, x=40, y=1.91, error=0.000658495
#  fSumw[3][287]=0.00104853, x=50, y=1.91, error=0.00062807
#  fSumw[4][287]=0.000222098, x=60, y=1.91, error=0.00020031
#  fSumw[5][287]=0.000321948, x=70, y=1.91, error=0.000258339
#  fSumw[6][287]=3.516e-05, x=80, y=1.91, error=3.15138e-05
#  fSumw[7][287]=0.000149134, x=90, y=1.91, error=0.000192756
#  fSumw[8][287]=7.92748e-06, x=100, y=1.91, error=7.14315e-06
#  fSumw[9][287]=-0.00020752, x=110, y=1.91, error=0.000216172
#  fSumw[10][287]=4.63606e-05, x=120, y=1.91, error=4.63606e-05
#  fSumw[11][287]=7.5551e-06, x=130, y=1.91, error=7.5551e-06
#  fSumw[12][287]=0, x=140, y=1.91, error=0
#  fSumw[13][287]=0, x=150, y=1.91, error=0
#  fSumw[14][287]=5.30279e-06, x=160, y=1.91, error=5.30279e-06
#  fSumw[0][288]=0.000612785, x=20, y=1.91667, error=0.000426094
#  fSumw[1][288]=0.00309278, x=30, y=1.91667, error=0.00100329
#  fSumw[2][288]=0.000303265, x=40, y=1.91667, error=0.000460068
#  fSumw[3][288]=0.000521014, x=50, y=1.91667, error=0.000470389
#  fSumw[4][288]=0.000124167, x=60, y=1.91667, error=5.72598e-05
#  fSumw[5][288]=0.00101585, x=70, y=1.91667, error=0.0004584
#  fSumw[6][288]=8.75523e-05, x=80, y=1.91667, error=5.85078e-05
#  fSumw[7][288]=0.00018009, x=90, y=1.91667, error=0.000192466
#  fSumw[8][288]=5.56357e-05, x=100, y=1.91667, error=4.47001e-05
#  fSumw[9][288]=0, x=110, y=1.91667, error=0
#  fSumw[10][288]=2.57295e-05, x=120, y=1.91667, error=1.49142e-05
#  fSumw[11][288]=1.54256e-05, x=130, y=1.91667, error=1.54256e-05
#  fSumw[12][288]=0, x=140, y=1.91667, error=0
#  fSumw[13][288]=0, x=150, y=1.91667, error=0
#  fSumw[14][288]=3.90629e-06, x=160, y=1.91667, error=3.90629e-06
#  fSumw[0][289]=0.000300687, x=20, y=1.92333, error=0.000476641
#  fSumw[1][289]=0.00209919, x=30, y=1.92333, error=0.000824869
#  fSumw[2][289]=0.00259627, x=40, y=1.92333, error=0.000831585
#  fSumw[3][289]=0.000172219, x=50, y=1.92333, error=0.000530411
#  fSumw[4][289]=0.000296738, x=60, y=1.92333, error=0.00028583
#  fSumw[5][289]=0.00027058, x=70, y=1.92333, error=0.000192534
#  fSumw[6][289]=0.0002682, x=80, y=1.92333, error=0.00028528
#  fSumw[7][289]=-1.17438e-05, x=90, y=1.92333, error=3.91633e-05
#  fSumw[8][289]=-1.9535e-05, x=100, y=1.92333, error=2.72503e-05
#  fSumw[9][289]=0, x=110, y=1.92333, error=0
#  fSumw[10][289]=0, x=120, y=1.92333, error=0
#  fSumw[11][289]=0, x=130, y=1.92333, error=0
#  fSumw[12][289]=0, x=140, y=1.92333, error=0
#  fSumw[13][289]=0, x=150, y=1.92333, error=0
#  fSumw[14][289]=-8.02771e-06, x=160, y=1.92333, error=8.02771e-06
#  fSumw[0][290]=0.0012613, x=20, y=1.93, error=0.000671965
#  fSumw[1][290]=0.00222548, x=30, y=1.93, error=0.000863305
#  fSumw[2][290]=0.00102254, x=40, y=1.93, error=0.000592753
#  fSumw[3][290]=0.00015855, x=50, y=1.93, error=9.07391e-05
#  fSumw[4][290]=0.000352435, x=60, y=1.93, error=0.000217507
#  fSumw[5][290]=7.67302e-05, x=70, y=1.93, error=6.14365e-05
#  fSumw[6][290]=0, x=80, y=1.93, error=0
#  fSumw[7][290]=-3.33457e-05, x=90, y=1.93, error=3.33457e-05
#  fSumw[8][290]=2.16854e-05, x=100, y=1.93, error=1.53413e-05
#  fSumw[9][290]=-6.58143e-06, x=110, y=1.93, error=6.58143e-06
#  fSumw[10][290]=0, x=120, y=1.93, error=0
#  fSumw[11][290]=0.000321167, x=130, y=1.93, error=0.000321167
#  fSumw[12][290]=6.59712e-06, x=140, y=1.93, error=6.59712e-06
#  fSumw[13][290]=0, x=150, y=1.93, error=0
#  fSumw[14][290]=0, x=160, y=1.93, error=0
#  fSumw[0][291]=0.00149458, x=20, y=1.93667, error=0.000881681
#  fSumw[1][291]=0.00110781, x=30, y=1.93667, error=0.000832056
#  fSumw[2][291]=0.000624622, x=40, y=1.93667, error=0.000394697
#  fSumw[3][291]=0.000476768, x=50, y=1.93667, error=0.000318816
#  fSumw[4][291]=0.000479733, x=60, y=1.93667, error=0.000394333
#  fSumw[5][291]=2.63814e-05, x=70, y=1.93667, error=1.76791e-05
#  fSumw[6][291]=-0.000139349, x=80, y=1.93667, error=0.000156797
#  fSumw[7][291]=-1.50497e-05, x=90, y=1.93667, error=2.98442e-05
#  fSumw[8][291]=0, x=100, y=1.93667, error=0
#  fSumw[9][291]=0, x=110, y=1.93667, error=0
#  fSumw[10][291]=0, x=120, y=1.93667, error=0
#  fSumw[11][291]=-1.65283e-05, x=130, y=1.93667, error=1.65283e-05
#  fSumw[12][291]=0, x=140, y=1.93667, error=0
#  fSumw[13][291]=0, x=150, y=1.93667, error=0
#  fSumw[14][291]=-7.14535e-06, x=160, y=1.93667, error=7.14535e-06
#  fSumw[0][292]=0.000882472, x=20, y=1.94333, error=0.000509142
#  fSumw[1][292]=0.00278523, x=30, y=1.94333, error=0.00108046
#  fSumw[2][292]=0.00121863, x=40, y=1.94333, error=0.000648962
#  fSumw[3][292]=0.00084216, x=50, y=1.94333, error=0.000393898
#  fSumw[4][292]=0.000439204, x=60, y=1.94333, error=0.000285231
#  fSumw[5][292]=0.000264619, x=70, y=1.94333, error=0.000196016
#  fSumw[6][292]=8.88097e-05, x=80, y=1.94333, error=5.78243e-05
#  fSumw[7][292]=0, x=90, y=1.94333, error=0
#  fSumw[8][292]=0.000260906, x=100, y=1.94333, error=0.000260906
#  fSumw[9][292]=7.10658e-06, x=110, y=1.94333, error=7.10658e-06
#  fSumw[10][292]=0, x=120, y=1.94333, error=0
#  fSumw[11][292]=0, x=130, y=1.94333, error=0
#  fSumw[12][292]=1.64086e-05, x=140, y=1.94333, error=1.64086e-05
#  fSumw[13][292]=0, x=150, y=1.94333, error=0
#  fSumw[14][292]=0, x=160, y=1.94333, error=0
#  fSumw[0][293]=0.000355235, x=20, y=1.95, error=0.000468326
#  fSumw[1][293]=0.00260994, x=30, y=1.95, error=0.000962181
#  fSumw[2][293]=0.000794267, x=40, y=1.95, error=0.000478765
#  fSumw[3][293]=-0.000305226, x=50, y=1.95, error=0.000279316
#  fSumw[4][293]=0.000158898, x=60, y=1.95, error=7.64927e-05
#  fSumw[5][293]=0.000181823, x=70, y=1.95, error=0.000159189
#  fSumw[6][293]=8.56978e-05, x=80, y=1.95, error=5.47822e-05
#  fSumw[7][293]=2.02402e-05, x=90, y=1.95, error=5.79341e-05
#  fSumw[8][293]=9.96148e-06, x=100, y=1.95, error=9.96148e-06
#  fSumw[9][293]=1.04972e-06, x=110, y=1.95, error=6.09952e-05
#  fSumw[10][293]=0, x=120, y=1.95, error=0
#  fSumw[11][293]=0, x=130, y=1.95, error=0
#  fSumw[12][293]=-7.03566e-06, x=140, y=1.95, error=7.03566e-06
#  fSumw[13][293]=0, x=150, y=1.95, error=0
#  fSumw[14][293]=1.19963e-05, x=160, y=1.95, error=1.19963e-05
#  fSumw[0][294]=0.000724351, x=20, y=1.95667, error=0.000567742
#  fSumw[1][294]=0.00195066, x=30, y=1.95667, error=0.000920245
#  fSumw[2][294]=0.000542576, x=40, y=1.95667, error=0.000595899
#  fSumw[3][294]=0.000681324, x=50, y=1.95667, error=0.000431294
#  fSumw[4][294]=0.000288944, x=60, y=1.95667, error=0.000199312
#  fSumw[5][294]=0.000324668, x=70, y=1.95667, error=0.000269905
#  fSumw[6][294]=4.00249e-05, x=80, y=1.95667, error=3.32505e-05
#  fSumw[7][294]=8.47751e-05, x=90, y=1.95667, error=5.13722e-05
#  fSumw[8][294]=0, x=100, y=1.95667, error=0
#  fSumw[9][294]=9.53433e-06, x=110, y=1.95667, error=9.53433e-06
#  fSumw[10][294]=0, x=120, y=1.95667, error=0
#  fSumw[11][294]=0, x=130, y=1.95667, error=0
#  fSumw[12][294]=0, x=140, y=1.95667, error=0
#  fSumw[13][294]=0, x=150, y=1.95667, error=0
#  fSumw[14][294]=0, x=160, y=1.95667, error=0
#  fSumw[0][295]=0.00031108, x=20, y=1.96333, error=0.000278939
#  fSumw[1][295]=0.00115574, x=30, y=1.96333, error=0.000715261
#  fSumw[2][295]=0.00105786, x=40, y=1.96333, error=0.000559584
#  fSumw[3][295]=0.00066644, x=50, y=1.96333, error=0.000395214
#  fSumw[4][295]=8.4749e-05, x=60, y=1.96333, error=0.000363166
#  fSumw[5][295]=8.89662e-05, x=70, y=1.96333, error=5.65029e-05
#  fSumw[6][295]=1.29888e-05, x=80, y=1.96333, error=2.2508e-05
#  fSumw[7][295]=-7.43485e-05, x=90, y=1.96333, error=5.79066e-05
#  fSumw[8][295]=5.13064e-06, x=100, y=1.96333, error=5.13064e-06
#  fSumw[9][295]=0, x=110, y=1.96333, error=0
#  fSumw[10][295]=-2.61249e-05, x=120, y=1.96333, error=4.51929e-05
#  fSumw[11][295]=0, x=130, y=1.96333, error=0
#  fSumw[12][295]=-4.76161e-05, x=140, y=1.96333, error=4.76161e-05
#  fSumw[13][295]=0, x=150, y=1.96333, error=0
#  fSumw[14][295]=0, x=160, y=1.96333, error=0
#  fSumw[0][296]=0.000861001, x=20, y=1.97, error=0.000468964
#  fSumw[1][296]=0.0030185, x=30, y=1.97, error=0.00119835
#  fSumw[2][296]=8.09796e-05, x=40, y=1.97, error=0.00041403
#  fSumw[3][296]=0.00115266, x=50, y=1.97, error=0.000483541
#  fSumw[4][296]=0.000379683, x=60, y=1.97, error=0.000245129
#  fSumw[5][296]=-1.88966e-05, x=70, y=1.97, error=4.61401e-05
#  fSumw[6][296]=-3.0275e-05, x=80, y=1.97, error=3.66828e-05
#  fSumw[7][296]=0.000287511, x=90, y=1.97, error=0.000281024
#  fSumw[8][296]=0, x=100, y=1.97, error=0
#  fSumw[9][296]=0, x=110, y=1.97, error=0
#  fSumw[10][296]=4.84781e-05, x=120, y=1.97, error=4.84781e-05
#  fSumw[11][296]=0, x=130, y=1.97, error=0
#  fSumw[12][296]=0, x=140, y=1.97, error=0
#  fSumw[13][296]=0, x=150, y=1.97, error=0
#  fSumw[14][296]=1.26943e-05, x=160, y=1.97, error=1.26943e-05
#  fSumw[0][297]=0.000317707, x=20, y=1.97667, error=0.000275464
#  fSumw[1][297]=0.00196063, x=30, y=1.97667, error=0.00110306
#  fSumw[2][297]=0.00157468, x=40, y=1.97667, error=0.00102412
#  fSumw[3][297]=-6.3452e-05, x=50, y=1.97667, error=0.000456564
#  fSumw[4][297]=0.00034054, x=60, y=1.97667, error=0.000197889
#  fSumw[5][297]=2.45064e-05, x=70, y=1.97667, error=0.000476106
#  fSumw[6][297]=-0.000328082, x=80, y=1.97667, error=0.000406681
#  fSumw[7][297]=1.37602e-05, x=90, y=1.97667, error=1.00139e-05
#  fSumw[8][297]=8.60049e-06, x=100, y=1.97667, error=1.38944e-05
#  fSumw[9][297]=0, x=110, y=1.97667, error=0
#  fSumw[10][297]=0, x=120, y=1.97667, error=0
#  fSumw[11][297]=0, x=130, y=1.97667, error=0
#  fSumw[12][297]=0, x=140, y=1.97667, error=0
#  fSumw[13][297]=0, x=150, y=1.97667, error=0
#  fSumw[14][297]=4.4286e-05, x=160, y=1.97667, error=4.4286e-05
#  fSumw[0][298]=7.12816e-05, x=20, y=1.98333, error=0.000527885
#  fSumw[1][298]=0.00382483, x=30, y=1.98333, error=0.00104059
#  fSumw[2][298]=0.00147186, x=40, y=1.98333, error=0.000575049
#  fSumw[3][298]=0.000505171, x=50, y=1.98333, error=0.000271637
#  fSumw[4][298]=0.000552415, x=60, y=1.98333, error=0.000343746
#  fSumw[5][298]=-0.00016307, x=70, y=1.98333, error=0.000243152
#  fSumw[6][298]=2.16722e-05, x=80, y=1.98333, error=1.75032e-05
#  fSumw[7][298]=0, x=90, y=1.98333, error=0
#  fSumw[8][298]=1.49467e-05, x=100, y=1.98333, error=1.05919e-05
#  fSumw[9][298]=4.90569e-06, x=110, y=1.98333, error=4.90569e-06
#  fSumw[10][298]=0, x=120, y=1.98333, error=0
#  fSumw[11][298]=0, x=130, y=1.98333, error=0
#  fSumw[12][298]=0, x=140, y=1.98333, error=0
#  fSumw[13][298]=0, x=150, y=1.98333, error=0
#  fSumw[14][298]=0, x=160, y=1.98333, error=0
#  fSumw[0][299]=-0.000489025, x=20, y=1.99, error=0.000596047
#  fSumw[1][299]=0.000559995, x=30, y=1.99, error=0.00083818
#  fSumw[2][299]=0.00114476, x=40, y=1.99, error=0.000693507
#  fSumw[3][299]=1.72172e-05, x=50, y=1.99, error=8.62589e-05
#  fSumw[4][299]=-6.71673e-05, x=60, y=1.99, error=7.84576e-05
#  fSumw[5][299]=4.47867e-05, x=70, y=1.99, error=3.66237e-05
#  fSumw[6][299]=-1.4642e-05, x=80, y=1.99, error=3.51653e-05
#  fSumw[7][299]=1.08858e-05, x=90, y=1.99, error=1.08858e-05
#  fSumw[8][299]=1.80547e-05, x=100, y=1.99, error=1.80547e-05
#  fSumw[9][299]=0, x=110, y=1.99, error=0
#  fSumw[10][299]=0, x=120, y=1.99, error=0
#  fSumw[11][299]=0, x=130, y=1.99, error=0
#  fSumw[12][299]=-5.43536e-06, x=140, y=1.99, error=5.43536e-06
#  fSumw[13][299]=1.78266e-05, x=150, y=1.99, error=1.29438e-05
#  fSumw[14][299]=0, x=160, y=1.99, error=0
#  fSumw[0][300]=0.000461703, x=20, y=1.99667, error=0.000257799
#  fSumw[1][300]=0.000929139, x=30, y=1.99667, error=0.000916119
#  fSumw[2][300]=0.000437878, x=40, y=1.99667, error=0.000338708
#  fSumw[3][300]=0.000491812, x=50, y=1.99667, error=0.000622567
#  fSumw[4][300]=0.00027723, x=60, y=1.99667, error=0.000269176
#  fSumw[5][300]=4.33241e-05, x=70, y=1.99667, error=4.33241e-05
#  fSumw[6][300]=0.000229018, x=80, y=1.99667, error=0.000229018
#  fSumw[7][300]=0, x=90, y=1.99667, error=0
#  fSumw[8][300]=1.21974e-05, x=100, y=1.99667, error=1.21974e-05
#  fSumw[9][300]=0, x=110, y=1.99667, error=0
#  fSumw[10][300]=0, x=120, y=1.99667, error=0
#  fSumw[11][300]=0, x=130, y=1.99667, error=0
#  fSumw[12][300]=0, x=140, y=1.99667, error=0
#  fSumw[13][300]=6.3797e-06, x=150, y=1.99667, error=6.3797e-06
#  fSumw[14][300]=0, x=160, y=1.99667, error=0
#  fSumw[0][301]=0.245699, x=20, y=2.00333, error=0.0100214
#  fSumw[1][301]=0.0998706, x=30, y=2.00333, error=0.00670269
#  fSumw[2][301]=0.0456137, x=40, y=2.00333, error=0.00442964
#  fSumw[3][301]=0.0185848, x=50, y=2.00333, error=0.00258522
#  fSumw[4][301]=0.00770041, x=60, y=2.00333, error=0.00151601
#  fSumw[5][301]=0.00486935, x=70, y=2.00333, error=0.00139668
#  fSumw[6][301]=0.00162259, x=80, y=2.00333, error=0.00121012
#  fSumw[7][301]=0.00201086, x=90, y=2.00333, error=0.000772872
#  fSumw[8][301]=0.000171152, x=100, y=2.00333, error=0.000669893
#  fSumw[9][301]=0.000975584, x=110, y=2.00333, error=0.000428301
#  fSumw[10][301]=3.96058e-05, x=120, y=2.00333, error=0.000459257
#  fSumw[11][301]=0.000527734, x=130, y=2.00333, error=0.000329908
#  fSumw[12][301]=-3.2794e-05, x=140, y=2.00333, error=0.000220279
#  fSumw[13][301]=-0.000217734, x=150, y=2.00333, error=0.000333053
#  fSumw[14][301]=0.000756535, x=160, y=2.00333, error=0.000409955

# %%
def fit_resp(hist, pt_do, pt_up, method):
    # build fitting pdf
    x       = ROOT.RooRealVar("x", " ", 0, 2)
    mu      = ROOT.RooRealVar("mu",   " ",  hist.GetBinCenter(hist.GetMaximumBin()), 0.95, 1.05)
    sigma   = ROOT.RooRealVar("sigma",  " ", hist.GetStdDev(), 0.0, 0.5)
    alpha1  = ROOT.RooRealVar("alpha1", " ", 1,   1e-1,   3)
    alpha2  = ROOT.RooRealVar("alpha2", " ", 1,   1e-1,   3)
    n1      = ROOT.RooRealVar("n1",     " ", 80,    1,     200)
    n2      = ROOT.RooRealVar("n2",     " ", 80,    1,     200)
    pdf     = ROOT.RooCrystalBall("dcb", "dcb", x, mu, sigma, alpha1, n1, alpha2, n2)
    
    # histogram to be fitted
    dh = ROOT.RooDataHist("dh", "dh", x, ROOT.RooFit.Import(hist))
    x.setRange("fitRange", 0.65, 1.35)
    for i in range(10):
        results = pdf.fitTo(
            dh, 
            ROOT.RooFit.Minimizer("Minuit2", "minimize"),
            ROOT.RooFit.Range("fitRange"),
            ROOT.RooFit.Save(1), ROOT.RooFit.Strategy(2),
            ROOT.RooFit.SumW2Error(1), 
            ROOT.RooFit.PrintLevel(1)
        )
        if results.status() == 0:
            print(color.YELLOW + "Fitting succeed!" + color.END)
            break
    if results.status() != 0:
        print(color.RED + "Fitting failed after 10 trials!" + color.END)
        
    # visualization
    canv = ROOT.TCanvas("canv", "", 800, 650)
    canv.cd()
    canv.SetRightMargin(0.04)
    canv.SetTopMargin(0.075)
    canv.SetLeftMargin(0.14)
    canv.SetBottomMargin(0.14)

    xframe = x.frame(0.65, 1.35)
    dh.plotOn(
        xframe,
        RooFit.Name("hist"),
        # RooFit.Binning(nbins),
        RooFit.MarkerStyle(ROOT.kFullCircle), RooFit.MarkerSize(1.2),
        RooFit.LineWidth(2)
    )
    pdf.plotOn(
        xframe,
        RooFit.Name("pdf"),
        # RooFit.NormRange("NormRange"),
        RooFit.LineColor(ROOT.kRed - 4), RooFit.LineWidth(2)
    )
    dh.plotOn(
        xframe,
        RooFit.Name("hist"),
        # RooFit.Binning(nbins),
        RooFit.MarkerStyle(ROOT.kFullCircle), RooFit.MarkerSize(1.2),
        RooFit.LineWidth(2)
    )
    xframe.SetTitle("")
    xframe.GetXaxis().SetTitleSize(0.047)
    xframe.GetXaxis().SetLabelSize(0.046)
    xframe.GetXaxis().SetTitleOffset(1.24)
    xframe.GetXaxis().SetLabelOffset(0.012)
    xframe.GetXaxis().SetTitle("p^{reco}_{T} / p^{true}_{T}")
    # xframe.GetYaxis().SetTitle("Events / 0.005")
    xframe.GetYaxis().SetTitleSize(0.047)
    xframe.GetYaxis().SetLabelSize(0.046)
    xframe.GetYaxis().SetTitleOffset(1.4)
    xframe.SetMaximum(xframe.GetMaximum() * 1.5)
    xframe.SetMinimum(0)
    xframe.Draw()
    
    leg = ROOT.TLegend(0.17, 0.64, 0.45, 0.76)
    leg.SetTextFont(42)
    leg.SetTextSize(0.04)
    leg.SetFillColor(0)
    leg.SetLineColor(0)
    leg.AddEntry(xframe.findObject("hist"), "Simulation", "LE1P")
    leg.AddEntry(xframe.findObject("pdf"), "DCB", "l")
    leg.Draw("same")

    var1 = results.floatParsFinal().find("mu")
    var2 = results.floatParsFinal().find("sigma")
    ltx = ROOT.TLatex()
    ltx.SetNDC()
    ltx.SetTextFont(42)
    ltx.SetTextSize(0.045)
    ltx.DrawLatex(0.58, 0.86, " #mu = %.4f #pm %.4f" %(var1.getValV(), var1.getError()))
    ltx.DrawLatex(0.58, 0.81, " #sigma = %.4f #pm %.4f" %(var2.getValV(), var2.getError()))
    
    region = "ECAL Barrrel" if iBE == 0 else "ECAL Endcap"
    ltx.DrawLatex(0.18, 0.58, "%d < p^{true}_{T} < %d GeV" %(pt_do, pt_up))
    ltx.DrawLatex(0.18, 0.5, region)
    
    CMS_lumi(canv, 5, 10, "", 2017, True, "Simulation Preliminary", "H #rightarrow #gamma* #gamma #rightarrow ee#gamma", "")
    canv.Update()
    canv.RedrawAxis()

    reg_ext = "EB" if iBE == 0 else "EE"
    directory = "../plots/validation/resp_fit_tmva/{}".format(reg_ext)
    if not os.path.exists(directory):
        os.makedirs(directory)
    canv.Print("{}/respFit_pt_{}_{}To{}GeV.pdf".format(directory, method, int(pt_do), int(pt_up)))
    canv.Close()
    
    return results

# %%
x_mu, y_mu, xerr_mu, yerr_mu = [], [], [], []
x_width, y_width, xerr_width, yerr_width = [], [], [], []
for i in range(hist2D_XGB.GetNbinsX()):
# for i in range(1):
    pt_do = hist2D_XGB.GetXaxis().GetBinLowEdge(i+1) 
    pt_up = hist2D_XGB.GetXaxis().GetBinUpEdge(i+1)
    print(color.GREEN + "[INFO] Perform the fitting in range [%d, %d]" %(int(pt_do), int(pt_up)) + color.END)
    histName_XGB = "hist1D_XGB_{}To{}".format(pt_do, pt_up)
    hist_XGB = hist2D_XGB.ProjectionY(histName_XGB, i+1, i+1).Clone()
    fitRes = fit_resp(hist_XGB, pt_do, pt_up, "XGB")
    fitRes.Print("V")
    
    x_mu.append(pt_do+(pt_up-pt_do)/2)
    y_mu.append(fitRes.floatParsFinal().find("mu").getValV())
    xerr_mu.append((pt_up-pt_do)/2)
    yerr_mu.append(fitRes.floatParsFinal().find("mu").getError())
    
    sigma_ave = fitRes.floatParsFinal().find("sigma").getValV()
    sigma_ave_err = fitRes.floatParsFinal().find("sigma").getError()
    x_width.append(pt_do+(pt_up-pt_do)/2)
    y_width.append(sigma_ave)
    xerr_width.append((pt_up-pt_do)/2)
    yerr_width.append(sigma_ave_err)
    
mu_err_XGB = ROOT.TGraphErrors(hist2D_XGB.GetNbinsX(), np.array(x_mu), np.array(y_mu), np.array(xerr_mu), np.array(yerr_mu)) 
width_err_XGB = ROOT.TGraphErrors(hist2D_XGB.GetNbinsX(), np.array(x_width), np.array(y_width), np.array(xerr_width), np.array(yerr_width)) 
width_err_XGB.Print()
# Out:
# [INFO] Perform the fitting in range [25, 35]
# Fitting succeed!
# [INFO] Perform the fitting in range [35, 45]
# Fitting succeed!
# [INFO] Perform the fitting in range [45, 55]
# Fitting succeed!
# [INFO] Perform the fitting in range [55, 65]
# Fitting succeed!
# [INFO] Perform the fitting in range [65, 75]
# Fitting succeed!
# [INFO] Perform the fitting in range [75, 85]
# Fitting succeed!
# [INFO] Perform the fitting in range [85, 95]
# Fitting succeed!
# [INFO] Perform the fitting in range [95, 105]
# Fitting succeed!
# [INFO] Perform the fitting in range [105, 115]
# Fitting succeed!
# [INFO] Perform the fitting in range [115, 125]
# Fitting succeed!
# [INFO] Perform the fitting in range [125, 135]
# Fitting succeed!
# [INFO] Perform the fitting in range [135, 145]
# Fitting succeed!
# [INFO] Perform the fitting in range [145, 155]
# Fitting succeed!
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-5.48164) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1	alpha2=1	mu=1.03	n1=80	n2=150.152	sigma=0.0449896
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=1.03, sigmaL=sigma=0.0449896, sigmaR=sigma=0.0449896, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=150.152
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=1.03, sigmaL=sigma=0.0449896, sigmaR=sigma=0.0449896, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=150.152
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=1.03, sigmaL=sigma=0.0449896, sigmaR=sigma=0.0449896, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=150.152
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=1.03, sigmaL=sigma=0.0449896, sigmaR=sigma=0.0449896, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=150.152
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=1.03, sigmaL=sigma=0.0449896, sigmaR=sigma=0.0449896, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=150.152
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=1.03, sigmaL=sigma=0.0449896, sigmaR=sigma=0.0449896, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=150.152
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.69, x0=mu=1.03, sigmaL=sigma=0.0449896, sigmaR=sigma=0.0449896, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=150.152
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.696667, x0=mu=1.03, sigmaL=sigma=0.0449896, sigmaR=sigma=0.0449896, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=150.152
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.703333, x0=mu=1.03, sigmaL=sigma=0.0449896, sigmaR=sigma=0.0449896, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=150.152
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.71, x0=mu=1.03, sigmaL=sigma=0.0449896, sigmaR=sigma=0.0449896, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=150.152
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.716667, x0=mu=1.03, sigmaL=sigma=0.0449896, sigmaR=sigma=0.0449896, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=150.152
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.723333, x0=mu=1.03, sigmaL=sigma=0.0449896, sigmaR=sigma=0.0449896, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=150.152
#     ... (remaining 138 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1,alpha2 = 1,mu = 1.03,n1 = 80,n2 = 150.152,sigma = 0.0449896)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=0.000490563/0.135881, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-5.48164) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=0.977585	alpha2=1.00264	mu=1.03021	n1=169.801	n2=11.3968	sigma=0.0449562
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.65, x0=mu=1.03021, sigmaL=sigma=0.0449562, sigmaR=sigma=0.0449562, alphaL=alpha1=0.977585, nL=n1=169.801, alphaR=alpha2=1.00264, nR=n2=11.3968
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=1.03021, sigmaL=sigma=0.0449562, sigmaR=sigma=0.0449562, alphaL=alpha1=0.977585, nL=n1=169.801, alphaR=alpha2=1.00264, nR=n2=11.3968
#      p.d.f value is Not-a-Number @ x=x=0.656667, x0=mu=1.03021, sigmaL=sigma=0.0449562, sigmaR=sigma=0.0449562, alphaL=alpha1=0.977585, nL=n1=169.801, alphaR=alpha2=1.00264, nR=n2=11.3968
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=1.03021, sigmaL=sigma=0.0449562, sigmaR=sigma=0.0449562, alphaL=alpha1=0.977585, nL=n1=169.801, alphaR=alpha2=1.00264, nR=n2=11.3968
#      p.d.f value is Not-a-Number @ x=x=0.663333, x0=mu=1.03021, sigmaL=sigma=0.0449562, sigmaR=sigma=0.0449562, alphaL=alpha1=0.977585, nL=n1=169.801, alphaR=alpha2=1.00264, nR=n2=11.3968
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=1.03021, sigmaL=sigma=0.0449562, sigmaR=sigma=0.0449562, alphaL=alpha1=0.977585, nL=n1=169.801, alphaR=alpha2=1.00264, nR=n2=11.3968
#      p.d.f value is Not-a-Number @ x=x=0.67, x0=mu=1.03021, sigmaL=sigma=0.0449562, sigmaR=sigma=0.0449562, alphaL=alpha1=0.977585, nL=n1=169.801, alphaR=alpha2=1.00264, nR=n2=11.3968
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=1.03021, sigmaL=sigma=0.0449562, sigmaR=sigma=0.0449562, alphaL=alpha1=0.977585, nL=n1=169.801, alphaR=alpha2=1.00264, nR=n2=11.3968
#      p.d.f value is Not-a-Number @ x=x=0.676667, x0=mu=1.03021, sigmaL=sigma=0.0449562, sigmaR=sigma=0.0449562, alphaL=alpha1=0.977585, nL=n1=169.801, alphaR=alpha2=1.00264, nR=n2=11.3968
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=1.03021, sigmaL=sigma=0.0449562, sigmaR=sigma=0.0449562, alphaL=alpha1=0.977585, nL=n1=169.801, alphaR=alpha2=1.00264, nR=n2=11.3968
#      p.d.f value is Not-a-Number @ x=x=0.683333, x0=mu=1.03021, sigmaL=sigma=0.0449562, sigmaR=sigma=0.0449562, alphaL=alpha1=0.977585, nL=n1=169.801, alphaR=alpha2=1.00264, nR=n2=11.3968
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=1.03021, sigmaL=sigma=0.0449562, sigmaR=sigma=0.0449562, alphaL=alpha1=0.977585, nL=n1=169.801, alphaR=alpha2=1.00264, nR=n2=11.3968
#     ... (remaining 147 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 0.977585,alpha2 = 1.00264,mu = 1.03021,n1 = 169.801,n2 = 11.3968,sigma = 0.0449562)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=-nan/0.138082, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-5.48164) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1.27218	alpha2=1.45975	mu=1.03261	n1=161.932	n2=5.38085	sigma=0.0578418
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.65, x0=mu=1.03261, sigmaL=sigma=0.0578418, sigmaR=sigma=0.0578418, alphaL=alpha1=1.27218, nL=n1=161.932, alphaR=alpha2=1.45975, nR=n2=5.38085
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=1.03261, sigmaL=sigma=0.0578418, sigmaR=sigma=0.0578418, alphaL=alpha1=1.27218, nL=n1=161.932, alphaR=alpha2=1.45975, nR=n2=5.38085
#      p.d.f value is Not-a-Number @ x=x=0.656667, x0=mu=1.03261, sigmaL=sigma=0.0578418, sigmaR=sigma=0.0578418, alphaL=alpha1=1.27218, nL=n1=161.932, alphaR=alpha2=1.45975, nR=n2=5.38085
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=1.03261, sigmaL=sigma=0.0578418, sigmaR=sigma=0.0578418, alphaL=alpha1=1.27218, nL=n1=161.932, alphaR=alpha2=1.45975, nR=n2=5.38085
#      p.d.f value is Not-a-Number @ x=x=0.663333, x0=mu=1.03261, sigmaL=sigma=0.0578418, sigmaR=sigma=0.0578418, alphaL=alpha1=1.27218, nL=n1=161.932, alphaR=alpha2=1.45975, nR=n2=5.38085
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=1.03261, sigmaL=sigma=0.0578418, sigmaR=sigma=0.0578418, alphaL=alpha1=1.27218, nL=n1=161.932, alphaR=alpha2=1.45975, nR=n2=5.38085
#      p.d.f value is Not-a-Number @ x=x=0.67, x0=mu=1.03261, sigmaL=sigma=0.0578418, sigmaR=sigma=0.0578418, alphaL=alpha1=1.27218, nL=n1=161.932, alphaR=alpha2=1.45975, nR=n2=5.38085
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=1.03261, sigmaL=sigma=0.0578418, sigmaR=sigma=0.0578418, alphaL=alpha1=1.27218, nL=n1=161.932, alphaR=alpha2=1.45975, nR=n2=5.38085
#      p.d.f value is Not-a-Number @ x=x=0.676667, x0=mu=1.03261, sigmaL=sigma=0.0578418, sigmaR=sigma=0.0578418, alphaL=alpha1=1.27218, nL=n1=161.932, alphaR=alpha2=1.45975, nR=n2=5.38085
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=1.03261, sigmaL=sigma=0.0578418, sigmaR=sigma=0.0578418, alphaL=alpha1=1.27218, nL=n1=161.932, alphaR=alpha2=1.45975, nR=n2=5.38085
#      p.d.f value is Not-a-Number @ x=x=0.683333, x0=mu=1.03261, sigmaL=sigma=0.0578418, sigmaR=sigma=0.0578418, alphaL=alpha1=1.27218, nL=n1=161.932, alphaR=alpha2=1.45975, nR=n2=5.38085
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=1.03261, sigmaL=sigma=0.0578418, sigmaR=sigma=0.0578418, alphaL=alpha1=1.27218, nL=n1=161.932, alphaR=alpha2=1.45975, nR=n2=5.38085
#     ... (remaining 143 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1.27218,alpha2 = 1.45975,mu = 1.03261,n1 = 161.932,n2 = 5.38085,sigma = 0.0578418)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=-nan/0.145378, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-5.48164) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1.19697	alpha2=1.3968	mu=1.03184	n1=196.146	n2=4.57891	sigma=0.0544793
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.65, x0=mu=1.03184, sigmaL=sigma=0.0544793, sigmaR=sigma=0.0544793, alphaL=alpha1=1.19697, nL=n1=196.146, alphaR=alpha2=1.3968, nR=n2=4.57891
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=1.03184, sigmaL=sigma=0.0544793, sigmaR=sigma=0.0544793, alphaL=alpha1=1.19697, nL=n1=196.146, alphaR=alpha2=1.3968, nR=n2=4.57891
#      p.d.f value is Not-a-Number @ x=x=0.656667, x0=mu=1.03184, sigmaL=sigma=0.0544793, sigmaR=sigma=0.0544793, alphaL=alpha1=1.19697, nL=n1=196.146, alphaR=alpha2=1.3968, nR=n2=4.57891
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=1.03184, sigmaL=sigma=0.0544793, sigmaR=sigma=0.0544793, alphaL=alpha1=1.19697, nL=n1=196.146, alphaR=alpha2=1.3968, nR=n2=4.57891
#      p.d.f value is Not-a-Number @ x=x=0.663333, x0=mu=1.03184, sigmaL=sigma=0.0544793, sigmaR=sigma=0.0544793, alphaL=alpha1=1.19697, nL=n1=196.146, alphaR=alpha2=1.3968, nR=n2=4.57891
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=1.03184, sigmaL=sigma=0.0544793, sigmaR=sigma=0.0544793, alphaL=alpha1=1.19697, nL=n1=196.146, alphaR=alpha2=1.3968, nR=n2=4.57891
#      p.d.f value is Not-a-Number @ x=x=0.67, x0=mu=1.03184, sigmaL=sigma=0.0544793, sigmaR=sigma=0.0544793, alphaL=alpha1=1.19697, nL=n1=196.146, alphaR=alpha2=1.3968, nR=n2=4.57891
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=1.03184, sigmaL=sigma=0.0544793, sigmaR=sigma=0.0544793, alphaL=alpha1=1.19697, nL=n1=196.146, alphaR=alpha2=1.3968, nR=n2=4.57891
#      p.d.f value is Not-a-Number @ x=x=0.676667, x0=mu=1.03184, sigmaL=sigma=0.0544793, sigmaR=sigma=0.0544793, alphaL=alpha1=1.19697, nL=n1=196.146, alphaR=alpha2=1.3968, nR=n2=4.57891
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=1.03184, sigmaL=sigma=0.0544793, sigmaR=sigma=0.0544793, alphaL=alpha1=1.19697, nL=n1=196.146, alphaR=alpha2=1.3968, nR=n2=4.57891
#      p.d.f value is Not-a-Number @ x=x=0.683333, x0=mu=1.03184, sigmaL=sigma=0.0544793, sigmaR=sigma=0.0544793, alphaL=alpha1=1.19697, nL=n1=196.146, alphaR=alpha2=1.3968, nR=n2=4.57891
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=1.03184, sigmaL=sigma=0.0544793, sigmaR=sigma=0.0544793, alphaL=alpha1=1.19697, nL=n1=196.146, alphaR=alpha2=1.3968, nR=n2=4.57891
#     ... (remaining 144 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1.19697,alpha2 = 1.3968,mu = 1.03184,n1 = 196.146,n2 = 4.57891,sigma = 0.0544793)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=-nan/0.14585, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-5.48164) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1.13583	alpha2=1.36791	mu=1.03199	n1=165.344	n2=4.65846	sigma=0.0530127
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.65, x0=mu=1.03199, sigmaL=sigma=0.0530127, sigmaR=sigma=0.0530127, alphaL=alpha1=1.13583, nL=n1=165.344, alphaR=alpha2=1.36791, nR=n2=4.65846
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=1.03199, sigmaL=sigma=0.0530127, sigmaR=sigma=0.0530127, alphaL=alpha1=1.13583, nL=n1=165.344, alphaR=alpha2=1.36791, nR=n2=4.65846
#      p.d.f value is Not-a-Number @ x=x=0.656667, x0=mu=1.03199, sigmaL=sigma=0.0530127, sigmaR=sigma=0.0530127, alphaL=alpha1=1.13583, nL=n1=165.344, alphaR=alpha2=1.36791, nR=n2=4.65846
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=1.03199, sigmaL=sigma=0.0530127, sigmaR=sigma=0.0530127, alphaL=alpha1=1.13583, nL=n1=165.344, alphaR=alpha2=1.36791, nR=n2=4.65846
#      p.d.f value is Not-a-Number @ x=x=0.663333, x0=mu=1.03199, sigmaL=sigma=0.0530127, sigmaR=sigma=0.0530127, alphaL=alpha1=1.13583, nL=n1=165.344, alphaR=alpha2=1.36791, nR=n2=4.65846
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=1.03199, sigmaL=sigma=0.0530127, sigmaR=sigma=0.0530127, alphaL=alpha1=1.13583, nL=n1=165.344, alphaR=alpha2=1.36791, nR=n2=4.65846
#      p.d.f value is Not-a-Number @ x=x=0.67, x0=mu=1.03199, sigmaL=sigma=0.0530127, sigmaR=sigma=0.0530127, alphaL=alpha1=1.13583, nL=n1=165.344, alphaR=alpha2=1.36791, nR=n2=4.65846
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=1.03199, sigmaL=sigma=0.0530127, sigmaR=sigma=0.0530127, alphaL=alpha1=1.13583, nL=n1=165.344, alphaR=alpha2=1.36791, nR=n2=4.65846
#      p.d.f value is Not-a-Number @ x=x=0.676667, x0=mu=1.03199, sigmaL=sigma=0.0530127, sigmaR=sigma=0.0530127, alphaL=alpha1=1.13583, nL=n1=165.344, alphaR=alpha2=1.36791, nR=n2=4.65846
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=1.03199, sigmaL=sigma=0.0530127, sigmaR=sigma=0.0530127, alphaL=alpha1=1.13583, nL=n1=165.344, alphaR=alpha2=1.36791, nR=n2=4.65846
#      p.d.f value is Not-a-Number @ x=x=0.683333, x0=mu=1.03199, sigmaL=sigma=0.0530127, sigmaR=sigma=0.0530127, alphaL=alpha1=1.13583, nL=n1=165.344, alphaR=alpha2=1.36791, nR=n2=4.65846
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=1.03199, sigmaL=sigma=0.0530127, sigmaR=sigma=0.0530127, alphaL=alpha1=1.13583, nL=n1=165.344, alphaR=alpha2=1.36791, nR=n2=4.65846
#     ... (remaining 145 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1.13583,alpha2 = 1.36791,mu = 1.03199,n1 = 165.344,n2 = 4.65846,sigma = 0.0530127)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=-nan/0.147938, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-5.48164) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1.13448	alpha2=1.37467	mu=1.03201	n1=149.118	n2=4.64496	sigma=0.0530917
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.65, x0=mu=1.03201, sigmaL=sigma=0.0530917, sigmaR=sigma=0.0530917, alphaL=alpha1=1.13448, nL=n1=149.118, alphaR=alpha2=1.37467, nR=n2=4.64496
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=1.03201, sigmaL=sigma=0.0530917, sigmaR=sigma=0.0530917, alphaL=alpha1=1.13448, nL=n1=149.118, alphaR=alpha2=1.37467, nR=n2=4.64496
#      p.d.f value is Not-a-Number @ x=x=0.656667, x0=mu=1.03201, sigmaL=sigma=0.0530917, sigmaR=sigma=0.0530917, alphaL=alpha1=1.13448, nL=n1=149.118, alphaR=alpha2=1.37467, nR=n2=4.64496
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=1.03201, sigmaL=sigma=0.0530917, sigmaR=sigma=0.0530917, alphaL=alpha1=1.13448, nL=n1=149.118, alphaR=alpha2=1.37467, nR=n2=4.64496
#      p.d.f value is Not-a-Number @ x=x=0.663333, x0=mu=1.03201, sigmaL=sigma=0.0530917, sigmaR=sigma=0.0530917, alphaL=alpha1=1.13448, nL=n1=149.118, alphaR=alpha2=1.37467, nR=n2=4.64496
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=1.03201, sigmaL=sigma=0.0530917, sigmaR=sigma=0.0530917, alphaL=alpha1=1.13448, nL=n1=149.118, alphaR=alpha2=1.37467, nR=n2=4.64496
#      p.d.f value is Not-a-Number @ x=x=0.67, x0=mu=1.03201, sigmaL=sigma=0.0530917, sigmaR=sigma=0.0530917, alphaL=alpha1=1.13448, nL=n1=149.118, alphaR=alpha2=1.37467, nR=n2=4.64496
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=1.03201, sigmaL=sigma=0.0530917, sigmaR=sigma=0.0530917, alphaL=alpha1=1.13448, nL=n1=149.118, alphaR=alpha2=1.37467, nR=n2=4.64496
#      p.d.f value is Not-a-Number @ x=x=0.676667, x0=mu=1.03201, sigmaL=sigma=0.0530917, sigmaR=sigma=0.0530917, alphaL=alpha1=1.13448, nL=n1=149.118, alphaR=alpha2=1.37467, nR=n2=4.64496
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=1.03201, sigmaL=sigma=0.0530917, sigmaR=sigma=0.0530917, alphaL=alpha1=1.13448, nL=n1=149.118, alphaR=alpha2=1.37467, nR=n2=4.64496
#      p.d.f value is Not-a-Number @ x=x=0.683333, x0=mu=1.03201, sigmaL=sigma=0.0530917, sigmaR=sigma=0.0530917, alphaL=alpha1=1.13448, nL=n1=149.118, alphaR=alpha2=1.37467, nR=n2=4.64496
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=1.03201, sigmaL=sigma=0.0530917, sigmaR=sigma=0.0530917, alphaL=alpha1=1.13448, nL=n1=149.118, alphaR=alpha2=1.37467, nR=n2=4.64496
#     ... (remaining 145 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1.13448,alpha2 = 1.37467,mu = 1.03201,n1 = 149.118,n2 = 4.64496,sigma = 0.0530917)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=-nan/-nan, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (172.757) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1.79496	alpha2=0.581161	mu=1.0438	n1=94.4857	n2=171.412	sigma=0.450809
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=1.0438, sigmaL=sigma=0.450809, sigmaR=sigma=0.450809, alphaL=alpha1=1.79496, nL=n1=94.4857, alphaR=alpha2=0.581161, nR=n2=171.412
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=1.0438, sigmaL=sigma=0.450809, sigmaR=sigma=0.450809, alphaL=alpha1=1.79496, nL=n1=94.4857, alphaR=alpha2=0.581161, nR=n2=171.412
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=1.0438, sigmaL=sigma=0.450809, sigmaR=sigma=0.450809, alphaL=alpha1=1.79496, nL=n1=94.4857, alphaR=alpha2=0.581161, nR=n2=171.412
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=1.0438, sigmaL=sigma=0.450809, sigmaR=sigma=0.450809, alphaL=alpha1=1.79496, nL=n1=94.4857, alphaR=alpha2=0.581161, nR=n2=171.412
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=1.0438, sigmaL=sigma=0.450809, sigmaR=sigma=0.450809, alphaL=alpha1=1.79496, nL=n1=94.4857, alphaR=alpha2=0.581161, nR=n2=171.412
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=1.0438, sigmaL=sigma=0.450809, sigmaR=sigma=0.450809, alphaL=alpha1=1.79496, nL=n1=94.4857, alphaR=alpha2=0.581161, nR=n2=171.412
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.69, x0=mu=1.0438, sigmaL=sigma=0.450809, sigmaR=sigma=0.450809, alphaL=alpha1=1.79496, nL=n1=94.4857, alphaR=alpha2=0.581161, nR=n2=171.412
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.696667, x0=mu=1.0438, sigmaL=sigma=0.450809, sigmaR=sigma=0.450809, alphaL=alpha1=1.79496, nL=n1=94.4857, alphaR=alpha2=0.581161, nR=n2=171.412
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.703333, x0=mu=1.0438, sigmaL=sigma=0.450809, sigmaR=sigma=0.450809, alphaL=alpha1=1.79496, nL=n1=94.4857, alphaR=alpha2=0.581161, nR=n2=171.412
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.71, x0=mu=1.0438, sigmaL=sigma=0.450809, sigmaR=sigma=0.450809, alphaL=alpha1=1.79496, nL=n1=94.4857, alphaR=alpha2=0.581161, nR=n2=171.412
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.716667, x0=mu=1.0438, sigmaL=sigma=0.450809, sigmaR=sigma=0.450809, alphaL=alpha1=1.79496, nL=n1=94.4857, alphaR=alpha2=0.581161, nR=n2=171.412
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.723333, x0=mu=1.0438, sigmaL=sigma=0.450809, sigmaR=sigma=0.450809, alphaL=alpha1=1.79496, nL=n1=94.4857, alphaR=alpha2=0.581161, nR=n2=171.412
#     ... (remaining 103 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1.79496,alpha2 = 0.581161,mu = 1.0438,n1 = 94.4857,n2 = 171.412,sigma = 0.450809)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=0.682804/0.568992, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (172.757) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=2.87716	alpha2=0.412068	mu=0.950014	n1=117.687	n2=176.433	sigma=0.0894855
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=0.950014, sigmaL=sigma=0.0894855, sigmaR=sigma=0.0894855, alphaL=alpha1=2.87716, nL=n1=117.687, alphaR=alpha2=0.412068, nR=n2=176.433
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=0.950014, sigmaL=sigma=0.0894855, sigmaR=sigma=0.0894855, alphaL=alpha1=2.87716, nL=n1=117.687, alphaR=alpha2=0.412068, nR=n2=176.433
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=0.950014, sigmaL=sigma=0.0894855, sigmaR=sigma=0.0894855, alphaL=alpha1=2.87716, nL=n1=117.687, alphaR=alpha2=0.412068, nR=n2=176.433
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=0.950014, sigmaL=sigma=0.0894855, sigmaR=sigma=0.0894855, alphaL=alpha1=2.87716, nL=n1=117.687, alphaR=alpha2=0.412068, nR=n2=176.433
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=0.950014, sigmaL=sigma=0.0894855, sigmaR=sigma=0.0894855, alphaL=alpha1=2.87716, nL=n1=117.687, alphaR=alpha2=0.412068, nR=n2=176.433
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=0.950014, sigmaL=sigma=0.0894855, sigmaR=sigma=0.0894855, alphaL=alpha1=2.87716, nL=n1=117.687, alphaR=alpha2=0.412068, nR=n2=176.433
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.69, x0=mu=0.950014, sigmaL=sigma=0.0894855, sigmaR=sigma=0.0894855, alphaL=alpha1=2.87716, nL=n1=117.687, alphaR=alpha2=0.412068, nR=n2=176.433
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.696667, x0=mu=0.950014, sigmaL=sigma=0.0894855, sigmaR=sigma=0.0894855, alphaL=alpha1=2.87716, nL=n1=117.687, alphaR=alpha2=0.412068, nR=n2=176.433
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.703333, x0=mu=0.950014, sigmaL=sigma=0.0894855, sigmaR=sigma=0.0894855, alphaL=alpha1=2.87716, nL=n1=117.687, alphaR=alpha2=0.412068, nR=n2=176.433
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.71, x0=mu=0.950014, sigmaL=sigma=0.0894855, sigmaR=sigma=0.0894855, alphaL=alpha1=2.87716, nL=n1=117.687, alphaR=alpha2=0.412068, nR=n2=176.433
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.716667, x0=mu=0.950014, sigmaL=sigma=0.0894855, sigmaR=sigma=0.0894855, alphaL=alpha1=2.87716, nL=n1=117.687, alphaR=alpha2=0.412068, nR=n2=176.433
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.723333, x0=mu=0.950014, sigmaL=sigma=0.0894855, sigmaR=sigma=0.0894855, alphaL=alpha1=2.87716, nL=n1=117.687, alphaR=alpha2=0.412068, nR=n2=176.433
#     ... (remaining 151 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 2.87716,alpha2 = 0.412068,mu = 0.950014,n1 = 117.687,n2 = 176.433,sigma = 0.0894855)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=0.00408999/0.584949, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (172.757) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=0.10207	alpha2=2.71509	mu=1.00514	n1=118.385	n2=124.441	sigma=0.0258976
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.65, x0=mu=1.00514, sigmaL=sigma=0.0258976, sigmaR=sigma=0.0258976, alphaL=alpha1=0.10207, nL=n1=118.385, alphaR=alpha2=2.71509, nR=n2=124.441
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=1.00514, sigmaL=sigma=0.0258976, sigmaR=sigma=0.0258976, alphaL=alpha1=0.10207, nL=n1=118.385, alphaR=alpha2=2.71509, nR=n2=124.441
#      p.d.f value is Not-a-Number @ x=x=0.656667, x0=mu=1.00514, sigmaL=sigma=0.0258976, sigmaR=sigma=0.0258976, alphaL=alpha1=0.10207, nL=n1=118.385, alphaR=alpha2=2.71509, nR=n2=124.441
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=1.00514, sigmaL=sigma=0.0258976, sigmaR=sigma=0.0258976, alphaL=alpha1=0.10207, nL=n1=118.385, alphaR=alpha2=2.71509, nR=n2=124.441
#      p.d.f value is Not-a-Number @ x=x=0.663333, x0=mu=1.00514, sigmaL=sigma=0.0258976, sigmaR=sigma=0.0258976, alphaL=alpha1=0.10207, nL=n1=118.385, alphaR=alpha2=2.71509, nR=n2=124.441
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=1.00514, sigmaL=sigma=0.0258976, sigmaR=sigma=0.0258976, alphaL=alpha1=0.10207, nL=n1=118.385, alphaR=alpha2=2.71509, nR=n2=124.441
#      p.d.f value is Not-a-Number @ x=x=0.67, x0=mu=1.00514, sigmaL=sigma=0.0258976, sigmaR=sigma=0.0258976, alphaL=alpha1=0.10207, nL=n1=118.385, alphaR=alpha2=2.71509, nR=n2=124.441
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=1.00514, sigmaL=sigma=0.0258976, sigmaR=sigma=0.0258976, alphaL=alpha1=0.10207, nL=n1=118.385, alphaR=alpha2=2.71509, nR=n2=124.441
#      p.d.f value is Not-a-Number @ x=x=0.676667, x0=mu=1.00514, sigmaL=sigma=0.0258976, sigmaR=sigma=0.0258976, alphaL=alpha1=0.10207, nL=n1=118.385, alphaR=alpha2=2.71509, nR=n2=124.441
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=1.00514, sigmaL=sigma=0.0258976, sigmaR=sigma=0.0258976, alphaL=alpha1=0.10207, nL=n1=118.385, alphaR=alpha2=2.71509, nR=n2=124.441
#      p.d.f value is Not-a-Number @ x=x=0.683333, x0=mu=1.00514, sigmaL=sigma=0.0258976, sigmaR=sigma=0.0258976, alphaL=alpha1=0.10207, nL=n1=118.385, alphaR=alpha2=2.71509, nR=n2=124.441
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=1.00514, sigmaL=sigma=0.0258976, sigmaR=sigma=0.0258976, alphaL=alpha1=0.10207, nL=n1=118.385, alphaR=alpha2=2.71509, nR=n2=124.441
#     ... (remaining 149 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 0.10207,alpha2 = 2.71509,mu = 1.00514,n1 = 118.385,n2 = 124.441,sigma = 0.0258976)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=-nan/0.588548, !sumCat=()
#
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -9.29444, estimated distance to minimum: 3.06993e-07
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.4636e+00 +/-  7.36e-02  <none>
#                 alpha2    1.0000e+00    2.0538e+00 +/-  6.21e-02  <none>
#                     mu    1.0300e+00    1.0312e+00 +/-  5.31e-04  <none>
#                     n1    8.0000e+01    1.3937e+01 +/-  6.71e+00  <none>
#                     n2    8.0000e+01    1.1677e+00 +/-  1.75e-01  <none>
#                  sigma    1.3153e-01    5.6578e-02 +/-  5.13e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (37.8262) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=0.951552	alpha2=1.03102	mu=1.03738	n1=197.116	n2=68.2139	sigma=0.0407606
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=-nan/0.16517, !sumCat=()
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 0.951552,alpha2 = 1.03102,mu = 1.03738,n1 = 197.116,n2 = 68.2139,sigma = 0.0407606)
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.65, x0=mu=1.03738, sigmaL=sigma=0.0407606, sigmaR=sigma=0.0407606, alphaL=alpha1=0.951552, nL=n1=197.116, alphaR=alpha2=1.03102, nR=n2=68.2139
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=1.03738, sigmaL=sigma=0.0407606, sigmaR=sigma=0.0407606, alphaL=alpha1=0.951552, nL=n1=197.116, alphaR=alpha2=1.03102, nR=n2=68.2139
#      p.d.f value is Not-a-Number @ x=x=0.656667, x0=mu=1.03738, sigmaL=sigma=0.0407606, sigmaR=sigma=0.0407606, alphaL=alpha1=0.951552, nL=n1=197.116, alphaR=alpha2=1.03102, nR=n2=68.2139
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=1.03738, sigmaL=sigma=0.0407606, sigmaR=sigma=0.0407606, alphaL=alpha1=0.951552, nL=n1=197.116, alphaR=alpha2=1.03102, nR=n2=68.2139
#      p.d.f value is Not-a-Number @ x=x=0.663333, x0=mu=1.03738, sigmaL=sigma=0.0407606, sigmaR=sigma=0.0407606, alphaL=alpha1=0.951552, nL=n1=197.116, alphaR=alpha2=1.03102, nR=n2=68.2139
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=1.03738, sigmaL=sigma=0.0407606, sigmaR=sigma=0.0407606, alphaL=alpha1=0.951552, nL=n1=197.116, alphaR=alpha2=1.03102, nR=n2=68.2139
#      p.d.f value is Not-a-Number @ x=x=0.67, x0=mu=1.03738, sigmaL=sigma=0.0407606, sigmaR=sigma=0.0407606, alphaL=alpha1=0.951552, nL=n1=197.116, alphaR=alpha2=1.03102, nR=n2=68.2139
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=1.03738, sigmaL=sigma=0.0407606, sigmaR=sigma=0.0407606, alphaL=alpha1=0.951552, nL=n1=197.116, alphaR=alpha2=1.03102, nR=n2=68.2139
#      p.d.f value is Not-a-Number @ x=x=0.676667, x0=mu=1.03738, sigmaL=sigma=0.0407606, sigmaR=sigma=0.0407606, alphaL=alpha1=0.951552, nL=n1=197.116, alphaR=alpha2=1.03102, nR=n2=68.2139
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=1.03738, sigmaL=sigma=0.0407606, sigmaR=sigma=0.0407606, alphaL=alpha1=0.951552, nL=n1=197.116, alphaR=alpha2=1.03102, nR=n2=68.2139
#      p.d.f value is Not-a-Number @ x=x=0.683333, x0=mu=1.03738, sigmaL=sigma=0.0407606, sigmaR=sigma=0.0407606, alphaL=alpha1=0.951552, nL=n1=197.116, alphaR=alpha2=1.03102, nR=n2=68.2139
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=1.03738, sigmaL=sigma=0.0407606, sigmaR=sigma=0.0407606, alphaL=alpha1=0.951552, nL=n1=197.116, alphaR=alpha2=1.03102, nR=n2=68.2139
#     ... (remaining 149 messages suppressed)
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (37.8262) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=0.99556	alpha2=1.0344	mu=1.03722	n1=197.136	n2=65.3203	sigma=0.0410404
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=-nan/0.162688, !sumCat=()
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 0.99556,alpha2 = 1.0344,mu = 1.03722,n1 = 197.136,n2 = 65.3203,sigma = 0.0410404)
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.65, x0=mu=1.03722, sigmaL=sigma=0.0410404, sigmaR=sigma=0.0410404, alphaL=alpha1=0.99556, nL=n1=197.136, alphaR=alpha2=1.0344, nR=n2=65.3203
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=1.03722, sigmaL=sigma=0.0410404, sigmaR=sigma=0.0410404, alphaL=alpha1=0.99556, nL=n1=197.136, alphaR=alpha2=1.0344, nR=n2=65.3203
#      p.d.f value is Not-a-Number @ x=x=0.656667, x0=mu=1.03722, sigmaL=sigma=0.0410404, sigmaR=sigma=0.0410404, alphaL=alpha1=0.99556, nL=n1=197.136, alphaR=alpha2=1.0344, nR=n2=65.3203
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=1.03722, sigmaL=sigma=0.0410404, sigmaR=sigma=0.0410404, alphaL=alpha1=0.99556, nL=n1=197.136, alphaR=alpha2=1.0344, nR=n2=65.3203
#      p.d.f value is Not-a-Number @ x=x=0.663333, x0=mu=1.03722, sigmaL=sigma=0.0410404, sigmaR=sigma=0.0410404, alphaL=alpha1=0.99556, nL=n1=197.136, alphaR=alpha2=1.0344, nR=n2=65.3203
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=1.03722, sigmaL=sigma=0.0410404, sigmaR=sigma=0.0410404, alphaL=alpha1=0.99556, nL=n1=197.136, alphaR=alpha2=1.0344, nR=n2=65.3203
#      p.d.f value is Not-a-Number @ x=x=0.67, x0=mu=1.03722, sigmaL=sigma=0.0410404, sigmaR=sigma=0.0410404, alphaL=alpha1=0.99556, nL=n1=197.136, alphaR=alpha2=1.0344, nR=n2=65.3203
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=1.03722, sigmaL=sigma=0.0410404, sigmaR=sigma=0.0410404, alphaL=alpha1=0.99556, nL=n1=197.136, alphaR=alpha2=1.0344, nR=n2=65.3203
#      p.d.f value is Not-a-Number @ x=x=0.676667, x0=mu=1.03722, sigmaL=sigma=0.0410404, sigmaR=sigma=0.0410404, alphaL=alpha1=0.99556, nL=n1=197.136, alphaR=alpha2=1.0344, nR=n2=65.3203
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=1.03722, sigmaL=sigma=0.0410404, sigmaR=sigma=0.0410404, alphaL=alpha1=0.99556, nL=n1=197.136, alphaR=alpha2=1.0344, nR=n2=65.3203
#      p.d.f value is Not-a-Number @ x=x=0.683333, x0=mu=1.03722, sigmaL=sigma=0.0410404, sigmaR=sigma=0.0410404, alphaL=alpha1=0.99556, nL=n1=197.136, alphaR=alpha2=1.0344, nR=n2=65.3203
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=1.03722, sigmaL=sigma=0.0410404, sigmaR=sigma=0.0410404, alphaL=alpha1=0.99556, nL=n1=197.136, alphaR=alpha2=1.0344, nR=n2=65.3203
#     ... (remaining 148 messages suppressed)
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (37.8262) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=0.924574	alpha2=1.05177	mu=1.03772	n1=184.547	n2=58.9787	sigma=0.0379995
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=-nan/0.160701, !sumCat=()
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 0.924574,alpha2 = 1.05177,mu = 1.03772,n1 = 184.547,n2 = 58.9787,sigma = 0.0379995)
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.65, x0=mu=1.03772, sigmaL=sigma=0.0379995, sigmaR=sigma=0.0379995, alphaL=alpha1=0.924574, nL=n1=184.547, alphaR=alpha2=1.05177, nR=n2=58.9787
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=1.03772, sigmaL=sigma=0.0379995, sigmaR=sigma=0.0379995, alphaL=alpha1=0.924574, nL=n1=184.547, alphaR=alpha2=1.05177, nR=n2=58.9787
#      p.d.f value is Not-a-Number @ x=x=0.656667, x0=mu=1.03772, sigmaL=sigma=0.0379995, sigmaR=sigma=0.0379995, alphaL=alpha1=0.924574, nL=n1=184.547, alphaR=alpha2=1.05177, nR=n2=58.9787
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=1.03772, sigmaL=sigma=0.0379995, sigmaR=sigma=0.0379995, alphaL=alpha1=0.924574, nL=n1=184.547, alphaR=alpha2=1.05177, nR=n2=58.9787
#      p.d.f value is Not-a-Number @ x=x=0.663333, x0=mu=1.03772, sigmaL=sigma=0.0379995, sigmaR=sigma=0.0379995, alphaL=alpha1=0.924574, nL=n1=184.547, alphaR=alpha2=1.05177, nR=n2=58.9787
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=1.03772, sigmaL=sigma=0.0379995, sigmaR=sigma=0.0379995, alphaL=alpha1=0.924574, nL=n1=184.547, alphaR=alpha2=1.05177, nR=n2=58.9787
#      p.d.f value is Not-a-Number @ x=x=0.67, x0=mu=1.03772, sigmaL=sigma=0.0379995, sigmaR=sigma=0.0379995, alphaL=alpha1=0.924574, nL=n1=184.547, alphaR=alpha2=1.05177, nR=n2=58.9787
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=1.03772, sigmaL=sigma=0.0379995, sigmaR=sigma=0.0379995, alphaL=alpha1=0.924574, nL=n1=184.547, alphaR=alpha2=1.05177, nR=n2=58.9787
#      p.d.f value is Not-a-Number @ x=x=0.676667, x0=mu=1.03772, sigmaL=sigma=0.0379995, sigmaR=sigma=0.0379995, alphaL=alpha1=0.924574, nL=n1=184.547, alphaR=alpha2=1.05177, nR=n2=58.9787
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=1.03772, sigmaL=sigma=0.0379995, sigmaR=sigma=0.0379995, alphaL=alpha1=0.924574, nL=n1=184.547, alphaR=alpha2=1.05177, nR=n2=58.9787
#      p.d.f value is Not-a-Number @ x=x=0.683333, x0=mu=1.03772, sigmaL=sigma=0.0379995, sigmaR=sigma=0.0379995, alphaL=alpha1=0.924574, nL=n1=184.547, alphaR=alpha2=1.05177, nR=n2=58.9787
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=1.03772, sigmaL=sigma=0.0379995, sigmaR=sigma=0.0379995, alphaL=alpha1=0.924574, nL=n1=184.547, alphaR=alpha2=1.05177, nR=n2=58.9787
#     ... (remaining 149 messages suppressed)
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (37.8262) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1.06664	alpha2=1.05226	mu=1.03701	n1=190.712	n2=56.2338	sigma=0.0404553
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=-nan/0.158032, !sumCat=()
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1.06664,alpha2 = 1.05226,mu = 1.03701,n1 = 190.712,n2 = 56.2338,sigma = 0.0404553)
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.65, x0=mu=1.03701, sigmaL=sigma=0.0404553, sigmaR=sigma=0.0404553, alphaL=alpha1=1.06664, nL=n1=190.712, alphaR=alpha2=1.05226, nR=n2=56.2338
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=1.03701, sigmaL=sigma=0.0404553, sigmaR=sigma=0.0404553, alphaL=alpha1=1.06664, nL=n1=190.712, alphaR=alpha2=1.05226, nR=n2=56.2338
#      p.d.f value is Not-a-Number @ x=x=0.656667, x0=mu=1.03701, sigmaL=sigma=0.0404553, sigmaR=sigma=0.0404553, alphaL=alpha1=1.06664, nL=n1=190.712, alphaR=alpha2=1.05226, nR=n2=56.2338
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=1.03701, sigmaL=sigma=0.0404553, sigmaR=sigma=0.0404553, alphaL=alpha1=1.06664, nL=n1=190.712, alphaR=alpha2=1.05226, nR=n2=56.2338
#      p.d.f value is Not-a-Number @ x=x=0.663333, x0=mu=1.03701, sigmaL=sigma=0.0404553, sigmaR=sigma=0.0404553, alphaL=alpha1=1.06664, nL=n1=190.712, alphaR=alpha2=1.05226, nR=n2=56.2338
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=1.03701, sigmaL=sigma=0.0404553, sigmaR=sigma=0.0404553, alphaL=alpha1=1.06664, nL=n1=190.712, alphaR=alpha2=1.05226, nR=n2=56.2338
#      p.d.f value is Not-a-Number @ x=x=0.67, x0=mu=1.03701, sigmaL=sigma=0.0404553, sigmaR=sigma=0.0404553, alphaL=alpha1=1.06664, nL=n1=190.712, alphaR=alpha2=1.05226, nR=n2=56.2338
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=1.03701, sigmaL=sigma=0.0404553, sigmaR=sigma=0.0404553, alphaL=alpha1=1.06664, nL=n1=190.712, alphaR=alpha2=1.05226, nR=n2=56.2338
#      p.d.f value is Not-a-Number @ x=x=0.676667, x0=mu=1.03701, sigmaL=sigma=0.0404553, sigmaR=sigma=0.0404553, alphaL=alpha1=1.06664, nL=n1=190.712, alphaR=alpha2=1.05226, nR=n2=56.2338
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=1.03701, sigmaL=sigma=0.0404553, sigmaR=sigma=0.0404553, alphaL=alpha1=1.06664, nL=n1=190.712, alphaR=alpha2=1.05226, nR=n2=56.2338
#      p.d.f value is Not-a-Number @ x=x=0.683333, x0=mu=1.03701, sigmaL=sigma=0.0404553, sigmaR=sigma=0.0404553, alphaL=alpha1=1.06664, nL=n1=190.712, alphaR=alpha2=1.05226, nR=n2=56.2338
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=1.03701, sigmaL=sigma=0.0404553, sigmaR=sigma=0.0404553, alphaL=alpha1=1.06664, nL=n1=190.712, alphaR=alpha2=1.05226, nR=n2=56.2338
#     ... (remaining 148 messages suppressed)
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (37.8262) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1.12966	alpha2=1.04677	mu=1.03732	n1=187.276	n2=48.0686	sigma=0.0405199
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=-nan/0.156227, !sumCat=()
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1.12966,alpha2 = 1.04677,mu = 1.03732,n1 = 187.276,n2 = 48.0686,sigma = 0.0405199)
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.65, x0=mu=1.03732, sigmaL=sigma=0.0405199, sigmaR=sigma=0.0405199, alphaL=alpha1=1.12966, nL=n1=187.276, alphaR=alpha2=1.04677, nR=n2=48.0686
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=1.03732, sigmaL=sigma=0.0405199, sigmaR=sigma=0.0405199, alphaL=alpha1=1.12966, nL=n1=187.276, alphaR=alpha2=1.04677, nR=n2=48.0686
#      p.d.f value is Not-a-Number @ x=x=0.656667, x0=mu=1.03732, sigmaL=sigma=0.0405199, sigmaR=sigma=0.0405199, alphaL=alpha1=1.12966, nL=n1=187.276, alphaR=alpha2=1.04677, nR=n2=48.0686
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=1.03732, sigmaL=sigma=0.0405199, sigmaR=sigma=0.0405199, alphaL=alpha1=1.12966, nL=n1=187.276, alphaR=alpha2=1.04677, nR=n2=48.0686
#      p.d.f value is Not-a-Number @ x=x=0.663333, x0=mu=1.03732, sigmaL=sigma=0.0405199, sigmaR=sigma=0.0405199, alphaL=alpha1=1.12966, nL=n1=187.276, alphaR=alpha2=1.04677, nR=n2=48.0686
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=1.03732, sigmaL=sigma=0.0405199, sigmaR=sigma=0.0405199, alphaL=alpha1=1.12966, nL=n1=187.276, alphaR=alpha2=1.04677, nR=n2=48.0686
#      p.d.f value is Not-a-Number @ x=x=0.67, x0=mu=1.03732, sigmaL=sigma=0.0405199, sigmaR=sigma=0.0405199, alphaL=alpha1=1.12966, nL=n1=187.276, alphaR=alpha2=1.04677, nR=n2=48.0686
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=1.03732, sigmaL=sigma=0.0405199, sigmaR=sigma=0.0405199, alphaL=alpha1=1.12966, nL=n1=187.276, alphaR=alpha2=1.04677, nR=n2=48.0686
#      p.d.f value is Not-a-Number @ x=x=0.676667, x0=mu=1.03732, sigmaL=sigma=0.0405199, sigmaR=sigma=0.0405199, alphaL=alpha1=1.12966, nL=n1=187.276, alphaR=alpha2=1.04677, nR=n2=48.0686
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=1.03732, sigmaL=sigma=0.0405199, sigmaR=sigma=0.0405199, alphaL=alpha1=1.12966, nL=n1=187.276, alphaR=alpha2=1.04677, nR=n2=48.0686
#      p.d.f value is Not-a-Number @ x=x=0.683333, x0=mu=1.03732, sigmaL=sigma=0.0405199, sigmaR=sigma=0.0405199, alphaL=alpha1=1.12966, nL=n1=187.276, alphaR=alpha2=1.04677, nR=n2=48.0686
# ...
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=1.04951, sigmaL=sigma=0.264199, sigmaR=sigma=0.264199, alphaL=alpha1=1.57465, nL=n1=113.012, alphaR=alpha2=1.01712, nR=n2=170.485
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=1.04951, sigmaL=sigma=0.264199, sigmaR=sigma=0.264199, alphaL=alpha1=1.57465, nL=n1=113.012, alphaR=alpha2=1.01712, nR=n2=170.485
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=1.04951, sigmaL=sigma=0.264199, sigmaR=sigma=0.264199, alphaL=alpha1=1.57465, nL=n1=113.012, alphaR=alpha2=1.01712, nR=n2=170.485
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.69, x0=mu=1.04951, sigmaL=sigma=0.264199, sigmaR=sigma=0.264199, alphaL=alpha1=1.57465, nL=n1=113.012, alphaR=alpha2=1.01712, nR=n2=170.485
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.696667, x0=mu=1.04951, sigmaL=sigma=0.264199, sigmaR=sigma=0.264199, alphaL=alpha1=1.57465, nL=n1=113.012, alphaR=alpha2=1.01712, nR=n2=170.485
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.703333, x0=mu=1.04951, sigmaL=sigma=0.264199, sigmaR=sigma=0.264199, alphaL=alpha1=1.57465, nL=n1=113.012, alphaR=alpha2=1.01712, nR=n2=170.485
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.71, x0=mu=1.04951, sigmaL=sigma=0.264199, sigmaR=sigma=0.264199, alphaL=alpha1=1.57465, nL=n1=113.012, alphaR=alpha2=1.01712, nR=n2=170.485
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.716667, x0=mu=1.04951, sigmaL=sigma=0.264199, sigmaR=sigma=0.264199, alphaL=alpha1=1.57465, nL=n1=113.012, alphaR=alpha2=1.01712, nR=n2=170.485
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.723333, x0=mu=1.04951, sigmaL=sigma=0.264199, sigmaR=sigma=0.264199, alphaL=alpha1=1.57465, nL=n1=113.012, alphaR=alpha2=1.01712, nR=n2=170.485
#     ... (remaining 101 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1.57465,alpha2 = 1.01712,mu = 1.04951,n1 = 113.012,n2 = 170.485,sigma = 0.264199)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=0.318762/-nan, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (28.1774) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1.63878	alpha2=0.13466	mu=1.04343	n1=45.6114	n2=191.86	sigma=0.37357
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=1.04343, sigmaL=sigma=0.37357, sigmaR=sigma=0.37357, alphaL=alpha1=1.63878, nL=n1=45.6114, alphaR=alpha2=0.13466, nR=n2=191.86
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=1.04343, sigmaL=sigma=0.37357, sigmaR=sigma=0.37357, alphaL=alpha1=1.63878, nL=n1=45.6114, alphaR=alpha2=0.13466, nR=n2=191.86
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=1.04343, sigmaL=sigma=0.37357, sigmaR=sigma=0.37357, alphaL=alpha1=1.63878, nL=n1=45.6114, alphaR=alpha2=0.13466, nR=n2=191.86
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=1.04343, sigmaL=sigma=0.37357, sigmaR=sigma=0.37357, alphaL=alpha1=1.63878, nL=n1=45.6114, alphaR=alpha2=0.13466, nR=n2=191.86
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=1.04343, sigmaL=sigma=0.37357, sigmaR=sigma=0.37357, alphaL=alpha1=1.63878, nL=n1=45.6114, alphaR=alpha2=0.13466, nR=n2=191.86
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=1.04343, sigmaL=sigma=0.37357, sigmaR=sigma=0.37357, alphaL=alpha1=1.63878, nL=n1=45.6114, alphaR=alpha2=0.13466, nR=n2=191.86
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.69, x0=mu=1.04343, sigmaL=sigma=0.37357, sigmaR=sigma=0.37357, alphaL=alpha1=1.63878, nL=n1=45.6114, alphaR=alpha2=0.13466, nR=n2=191.86
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.696667, x0=mu=1.04343, sigmaL=sigma=0.37357, sigmaR=sigma=0.37357, alphaL=alpha1=1.63878, nL=n1=45.6114, alphaR=alpha2=0.13466, nR=n2=191.86
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.703333, x0=mu=1.04343, sigmaL=sigma=0.37357, sigmaR=sigma=0.37357, alphaL=alpha1=1.63878, nL=n1=45.6114, alphaR=alpha2=0.13466, nR=n2=191.86
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.71, x0=mu=1.04343, sigmaL=sigma=0.37357, sigmaR=sigma=0.37357, alphaL=alpha1=1.63878, nL=n1=45.6114, alphaR=alpha2=0.13466, nR=n2=191.86
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.716667, x0=mu=1.04343, sigmaL=sigma=0.37357, sigmaR=sigma=0.37357, alphaL=alpha1=1.63878, nL=n1=45.6114, alphaR=alpha2=0.13466, nR=n2=191.86
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.723333, x0=mu=1.04343, sigmaL=sigma=0.37357, sigmaR=sigma=0.37357, alphaL=alpha1=1.63878, nL=n1=45.6114, alphaR=alpha2=0.13466, nR=n2=191.86
#     ... (remaining 135 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1.63878,alpha2 = 0.13466,mu = 1.04343,n1 = 45.6114,n2 = 191.86,sigma = 0.37357)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=0.574318/0.599084, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (28.1774) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=0.956793	alpha2=1.16789	mu=0.951202	n1=190.53	n2=163.596	sigma=0.0363234
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.65, x0=mu=0.951202, sigmaL=sigma=0.0363234, sigmaR=sigma=0.0363234, alphaL=alpha1=0.956793, nL=n1=190.53, alphaR=alpha2=1.16789, nR=n2=163.596
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=0.951202, sigmaL=sigma=0.0363234, sigmaR=sigma=0.0363234, alphaL=alpha1=0.956793, nL=n1=190.53, alphaR=alpha2=1.16789, nR=n2=163.596
#      p.d.f value is Not-a-Number @ x=x=0.656667, x0=mu=0.951202, sigmaL=sigma=0.0363234, sigmaR=sigma=0.0363234, alphaL=alpha1=0.956793, nL=n1=190.53, alphaR=alpha2=1.16789, nR=n2=163.596
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=0.951202, sigmaL=sigma=0.0363234, sigmaR=sigma=0.0363234, alphaL=alpha1=0.956793, nL=n1=190.53, alphaR=alpha2=1.16789, nR=n2=163.596
#      p.d.f value is Not-a-Number @ x=x=0.663333, x0=mu=0.951202, sigmaL=sigma=0.0363234, sigmaR=sigma=0.0363234, alphaL=alpha1=0.956793, nL=n1=190.53, alphaR=alpha2=1.16789, nR=n2=163.596
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=0.951202, sigmaL=sigma=0.0363234, sigmaR=sigma=0.0363234, alphaL=alpha1=0.956793, nL=n1=190.53, alphaR=alpha2=1.16789, nR=n2=163.596
#      p.d.f value is Not-a-Number @ x=x=0.67, x0=mu=0.951202, sigmaL=sigma=0.0363234, sigmaR=sigma=0.0363234, alphaL=alpha1=0.956793, nL=n1=190.53, alphaR=alpha2=1.16789, nR=n2=163.596
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=0.951202, sigmaL=sigma=0.0363234, sigmaR=sigma=0.0363234, alphaL=alpha1=0.956793, nL=n1=190.53, alphaR=alpha2=1.16789, nR=n2=163.596
#      p.d.f value is Not-a-Number @ x=x=0.676667, x0=mu=0.951202, sigmaL=sigma=0.0363234, sigmaR=sigma=0.0363234, alphaL=alpha1=0.956793, nL=n1=190.53, alphaR=alpha2=1.16789, nR=n2=163.596
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=0.951202, sigmaL=sigma=0.0363234, sigmaR=sigma=0.0363234, alphaL=alpha1=0.956793, nL=n1=190.53, alphaR=alpha2=1.16789, nR=n2=163.596
#      p.d.f value is Not-a-Number @ x=x=0.683333, x0=mu=0.951202, sigmaL=sigma=0.0363234, sigmaR=sigma=0.0363234, alphaL=alpha1=0.956793, nL=n1=190.53, alphaR=alpha2=1.16789, nR=n2=163.596
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=0.951202, sigmaL=sigma=0.0363234, sigmaR=sigma=0.0363234, alphaL=alpha1=0.956793, nL=n1=190.53, alphaR=alpha2=1.16789, nR=n2=163.596
#     ... (remaining 190 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 0.956793,alpha2 = 1.16789,mu = 0.951202,n1 = 190.53,n2 = 163.596,sigma = 0.0363234)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=-nan/0.0888513, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (28.1774) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=2.98335	alpha2=0.732033	mu=1.02197	n1=177.639	n2=2.0404	sigma=0.0531421
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.65, x0=mu=1.02197, sigmaL=sigma=0.0531421, sigmaR=sigma=0.0531421, alphaL=alpha1=2.98335, nL=n1=177.639, alphaR=alpha2=0.732033, nR=n2=2.0404
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=1.02197, sigmaL=sigma=0.0531421, sigmaR=sigma=0.0531421, alphaL=alpha1=2.98335, nL=n1=177.639, alphaR=alpha2=0.732033, nR=n2=2.0404
#      p.d.f value is Not-a-Number @ x=x=0.656667, x0=mu=1.02197, sigmaL=sigma=0.0531421, sigmaR=sigma=0.0531421, alphaL=alpha1=2.98335, nL=n1=177.639, alphaR=alpha2=0.732033, nR=n2=2.0404
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=1.02197, sigmaL=sigma=0.0531421, sigmaR=sigma=0.0531421, alphaL=alpha1=2.98335, nL=n1=177.639, alphaR=alpha2=0.732033, nR=n2=2.0404
#      p.d.f value is Not-a-Number @ x=x=0.663333, x0=mu=1.02197, sigmaL=sigma=0.0531421, sigmaR=sigma=0.0531421, alphaL=alpha1=2.98335, nL=n1=177.639, alphaR=alpha2=0.732033, nR=n2=2.0404
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=1.02197, sigmaL=sigma=0.0531421, sigmaR=sigma=0.0531421, alphaL=alpha1=2.98335, nL=n1=177.639, alphaR=alpha2=0.732033, nR=n2=2.0404
#      p.d.f value is Not-a-Number @ x=x=0.67, x0=mu=1.02197, sigmaL=sigma=0.0531421, sigmaR=sigma=0.0531421, alphaL=alpha1=2.98335, nL=n1=177.639, alphaR=alpha2=0.732033, nR=n2=2.0404
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=1.02197, sigmaL=sigma=0.0531421, sigmaR=sigma=0.0531421, alphaL=alpha1=2.98335, nL=n1=177.639, alphaR=alpha2=0.732033, nR=n2=2.0404
#      p.d.f value is Not-a-Number @ x=x=0.676667, x0=mu=1.02197, sigmaL=sigma=0.0531421, sigmaR=sigma=0.0531421, alphaL=alpha1=2.98335, nL=n1=177.639, alphaR=alpha2=0.732033, nR=n2=2.0404
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=1.02197, sigmaL=sigma=0.0531421, sigmaR=sigma=0.0531421, alphaL=alpha1=2.98335, nL=n1=177.639, alphaR=alpha2=0.732033, nR=n2=2.0404
#      p.d.f value is Not-a-Number @ x=x=0.683333, x0=mu=1.02197, sigmaL=sigma=0.0531421, sigmaR=sigma=0.0531421, alphaL=alpha1=2.98335, nL=n1=177.639, alphaR=alpha2=0.732033, nR=n2=2.0404
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=1.02197, sigmaL=sigma=0.0531421, sigmaR=sigma=0.0531421, alphaL=alpha1=2.98335, nL=n1=177.639, alphaR=alpha2=0.732033, nR=n2=2.0404
#     ... (remaining 129 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 2.98335,alpha2 = 0.732033,mu = 1.02197,n1 = 177.639,n2 = 2.0404,sigma = 0.0531421)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=-nan/0.0885402, !sumCat=()
#
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -1.23267, estimated distance to minimum: 2.42769e-05
#                 covariance matrix quality: Full matrix, but forced positive-definite
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    2.2390e+00 +/-  2.47e-01  <none>
#                 alpha2    1.0000e+00    1.5547e+00 +/-  1.99e-01  <none>
#                     mu    1.0433e+00    1.0500e+00 +/-  1.62e-04  <none>
#                     n1    8.0000e+01    1.3792e+00 +/-  5.00e-01  <none>
#                     n2    8.0000e+01    4.0715e+00 +/-  1.47e+00  <none>
#                  sigma    7.5229e-02    3.3671e-02 +/-  1.57e-03  <none>
#
# x[0]=30, y[0]=0.0565784, ex[0]=5, ey[0]=0.000512503
# x[1]=40, y[1]=0.0507222, ex[1]=5, ey[1]=0.000326814
# x[2]=50, y[2]=0.0464616, ex[2]=5, ey[2]=0.000227409
# x[3]=60, y[3]=0.0431251, ex[3]=5, ey[3]=0.000154911
# x[4]=70, y[4]=0.0405226, ex[4]=5, ey[4]=0.000202034
# x[5]=80, y[5]=0.0376275, ex[5]=5, ey[5]=0.0076774
# x[6]=90, y[6]=0.0379605, ex[6]=5, ey[6]=0.00202513
# x[7]=100, y[7]=0.0366987, ex[7]=5, ey[7]=0.000461023
# x[8]=110, y[8]=0.0365127, ex[8]=5, ey[8]=0.0145059
# x[9]=120, y[9]=0.0355527, ex[9]=5, ey[9]=0.000586631
# x[10]=130, y[10]=0.0344555, ex[10]=5, ey[10]=0.0547876
# x[11]=140, y[11]=0.0346208, ex[11]=5, ey[11]=0.00175428
# x[12]=150, y[12]=0.0336714, ex[12]=5, ey[12]=0.00157039
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_XGB_25To35GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_XGB_35To45GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_XGB_45To55GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_XGB_55To65GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_XGB_65To75GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_XGB_75To85GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_XGB_85To95GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_XGB_95To105GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_XGB_105To115GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_XGB_115To125GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_XGB_125To135GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_XGB_135To145GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_XGB_145To155GeV.pdf has been created

# %%
x_mu_egm, y_mu_egm, xerr_mu_egm, yerr_mu_egm = [], [], [], []
x_width_egm, y_width_egm, xerr_width_egm, yerr_width_egm = [], [], [], []
for i in range(hist2D_EGM.GetNbinsX()):
    pt_do = hist2D_EGM.GetXaxis().GetBinLowEdge(i+1) 
    pt_up = hist2D_EGM.GetXaxis().GetBinUpEdge(i+1)
    print(color.GREEN + "[INFO] Perform the fitting in range [%d, %d]" %(int(pt_do), int(pt_up)) + color.END)
    histName_EGM = "hist1D_EGM_{}To{}".format(pt_do, pt_up) 
    hist_EGM = hist2D_EGM.ProjectionY(histName_EGM, i+1, i+1).Clone()
    fitRes = fit_resp(hist_EGM, pt_do, pt_up, "EGM")
    fitRes.Print("V")
    
    x_mu_egm.append(pt_do+(pt_up-pt_do)/2)
    y_mu_egm.append(fitRes.floatParsFinal().find("mu").getValV())
    xerr_mu_egm.append((pt_up-pt_do)/2)
    yerr_mu_egm.append(fitRes.floatParsFinal().find("mu").getError())
    
    sigma_ave = fitRes.floatParsFinal().find("sigma").getValV()
    sigma_ave_err = fitRes.floatParsFinal().find("sigma").getError()
    x_width_egm.append(pt_do+(pt_up-pt_do)/2)
    y_width_egm.append(sigma_ave)
    xerr_width_egm.append((pt_up-pt_do)/2)
    yerr_width_egm.append(sigma_ave_err)
    
mu_err_EGM = ROOT.TGraphErrors(hist2D_EGM.GetNbinsX(), np.array(x_mu_egm), np.array(y_mu_egm), np.array(xerr_mu_egm), np.array(yerr_mu_egm)) 
width_err_EGM = ROOT.TGraphErrors(hist2D_EGM.GetNbinsX(), np.array(x_width_egm), np.array(y_width_egm), np.array(xerr_width_egm), np.array(yerr_width_egm)) 
width_err_EGM.Print()
# Out:
# [INFO] Perform the fitting in range [25, 35]
# Fitting succeed!
# [INFO] Perform the fitting in range [35, 45]
# Fitting succeed!
# [INFO] Perform the fitting in range [45, 55]
# Fitting succeed!
# [INFO] Perform the fitting in range [55, 65]
# Fitting succeed!
# [INFO] Perform the fitting in range [65, 75]
# Fitting succeed!
# [INFO] Perform the fitting in range [75, 85]
# Fitting succeed!
# [INFO] Perform the fitting in range [85, 95]
# Fitting succeed!
# [INFO] Perform the fitting in range [95, 105]
# Fitting succeed!
# [INFO] Perform the fitting in range [105, 115]
# Fitting succeed!
# [INFO] Perform the fitting in range [115, 125]
# Fitting succeed!
# [INFO] Perform the fitting in range [125, 135]
# Fitting succeed!
# [INFO] Perform the fitting in range [135, 145]
# Fitting succeed!
# [INFO] Perform the fitting in range [145, 155]
# Fitting succeed!
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -10.27, estimated distance to minimum: 8.43305e-07
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.2721e+00 +/-  4.82e-02  <none>
#                 alpha2    1.0000e+00    2.1355e+00 +/-  2.34e-02  <none>
#                     mu    9.7667e-01    9.7772e-01 +/-  5.30e-04  <none>
#                     n1    8.0000e+01    1.0549e+01 +/-  1.96e+00  <none>
#                     n2    8.0000e+01    1.0004e+00 +/-  1.18e-02  <none>
#                  sigma    1.3420e-01    4.5854e-02 +/-  5.58e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (0.118085) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1	alpha2=1	mu=0.983333	n1=11.6615	n2=151.712	sigma=0.0414077
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=151.712
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=151.712
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=151.712
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=151.712
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=151.712
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=151.712
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.69, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=151.712
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.696667, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=151.712
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.703333, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=151.712
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.71, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=151.712
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.716667, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=151.712
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.723333, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=151.712
#     ... (remaining 145 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1,alpha2 = 1,mu = 0.983333,n1 = 11.6615,n2 = 151.712,sigma = 0.0414077)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=0.00244403/0.126856, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (0.118085) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1	alpha2=1	mu=0.983333	n1=11.6615	n2=168.754	sigma=0.0414077
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=168.754
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=168.754
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=168.754
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=168.754
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=168.754
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=168.754
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.69, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=168.754
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.696667, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=168.754
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.703333, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=168.754
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.71, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=168.754
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.716667, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=168.754
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.723333, x0=mu=0.983333, sigmaL=sigma=0.0414077, sigmaR=sigma=0.0414077, alphaL=alpha1=1, nL=n1=11.6615, alphaR=alpha2=1, nR=n2=168.754
#     ... (remaining 145 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1,alpha2 = 1,mu = 0.983333,n1 = 11.6615,n2 = 168.754,sigma = 0.0414077)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=0.00244403/-nan, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (0.118085) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=2.3843	alpha2=0.892016	mu=0.95041	n1=127.814	n2=93.3016	sigma=5.41869e-05
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.65, x0=mu=0.95041, sigmaL=sigma=5.41869e-05, sigmaR=sigma=5.41869e-05, alphaL=alpha1=2.3843, nL=n1=127.814, alphaR=alpha2=0.892016, nR=n2=93.3016
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.656667, x0=mu=0.95041, sigmaL=sigma=5.41869e-05, sigmaR=sigma=5.41869e-05, alphaL=alpha1=2.3843, nL=n1=127.814, alphaR=alpha2=0.892016, nR=n2=93.3016
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.663333, x0=mu=0.95041, sigmaL=sigma=5.41869e-05, sigmaR=sigma=5.41869e-05, alphaL=alpha1=2.3843, nL=n1=127.814, alphaR=alpha2=0.892016, nR=n2=93.3016
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.67, x0=mu=0.95041, sigmaL=sigma=5.41869e-05, sigmaR=sigma=5.41869e-05, alphaL=alpha1=2.3843, nL=n1=127.814, alphaR=alpha2=0.892016, nR=n2=93.3016
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.676667, x0=mu=0.95041, sigmaL=sigma=5.41869e-05, sigmaR=sigma=5.41869e-05, alphaL=alpha1=2.3843, nL=n1=127.814, alphaR=alpha2=0.892016, nR=n2=93.3016
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.683333, x0=mu=0.95041, sigmaL=sigma=5.41869e-05, sigmaR=sigma=5.41869e-05, alphaL=alpha1=2.3843, nL=n1=127.814, alphaR=alpha2=0.892016, nR=n2=93.3016
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.69, x0=mu=0.95041, sigmaL=sigma=5.41869e-05, sigmaR=sigma=5.41869e-05, alphaL=alpha1=2.3843, nL=n1=127.814, alphaR=alpha2=0.892016, nR=n2=93.3016
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.696667, x0=mu=0.95041, sigmaL=sigma=5.41869e-05, sigmaR=sigma=5.41869e-05, alphaL=alpha1=2.3843, nL=n1=127.814, alphaR=alpha2=0.892016, nR=n2=93.3016
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.703333, x0=mu=0.95041, sigmaL=sigma=5.41869e-05, sigmaR=sigma=5.41869e-05, alphaL=alpha1=2.3843, nL=n1=127.814, alphaR=alpha2=0.892016, nR=n2=93.3016
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.71, x0=mu=0.95041, sigmaL=sigma=5.41869e-05, sigmaR=sigma=5.41869e-05, alphaL=alpha1=2.3843, nL=n1=127.814, alphaR=alpha2=0.892016, nR=n2=93.3016
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.716667, x0=mu=0.95041, sigmaL=sigma=5.41869e-05, sigmaR=sigma=5.41869e-05, alphaL=alpha1=2.3843, nL=n1=127.814, alphaR=alpha2=0.892016, nR=n2=93.3016
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.723333, x0=mu=0.95041, sigmaL=sigma=5.41869e-05, sigmaR=sigma=5.41869e-05, alphaL=alpha1=2.3843, nL=n1=127.814, alphaR=alpha2=0.892016, nR=n2=93.3016
#     ... (remaining 79 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 2.3843,alpha2 = 0.892016,mu = 0.95041,n1 = 127.814,n2 = 93.3016,sigma = 5.41869e-05)
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (0.118085) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=0.414216	alpha2=2.69865	mu=0.98625	n1=59.7867	n2=185.213	sigma=0.0104976
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=0.98625, sigmaL=sigma=0.0104976, sigmaR=sigma=0.0104976, alphaL=alpha1=0.414216, nL=n1=59.7867, alphaR=alpha2=2.69865, nR=n2=185.213
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=0.98625, sigmaL=sigma=0.0104976, sigmaR=sigma=0.0104976, alphaL=alpha1=0.414216, nL=n1=59.7867, alphaR=alpha2=2.69865, nR=n2=185.213
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=0.98625, sigmaL=sigma=0.0104976, sigmaR=sigma=0.0104976, alphaL=alpha1=0.414216, nL=n1=59.7867, alphaR=alpha2=2.69865, nR=n2=185.213
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=0.98625, sigmaL=sigma=0.0104976, sigmaR=sigma=0.0104976, alphaL=alpha1=0.414216, nL=n1=59.7867, alphaR=alpha2=2.69865, nR=n2=185.213
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=0.98625, sigmaL=sigma=0.0104976, sigmaR=sigma=0.0104976, alphaL=alpha1=0.414216, nL=n1=59.7867, alphaR=alpha2=2.69865, nR=n2=185.213
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=0.98625, sigmaL=sigma=0.0104976, sigmaR=sigma=0.0104976, alphaL=alpha1=0.414216, nL=n1=59.7867, alphaR=alpha2=2.69865, nR=n2=185.213
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.69, x0=mu=0.98625, sigmaL=sigma=0.0104976, sigmaR=sigma=0.0104976, alphaL=alpha1=0.414216, nL=n1=59.7867, alphaR=alpha2=2.69865, nR=n2=185.213
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.696667, x0=mu=0.98625, sigmaL=sigma=0.0104976, sigmaR=sigma=0.0104976, alphaL=alpha1=0.414216, nL=n1=59.7867, alphaR=alpha2=2.69865, nR=n2=185.213
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.703333, x0=mu=0.98625, sigmaL=sigma=0.0104976, sigmaR=sigma=0.0104976, alphaL=alpha1=0.414216, nL=n1=59.7867, alphaR=alpha2=2.69865, nR=n2=185.213
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.71, x0=mu=0.98625, sigmaL=sigma=0.0104976, sigmaR=sigma=0.0104976, alphaL=alpha1=0.414216, nL=n1=59.7867, alphaR=alpha2=2.69865, nR=n2=185.213
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.716667, x0=mu=0.98625, sigmaL=sigma=0.0104976, sigmaR=sigma=0.0104976, alphaL=alpha1=0.414216, nL=n1=59.7867, alphaR=alpha2=2.69865, nR=n2=185.213
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.723333, x0=mu=0.98625, sigmaL=sigma=0.0104976, sigmaR=sigma=0.0104976, alphaL=alpha1=0.414216, nL=n1=59.7867, alphaR=alpha2=2.69865, nR=n2=185.213
#     ... (remaining 147 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 0.414216,alpha2 = 2.69865,mu = 0.98625,n1 = 59.7867,n2 = 185.213,sigma = 0.0104976)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=6.60432e-06/0.108303, !sumCat=()
#
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -21.1097, estimated distance to minimum: 1.128e-06
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.4236e+00 +/-  3.03e-02  <none>
#                 alpha2    1.0000e+00    2.1149e+00 +/-  1.66e-02  <none>
#                     mu    9.8333e-01    9.8348e-01 +/-  2.87e-04  <none>
#                     n1    8.0000e+01    2.6039e+00 +/-  1.47e-01  <none>
#                     n2    8.0000e+01    1.0106e+00 +/-  1.94e-02  <none>
#                  sigma    1.0817e-01    3.9539e-02 +/-  2.75e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-18.0841) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1.9983	alpha2=1.78035	mu=0.951265	n1=195.318	n2=62.4518	sigma=0.0886442
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.65, x0=mu=0.951265, sigmaL=sigma=0.0886442, sigmaR=sigma=0.0886442, alphaL=alpha1=1.9983, nL=n1=195.318, alphaR=alpha2=1.78035, nR=n2=62.4518
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=0.951265, sigmaL=sigma=0.0886442, sigmaR=sigma=0.0886442, alphaL=alpha1=1.9983, nL=n1=195.318, alphaR=alpha2=1.78035, nR=n2=62.4518
#      p.d.f value is Not-a-Number @ x=x=0.656667, x0=mu=0.951265, sigmaL=sigma=0.0886442, sigmaR=sigma=0.0886442, alphaL=alpha1=1.9983, nL=n1=195.318, alphaR=alpha2=1.78035, nR=n2=62.4518
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=0.951265, sigmaL=sigma=0.0886442, sigmaR=sigma=0.0886442, alphaL=alpha1=1.9983, nL=n1=195.318, alphaR=alpha2=1.78035, nR=n2=62.4518
#      p.d.f value is Not-a-Number @ x=x=0.663333, x0=mu=0.951265, sigmaL=sigma=0.0886442, sigmaR=sigma=0.0886442, alphaL=alpha1=1.9983, nL=n1=195.318, alphaR=alpha2=1.78035, nR=n2=62.4518
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=0.951265, sigmaL=sigma=0.0886442, sigmaR=sigma=0.0886442, alphaL=alpha1=1.9983, nL=n1=195.318, alphaR=alpha2=1.78035, nR=n2=62.4518
#      p.d.f value is Not-a-Number @ x=x=0.67, x0=mu=0.951265, sigmaL=sigma=0.0886442, sigmaR=sigma=0.0886442, alphaL=alpha1=1.9983, nL=n1=195.318, alphaR=alpha2=1.78035, nR=n2=62.4518
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=0.951265, sigmaL=sigma=0.0886442, sigmaR=sigma=0.0886442, alphaL=alpha1=1.9983, nL=n1=195.318, alphaR=alpha2=1.78035, nR=n2=62.4518
#      p.d.f value is Not-a-Number @ x=x=0.676667, x0=mu=0.951265, sigmaL=sigma=0.0886442, sigmaR=sigma=0.0886442, alphaL=alpha1=1.9983, nL=n1=195.318, alphaR=alpha2=1.78035, nR=n2=62.4518
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=0.951265, sigmaL=sigma=0.0886442, sigmaR=sigma=0.0886442, alphaL=alpha1=1.9983, nL=n1=195.318, alphaR=alpha2=1.78035, nR=n2=62.4518
#      p.d.f value is Not-a-Number @ x=x=0.683333, x0=mu=0.951265, sigmaL=sigma=0.0886442, sigmaR=sigma=0.0886442, alphaL=alpha1=1.9983, nL=n1=195.318, alphaR=alpha2=1.78035, nR=n2=62.4518
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=0.951265, sigmaL=sigma=0.0886442, sigmaR=sigma=0.0886442, alphaL=alpha1=1.9983, nL=n1=195.318, alphaR=alpha2=1.78035, nR=n2=62.4518
#     ... (remaining 115 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1.9983,alpha2 = 1.78035,mu = 0.951265,n1 = 195.318,n2 = 62.4518,sigma = 0.0886442)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=-nan/0.112636, !sumCat=()
#
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -35.8966, estimated distance to minimum: 7.14842e-07
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.5276e+00 +/-  2.14e-02  <none>
#                 alpha2    1.0000e+00    2.0635e+00 +/-  2.32e-02  <none>
#                     mu    9.9667e-01    9.8806e-01 +/-  1.84e-04  <none>
#                     n1    8.0000e+01    2.2978e+00 +/-  8.42e-02  <none>
#                     n2    8.0000e+01    1.2529e+00 +/-  5.00e-02  <none>
#                  sigma    8.1480e-02    3.4323e-02 +/-  1.75e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-21.1125) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1	alpha2=1	mu=0.99	n1=180.984	n2=80	sigma=0.0290641
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.65, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=180.984, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=180.984, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.656667, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=180.984, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=180.984, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.663333, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=180.984, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=180.984, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.67, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=180.984, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=180.984, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.676667, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=180.984, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=180.984, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.683333, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=180.984, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=180.984, alphaR=alpha2=1, nR=n2=80
#     ... (remaining 143 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1,alpha2 = 1,mu = 0.99,n1 = 180.984,n2 = 80,sigma = 0.0290641)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=-nan/0.0880931, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-21.1125) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1	alpha2=1	mu=0.99	n1=147.169	n2=80	sigma=0.0290641
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.65, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=147.169, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=147.169, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.656667, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=147.169, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=147.169, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.663333, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=147.169, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=147.169, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.67, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=147.169, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=147.169, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.676667, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=147.169, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=147.169, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.683333, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=147.169, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=0.99, sigmaL=sigma=0.0290641, sigmaR=sigma=0.0290641, alphaL=alpha1=1, nL=n1=147.169, alphaR=alpha2=1, nR=n2=80
#     ... (remaining 143 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1,alpha2 = 1,mu = 0.99,n1 = 147.169,n2 = 80,sigma = 0.0290641)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=-nan/-nan, !sumCat=()
#
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -49.2933, estimated distance to minimum: 1.9694e-06
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.5720e+00 +/-  1.61e-02  <none>
#                 alpha2    1.0000e+00    2.0802e+00 +/-  2.92e-02  <none>
#                     mu    9.9000e-01    9.9028e-01 +/-  1.34e-04  <none>
#                     n1    8.0000e+01    2.1494e+00 +/-  5.87e-02  <none>
#                     n2    8.0000e+01    1.8364e+00 +/-  8.67e-02  <none>
#                  sigma    6.8137e-02    3.0225e-02 +/-  1.27e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (31.9349) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1	alpha2=1	mu=0.996667	n1=152.194	n2=80	sigma=0.0263392
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1,alpha2 = 1,mu = 0.996667,n1 = 152.194,n2 = 80,sigma = 0.0263392)
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.65, x0=mu=0.996667, sigmaL=sigma=0.0263392, sigmaR=sigma=0.0263392, alphaL=alpha1=1, nL=n1=152.194, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=0.996667, sigmaL=sigma=0.0263392, sigmaR=sigma=0.0263392, alphaL=alpha1=1, nL=n1=152.194, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.656667, x0=mu=0.996667, sigmaL=sigma=0.0263392, sigmaR=sigma=0.0263392, alphaL=alpha1=1, nL=n1=152.194, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=0.996667, sigmaL=sigma=0.0263392, sigmaR=sigma=0.0263392, alphaL=alpha1=1, nL=n1=152.194, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.663333, x0=mu=0.996667, sigmaL=sigma=0.0263392, sigmaR=sigma=0.0263392, alphaL=alpha1=1, nL=n1=152.194, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=0.996667, sigmaL=sigma=0.0263392, sigmaR=sigma=0.0263392, alphaL=alpha1=1, nL=n1=152.194, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.67, x0=mu=0.996667, sigmaL=sigma=0.0263392, sigmaR=sigma=0.0263392, alphaL=alpha1=1, nL=n1=152.194, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=0.996667, sigmaL=sigma=0.0263392, sigmaR=sigma=0.0263392, alphaL=alpha1=1, nL=n1=152.194, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.676667, x0=mu=0.996667, sigmaL=sigma=0.0263392, sigmaR=sigma=0.0263392, alphaL=alpha1=1, nL=n1=152.194, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=0.996667, sigmaL=sigma=0.0263392, sigmaR=sigma=0.0263392, alphaL=alpha1=1, nL=n1=152.194, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.683333, x0=mu=0.996667, sigmaL=sigma=0.0263392, sigmaR=sigma=0.0263392, alphaL=alpha1=1, nL=n1=152.194, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=0.996667, sigmaL=sigma=0.0263392, sigmaR=sigma=0.0263392, alphaL=alpha1=1, nL=n1=152.194, alphaR=alpha2=1, nR=n2=80
#     ... (remaining 145 messages suppressed)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=-nan/0.083215, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (31.9349) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=0.373157	alpha2=2.08741	mu=0.952797	n1=197.659	n2=193.426	sigma=0.12782
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 0.373157,alpha2 = 2.08741,mu = 0.952797,n1 = 197.659,n2 = 193.426,sigma = 0.12782)
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.65, x0=mu=0.952797, sigmaL=sigma=0.12782, sigmaR=sigma=0.12782, alphaL=alpha1=0.373157, nL=n1=197.659, alphaR=alpha2=2.08741, nR=n2=193.426
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=0.952797, sigmaL=sigma=0.12782, sigmaR=sigma=0.12782, alphaL=alpha1=0.373157, nL=n1=197.659, alphaR=alpha2=2.08741, nR=n2=193.426
#      p.d.f value is Not-a-Number @ x=x=0.656667, x0=mu=0.952797, sigmaL=sigma=0.12782, sigmaR=sigma=0.12782, alphaL=alpha1=0.373157, nL=n1=197.659, alphaR=alpha2=2.08741, nR=n2=193.426
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=0.952797, sigmaL=sigma=0.12782, sigmaR=sigma=0.12782, alphaL=alpha1=0.373157, nL=n1=197.659, alphaR=alpha2=2.08741, nR=n2=193.426
#      p.d.f value is Not-a-Number @ x=x=0.663333, x0=mu=0.952797, sigmaL=sigma=0.12782, sigmaR=sigma=0.12782, alphaL=alpha1=0.373157, nL=n1=197.659, alphaR=alpha2=2.08741, nR=n2=193.426
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=0.952797, sigmaL=sigma=0.12782, sigmaR=sigma=0.12782, alphaL=alpha1=0.373157, nL=n1=197.659, alphaR=alpha2=2.08741, nR=n2=193.426
#      p.d.f value is Not-a-Number @ x=x=0.67, x0=mu=0.952797, sigmaL=sigma=0.12782, sigmaR=sigma=0.12782, alphaL=alpha1=0.373157, nL=n1=197.659, alphaR=alpha2=2.08741, nR=n2=193.426
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=0.952797, sigmaL=sigma=0.12782, sigmaR=sigma=0.12782, alphaL=alpha1=0.373157, nL=n1=197.659, alphaR=alpha2=2.08741, nR=n2=193.426
#      p.d.f value is Not-a-Number @ x=x=0.676667, x0=mu=0.952797, sigmaL=sigma=0.12782, sigmaR=sigma=0.12782, alphaL=alpha1=0.373157, nL=n1=197.659, alphaR=alpha2=2.08741, nR=n2=193.426
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=0.952797, sigmaL=sigma=0.12782, sigmaR=sigma=0.12782, alphaL=alpha1=0.373157, nL=n1=197.659, alphaR=alpha2=2.08741, nR=n2=193.426
#      p.d.f value is Not-a-Number @ x=x=0.683333, x0=mu=0.952797, sigmaL=sigma=0.12782, sigmaR=sigma=0.12782, alphaL=alpha1=0.373157, nL=n1=197.659, alphaR=alpha2=2.08741, nR=n2=193.426
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=0.952797, sigmaL=sigma=0.12782, sigmaR=sigma=0.12782, alphaL=alpha1=0.373157, nL=n1=197.659, alphaR=alpha2=2.08741, nR=n2=193.426
#     ... (remaining 155 messages suppressed)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=-nan/0.0803945, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (31.9349) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=0.825238	alpha2=2.8789	mu=0.987745	n1=6.18277	n2=190.124	sigma=0.00935965
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 0.825238,alpha2 = 2.8789,mu = 0.987745,n1 = 6.18277,n2 = 190.124,sigma = 0.00935965)
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=0.987745, sigmaL=sigma=0.00935965, sigmaR=sigma=0.00935965, alphaL=alpha1=0.825238, nL=n1=6.18277, alphaR=alpha2=2.8789, nR=n2=190.124
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=0.987745, sigmaL=sigma=0.00935965, sigmaR=sigma=0.00935965, alphaL=alpha1=0.825238, nL=n1=6.18277, alphaR=alpha2=2.8789, nR=n2=190.124
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=0.987745, sigmaL=sigma=0.00935965, sigmaR=sigma=0.00935965, alphaL=alpha1=0.825238, nL=n1=6.18277, alphaR=alpha2=2.8789, nR=n2=190.124
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=0.987745, sigmaL=sigma=0.00935965, sigmaR=sigma=0.00935965, alphaL=alpha1=0.825238, nL=n1=6.18277, alphaR=alpha2=2.8789, nR=n2=190.124
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=0.987745, sigmaL=sigma=0.00935965, sigmaR=sigma=0.00935965, alphaL=alpha1=0.825238, nL=n1=6.18277, alphaR=alpha2=2.8789, nR=n2=190.124
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=0.987745, sigmaL=sigma=0.00935965, sigmaR=sigma=0.00935965, alphaL=alpha1=0.825238, nL=n1=6.18277, alphaR=alpha2=2.8789, nR=n2=190.124
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.69, x0=mu=0.987745, sigmaL=sigma=0.00935965, sigmaR=sigma=0.00935965, alphaL=alpha1=0.825238, nL=n1=6.18277, alphaR=alpha2=2.8789, nR=n2=190.124
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.696667, x0=mu=0.987745, sigmaL=sigma=0.00935965, sigmaR=sigma=0.00935965, alphaL=alpha1=0.825238, nL=n1=6.18277, alphaR=alpha2=2.8789, nR=n2=190.124
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.703333, x0=mu=0.987745, sigmaL=sigma=0.00935965, sigmaR=sigma=0.00935965, alphaL=alpha1=0.825238, nL=n1=6.18277, alphaR=alpha2=2.8789, nR=n2=190.124
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.71, x0=mu=0.987745, sigmaL=sigma=0.00935965, sigmaR=sigma=0.00935965, alphaL=alpha1=0.825238, nL=n1=6.18277, alphaR=alpha2=2.8789, nR=n2=190.124
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.716667, x0=mu=0.987745, sigmaL=sigma=0.00935965, sigmaR=sigma=0.00935965, alphaL=alpha1=0.825238, nL=n1=6.18277, alphaR=alpha2=2.8789, nR=n2=190.124
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.723333, x0=mu=0.987745, sigmaL=sigma=0.00935965, sigmaR=sigma=0.00935965, alphaL=alpha1=0.825238, nL=n1=6.18277, alphaR=alpha2=2.8789, nR=n2=190.124
#     ... (remaining 147 messages suppressed)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=1.49886e-05/0.078517, !sumCat=()
#
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -30.5362, estimated distance to minimum: 2.303e-06
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.5691e+00 +/-  2.13e-02  <none>
#                 alpha2    1.0000e+00    2.1722e+00 +/-  3.02e-02  <none>
#                     mu    9.9667e-01    9.9190e-01 +/-  1.62e-04  <none>
#                     n1    8.0000e+01    2.1819e+00 +/-  7.51e-02  <none>
#                     n2    8.0000e+01    1.6100e+00 +/-  8.32e-02  <none>
#                  sigma    6.6247e-02    2.7164e-02 +/-  1.44e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -16.1867, estimated distance to minimum: 3.20717e-07
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
# ...
# Parameter values: 	alpha1=1	alpha2=1	mu=1.01	n1=4.18001	n2=189.055	sigma=0.0228565
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=1.01, sigmaL=sigma=0.0228565, sigmaR=sigma=0.0228565, alphaL=alpha1=1, nL=n1=4.18001, alphaR=alpha2=1, nR=n2=189.055
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=1.01, sigmaL=sigma=0.0228565, sigmaR=sigma=0.0228565, alphaL=alpha1=1, nL=n1=4.18001, alphaR=alpha2=1, nR=n2=189.055
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=1.01, sigmaL=sigma=0.0228565, sigmaR=sigma=0.0228565, alphaL=alpha1=1, nL=n1=4.18001, alphaR=alpha2=1, nR=n2=189.055
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=1.01, sigmaL=sigma=0.0228565, sigmaR=sigma=0.0228565, alphaL=alpha1=1, nL=n1=4.18001, alphaR=alpha2=1, nR=n2=189.055
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=1.01, sigmaL=sigma=0.0228565, sigmaR=sigma=0.0228565, alphaL=alpha1=1, nL=n1=4.18001, alphaR=alpha2=1, nR=n2=189.055
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=1.01, sigmaL=sigma=0.0228565, sigmaR=sigma=0.0228565, alphaL=alpha1=1, nL=n1=4.18001, alphaR=alpha2=1, nR=n2=189.055
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.69, x0=mu=1.01, sigmaL=sigma=0.0228565, sigmaR=sigma=0.0228565, alphaL=alpha1=1, nL=n1=4.18001, alphaR=alpha2=1, nR=n2=189.055
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.696667, x0=mu=1.01, sigmaL=sigma=0.0228565, sigmaR=sigma=0.0228565, alphaL=alpha1=1, nL=n1=4.18001, alphaR=alpha2=1, nR=n2=189.055
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.703333, x0=mu=1.01, sigmaL=sigma=0.0228565, sigmaR=sigma=0.0228565, alphaL=alpha1=1, nL=n1=4.18001, alphaR=alpha2=1, nR=n2=189.055
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.71, x0=mu=1.01, sigmaL=sigma=0.0228565, sigmaR=sigma=0.0228565, alphaL=alpha1=1, nL=n1=4.18001, alphaR=alpha2=1, nR=n2=189.055
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.716667, x0=mu=1.01, sigmaL=sigma=0.0228565, sigmaR=sigma=0.0228565, alphaL=alpha1=1, nL=n1=4.18001, alphaR=alpha2=1, nR=n2=189.055
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.723333, x0=mu=1.01, sigmaL=sigma=0.0228565, sigmaR=sigma=0.0228565, alphaL=alpha1=1, nL=n1=4.18001, alphaR=alpha2=1, nR=n2=189.055
#     ... (remaining 144 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1,alpha2 = 1,mu = 1.01,n1 = 4.18001,n2 = 189.055,sigma = 0.0228565)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=0.00109859/0.071185, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (2.14357) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=2.16511	alpha2=0.353741	mu=0.980256	n1=80.225	n2=158.19	sigma=0.0788848
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.65, x0=mu=0.980256, sigmaL=sigma=0.0788848, sigmaR=sigma=0.0788848, alphaL=alpha1=2.16511, nL=n1=80.225, alphaR=alpha2=0.353741, nR=n2=158.19
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.656667, x0=mu=0.980256, sigmaL=sigma=0.0788848, sigmaR=sigma=0.0788848, alphaL=alpha1=2.16511, nL=n1=80.225, alphaR=alpha2=0.353741, nR=n2=158.19
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.663333, x0=mu=0.980256, sigmaL=sigma=0.0788848, sigmaR=sigma=0.0788848, alphaL=alpha1=2.16511, nL=n1=80.225, alphaR=alpha2=0.353741, nR=n2=158.19
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.67, x0=mu=0.980256, sigmaL=sigma=0.0788848, sigmaR=sigma=0.0788848, alphaL=alpha1=2.16511, nL=n1=80.225, alphaR=alpha2=0.353741, nR=n2=158.19
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.676667, x0=mu=0.980256, sigmaL=sigma=0.0788848, sigmaR=sigma=0.0788848, alphaL=alpha1=2.16511, nL=n1=80.225, alphaR=alpha2=0.353741, nR=n2=158.19
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.683333, x0=mu=0.980256, sigmaL=sigma=0.0788848, sigmaR=sigma=0.0788848, alphaL=alpha1=2.16511, nL=n1=80.225, alphaR=alpha2=0.353741, nR=n2=158.19
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.69, x0=mu=0.980256, sigmaL=sigma=0.0788848, sigmaR=sigma=0.0788848, alphaL=alpha1=2.16511, nL=n1=80.225, alphaR=alpha2=0.353741, nR=n2=158.19
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.696667, x0=mu=0.980256, sigmaL=sigma=0.0788848, sigmaR=sigma=0.0788848, alphaL=alpha1=2.16511, nL=n1=80.225, alphaR=alpha2=0.353741, nR=n2=158.19
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.703333, x0=mu=0.980256, sigmaL=sigma=0.0788848, sigmaR=sigma=0.0788848, alphaL=alpha1=2.16511, nL=n1=80.225, alphaR=alpha2=0.353741, nR=n2=158.19
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.71, x0=mu=0.980256, sigmaL=sigma=0.0788848, sigmaR=sigma=0.0788848, alphaL=alpha1=2.16511, nL=n1=80.225, alphaR=alpha2=0.353741, nR=n2=158.19
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.716667, x0=mu=0.980256, sigmaL=sigma=0.0788848, sigmaR=sigma=0.0788848, alphaL=alpha1=2.16511, nL=n1=80.225, alphaR=alpha2=0.353741, nR=n2=158.19
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.723333, x0=mu=0.980256, sigmaL=sigma=0.0788848, sigmaR=sigma=0.0788848, alphaL=alpha1=2.16511, nL=n1=80.225, alphaR=alpha2=0.353741, nR=n2=158.19
#     ... (remaining 148 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 2.16511,alpha2 = 0.353741,mu = 0.980256,n1 = 80.225,n2 = 158.19,sigma = 0.0788848)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.65), !jacList=(), !facList=(), !func=dcb=0.00135319/0.653554, !sumCat=()
#
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -1.88124, estimated distance to minimum: 7.14117e-07
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    2.0128e+00 +/-  1.48e-01  <none>
#                 alpha2    1.0000e+00    1.7520e+00 +/-  9.05e-02  <none>
#                     mu    1.0100e+00    9.9732e-01 +/-  5.08e-04  <none>
#                     n1    8.0000e+01    1.3335e+00 +/-  2.70e-01  <none>
#                     n2    8.0000e+01    1.9091e+00 +/-  2.49e-01  <none>
#                  sigma    6.1510e-02    1.9185e-02 +/-  4.84e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.03307) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1	alpha2=1	mu=0.996667	n1=80	n2=80	sigma=7.39406e-06
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.65, x0=mu=0.996667, sigmaL=sigma=7.39406e-06, sigmaR=sigma=7.39406e-06, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.656667, x0=mu=0.996667, sigmaL=sigma=7.39406e-06, sigmaR=sigma=7.39406e-06, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.663333, x0=mu=0.996667, sigmaL=sigma=7.39406e-06, sigmaR=sigma=7.39406e-06, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.67, x0=mu=0.996667, sigmaL=sigma=7.39406e-06, sigmaR=sigma=7.39406e-06, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.676667, x0=mu=0.996667, sigmaL=sigma=7.39406e-06, sigmaR=sigma=7.39406e-06, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.683333, x0=mu=0.996667, sigmaL=sigma=7.39406e-06, sigmaR=sigma=7.39406e-06, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.69, x0=mu=0.996667, sigmaL=sigma=7.39406e-06, sigmaR=sigma=7.39406e-06, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.696667, x0=mu=0.996667, sigmaL=sigma=7.39406e-06, sigmaR=sigma=7.39406e-06, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.703333, x0=mu=0.996667, sigmaL=sigma=7.39406e-06, sigmaR=sigma=7.39406e-06, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.71, x0=mu=0.996667, sigmaL=sigma=7.39406e-06, sigmaR=sigma=7.39406e-06, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.716667, x0=mu=0.996667, sigmaL=sigma=7.39406e-06, sigmaR=sigma=7.39406e-06, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.723333, x0=mu=0.996667, sigmaL=sigma=7.39406e-06, sigmaR=sigma=7.39406e-06, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#     ... (remaining 81 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1,alpha2 = 1,mu = 0.996667,n1 = 80,n2 = 80,sigma = 7.39406e-06)
#
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -1.50621, estimated distance to minimum: 3.57093e-05
#                 covariance matrix quality: Full matrix, but forced positive-definite
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.4979e+00 +/-  1.09e-01  <none>
#                 alpha2    1.0000e+00    2.0929e+00 +/-  9.75e-02  <none>
#                     mu    9.9667e-01    9.9931e-01 +/-  5.49e-04  <none>
#                     n1    8.0000e+01    2.5281e+00 +/-  4.99e-01  <none>
#                     n2    8.0000e+01    1.2655e+00 +/-  1.64e-01  <none>
#                  sigma    6.9060e-02    1.8508e-02 +/-  3.68e-04  <none>
#
# x[0]=30, y[0]=0.0458542, ex[0]=5, ey[0]=0.000557524
# x[1]=40, y[1]=0.0395394, ex[1]=5, ey[1]=0.000274802
# x[2]=50, y[2]=0.0343235, ex[2]=5, ey[2]=0.000174567
# x[3]=60, y[3]=0.0302246, ex[3]=5, ey[3]=0.000126555
# x[4]=70, y[4]=0.0271645, ex[4]=5, ey[4]=0.000144125
# x[5]=80, y[5]=0.0254027, ex[5]=5, ey[5]=0.000239528
# x[6]=90, y[6]=0.0235474, ex[6]=5, ey[6]=0.000269059
# x[7]=100, y[7]=0.0231953, ex[7]=5, ey[7]=0.000291365
# x[8]=110, y[8]=0.0224714, ex[8]=5, ey[8]=0.000303806
# x[9]=120, y[9]=0.0215077, ex[9]=5, ey[9]=0.000335085
# x[10]=130, y[10]=0.0207196, ex[10]=5, ey[10]=0.000441509
# x[11]=140, y[11]=0.0191853, ex[11]=5, ey[11]=0.000483622
# x[12]=150, y[12]=0.0185082, ex[12]=5, ey[12]=0.000368351
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_EGM_25To35GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_EGM_35To45GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_EGM_45To55GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_EGM_55To65GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_EGM_65To75GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_EGM_75To85GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_EGM_85To95GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_EGM_95To105GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_EGM_105To115GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_EGM_115To125GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_EGM_125To135GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_EGM_135To145GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit_tmva/EE/respFit_pt_EGM_145To155GeV.pdf has been created

# %%
c1 = ROOT.TCanvas("c1", "", 800, 800)
c1.cd()

pad1 = ROOT.TPad("pad1", " ", 0, 0.3, 1, 1.0)
pad1.SetBottomMargin(0.03)
pad1.SetTopMargin(0.09)
pad1.SetRightMargin(0.05)
pad1.SetLeftMargin(0.14)
pad1.Draw()
pad1.cd()

mu_err_XGB.GetXaxis().SetTitle("")
mu_err_XGB.GetYaxis().SetTitle("#LT p^{reco}_{T} / p^{true}_{T} #GT")
mu_err_XGB.GetYaxis().SetRangeUser(0.97, 1.03)
mu_err_XGB.GetYaxis().SetNdivisions(506)
mu_err_XGB.GetYaxis().SetTickSize(0.03)
mu_err_XGB.GetYaxis().SetTitleSize(0.06)
mu_err_XGB.GetYaxis().SetLabelSize(0.06)
mu_err_XGB.GetYaxis().SetTitleOffset(1.15)

mu_err_XGB.GetXaxis().SetRangeUser(25, 155)
mu_err_XGB.GetXaxis().SetTickSize(0.03)
mu_err_XGB.GetXaxis().SetTitleSize(0.06)
mu_err_XGB.GetXaxis().SetLabelSize(0.05)
mu_err_XGB.GetXaxis().SetLabelOffset(0.1)
mu_err_XGB.GetXaxis().SetTitleOffset(1)
mu_err_XGB.SetMarkerColor(ROOT.TColor.GetColor("#CC4054"))
mu_err_XGB.SetMarkerSize(1.4)
mu_err_XGB.SetMarkerStyle(20)
mu_err_XGB.SetLineColor(ROOT.TColor.GetColor("#CC4054"))
mu_err_XGB.SetLineWidth(2)
mu_err_XGB.Draw("AP")

mu_err_EGM.SetMarkerColor(ROOT.TColor.GetColor("#202020"))
mu_err_EGM.SetMarkerSize(1.4)
mu_err_EGM.SetMarkerStyle(20)
mu_err_EGM.SetLineColor(ROOT.TColor.GetColor("#202020"))
mu_err_EGM.SetLineWidth(2)

l = ROOT.TLine(25, 1, 155, 1)
l.SetLineStyle(2)
l.SetLineColor(1)
l.Draw()

mu_err_EGM.Draw("P same")
mu_err_XGB.Draw("P same")

region = "ECAL Barrrel" if iBE == 0 else "ECAL Endcap"
leg = ROOT.TLegend(0.53, 0.66, 0.88, 0.86)
leg.SetHeader(region)
leg.SetTextFont(42)
leg.SetTextSize(0.05)
leg.SetFillColor(0)
leg.SetLineColor(0)
leg.AddEntry(mu_err_XGB, "dedicated regression", "LE1P")
leg.AddEntry(mu_err_EGM, "standard regression", "LE1P")
leg.Draw("same")

CMS_lumi(pad1, 5, 10, "", 2017, True, "Simulation Preliminary", "H #rightarrow #gamma* #gamma #rightarrow ee#gamma", "")
c1.cd()

pad2 = ROOT.TPad("pad2", "", 0, 0, 1, 0.3)
pad2.SetGridy()
pad2.SetRightMargin(0.05)
pad2.SetLeftMargin(0.14)
pad2.SetTopMargin(0.06)
pad2.SetBottomMargin(0.43)
pad2.Draw()
pad2.cd()

nPoints = mu_err_XGB.GetN()
ratio_err = ROOT.TGraphErrors(nPoints)
for i in range(nPoints):
    xp = mu_err_XGB.GetPointX(i)
    yp = mu_err_XGB.GetPointY(i)/mu_err_EGM.GetPointY(i)
    xp_err = mu_err_XGB.GetErrorX(i)
    yp_err = yp * np.sqrt(pow(mu_err_XGB.GetErrorY(i)/mu_err_XGB.GetPointY(i), 2) + pow(mu_err_EGM.GetErrorY(i)/mu_err_EGM.GetPointY(i), 2))
    
    ratio_err.SetPoint(i, xp, yp)
    ratio_err.SetPointError(i, xp_err, yp_err)

ratio_err.SetName("")
ratio_err.SetTitle("")
ratio_err.GetXaxis().SetTitle("p^{true}_{T} [GeV]")
ratio_err.GetYaxis().SetTitle("Ratio")
ratio_err.GetYaxis().SetRangeUser(0.97 , 1.03)

ratio_err.SetMarkerColor(ROOT.TColor.GetColor("#202020"))
ratio_err.SetMarkerSize(1.4)
ratio_err.SetMarkerStyle(20)
ratio_err.SetLineColor(ROOT.TColor.GetColor("#202020"))
ratio_err.SetLineWidth(2)

ratio_err.GetXaxis().SetRangeUser(25, 155)
ratio_err.GetXaxis().SetTickSize(0.03 * (7/3.))
ratio_err.GetXaxis().SetTitleSize(0.16)
ratio_err.GetXaxis().SetTitleOffset(1.2)
ratio_err.GetXaxis().SetLabelSize(0.06  * (7/3.))
ratio_err.GetXaxis().SetLabelOffset(0.05)
ratio_err.GetYaxis().SetTitleSize(0.13)
ratio_err.GetYaxis().SetTitleOffset(0.22 * (7/3.))
ratio_err.GetYaxis().SetLabelSize(0.06  * (7/3.))
ratio_err.GetYaxis().SetNdivisions(502)
ratio_err.Draw("AP")

c1.Draw()

# %%
c1 = ROOT.TCanvas("c1", "", 800, 800)
c1.cd()

pad1 = ROOT.TPad("pad1", " ", 0, 0.3, 1, 1.0)
pad1.SetBottomMargin(0.03)
pad1.SetTopMargin(0.09)
pad1.SetRightMargin(0.05)
pad1.SetLeftMargin(0.14)
pad1.Draw()
pad1.cd()

width_err_XGB.GetXaxis().SetTitle("")
width_err_XGB.GetYaxis().SetTitle("#sigma_{p^{reco}_{T} / p^{true}_{T}}")
width_err_XGB.GetYaxis().SetRangeUser(0, 0.06)
width_err_XGB.GetYaxis().SetNdivisions(506)
width_err_XGB.GetYaxis().SetTickSize(0.03)
width_err_XGB.GetYaxis().SetTitleSize(0.06)
width_err_XGB.GetYaxis().SetLabelSize(0.06)
width_err_XGB.GetYaxis().SetTitleOffset(1.15)

width_err_XGB.GetXaxis().SetRangeUser(25, 155)
width_err_XGB.GetXaxis().SetTickSize(0.03)
width_err_XGB.GetXaxis().SetTitleSize(0.06)
width_err_XGB.GetXaxis().SetLabelSize(0.05)
width_err_XGB.GetXaxis().SetLabelOffset(0.1)
width_err_XGB.GetXaxis().SetTitleOffset(1)
width_err_XGB.SetMarkerColor(ROOT.TColor.GetColor("#CC4054"))
width_err_XGB.SetMarkerSize(1.4)
width_err_XGB.SetMarkerStyle(20)
width_err_XGB.SetLineColor(ROOT.TColor.GetColor("#CC4054"))
width_err_XGB.SetLineWidth(2)
width_err_XGB.Draw("AP")

width_err_EGM.SetMarkerColor(ROOT.TColor.GetColor("#202020"))
width_err_EGM.SetMarkerSize(1.4)
width_err_EGM.SetMarkerStyle(20)
width_err_EGM.SetLineColor(ROOT.TColor.GetColor("#202020"))
width_err_EGM.SetLineWidth(2)

# l = ROOT.TLine(25, 1, 155, 1)
# l.SetLineStyle(2)
# l.SetLineColor(1)
# l.Draw()
    
width_err_EGM.Draw("P same")
width_err_XGB.Draw("P same")

region = "ECAL Barrrel" if iBE == 0 else "ECAL Endcap"
leg = ROOT.TLegend(0.53, 0.66, 0.88, 0.86)
leg.SetHeader(region)
leg.SetTextFont(42)
leg.SetTextSize(0.05)
leg.SetFillColor(0)
leg.SetLineColor(0)
leg.AddEntry(mu_err_XGB, "dedicated regression", "LE1P")
leg.AddEntry(mu_err_EGM, "standard regression", "LE1P")
leg.Draw("same")

CMS_lumi(pad1, 5, 10, "", 2017, True, "Simulation Preliminary", "H #rightarrow #gamma* #gamma #rightarrow ee#gamma", "")
c1.cd()

pad2 = ROOT.TPad("pad2", "", 0, 0, 1, 0.3)
pad2.SetGridy()
pad2.SetRightMargin(0.05)
pad2.SetLeftMargin(0.14)
pad2.SetTopMargin(0.06)
pad2.SetBottomMargin(0.43)
pad2.Draw()
pad2.cd()

nPoints = width_err_XGB.GetN()
ratio_err = ROOT.TGraphErrors(nPoints)
for i in range(nPoints):
    xp = width_err_XGB.GetPointX(i)
    yp = width_err_XGB.GetPointY(i)/width_err_EGM.GetPointY(i)
    xp_err = width_err_XGB.GetErrorX(i)
    yp_err = yp * np.sqrt(pow(width_err_XGB.GetErrorY(i)/width_err_XGB.GetPointY(i), 2) + pow(width_err_EGM.GetErrorY(i)/width_err_EGM.GetPointY(i), 2))
    
    ratio_err.SetPoint(i, xp, yp)
    ratio_err.SetPointError(i, xp_err, yp_err)

ratio_err.SetName("")
ratio_err.SetTitle("")
ratio_err.GetXaxis().SetTitle("p^{true}_{T} [GeV]")
ratio_err.GetYaxis().SetTitle("Ratio")
ratio_err.GetYaxis().SetRangeUser(0.4 , 1.6)

ratio_err.SetMarkerColor(ROOT.TColor.GetColor("#202020"))
ratio_err.SetMarkerSize(1.4)
ratio_err.SetMarkerStyle(20)
ratio_err.SetLineColor(ROOT.TColor.GetColor("#202020"))
ratio_err.SetLineWidth(2)

ratio_err.GetXaxis().SetRangeUser(25, 155)
ratio_err.GetXaxis().SetTickSize(0.03 * (7/3.))
ratio_err.GetXaxis().SetTitleSize(0.16)
ratio_err.GetXaxis().SetTitleOffset(1.2)
ratio_err.GetXaxis().SetLabelSize(0.06  * (7/3.))
ratio_err.GetXaxis().SetLabelOffset(0.05)
ratio_err.GetYaxis().SetTitleSize(0.13)
ratio_err.GetYaxis().SetTitleOffset(0.22 * (7/3.))
ratio_err.GetYaxis().SetLabelSize(0.06  * (7/3.))
ratio_err.GetYaxis().SetNdivisions(502)
ratio_err.Draw("AP")

c1.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
