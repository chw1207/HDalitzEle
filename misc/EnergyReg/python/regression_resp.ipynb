# %%
import sys, os
import ROOT
import numpy as np
import xgboost as xgb
import pandas as pd
from CMS_lumi import CMS_lumi
from colorPrint import *
from ROOT import RooFit

ROOT.RooMsgService.instance().setSilentMode(True)
ROOT.gROOT.LoadMacro("../interface/tdrstyle.C")
ROOT.gROOT.ProcessLine("setTDRStyle();")
# Out:
# Welcome to JupyROOT 6.24/02
# /home/chenghan/.conda/envs/hdalitz2/lib/python3.8/site-packages/ROOT/_facade.py:150: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   return _orig_ihook(name, *args, **kwds)
# /home/chenghan/.conda/envs/hdalitz2/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# RooFit v3.60 -- Developed by Wouter Verkerke and David Kirkby
#                 Copyright (C) 2000-2013 NIKHEF, University of California & Stanford University
#                 All rights reserved, please read http://roofit.sourceforge.net/license.txt
# 0

# %%
import pickle as pkl
from pprint import pprint

iBE = 1 # 0 for EB and 1 for EE
region = "EB" if iBE == 0 else "EE"
inpath = "../reg_results/XGBRegression_NoRobustScaling_EGMRegTarget_{}".format(region)

features = []
with (open("{}/features.pkl".format(inpath), "rb")) as f:
    features = pkl.load(f)
print("[INFO] {} features are used for training".format(len(features)))
pprint(features)
# Out:
# [INFO] 24 features are used for training
# ['rho',
#  'nVtx',
#  'eleSCEta_Lead',
#  'eleSCPhi_Lead',
#  'eleSCRawEn_Lead',
#  'eleCalibPt_Lead',
#  'eledEtaAtVtx_Lead',
#  'eledPhiAtVtx_Lead',
#  'elePtError_Lead',
#  'eleHoverE_Lead',
#  'eleEoverP_Lead',
#  'eleEoverPout_Lead',
#  'eleEoverPInv_Lead',
#  'eleSCEtaWidth_Lead',
#  'eleSCPhiWidth_Lead',
#  'eleSigmaIEtaIEtaFull5x5_Lead',
#  'eleSigmaIPhiIPhiFull5x5_Lead',
#  'eleR9Full5x5_Lead',
#  'eleBrem_Lead',
#  'gsfPtSum_Lead',
#  'gsfPtRatio_Lead',
#  'diTrkPt',
#  'gsfDeltaR_Lead',
#  'eleESEnToRawE_Lead']

# %%
# preselection
cut_base = "elePresel_Lead == 1 && eleCalibPt_Lead > 25 && category == 2"
cut_region = "fabs(eleSCEta_Lead) < 1.479"
if iBE == 1:
    cut_region = "fabs(eleSCEta_Lead) >= 1.479 && fabs(eleSCEta_Lead) < 2.5"
# cut_target = "target < 2 && target > 0"

# convert RDataFrame to dataframe
ROOT.EnableImplicitMT(20)
data = ROOT.RDataFrame("miniTree", "../reg_signal.root")\
           .Define("target",    
                #    "diGenEle.Pt()/eleCalibPt_Lead"
                   "dilheEle.Pt()/elePt_Lead"
            )\
           .Define("diTrkPt",       "diTrk.Pt()")\
           .Define("RatioRL",       "(eleEright_Lead - eleEleft_Lead)/(eleEright_Lead + eleEleft_Lead)")\
           .Define("RatioBT",       "(eleEtop_Lead - eleEbottom_Lead)/(eleEtop_Lead + eleEbottom_Lead)")\
           .Define("diTrkPtToRawE", "diTrkPt/eleSCRawEn_Lead")\
           .Define("eleEmaxToRawE", "eleEmax_Lead/eleSCRawEn_Lead")\
           .Define("eleE2ndToRawE", "eleE2nd_Lead/eleSCRawEn_Lead")\
           .Define("eleE2x2ToRawE", "eleE2x2Full5x5_Lead/eleSCRawEn_Lead")\
           .Define("eleE2x5ToRawE", "eleE2x5Full5x5_Lead/eleSCRawEn_Lead")\
           .Define("eleE1x3ToRawE", "eleE1x3Full5x5_Lead/eleSCRawEn_Lead")\
           .Define("genPt",         "diGenEle.Pt()")\
           .Filter("{} && {}".format(cut_base, cut_region))\
           .AsNumpy(columns=features+["instwei", "target", "mcwei", "genwei", "puwei", "genPt", "elePt_Lead", "eleCalibPt_Lead"])

df = pd.DataFrame(data)
df
# Out:
#                rho  nVtx  eleSCEta_Lead  eleSCPhi_Lead  eleSCRawEn_Lead  \
# 0        11.031949    17       2.359343      -2.742695       660.674866
# 1         8.082479    10      -2.076409      -0.926333       178.173630
# 2         7.617640    13      -2.298564       1.612960       272.493713
# 3        11.440117    11      -1.802619      -2.288553       240.401505
# 4         6.018579    12       2.387595       0.857391       197.159912
# ...            ...   ...            ...            ...              ...
# 2928336   9.295928    19       1.643801      -0.130650       351.057648
# 2928337  16.798147    20      -2.419783       3.005272       366.354401
# 2928338  14.033702    21      -2.257422      -2.828263       224.113434
# 2928339  18.800255    25       2.440557       0.185896       369.281128
# 2928340  14.531665    12      -2.132461      -2.082588        94.849228
#
#          eleCalibPt_Lead  eledEtaAtVtx_Lead  eledPhiAtVtx_Lead  \
# 0             134.004562           0.002229          -0.002919
# 1              50.126953          -0.004024           0.009281
# 2              59.588249           0.003165          -0.008887
# 3              93.691475          -0.002860          -0.002689
# 4              39.067402           0.001941          -0.010827
# ...                  ...                ...                ...
# 2928336       142.094330          -0.001457          -0.000002
# 2928337        72.145706          -0.003794           0.005758
# 2928338        52.596188           0.000538           0.000379
# 2928339        66.985298           0.001514          -0.012744
# 2928340        28.041780          -0.000639          -0.029107
#
#          elePtError_Lead  eleHoverE_Lead  ...     diTrkPt  gsfDeltaR_Lead  \
# 0               2.712868        0.008292  ...  105.275536        0.102041
# 1               1.099781        0.018899  ...   53.545704        0.001480
# 2               1.448830        0.007411  ...   66.503342        0.031778
# 3               1.877192        0.007233  ...  393.528625        0.003537
# 4               1.104294        0.011272  ...   18.108044        2.544128
# ...                  ...             ...  ...         ...             ...
# 2928336         2.378369        0.000000  ...  163.217041        1.635336
# 2928337         1.676341        0.002978  ...   56.080902        0.019760
# 2928338         1.159289        0.026649  ...   51.015461        3.598429
# 2928339         1.291834        0.017293  ...   74.974754        0.085166
# 2928340         1.161447        0.009829  ...   11.858337        1.123160
#
#          eleESEnToRawE_Lead   instwei    target     mcwei  genwei     puwei  \
# 0                  0.041839  0.077851  1.009569  0.000025     1.0  1.101410
# 1                  0.099959  0.077851  1.193830  0.000025     1.0  1.101137
# 2                  0.076071  0.077851  0.989657  0.000025     1.0  1.101410
# 3                  0.164880  0.077851  1.022705  0.000025     1.0  1.102826
# 4                  0.033233  0.077851  0.763406  0.000025    -1.0  1.101410
# ...                     ...       ...       ...       ...     ...       ...
# 2928336            0.002068  1.000000  0.936605  0.000192     1.0  1.228101
# 2928337            0.081438  1.000000  1.054268  0.000192     1.0  1.228101
# 2928338            0.077300  1.000000  1.257545  0.000192     1.0  1.011431
# 2928339            0.040436  1.000000  1.031085  0.000192    -1.0  0.962389
# 2928340            0.138532  1.000000  1.355723  0.000192     1.0  0.578890
#
#               genPt  elePt_Lead
# 0        136.297791  134.253448
# 1         53.170948   50.617683
# 2         46.555752   60.757839
# 3         96.904366   95.269096
# 4         37.661922   39.678589
# ...             ...         ...
# 2928336  139.503662  138.847122
# 2928337   75.392586   72.293358
# 2928338   48.167191   52.489368
# 2928339   65.909378   66.771790
# 2928340   23.909855   28.030066
#
# [2928341 rows x 31 columns]

# %%
# make prediction
reader = xgb.Booster()
reader.load_model("{}/XGB_Regression.txt".format(inpath))

# scaler = pkl.load(open("{}/RobustScaler.pkl".format(inpath), "rb"))
# x_values = scaler.transform(df.loc[:, features].values)
x_values = df.loc[:, features].values

preds = reader.predict(xgb.DMatrix(x_values))
preds
# Out:
# array([0.99255955, 1.0092995 , 0.9970873 , ..., 1.0012096 , 0.99644464,
#        1.0105695 ], dtype=float32)

# %%
import matplotlib.pyplot as plt

df["wei"] = df["mcwei"] * df["genwei"] * df["puwei"]
weights = df["wei"].to_numpy()

binContent, binEdge, _ = plt.hist(preds, bins=100, range=(0.8, 1.2), histtype="step", weights=weights, linewidth=2)

# %%
def pltSty(ax, xName="x-axis", yName="y-axis", TitleSize=15, LabelSize=15, TickSize=13, yAuto=True):
    from matplotlib.ticker import AutoLocator, AutoMinorLocator
    ax.set_xlabel(xName, fontsize=LabelSize, loc="right")
    ax.set_ylabel(yName, fontsize=LabelSize, loc="top")
    ax.text(1, 1, "(13 TeV)", horizontalalignment="right", verticalalignment="bottom", transform=ax.transAxes, fontsize=TitleSize)
    ax.text(0, 1, "CMS", horizontalalignment="left", verticalalignment="bottom", transform=ax.transAxes, fontsize=TitleSize * 1.2, fontweight="bold")
    ax.text(TitleSize * 0.009 + 0.025, 1, "Simulation Preliminary", horizontalalignment="left", verticalalignment="bottom", transform=ax.transAxes, fontsize=TitleSize)

    ax.xaxis.set_major_locator(AutoLocator())
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    if (yAuto):
        ax.yaxis.set_major_locator(AutoLocator())
        ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.tick_params(direction="in", length=7, labelsize=TickSize, top=True, right=True)
    ax.tick_params(direction="in", length=4, which="minor", labelsize=TickSize, top=True, right=True)


df["eleHDALRegPt_Lead"] = preds * df["elePt_Lead"]
df[["genPt", "elePt_Lead", "eleHDALRegPt_Lead"]]

fig, ax = plt.subplots(figsize=(7, 6))
pltSty(ax, xName="$p_{T}$ [GeV]", yName="a.u.")
# ax.set_yscale("log")

reg_out = "ECAL Barrel" if (iBE == 0) else "ECAL Endcap"
binContent, binEdge, _ = plt.hist(df["eleHDALRegPt_Lead"], bins=60, range=(25, 150), histtype="step", density=True, color="#008891", linewidth=2.5, label="dedicated regression")
binContent, binEdge, _ = plt.hist(df["elePt_Lead"],        bins=60, range=(25, 150), histtype="step", density=True, color="#EC524B", linewidth=2.5, label="standard regression")
binContent, binEdge, _ = plt.hist(df["genPt"],             bins=60, range=(25, 150), histtype="step", density=True, color="#005792", linewidth=2.5, label="generator")
plt.legend(loc="best", fontsize=14, edgecolor="none", title=reg_out, title_fontsize=16)
plt.tight_layout()
plt.ylim([0, max(binContent)*1.2])
plt.xlim([25, 150])

directory = "../plots/validation/pt_dist"
if not os.path.exists(directory):
    os.makedirs(directory)
plt.savefig("{}/pt_distribution_{}.pdf".format(directory, region), bbox_inches="tight")

# %%
df["resp_XGB"] = df["eleHDALRegPt_Lead"]/df["genPt"]
df["resp_EGM"] = df["elePt_Lead"]/df["genPt"]

genPt = df["genPt"].to_numpy()
resp_XGB = df["resp_XGB"].to_numpy()
resp_EGM = df["resp_EGM"].to_numpy()

bins = 350 if iBE == 0 else 350
hist2D_XGB = ROOT.TH2D("hist2D_XGB", "", 13, 25, 155, bins, 0, 2)
hist2D_EGM = ROOT.TH2D("hist2D_EGM", "", 13, 25, 155, bins, 0, 2)

for i in range(len(resp_XGB)):
    hist2D_XGB.Fill(genPt[i], resp_XGB[i], weights[i])
    hist2D_EGM.Fill(genPt[i], resp_EGM[i], weights[i])
    
hist2D_XGB.Print("all")
# Out:
# TH1.Print Name  = hist2D_XGB, Entries= 2928341, Total sum= 114.991
#  fSumw[0][0]=0, x=20, y=-0.00285714, error=0
#  fSumw[1][0]=0, x=30, y=-0.00285714, error=0
#  fSumw[2][0]=0, x=40, y=-0.00285714, error=0
#  fSumw[3][0]=0, x=50, y=-0.00285714, error=0
#  fSumw[4][0]=0, x=60, y=-0.00285714, error=0
#  fSumw[5][0]=0, x=70, y=-0.00285714, error=0
#  fSumw[6][0]=0, x=80, y=-0.00285714, error=0
#  fSumw[7][0]=0, x=90, y=-0.00285714, error=0
#  fSumw[8][0]=0, x=100, y=-0.00285714, error=0
#  fSumw[9][0]=0, x=110, y=-0.00285714, error=0
#  fSumw[10][0]=0, x=120, y=-0.00285714, error=0
#  fSumw[11][0]=0, x=130, y=-0.00285714, error=0
#  fSumw[12][0]=0, x=140, y=-0.00285714, error=0
#  fSumw[13][0]=0, x=150, y=-0.00285714, error=0
#  fSumw[14][0]=0, x=160, y=-0.00285714, error=0
#  fSumw[0][1]=0, x=20, y=0.00285714, error=0
#  fSumw[1][1]=0, x=30, y=0.00285714, error=0
#  fSumw[2][1]=0, x=40, y=0.00285714, error=0
#  fSumw[3][1]=0, x=50, y=0.00285714, error=0
#  fSumw[4][1]=0, x=60, y=0.00285714, error=0
#  fSumw[5][1]=0, x=70, y=0.00285714, error=0
#  fSumw[6][1]=0, x=80, y=0.00285714, error=0
#  fSumw[7][1]=0, x=90, y=0.00285714, error=0
#  fSumw[8][1]=0, x=100, y=0.00285714, error=0
#  fSumw[9][1]=0, x=110, y=0.00285714, error=0
#  fSumw[10][1]=0, x=120, y=0.00285714, error=0
#  fSumw[11][1]=0, x=130, y=0.00285714, error=0
#  fSumw[12][1]=0, x=140, y=0.00285714, error=0
#  fSumw[13][1]=0, x=150, y=0.00285714, error=0
#  fSumw[14][1]=0, x=160, y=0.00285714, error=0
#  fSumw[0][2]=0, x=20, y=0.00857143, error=0
#  fSumw[1][2]=0, x=30, y=0.00857143, error=0
#  fSumw[2][2]=0, x=40, y=0.00857143, error=0
#  fSumw[3][2]=0, x=50, y=0.00857143, error=0
#  fSumw[4][2]=0, x=60, y=0.00857143, error=0
#  fSumw[5][2]=0, x=70, y=0.00857143, error=0
#  fSumw[6][2]=0, x=80, y=0.00857143, error=0
#  fSumw[7][2]=0, x=90, y=0.00857143, error=0
#  fSumw[8][2]=0, x=100, y=0.00857143, error=0
#  fSumw[9][2]=0, x=110, y=0.00857143, error=0
#  fSumw[10][2]=0, x=120, y=0.00857143, error=0
#  fSumw[11][2]=0, x=130, y=0.00857143, error=0
#  fSumw[12][2]=0, x=140, y=0.00857143, error=0
#  fSumw[13][2]=0, x=150, y=0.00857143, error=0
#  fSumw[14][2]=0, x=160, y=0.00857143, error=0
#  fSumw[0][3]=0, x=20, y=0.0142857, error=0
#  fSumw[1][3]=0, x=30, y=0.0142857, error=0
#  fSumw[2][3]=0, x=40, y=0.0142857, error=0
#  fSumw[3][3]=0, x=50, y=0.0142857, error=0
#  fSumw[4][3]=0, x=60, y=0.0142857, error=0
#  fSumw[5][3]=0, x=70, y=0.0142857, error=0
#  fSumw[6][3]=0, x=80, y=0.0142857, error=0
#  fSumw[7][3]=0, x=90, y=0.0142857, error=0
#  fSumw[8][3]=0, x=100, y=0.0142857, error=0
#  fSumw[9][3]=0, x=110, y=0.0142857, error=0
#  fSumw[10][3]=0, x=120, y=0.0142857, error=0
#  fSumw[11][3]=0, x=130, y=0.0142857, error=0
#  fSumw[12][3]=0, x=140, y=0.0142857, error=0
#  fSumw[13][3]=0, x=150, y=0.0142857, error=0
#  fSumw[14][3]=0, x=160, y=0.0142857, error=0
#  fSumw[0][4]=0, x=20, y=0.02, error=0
#  fSumw[1][4]=0, x=30, y=0.02, error=0
#  fSumw[2][4]=0, x=40, y=0.02, error=0
#  fSumw[3][4]=0, x=50, y=0.02, error=0
#  fSumw[4][4]=0, x=60, y=0.02, error=0
#  fSumw[5][4]=0, x=70, y=0.02, error=0
#  fSumw[6][4]=0, x=80, y=0.02, error=0
#  fSumw[7][4]=0, x=90, y=0.02, error=0
#  fSumw[8][4]=0, x=100, y=0.02, error=0
#  fSumw[9][4]=0, x=110, y=0.02, error=0
#  fSumw[10][4]=0, x=120, y=0.02, error=0
#  fSumw[11][4]=0, x=130, y=0.02, error=0
#  fSumw[12][4]=0, x=140, y=0.02, error=0
#  fSumw[13][4]=0, x=150, y=0.02, error=0
#  fSumw[14][4]=0, x=160, y=0.02, error=0
#  fSumw[0][5]=0, x=20, y=0.0257143, error=0
#  fSumw[1][5]=0, x=30, y=0.0257143, error=0
#  fSumw[2][5]=0, x=40, y=0.0257143, error=0
#  fSumw[3][5]=0, x=50, y=0.0257143, error=0
#  fSumw[4][5]=0, x=60, y=0.0257143, error=0
#  fSumw[5][5]=0, x=70, y=0.0257143, error=0
#  fSumw[6][5]=0, x=80, y=0.0257143, error=0
#  fSumw[7][5]=0, x=90, y=0.0257143, error=0
#  fSumw[8][5]=0, x=100, y=0.0257143, error=0
#  fSumw[9][5]=0, x=110, y=0.0257143, error=0
#  fSumw[10][5]=0, x=120, y=0.0257143, error=0
#  fSumw[11][5]=0, x=130, y=0.0257143, error=0
#  fSumw[12][5]=0, x=140, y=0.0257143, error=0
#  fSumw[13][5]=0, x=150, y=0.0257143, error=0
#  fSumw[14][5]=0, x=160, y=0.0257143, error=0
#  fSumw[0][6]=0, x=20, y=0.0314286, error=0
#  fSumw[1][6]=0, x=30, y=0.0314286, error=0
#  fSumw[2][6]=0, x=40, y=0.0314286, error=0
#  fSumw[3][6]=0, x=50, y=0.0314286, error=0
#  fSumw[4][6]=0, x=60, y=0.0314286, error=0
#  fSumw[5][6]=0, x=70, y=0.0314286, error=0
#  fSumw[6][6]=0, x=80, y=0.0314286, error=0
#  fSumw[7][6]=0, x=90, y=0.0314286, error=0
#  fSumw[8][6]=0, x=100, y=0.0314286, error=0
#  fSumw[9][6]=0, x=110, y=0.0314286, error=0
#  fSumw[10][6]=0, x=120, y=0.0314286, error=0
#  fSumw[11][6]=0, x=130, y=0.0314286, error=0
#  fSumw[12][6]=0, x=140, y=0.0314286, error=0
#  fSumw[13][6]=0, x=150, y=0.0314286, error=0
#  fSumw[14][6]=0, x=160, y=0.0314286, error=0
#  fSumw[0][7]=0, x=20, y=0.0371429, error=0
#  fSumw[1][7]=0, x=30, y=0.0371429, error=0
#  fSumw[2][7]=0, x=40, y=0.0371429, error=0
#  fSumw[3][7]=0, x=50, y=0.0371429, error=0
#  fSumw[4][7]=0, x=60, y=0.0371429, error=0
#  fSumw[5][7]=0, x=70, y=0.0371429, error=0
#  fSumw[6][7]=0, x=80, y=0.0371429, error=0
#  fSumw[7][7]=0, x=90, y=0.0371429, error=0
#  fSumw[8][7]=0, x=100, y=0.0371429, error=0
#  fSumw[9][7]=0, x=110, y=0.0371429, error=0
#  fSumw[10][7]=0, x=120, y=0.0371429, error=0
#  fSumw[11][7]=0, x=130, y=0.0371429, error=0
#  fSumw[12][7]=0, x=140, y=0.0371429, error=0
#  fSumw[13][7]=0, x=150, y=0.0371429, error=0
#  fSumw[14][7]=0, x=160, y=0.0371429, error=0
#  fSumw[0][8]=0, x=20, y=0.0428571, error=0
#  fSumw[1][8]=0, x=30, y=0.0428571, error=0
#  fSumw[2][8]=0, x=40, y=0.0428571, error=0
#  fSumw[3][8]=0, x=50, y=0.0428571, error=0
#  fSumw[4][8]=0, x=60, y=0.0428571, error=0
#  fSumw[5][8]=0, x=70, y=0.0428571, error=0
#  fSumw[6][8]=0, x=80, y=0.0428571, error=0
#  fSumw[7][8]=0, x=90, y=0.0428571, error=0
#  fSumw[8][8]=0, x=100, y=0.0428571, error=0
#  fSumw[9][8]=0, x=110, y=0.0428571, error=0
#  fSumw[10][8]=0, x=120, y=0.0428571, error=0
#  fSumw[11][8]=0, x=130, y=0.0428571, error=0
#  fSumw[12][8]=0, x=140, y=0.0428571, error=0
#  fSumw[13][8]=0, x=150, y=0.0428571, error=0
#  fSumw[14][8]=0, x=160, y=0.0428571, error=0
#  fSumw[0][9]=0, x=20, y=0.0485714, error=0
#  fSumw[1][9]=0, x=30, y=0.0485714, error=0
#  fSumw[2][9]=0, x=40, y=0.0485714, error=0
#  fSumw[3][9]=0, x=50, y=0.0485714, error=0
#  fSumw[4][9]=0, x=60, y=0.0485714, error=0
#  fSumw[5][9]=0, x=70, y=0.0485714, error=0
#  fSumw[6][9]=0, x=80, y=0.0485714, error=0
#  fSumw[7][9]=0, x=90, y=0.0485714, error=0
#  fSumw[8][9]=0, x=100, y=0.0485714, error=0
#  fSumw[9][9]=0, x=110, y=0.0485714, error=0
#  fSumw[10][9]=0, x=120, y=0.0485714, error=0
#  fSumw[11][9]=0, x=130, y=0.0485714, error=0
#  fSumw[12][9]=0, x=140, y=0.0485714, error=0
#  fSumw[13][9]=0, x=150, y=0.0485714, error=0
#  fSumw[14][9]=0, x=160, y=0.0485714, error=0
#  fSumw[0][10]=0, x=20, y=0.0542857, error=0
#  fSumw[1][10]=0, x=30, y=0.0542857, error=0
#  fSumw[2][10]=0, x=40, y=0.0542857, error=0
#  fSumw[3][10]=0, x=50, y=0.0542857, error=0
#  fSumw[4][10]=0, x=60, y=0.0542857, error=0
#  fSumw[5][10]=0, x=70, y=0.0542857, error=0
#  fSumw[6][10]=0, x=80, y=0.0542857, error=0
#  fSumw[7][10]=0, x=90, y=0.0542857, error=0
#  fSumw[8][10]=0, x=100, y=0.0542857, error=0
#  fSumw[9][10]=0, x=110, y=0.0542857, error=0
#  fSumw[10][10]=0, x=120, y=0.0542857, error=0
#  fSumw[11][10]=0, x=130, y=0.0542857, error=0
#  fSumw[12][10]=0, x=140, y=0.0542857, error=0
#  fSumw[13][10]=0, x=150, y=0.0542857, error=0
#  fSumw[14][10]=0, x=160, y=0.0542857, error=0
#  fSumw[0][11]=0, x=20, y=0.06, error=0
#  fSumw[1][11]=0, x=30, y=0.06, error=0
#  fSumw[2][11]=0, x=40, y=0.06, error=0
#  fSumw[3][11]=0, x=50, y=0.06, error=0
#  fSumw[4][11]=0, x=60, y=0.06, error=0
#  fSumw[5][11]=0, x=70, y=0.06, error=0
#  fSumw[6][11]=0, x=80, y=0.06, error=0
#  fSumw[7][11]=0, x=90, y=0.06, error=0
#  fSumw[8][11]=0, x=100, y=0.06, error=0
#  fSumw[9][11]=0, x=110, y=0.06, error=0
#  fSumw[10][11]=0, x=120, y=0.06, error=0
#  fSumw[11][11]=0, x=130, y=0.06, error=0
#  fSumw[12][11]=0, x=140, y=0.06, error=0
#  fSumw[13][11]=0, x=150, y=0.06, error=0
#  fSumw[14][11]=0, x=160, y=0.06, error=0
#  fSumw[0][12]=0, x=20, y=0.0657143, error=0
#  fSumw[1][12]=0, x=30, y=0.0657143, error=0
#  fSumw[2][12]=0, x=40, y=0.0657143, error=0
#  fSumw[3][12]=0, x=50, y=0.0657143, error=0
#  fSumw[4][12]=0, x=60, y=0.0657143, error=0
#  fSumw[5][12]=0, x=70, y=0.0657143, error=0
#  fSumw[6][12]=0, x=80, y=0.0657143, error=0
#  fSumw[7][12]=0, x=90, y=0.0657143, error=0
#  fSumw[8][12]=0, x=100, y=0.0657143, error=0
#  fSumw[9][12]=0, x=110, y=0.0657143, error=0
#  fSumw[10][12]=0, x=120, y=0.0657143, error=0
#  fSumw[11][12]=0, x=130, y=0.0657143, error=0
#  fSumw[12][12]=0, x=140, y=0.0657143, error=0
#  fSumw[13][12]=0, x=150, y=0.0657143, error=0
#  fSumw[14][12]=0, x=160, y=0.0657143, error=0
#  fSumw[0][13]=0, x=20, y=0.0714286, error=0
#  fSumw[1][13]=0, x=30, y=0.0714286, error=0
#  fSumw[2][13]=0, x=40, y=0.0714286, error=0
#  fSumw[3][13]=0, x=50, y=0.0714286, error=0
#  fSumw[4][13]=0, x=60, y=0.0714286, error=0
#  fSumw[5][13]=0, x=70, y=0.0714286, error=0
#  fSumw[6][13]=0, x=80, y=0.0714286, error=0
#  fSumw[7][13]=0, x=90, y=0.0714286, error=0
#  fSumw[8][13]=0, x=100, y=0.0714286, error=0
#  fSumw[9][13]=0, x=110, y=0.0714286, error=0
#  fSumw[10][13]=0, x=120, y=0.0714286, error=0
#  fSumw[11][13]=0, x=130, y=0.0714286, error=0
#  fSumw[12][13]=0, x=140, y=0.0714286, error=0
#  fSumw[13][13]=0, x=150, y=0.0714286, error=0
#  fSumw[14][13]=0, x=160, y=0.0714286, error=0
#  fSumw[0][14]=0, x=20, y=0.0771429, error=0
#  fSumw[1][14]=0, x=30, y=0.0771429, error=0
#  fSumw[2][14]=0, x=40, y=0.0771429, error=0
#  fSumw[3][14]=0, x=50, y=0.0771429, error=0
#  fSumw[4][14]=0, x=60, y=0.0771429, error=0
#  fSumw[5][14]=0, x=70, y=0.0771429, error=0
#  fSumw[6][14]=0, x=80, y=0.0771429, error=0
#  fSumw[7][14]=0, x=90, y=0.0771429, error=0
#  fSumw[8][14]=0, x=100, y=0.0771429, error=0
#  fSumw[9][14]=0, x=110, y=0.0771429, error=0
#  fSumw[10][14]=0, x=120, y=0.0771429, error=0
#  fSumw[11][14]=0, x=130, y=0.0771429, error=0
#  fSumw[12][14]=0, x=140, y=0.0771429, error=0
#  fSumw[13][14]=0, x=150, y=0.0771429, error=0
#  fSumw[14][14]=0, x=160, y=0.0771429, error=0
#  fSumw[0][15]=0, x=20, y=0.0828571, error=0
#  fSumw[1][15]=0, x=30, y=0.0828571, error=0
#  fSumw[2][15]=0, x=40, y=0.0828571, error=0
#  fSumw[3][15]=0, x=50, y=0.0828571, error=0
#  fSumw[4][15]=0, x=60, y=0.0828571, error=0
#  fSumw[5][15]=0, x=70, y=0.0828571, error=0
#  fSumw[6][15]=0, x=80, y=0.0828571, error=0
#  fSumw[7][15]=0, x=90, y=0.0828571, error=0
#  fSumw[8][15]=0, x=100, y=0.0828571, error=0
#  fSumw[9][15]=0, x=110, y=0.0828571, error=0
#  fSumw[10][15]=0, x=120, y=0.0828571, error=0
#  fSumw[11][15]=0, x=130, y=0.0828571, error=0
#  fSumw[12][15]=0, x=140, y=0.0828571, error=0
#  fSumw[13][15]=0, x=150, y=0.0828571, error=0
#  fSumw[14][15]=0, x=160, y=0.0828571, error=0
#  fSumw[0][16]=0, x=20, y=0.0885714, error=0
#  fSumw[1][16]=0, x=30, y=0.0885714, error=0
#  fSumw[2][16]=0, x=40, y=0.0885714, error=0
#  fSumw[3][16]=0, x=50, y=0.0885714, error=0
#  fSumw[4][16]=0, x=60, y=0.0885714, error=0
#  fSumw[5][16]=0, x=70, y=0.0885714, error=0
#  fSumw[6][16]=0, x=80, y=0.0885714, error=0
#  fSumw[7][16]=0, x=90, y=0.0885714, error=0
#  fSumw[8][16]=0, x=100, y=0.0885714, error=0
#  fSumw[9][16]=0, x=110, y=0.0885714, error=0
#  fSumw[10][16]=0, x=120, y=0.0885714, error=0
#  fSumw[11][16]=0, x=130, y=0.0885714, error=0
#  fSumw[12][16]=0, x=140, y=0.0885714, error=0
#  fSumw[13][16]=0, x=150, y=0.0885714, error=0
#  fSumw[14][16]=0, x=160, y=0.0885714, error=0
#  fSumw[0][17]=0, x=20, y=0.0942857, error=0
#  fSumw[1][17]=0, x=30, y=0.0942857, error=0
#  fSumw[2][17]=0, x=40, y=0.0942857, error=0
#  fSumw[3][17]=0, x=50, y=0.0942857, error=0
#  fSumw[4][17]=0, x=60, y=0.0942857, error=0
#  fSumw[5][17]=0, x=70, y=0.0942857, error=0
#  fSumw[6][17]=0, x=80, y=0.0942857, error=0
#  fSumw[7][17]=0, x=90, y=0.0942857, error=0
#  fSumw[8][17]=0, x=100, y=0.0942857, error=0
#  fSumw[9][17]=4.09406e-05, x=110, y=0.0942857, error=4.09406e-05
#  fSumw[10][17]=0, x=120, y=0.0942857, error=0
#  fSumw[11][17]=0, x=130, y=0.0942857, error=0
#  fSumw[12][17]=0, x=140, y=0.0942857, error=0
#  fSumw[13][17]=0, x=150, y=0.0942857, error=0
#  fSumw[14][17]=0, x=160, y=0.0942857, error=0
#  fSumw[0][18]=0, x=20, y=0.1, error=0
#  fSumw[1][18]=0, x=30, y=0.1, error=0
#  fSumw[2][18]=0, x=40, y=0.1, error=0
#  fSumw[3][18]=0, x=50, y=0.1, error=0
#  fSumw[4][18]=0, x=60, y=0.1, error=0
#  fSumw[5][18]=0, x=70, y=0.1, error=0
#  fSumw[6][18]=0, x=80, y=0.1, error=0
#  fSumw[7][18]=0, x=90, y=0.1, error=0
#  fSumw[8][18]=0, x=100, y=0.1, error=0
#  fSumw[9][18]=0, x=110, y=0.1, error=0
#  fSumw[10][18]=0, x=120, y=0.1, error=0
#  fSumw[11][18]=0, x=130, y=0.1, error=0
#  fSumw[12][18]=0, x=140, y=0.1, error=0
#  fSumw[13][18]=0, x=150, y=0.1, error=0
#  fSumw[14][18]=0, x=160, y=0.1, error=0
#  fSumw[0][19]=0, x=20, y=0.105714, error=0
#  fSumw[1][19]=0, x=30, y=0.105714, error=0
#  fSumw[2][19]=0, x=40, y=0.105714, error=0
#  fSumw[3][19]=0, x=50, y=0.105714, error=0
#  fSumw[4][19]=0, x=60, y=0.105714, error=0
#  fSumw[5][19]=0, x=70, y=0.105714, error=0
#  fSumw[6][19]=0, x=80, y=0.105714, error=0
#  fSumw[7][19]=0, x=90, y=0.105714, error=0
#  fSumw[8][19]=0, x=100, y=0.105714, error=0
#  fSumw[9][19]=0, x=110, y=0.105714, error=0
#  fSumw[10][19]=0, x=120, y=0.105714, error=0
#  fSumw[11][19]=0, x=130, y=0.105714, error=0
#  fSumw[12][19]=0, x=140, y=0.105714, error=0
#  fSumw[13][19]=0, x=150, y=0.105714, error=0
#  fSumw[14][19]=0, x=160, y=0.105714, error=0
#  fSumw[0][20]=0, x=20, y=0.111429, error=0
#  fSumw[1][20]=0, x=30, y=0.111429, error=0
#  fSumw[2][20]=0, x=40, y=0.111429, error=0
#  fSumw[3][20]=0, x=50, y=0.111429, error=0
#  fSumw[4][20]=0, x=60, y=0.111429, error=0
#  fSumw[5][20]=0, x=70, y=0.111429, error=0
#  fSumw[6][20]=0, x=80, y=0.111429, error=0
#  fSumw[7][20]=0, x=90, y=0.111429, error=0
#  fSumw[8][20]=0, x=100, y=0.111429, error=0
#  fSumw[9][20]=0, x=110, y=0.111429, error=0
#  fSumw[10][20]=0, x=120, y=0.111429, error=0
#  fSumw[11][20]=0, x=130, y=0.111429, error=0
#  fSumw[12][20]=0, x=140, y=0.111429, error=0
#  fSumw[13][20]=0, x=150, y=0.111429, error=0
#  fSumw[14][20]=0, x=160, y=0.111429, error=0
#  fSumw[0][21]=0, x=20, y=0.117143, error=0
#  fSumw[1][21]=0, x=30, y=0.117143, error=0
#  fSumw[2][21]=0, x=40, y=0.117143, error=0
#  fSumw[3][21]=0, x=50, y=0.117143, error=0
#  fSumw[4][21]=0, x=60, y=0.117143, error=0
#  fSumw[5][21]=0, x=70, y=0.117143, error=0
#  fSumw[6][21]=0, x=80, y=0.117143, error=0
#  fSumw[7][21]=0, x=90, y=0.117143, error=0
#  fSumw[8][21]=0, x=100, y=0.117143, error=0
#  fSumw[9][21]=0, x=110, y=0.117143, error=0
#  fSumw[10][21]=0, x=120, y=0.117143, error=0
#  fSumw[11][21]=0, x=130, y=0.117143, error=0
#  fSumw[12][21]=0, x=140, y=0.117143, error=0
#  fSumw[13][21]=0, x=150, y=0.117143, error=0
#  fSumw[14][21]=0, x=160, y=0.117143, error=0
#  fSumw[0][22]=0, x=20, y=0.122857, error=0
#  fSumw[1][22]=0, x=30, y=0.122857, error=0
#  fSumw[2][22]=0, x=40, y=0.122857, error=0
#  fSumw[3][22]=0, x=50, y=0.122857, error=0
#  fSumw[4][22]=0, x=60, y=0.122857, error=0
#  fSumw[5][22]=0, x=70, y=0.122857, error=0
#  fSumw[6][22]=0, x=80, y=0.122857, error=0
#  fSumw[7][22]=0, x=90, y=0.122857, error=0
#  fSumw[8][22]=0, x=100, y=0.122857, error=0
#  fSumw[9][22]=0, x=110, y=0.122857, error=0
#  fSumw[10][22]=0, x=120, y=0.122857, error=0
#  fSumw[11][22]=0, x=130, y=0.122857, error=0
#  fSumw[12][22]=0, x=140, y=0.122857, error=0
#  fSumw[13][22]=0, x=150, y=0.122857, error=0
#  fSumw[14][22]=0, x=160, y=0.122857, error=0
#  fSumw[0][23]=0, x=20, y=0.128571, error=0
#  fSumw[1][23]=0, x=30, y=0.128571, error=0
#  fSumw[2][23]=0, x=40, y=0.128571, error=0
#  fSumw[3][23]=0, x=50, y=0.128571, error=0
#  fSumw[4][23]=0, x=60, y=0.128571, error=0
#  fSumw[5][23]=0, x=70, y=0.128571, error=0
#  fSumw[6][23]=0, x=80, y=0.128571, error=0
#  fSumw[7][23]=0, x=90, y=0.128571, error=0
#  fSumw[8][23]=0, x=100, y=0.128571, error=0
#  fSumw[9][23]=0, x=110, y=0.128571, error=0
#  fSumw[10][23]=0, x=120, y=0.128571, error=0
#  fSumw[11][23]=0, x=130, y=0.128571, error=0
#  fSumw[12][23]=0, x=140, y=0.128571, error=0
#  fSumw[13][23]=0, x=150, y=0.128571, error=0
#  fSumw[14][23]=7.64151e-06, x=160, y=0.128571, error=7.64151e-06
#  fSumw[0][24]=0, x=20, y=0.134286, error=0
#  fSumw[1][24]=0, x=30, y=0.134286, error=0
#  fSumw[2][24]=0, x=40, y=0.134286, error=0
#  fSumw[3][24]=0, x=50, y=0.134286, error=0
#  fSumw[4][24]=0, x=60, y=0.134286, error=0
#  fSumw[5][24]=0, x=70, y=0.134286, error=0
#  fSumw[6][24]=0, x=80, y=0.134286, error=0
#  fSumw[7][24]=0, x=90, y=0.134286, error=0
#  fSumw[8][24]=0, x=100, y=0.134286, error=0
#  fSumw[9][24]=0, x=110, y=0.134286, error=0
#  fSumw[10][24]=0, x=120, y=0.134286, error=0
#  fSumw[11][24]=0, x=130, y=0.134286, error=0
#  fSumw[12][24]=0, x=140, y=0.134286, error=0
#  fSumw[13][24]=0, x=150, y=0.134286, error=0
#  fSumw[14][24]=0, x=160, y=0.134286, error=0
#  fSumw[0][25]=0, x=20, y=0.14, error=0
#  fSumw[1][25]=0, x=30, y=0.14, error=0
#  fSumw[2][25]=0, x=40, y=0.14, error=0
#  fSumw[3][25]=0, x=50, y=0.14, error=0
#  fSumw[4][25]=0, x=60, y=0.14, error=0
#  fSumw[5][25]=0, x=70, y=0.14, error=0
#  fSumw[6][25]=0, x=80, y=0.14, error=0
#  fSumw[7][25]=0, x=90, y=0.14, error=0
#  fSumw[8][25]=0, x=100, y=0.14, error=0
#  fSumw[9][25]=0, x=110, y=0.14, error=0
#  fSumw[10][25]=0, x=120, y=0.14, error=0
#  fSumw[11][25]=0, x=130, y=0.14, error=0
#  fSumw[12][25]=0, x=140, y=0.14, error=0
#  fSumw[13][25]=0, x=150, y=0.14, error=0
#  fSumw[14][25]=2.22159e-05, x=160, y=0.14, error=2.22159e-05
#  fSumw[0][26]=0, x=20, y=0.145714, error=0
#  fSumw[1][26]=0, x=30, y=0.145714, error=0
#  fSumw[2][26]=0, x=40, y=0.145714, error=0
#  fSumw[3][26]=0, x=50, y=0.145714, error=0
#  fSumw[4][26]=0, x=60, y=0.145714, error=0
#  fSumw[5][26]=0, x=70, y=0.145714, error=0
#  fSumw[6][26]=0, x=80, y=0.145714, error=0
#  fSumw[7][26]=0, x=90, y=0.145714, error=0
#  fSumw[8][26]=0, x=100, y=0.145714, error=0
#  fSumw[9][26]=0, x=110, y=0.145714, error=0
#  fSumw[10][26]=0, x=120, y=0.145714, error=0
#  fSumw[11][26]=0, x=130, y=0.145714, error=0
#  fSumw[12][26]=0, x=140, y=0.145714, error=0
#  fSumw[13][26]=0, x=150, y=0.145714, error=0
#  fSumw[14][26]=4.01535e-07, x=160, y=0.145714, error=1.5351e-05
#  fSumw[0][27]=0, x=20, y=0.151429, error=0
#  fSumw[1][27]=0, x=30, y=0.151429, error=0
#  fSumw[2][27]=0, x=40, y=0.151429, error=0
#  fSumw[3][27]=0, x=50, y=0.151429, error=0
#  fSumw[4][27]=0, x=60, y=0.151429, error=0
#  fSumw[5][27]=0, x=70, y=0.151429, error=0
#  fSumw[6][27]=0, x=80, y=0.151429, error=0
#  fSumw[7][27]=0, x=90, y=0.151429, error=0
#  fSumw[8][27]=0, x=100, y=0.151429, error=0
#  fSumw[9][27]=0, x=110, y=0.151429, error=0
#  fSumw[10][27]=0, x=120, y=0.151429, error=0
#  fSumw[11][27]=0, x=130, y=0.151429, error=0
#  fSumw[12][27]=0, x=140, y=0.151429, error=0
#  fSumw[13][27]=0, x=150, y=0.151429, error=0
#  fSumw[14][27]=-3.22405e-05, x=160, y=0.151429, error=4.37624e-05
#  fSumw[0][28]=0, x=20, y=0.157143, error=0
#  fSumw[1][28]=0, x=30, y=0.157143, error=0
#  fSumw[2][28]=0, x=40, y=0.157143, error=0
#  fSumw[3][28]=0, x=50, y=0.157143, error=0
#  fSumw[4][28]=0, x=60, y=0.157143, error=0
#  fSumw[5][28]=0, x=70, y=0.157143, error=0
#  fSumw[6][28]=0, x=80, y=0.157143, error=0
#  fSumw[7][28]=0, x=90, y=0.157143, error=0
#  fSumw[8][28]=0, x=100, y=0.157143, error=0
#  fSumw[9][28]=0, x=110, y=0.157143, error=0
#  fSumw[10][28]=0, x=120, y=0.157143, error=0
#  fSumw[11][28]=0, x=130, y=0.157143, error=0
#  fSumw[12][28]=0, x=140, y=0.157143, error=0
#  fSumw[13][28]=0, x=150, y=0.157143, error=0
#  fSumw[14][28]=6.77045e-05, x=160, y=0.157143, error=4.50287e-05
#  fSumw[0][29]=0, x=20, y=0.162857, error=0
#  fSumw[1][29]=0, x=30, y=0.162857, error=0
#  fSumw[2][29]=0, x=40, y=0.162857, error=0
#  fSumw[3][29]=0, x=50, y=0.162857, error=0
#  fSumw[4][29]=0, x=60, y=0.162857, error=0
#  fSumw[5][29]=0, x=70, y=0.162857, error=0
#  fSumw[6][29]=0, x=80, y=0.162857, error=0
#  fSumw[7][29]=0, x=90, y=0.162857, error=0
#  fSumw[8][29]=0, x=100, y=0.162857, error=0
#  fSumw[9][29]=0, x=110, y=0.162857, error=0
#  fSumw[10][29]=0, x=120, y=0.162857, error=0
#  fSumw[11][29]=0, x=130, y=0.162857, error=0
#  fSumw[12][29]=0, x=140, y=0.162857, error=0
#  fSumw[13][29]=0, x=150, y=0.162857, error=0
#  fSumw[14][29]=5.36971e-06, x=160, y=0.162857, error=5.36971e-06
#  fSumw[0][30]=0, x=20, y=0.168571, error=0
#  fSumw[1][30]=0, x=30, y=0.168571, error=0
#  fSumw[2][30]=0, x=40, y=0.168571, error=0
#  fSumw[3][30]=0, x=50, y=0.168571, error=0
#  fSumw[4][30]=0, x=60, y=0.168571, error=0
#  fSumw[5][30]=0, x=70, y=0.168571, error=0
#  fSumw[6][30]=0, x=80, y=0.168571, error=0
#  fSumw[7][30]=0, x=90, y=0.168571, error=0
#  fSumw[8][30]=0, x=100, y=0.168571, error=0
#  fSumw[9][30]=0, x=110, y=0.168571, error=0
#  fSumw[10][30]=0, x=120, y=0.168571, error=0
#  fSumw[11][30]=0, x=130, y=0.168571, error=0
#  fSumw[12][30]=0, x=140, y=0.168571, error=0
#  fSumw[13][30]=0, x=150, y=0.168571, error=0
#  fSumw[14][30]=4.39508e-06, x=160, y=0.168571, error=1.40594e-05
#  fSumw[0][31]=0, x=20, y=0.174286, error=0
#  fSumw[1][31]=0, x=30, y=0.174286, error=0
#  fSumw[2][31]=0, x=40, y=0.174286, error=0
#  fSumw[3][31]=0, x=50, y=0.174286, error=0
#  fSumw[4][31]=0, x=60, y=0.174286, error=0
#  fSumw[5][31]=0, x=70, y=0.174286, error=0
#  fSumw[6][31]=0, x=80, y=0.174286, error=0
#  fSumw[7][31]=0, x=90, y=0.174286, error=0
#  fSumw[8][31]=0, x=100, y=0.174286, error=0
#  fSumw[9][31]=0, x=110, y=0.174286, error=0
#  fSumw[10][31]=0, x=120, y=0.174286, error=0
#  fSumw[11][31]=0, x=130, y=0.174286, error=0
#  fSumw[12][31]=0, x=140, y=0.174286, error=0
#  fSumw[13][31]=0, x=150, y=0.174286, error=0
#  fSumw[14][31]=2.50041e-05, x=160, y=0.174286, error=2.50041e-05
#  fSumw[0][32]=0, x=20, y=0.18, error=0
#  fSumw[1][32]=0, x=30, y=0.18, error=0
#  fSumw[2][32]=0, x=40, y=0.18, error=0
#  fSumw[3][32]=0, x=50, y=0.18, error=0
#  fSumw[4][32]=0, x=60, y=0.18, error=0
#  fSumw[5][32]=0, x=70, y=0.18, error=0
#  fSumw[6][32]=0, x=80, y=0.18, error=0
#  fSumw[7][32]=0, x=90, y=0.18, error=0
#  fSumw[8][32]=0, x=100, y=0.18, error=0
#  fSumw[9][32]=0, x=110, y=0.18, error=0
#  fSumw[10][32]=0, x=120, y=0.18, error=0
#  fSumw[11][32]=5.52677e-06, x=130, y=0.18, error=5.52677e-06
#  fSumw[12][32]=0, x=140, y=0.18, error=0
#  fSumw[13][32]=1.12736e-05, x=150, y=0.18, error=1.12736e-05
#  fSumw[14][32]=2.07242e-05, x=160, y=0.18, error=1.4659e-05
#  fSumw[0][33]=0, x=20, y=0.185714, error=0
#  fSumw[1][33]=0, x=30, y=0.185714, error=0
#  fSumw[2][33]=0, x=40, y=0.185714, error=0
#  fSumw[3][33]=0, x=50, y=0.185714, error=0
#  fSumw[4][33]=0, x=60, y=0.185714, error=0
#  fSumw[5][33]=0, x=70, y=0.185714, error=0
#  fSumw[6][33]=0, x=80, y=0.185714, error=0
#  fSumw[7][33]=0, x=90, y=0.185714, error=0
#  fSumw[8][33]=0, x=100, y=0.185714, error=0
#  fSumw[9][33]=0, x=110, y=0.185714, error=0
#  fSumw[10][33]=0, x=120, y=0.185714, error=0
#  fSumw[11][33]=0, x=130, y=0.185714, error=0
#  fSumw[12][33]=0, x=140, y=0.185714, error=0
#  fSumw[13][33]=2.14531e-05, x=150, y=0.185714, error=2.14531e-05
#  fSumw[14][33]=4.34452e-05, x=160, y=0.185714, error=3.6391e-05
#  fSumw[0][34]=0, x=20, y=0.191429, error=0
#  fSumw[1][34]=0, x=30, y=0.191429, error=0
#  fSumw[2][34]=0, x=40, y=0.191429, error=0
#  fSumw[3][34]=0, x=50, y=0.191429, error=0
#  fSumw[4][34]=0, x=60, y=0.191429, error=0
#  fSumw[5][34]=0, x=70, y=0.191429, error=0
#  fSumw[6][34]=0, x=80, y=0.191429, error=0
#  fSumw[7][34]=-8.09596e-06, x=90, y=0.191429, error=8.09596e-06
#  fSumw[8][34]=0, x=100, y=0.191429, error=0
#  fSumw[9][34]=0, x=110, y=0.191429, error=0
#  fSumw[10][34]=0, x=120, y=0.191429, error=0
#  fSumw[11][34]=0, x=130, y=0.191429, error=0
#  fSumw[12][34]=8.57141e-06, x=140, y=0.191429, error=8.57141e-06
#  fSumw[13][34]=0, x=150, y=0.191429, error=0
#  fSumw[14][34]=1.24007e-05, x=160, y=0.191429, error=2.56841e-05
#  fSumw[0][35]=0, x=20, y=0.197143, error=0
#  fSumw[1][35]=0, x=30, y=0.197143, error=0
#  fSumw[2][35]=0, x=40, y=0.197143, error=0
#  fSumw[3][35]=0, x=50, y=0.197143, error=0
#  fSumw[4][35]=0, x=60, y=0.197143, error=0
#  fSumw[5][35]=0, x=70, y=0.197143, error=0
#  fSumw[6][35]=0, x=80, y=0.197143, error=0
#  fSumw[7][35]=0, x=90, y=0.197143, error=0
#  fSumw[8][35]=0, x=100, y=0.197143, error=0
#  fSumw[9][35]=0, x=110, y=0.197143, error=0
#  fSumw[10][35]=0, x=120, y=0.197143, error=0
#  fSumw[11][35]=1.2358e-05, x=130, y=0.197143, error=1.2358e-05
#  fSumw[12][35]=0, x=140, y=0.197143, error=0
#  fSumw[13][35]=-7.77926e-06, x=150, y=0.197143, error=7.77926e-06
#  fSumw[14][35]=1.89266e-05, x=160, y=0.197143, error=3.11683e-05
#  fSumw[0][36]=0, x=20, y=0.202857, error=0
#  fSumw[1][36]=0, x=30, y=0.202857, error=0
#  fSumw[2][36]=1.61021e-05, x=40, y=0.202857, error=1.61021e-05
#  fSumw[3][36]=0, x=50, y=0.202857, error=0
#  fSumw[4][36]=0, x=60, y=0.202857, error=0
#  fSumw[5][36]=0, x=70, y=0.202857, error=0
#  fSumw[6][36]=0.000293727, x=80, y=0.202857, error=0.000293727
#  fSumw[7][36]=0, x=90, y=0.202857, error=0
#  fSumw[8][36]=-4.51858e-05, x=100, y=0.202857, error=4.51858e-05
#  fSumw[9][36]=-2.83414e-05, x=110, y=0.202857, error=2.83414e-05
#  fSumw[10][36]=0, x=120, y=0.202857, error=0
#  fSumw[11][36]=0, x=130, y=0.202857, error=0
#  fSumw[12][36]=0, x=140, y=0.202857, error=0
#  fSumw[13][36]=4.4242e-05, x=150, y=0.202857, error=4.4242e-05
#  fSumw[14][36]=-1.62252e-05, x=160, y=0.202857, error=4.46975e-05
#  fSumw[0][37]=0, x=20, y=0.208571, error=0
#  fSumw[1][37]=0, x=30, y=0.208571, error=0
#  fSumw[2][37]=0, x=40, y=0.208571, error=0
#  fSumw[3][37]=0, x=50, y=0.208571, error=0
#  fSumw[4][37]=0, x=60, y=0.208571, error=0
#  fSumw[5][37]=0, x=70, y=0.208571, error=0
#  fSumw[6][37]=0, x=80, y=0.208571, error=0
#  fSumw[7][37]=0, x=90, y=0.208571, error=0
#  fSumw[8][37]=0, x=100, y=0.208571, error=0
#  fSumw[9][37]=0, x=110, y=0.208571, error=0
#  fSumw[10][37]=0, x=120, y=0.208571, error=0
#  fSumw[11][37]=0.000219725, x=130, y=0.208571, error=0.000219725
#  fSumw[12][37]=4.30373e-05, x=140, y=0.208571, error=3.15102e-05
#  fSumw[13][37]=0.000408521, x=150, y=0.208571, error=0.000373283
#  fSumw[14][37]=-0.000225654, x=160, y=0.208571, error=0.000264518
#  fSumw[0][38]=0, x=20, y=0.214286, error=0
#  fSumw[1][38]=0, x=30, y=0.214286, error=0
#  fSumw[2][38]=0, x=40, y=0.214286, error=0
#  fSumw[3][38]=0, x=50, y=0.214286, error=0
#  fSumw[4][38]=0, x=60, y=0.214286, error=0
#  fSumw[5][38]=0, x=70, y=0.214286, error=0
#  fSumw[6][38]=0, x=80, y=0.214286, error=0
#  fSumw[7][38]=0, x=90, y=0.214286, error=0
#  fSumw[8][38]=0, x=100, y=0.214286, error=0
#  fSumw[9][38]=0, x=110, y=0.214286, error=0
#  fSumw[10][38]=0, x=120, y=0.214286, error=0
#  fSumw[11][38]=4.79659e-05, x=130, y=0.214286, error=4.79659e-05
#  fSumw[12][38]=4.27587e-06, x=140, y=0.214286, error=4.27587e-06
#  fSumw[13][38]=0, x=150, y=0.214286, error=0
#  fSumw[14][38]=4.28192e-05, x=160, y=0.214286, error=3.3385e-05
#  fSumw[0][39]=0, x=20, y=0.22, error=0
#  fSumw[1][39]=0, x=30, y=0.22, error=0
#  fSumw[2][39]=0, x=40, y=0.22, error=0
#  fSumw[3][39]=0, x=50, y=0.22, error=0
#  fSumw[4][39]=0, x=60, y=0.22, error=0
#  fSumw[5][39]=0, x=70, y=0.22, error=0
#  fSumw[6][39]=0, x=80, y=0.22, error=0
#  fSumw[7][39]=1.19696e-05, x=90, y=0.22, error=1.19696e-05
#  fSumw[8][39]=0, x=100, y=0.22, error=0
#  fSumw[9][39]=0, x=110, y=0.22, error=0
#  fSumw[10][39]=0, x=120, y=0.22, error=0
#  fSumw[11][39]=1.40656e-06, x=130, y=0.22, error=4.30056e-05
#  fSumw[12][39]=0, x=140, y=0.22, error=0
#  fSumw[13][39]=0.000240254, x=150, y=0.22, error=0.00023305
#  fSumw[14][39]=-6.81476e-06, x=160, y=0.22, error=4.98957e-05
#  fSumw[0][40]=0, x=20, y=0.225714, error=0
#  fSumw[1][40]=0, x=30, y=0.225714, error=0
#  fSumw[2][40]=0, x=40, y=0.225714, error=0
#  fSumw[3][40]=0, x=50, y=0.225714, error=0
#  fSumw[4][40]=0, x=60, y=0.225714, error=0
#  fSumw[5][40]=0, x=70, y=0.225714, error=0
#  fSumw[6][40]=0, x=80, y=0.225714, error=0
#  fSumw[7][40]=0, x=90, y=0.225714, error=0
#  fSumw[8][40]=0, x=100, y=0.225714, error=0
#  fSumw[9][40]=3.57343e-05, x=110, y=0.225714, error=3.57343e-05
#  fSumw[10][40]=-3.63504e-06, x=120, y=0.225714, error=9.50193e-06
#  fSumw[11][40]=-0.000147505, x=130, y=0.225714, error=0.0002014
#  fSumw[12][40]=8.18878e-06, x=140, y=0.225714, error=8.18878e-06
#  fSumw[13][40]=0.000217254, x=150, y=0.225714, error=0.000176348
#  fSumw[14][40]=0.00033061, x=160, y=0.225714, error=0.000289867
#  fSumw[0][41]=0, x=20, y=0.231429, error=0
#  fSumw[1][41]=0, x=30, y=0.231429, error=0
#  fSumw[2][41]=0, x=40, y=0.231429, error=0
#  fSumw[3][41]=0, x=50, y=0.231429, error=0
#  fSumw[4][41]=0, x=60, y=0.231429, error=0
#  fSumw[5][41]=0, x=70, y=0.231429, error=0
#  fSumw[6][41]=0, x=80, y=0.231429, error=0
#  fSumw[7][41]=0, x=90, y=0.231429, error=0
#  fSumw[8][41]=0, x=100, y=0.231429, error=0
#  fSumw[9][41]=-5.53466e-05, x=110, y=0.231429, error=0.000413128
#  fSumw[10][41]=-1.31918e-05, x=120, y=0.231429, error=1.31918e-05
#  fSumw[11][41]=6.39928e-06, x=130, y=0.231429, error=1.6262e-05
#  fSumw[12][41]=0, x=140, y=0.231429, error=0
#  fSumw[13][41]=0, x=150, y=0.231429, error=0
#  fSumw[14][41]=0.000244052, x=160, y=0.231429, error=0.000179858
#  fSumw[0][42]=0, x=20, y=0.237143, error=0
#  fSumw[1][42]=0, x=30, y=0.237143, error=0
#  fSumw[2][42]=0, x=40, y=0.237143, error=0
#  fSumw[3][42]=0, x=50, y=0.237143, error=0
#  fSumw[4][42]=0, x=60, y=0.237143, error=0
#  fSumw[5][42]=0, x=70, y=0.237143, error=0
#  fSumw[6][42]=0, x=80, y=0.237143, error=0
#  fSumw[7][42]=0, x=90, y=0.237143, error=0
#  fSumw[8][42]=0, x=100, y=0.237143, error=0
#  fSumw[9][42]=0, x=110, y=0.237143, error=0
#  fSumw[10][42]=1.07705e-05, x=120, y=0.237143, error=1.07705e-05
#  fSumw[11][42]=2.68624e-05, x=130, y=0.237143, error=1.90511e-05
#  fSumw[12][42]=-0.000271275, x=140, y=0.237143, error=0.000279912
#  fSumw[13][42]=3.03939e-05, x=150, y=0.237143, error=3.03939e-05
#  fSumw[14][42]=0.000296909, x=160, y=0.237143, error=0.000279123
#  fSumw[0][43]=0, x=20, y=0.242857, error=0
#  fSumw[1][43]=0, x=30, y=0.242857, error=0
#  fSumw[2][43]=0, x=40, y=0.242857, error=0
#  fSumw[3][43]=0, x=50, y=0.242857, error=0
#  fSumw[4][43]=0, x=60, y=0.242857, error=0
#  fSumw[5][43]=0, x=70, y=0.242857, error=0
#  fSumw[6][43]=0, x=80, y=0.242857, error=0
#  fSumw[7][43]=0, x=90, y=0.242857, error=0
#  fSumw[8][43]=0, x=100, y=0.242857, error=0
#  fSumw[9][43]=0, x=110, y=0.242857, error=0
#  fSumw[10][43]=1.38446e-05, x=120, y=0.242857, error=6.20455e-05
#  fSumw[11][43]=0.00035063, x=130, y=0.242857, error=0.00035063
#  fSumw[12][43]=-6.34816e-06, x=140, y=0.242857, error=4.85062e-05
#  fSumw[13][43]=1.87302e-05, x=150, y=0.242857, error=1.87302e-05
#  fSumw[14][43]=-0.000185075, x=160, y=0.242857, error=0.000257509
#  fSumw[0][44]=0, x=20, y=0.248571, error=0
#  fSumw[1][44]=0, x=30, y=0.248571, error=0
#  fSumw[2][44]=0, x=40, y=0.248571, error=0
#  fSumw[3][44]=0, x=50, y=0.248571, error=0
#  fSumw[4][44]=0, x=60, y=0.248571, error=0
#  fSumw[5][44]=0, x=70, y=0.248571, error=0
#  fSumw[6][44]=0, x=80, y=0.248571, error=0
#  fSumw[7][44]=0, x=90, y=0.248571, error=0
#  fSumw[8][44]=0, x=100, y=0.248571, error=0
#  fSumw[9][44]=4.98599e-05, x=110, y=0.248571, error=4.98599e-05
#  fSumw[10][44]=0.000122638, x=120, y=0.248571, error=6.04537e-05
#  fSumw[11][44]=0.00017545, x=130, y=0.248571, error=0.00015633
#  fSumw[12][44]=0.000275237, x=140, y=0.248571, error=0.000275237
#  fSumw[13][44]=3.13007e-07, x=150, y=0.248571, error=6.93596e-06
#  fSumw[14][44]=4.25825e-05, x=160, y=0.248571, error=4.25825e-05
#  fSumw[0][45]=0, x=20, y=0.254286, error=0
#  fSumw[1][45]=-4.54487e-05, x=30, y=0.254286, error=4.54487e-05
#  fSumw[2][45]=0, x=40, y=0.254286, error=0
#  fSumw[3][45]=0, x=50, y=0.254286, error=0
#  fSumw[4][45]=0, x=60, y=0.254286, error=0
#  fSumw[5][45]=0.000206893, x=70, y=0.254286, error=0.000206893
#  fSumw[6][45]=0, x=80, y=0.254286, error=0
#  fSumw[7][45]=0, x=90, y=0.254286, error=0
#  fSumw[8][45]=5.13837e-05, x=100, y=0.254286, error=5.13837e-05
#  fSumw[9][45]=3.70914e-05, x=110, y=0.254286, error=2.96634e-05
#  fSumw[10][45]=-4.87339e-05, x=120, y=0.254286, error=4.87339e-05
#  fSumw[11][45]=1.73608e-06, x=130, y=0.254286, error=9.21948e-06
#  fSumw[12][45]=0.000248004, x=140, y=0.254286, error=0.000236936
#  fSumw[13][45]=0, x=150, y=0.254286, error=0
#  fSumw[14][45]=0.000293588, x=160, y=0.254286, error=0.000206634
#  fSumw[0][46]=0, x=20, y=0.26, error=0
#  fSumw[1][46]=0, x=30, y=0.26, error=0
#  fSumw[2][46]=0, x=40, y=0.26, error=0
#  fSumw[3][46]=0, x=50, y=0.26, error=0
#  fSumw[4][46]=0, x=60, y=0.26, error=0
#  fSumw[5][46]=0, x=70, y=0.26, error=0
#  fSumw[6][46]=0, x=80, y=0.26, error=0
#  fSumw[7][46]=0, x=90, y=0.26, error=0
#  fSumw[8][46]=0, x=100, y=0.26, error=0
#  fSumw[9][46]=4.16224e-06, x=110, y=0.26, error=4.16224e-06
#  fSumw[10][46]=0.000242146, x=120, y=0.26, error=0.000226845
#  fSumw[11][46]=-2.97354e-05, x=130, y=0.26, error=2.97354e-05
#  fSumw[12][46]=-4.1732e-07, x=140, y=0.26, error=6.56348e-05
#  fSumw[13][46]=0, x=150, y=0.26, error=0
#  fSumw[14][46]=1.47761e-05, x=160, y=0.26, error=1.10813e-05
#  fSumw[0][47]=0, x=20, y=0.265714, error=0
#  fSumw[1][47]=0, x=30, y=0.265714, error=0
#  fSumw[2][47]=8.3359e-06, x=40, y=0.265714, error=8.3359e-06
#  fSumw[3][47]=0, x=50, y=0.265714, error=0
#  fSumw[4][47]=0, x=60, y=0.265714, error=0
#  fSumw[5][47]=0.000192821, x=70, y=0.265714, error=0.000192821
#  fSumw[6][47]=0, x=80, y=0.265714, error=0
#  fSumw[7][47]=1.28546e-05, x=90, y=0.265714, error=1.28546e-05
#  fSumw[8][47]=0, x=100, y=0.265714, error=0
#  fSumw[9][47]=0, x=110, y=0.265714, error=0
#  fSumw[10][47]=1.94914e-05, x=120, y=0.265714, error=2.58528e-05
#  fSumw[11][47]=4.1511e-05, x=130, y=0.265714, error=3.26427e-05
#  fSumw[12][47]=-0.000329106, x=140, y=0.265714, error=0.000335151
#  fSumw[13][47]=0, x=150, y=0.265714, error=0
#  fSumw[14][47]=-1.57117e-05, x=160, y=0.265714, error=3.89046e-05
#  fSumw[0][48]=0, x=20, y=0.271429, error=0
#  fSumw[1][48]=0, x=30, y=0.271429, error=0
#  fSumw[2][48]=0, x=40, y=0.271429, error=0
#  fSumw[3][48]=0, x=50, y=0.271429, error=0
#  fSumw[4][48]=1.35756e-05, x=60, y=0.271429, error=1.35756e-05
#  fSumw[5][48]=4.18907e-05, x=70, y=0.271429, error=2.96212e-05
#  fSumw[6][48]=1.00709e-05, x=80, y=0.271429, error=1.00709e-05
#  fSumw[7][48]=0, x=90, y=0.271429, error=0
#  fSumw[8][48]=-1.07265e-05, x=100, y=0.271429, error=1.07265e-05
#  fSumw[9][48]=4.3997e-05, x=110, y=0.271429, error=3.1398e-05
#  fSumw[10][48]=1.08858e-05, x=120, y=0.271429, error=1.08858e-05
#  fSumw[11][48]=8.01109e-06, x=130, y=0.271429, error=8.01109e-06
#  fSumw[12][48]=0, x=140, y=0.271429, error=0
#  fSumw[13][48]=8.09364e-06, x=150, y=0.271429, error=8.09364e-06
#  fSumw[14][48]=-0.000194081, x=160, y=0.271429, error=0.000227251
#  fSumw[0][49]=0, x=20, y=0.277143, error=0
#  fSumw[1][49]=0, x=30, y=0.277143, error=0
#  fSumw[2][49]=0, x=40, y=0.277143, error=0
#  fSumw[3][49]=0, x=50, y=0.277143, error=0
#  fSumw[4][49]=2.45672e-05, x=60, y=0.277143, error=1.96239e-05
#  fSumw[5][49]=3.15497e-05, x=70, y=0.277143, error=3.15497e-05
#  fSumw[6][49]=0, x=80, y=0.277143, error=0
#  fSumw[7][49]=0, x=90, y=0.277143, error=0
#  fSumw[8][49]=4.25825e-05, x=100, y=0.277143, error=4.25825e-05
#  fSumw[9][49]=0.000495113, x=110, y=0.277143, error=0.000342441
#  fSumw[10][49]=7.36518e-05, x=120, y=0.277143, error=4.54634e-05
#  fSumw[11][49]=-3.67018e-05, x=130, y=0.277143, error=4.62828e-05
#  fSumw[12][49]=1.10985e-05, x=140, y=0.277143, error=1.10985e-05
#  fSumw[13][49]=0, x=150, y=0.277143, error=0
#  fSumw[14][49]=0.000292288, x=160, y=0.277143, error=0.000196907
#  fSumw[0][50]=0, x=20, y=0.282857, error=0
#  fSumw[1][50]=0, x=30, y=0.282857, error=0
#  fSumw[2][50]=-0.000426662, x=40, y=0.282857, error=0.000426662
#  fSumw[3][50]=0.0001946, x=50, y=0.282857, error=0.0001946
#  fSumw[4][50]=-4.50076e-05, x=60, y=0.282857, error=3.92604e-05
#  fSumw[5][50]=0, x=70, y=0.282857, error=0
#  fSumw[6][50]=0, x=80, y=0.282857, error=0
#  fSumw[7][50]=-0.000129242, x=90, y=0.282857, error=0.000129242
#  fSumw[8][50]=-0.000230727, x=100, y=0.282857, error=0.000264642
#  fSumw[9][50]=0.000361297, x=110, y=0.282857, error=0.000323075
#  fSumw[10][50]=-1.62001e-06, x=120, y=0.282857, error=1.62001e-06
#  fSumw[11][50]=2.33579e-05, x=130, y=0.282857, error=3.33753e-05
#  fSumw[12][50]=8.98392e-05, x=140, y=0.282857, error=6.35402e-05
#  fSumw[13][50]=0.000202342, x=150, y=0.282857, error=0.000171058
#  fSumw[14][50]=1.98109e-05, x=160, y=0.282857, error=1.76846e-05
#  fSumw[0][51]=0, x=20, y=0.288571, error=0
#  fSumw[1][51]=0, x=30, y=0.288571, error=0
#  fSumw[2][51]=0, x=40, y=0.288571, error=0
#  fSumw[3][51]=0, x=50, y=0.288571, error=0
#  fSumw[4][51]=0.000249872, x=60, y=0.288571, error=0.000249872
#  fSumw[5][51]=-1.45605e-06, x=70, y=0.288571, error=1.45605e-06
#  fSumw[6][51]=-0.000316421, x=80, y=0.288571, error=0.000316421
#  fSumw[7][51]=6.65788e-05, x=90, y=0.288571, error=4.79136e-05
#  fSumw[8][51]=-1.60585e-05, x=100, y=0.288571, error=2.65562e-05
#  fSumw[9][51]=0.000230368, x=110, y=0.288571, error=0.000170506
#  fSumw[10][51]=-3.20789e-05, x=120, y=0.288571, error=3.20789e-05
#  fSumw[11][51]=-0.000251282, x=130, y=0.288571, error=0.000259269
#  fSumw[12][51]=7.90924e-06, x=140, y=0.288571, error=7.90924e-06
#  fSumw[13][51]=-9.52223e-06, x=150, y=0.288571, error=2.09922e-05
#  fSumw[14][51]=-0.000143498, x=160, y=0.288571, error=0.000265386
#  fSumw[0][52]=0, x=20, y=0.294286, error=0
#  fSumw[1][52]=0, x=30, y=0.294286, error=0
#  fSumw[2][52]=0, x=40, y=0.294286, error=0
#  fSumw[3][52]=0, x=50, y=0.294286, error=0
#  fSumw[4][52]=1.98762e-05, x=60, y=0.294286, error=1.98762e-05
#  fSumw[5][52]=0, x=70, y=0.294286, error=0
#  fSumw[6][52]=0, x=80, y=0.294286, error=0
#  fSumw[7][52]=3.62687e-05, x=90, y=0.294286, error=5.73824e-05
#  fSumw[8][52]=-0.000204439, x=100, y=0.294286, error=0.000236424
#  fSumw[9][52]=0.000381532, x=110, y=0.294286, error=0.000418463
#  fSumw[10][52]=-2.60301e-05, x=120, y=0.294286, error=4.79012e-05
#  fSumw[11][52]=1.7593e-05, x=130, y=0.294286, error=1.29625e-05
#  fSumw[12][52]=7.2444e-06, x=140, y=0.294286, error=7.2444e-06
#  fSumw[13][52]=3.33237e-05, x=150, y=0.294286, error=1.92426e-05
#  fSumw[14][52]=4.81308e-05, x=160, y=0.294286, error=3.657e-05
#  fSumw[0][53]=0, x=20, y=0.3, error=0
#  fSumw[1][53]=0, x=30, y=0.3, error=0
#  fSumw[2][53]=0, x=40, y=0.3, error=0
#  fSumw[3][53]=0, x=50, y=0.3, error=0
#  fSumw[4][53]=0, x=60, y=0.3, error=0
#  fSumw[5][53]=0.000333724, x=70, y=0.3, error=0.00034028
#  fSumw[6][53]=0, x=80, y=0.3, error=0
#  fSumw[7][53]=1.46128e-05, x=90, y=0.3, error=5.17532e-05
#  fSumw[8][53]=0.000107832, x=100, y=0.3, error=6.32741e-05
#  fSumw[9][53]=4.41211e-06, x=110, y=0.3, error=4.72117e-05
#  fSumw[10][53]=0.00033842, x=120, y=0.3, error=0.000330421
#  fSumw[11][53]=2.98193e-05, x=130, y=0.3, error=2.16101e-05
#  fSumw[12][53]=0.000145842, x=140, y=0.3, error=0.000145842
#  fSumw[13][53]=0, x=150, y=0.3, error=0
#  fSumw[14][53]=0.00033926, x=160, y=0.3, error=0.000209137
#  fSumw[0][54]=0, x=20, y=0.305714, error=0
#  fSumw[1][54]=0, x=30, y=0.305714, error=0
#  fSumw[2][54]=0, x=40, y=0.305714, error=0
#  fSumw[3][54]=0, x=50, y=0.305714, error=0
#  fSumw[4][54]=0, x=60, y=0.305714, error=0
#  fSumw[5][54]=0, x=70, y=0.305714, error=0
#  fSumw[6][54]=0, x=80, y=0.305714, error=0
#  fSumw[7][54]=0.000214872, x=90, y=0.305714, error=0.000194735
#  fSumw[8][54]=0.000644571, x=100, y=0.305714, error=0.000420263
#  fSumw[9][54]=-3.77592e-05, x=110, y=0.305714, error=4.64144e-05
#  fSumw[10][54]=0.000202248, x=120, y=0.305714, error=0.000174829
#  fSumw[11][54]=0, x=130, y=0.305714, error=0
#  fSumw[12][54]=-1.26663e-05, x=140, y=0.305714, error=1.26663e-05
#  fSumw[13][54]=4.13433e-06, x=150, y=0.305714, error=4.13433e-06
#  fSumw[14][54]=-0.000169658, x=160, y=0.305714, error=0.000145181
#  fSumw[0][55]=0, x=20, y=0.311429, error=0
#  fSumw[1][55]=0, x=30, y=0.311429, error=0
#  fSumw[2][55]=0, x=40, y=0.311429, error=0
#  fSumw[3][55]=1.04425e-05, x=50, y=0.311429, error=1.04425e-05
#  fSumw[4][55]=0, x=60, y=0.311429, error=0
#  fSumw[5][55]=0, x=70, y=0.311429, error=0
#  fSumw[6][55]=0, x=80, y=0.311429, error=0
#  fSumw[7][55]=0.00012311, x=90, y=0.311429, error=6.16219e-05
#  fSumw[8][55]=3.42005e-05, x=100, y=0.311429, error=2.1932e-05
#  fSumw[9][55]=0.000205573, x=110, y=0.311429, error=0.000183867
#  fSumw[10][55]=5.16102e-05, x=120, y=0.311429, error=3.93019e-05
#  fSumw[11][55]=1.47043e-05, x=130, y=0.311429, error=2.87352e-05
#  fSumw[12][55]=6.11298e-05, x=140, y=0.311429, error=4.68878e-05
#  fSumw[13][55]=2.74013e-06, x=150, y=0.311429, error=2.74013e-06
#  fSumw[14][55]=-0.000115603, x=160, y=0.311429, error=0.000357718
#  fSumw[0][56]=0, x=20, y=0.317143, error=0
#  fSumw[1][56]=0, x=30, y=0.317143, error=0
#  fSumw[2][56]=0, x=40, y=0.317143, error=0
#  fSumw[3][56]=0.000242057, x=50, y=0.317143, error=0.000229027
#  fSumw[4][56]=0.000364869, x=60, y=0.317143, error=0.000358089
#  fSumw[5][56]=0.000145842, x=70, y=0.317143, error=0.000145842
#  fSumw[6][56]=0, x=80, y=0.317143, error=0
#  fSumw[7][56]=-9.7907e-06, x=90, y=0.317143, error=3.90443e-05
#  fSumw[8][56]=8.16158e-05, x=100, y=0.317143, error=4.79085e-05
#  fSumw[9][56]=0.000267768, x=110, y=0.317143, error=0.000208413
#  fSumw[10][56]=3.49205e-05, x=120, y=0.317143, error=4.37689e-05
#  fSumw[11][56]=0.000394461, x=130, y=0.317143, error=0.000303721
#  fSumw[12][56]=1.16283e-05, x=140, y=0.317143, error=1.16283e-05
#  fSumw[13][56]=0, x=150, y=0.317143, error=0
#  fSumw[14][56]=4.85907e-05, x=160, y=0.317143, error=2.89584e-05
#  fSumw[0][57]=0, x=20, y=0.322857, error=0
#  fSumw[1][57]=0, x=30, y=0.322857, error=0
#  fSumw[2][57]=0, x=40, y=0.322857, error=0
#  fSumw[3][57]=0.000320686, x=50, y=0.322857, error=0.000320686
#  fSumw[4][57]=0.000301527, x=60, y=0.322857, error=0.000294158
#  fSumw[5][57]=7.59153e-06, x=70, y=0.322857, error=7.59153e-06
#  fSumw[6][57]=-0.000255671, x=80, y=0.322857, error=0.000262624
#  fSumw[7][57]=1.78819e-05, x=90, y=0.322857, error=4.59503e-05
#  fSumw[8][57]=5.03356e-06, x=100, y=0.322857, error=1.63393e-05
#  fSumw[9][57]=3.17875e-05, x=110, y=0.322857, error=4.68738e-05
#  fSumw[10][57]=-2.48443e-06, x=120, y=0.322857, error=8.07459e-06
#  fSumw[11][57]=9.15584e-06, x=130, y=0.322857, error=9.15584e-06
#  fSumw[12][57]=2.64635e-06, x=140, y=0.322857, error=4.35355e-05
#  fSumw[13][57]=1.35176e-05, x=150, y=0.322857, error=1.09362e-05
#  fSumw[14][57]=0.000276076, x=160, y=0.322857, error=0.000253466
#  fSumw[0][58]=0, x=20, y=0.328571, error=0
#  fSumw[1][58]=0, x=30, y=0.328571, error=0
#  fSumw[2][58]=0, x=40, y=0.328571, error=0
#  fSumw[3][58]=0, x=50, y=0.328571, error=0
#  fSumw[4][58]=0.000218875, x=60, y=0.328571, error=0.000193949
#  fSumw[5][58]=0, x=70, y=0.328571, error=0
#  fSumw[6][58]=4.94185e-05, x=80, y=0.328571, error=7.18639e-05
#  fSumw[7][58]=0.000209605, x=90, y=0.328571, error=0.000199391
#  fSumw[8][58]=-1.75321e-06, x=100, y=0.328571, error=6.26443e-05
#  fSumw[9][58]=9.08983e-06, x=110, y=0.328571, error=2.95387e-05
#  fSumw[10][58]=8.9491e-05, x=120, y=0.328571, error=6.33416e-05
#  fSumw[11][58]=-1.38409e-05, x=130, y=0.328571, error=9.79053e-06
#  fSumw[12][58]=4.64463e-05, x=140, y=0.328571, error=4.64463e-05
#  fSumw[13][58]=-0.000314851, x=150, y=0.328571, error=0.000284225
#  fSumw[14][58]=0.000358422, x=160, y=0.328571, error=0.000349863
#  fSumw[0][59]=0, x=20, y=0.334286, error=0
#  fSumw[1][59]=0, x=30, y=0.334286, error=0
#  fSumw[2][59]=0, x=40, y=0.334286, error=0
#  fSumw[3][59]=0, x=50, y=0.334286, error=0
#  fSumw[4][59]=0.000279673, x=60, y=0.334286, error=0.000279673
#  fSumw[5][59]=0.000287985, x=70, y=0.334286, error=0.000287985
#  fSumw[6][59]=0.000150464, x=80, y=0.334286, error=0.000143195
#  fSumw[7][59]=0.000580068, x=90, y=0.334286, error=0.000480403
#  fSumw[8][59]=-0.000231192, x=100, y=0.334286, error=0.00027827
#  fSumw[9][59]=0.00032201, x=110, y=0.334286, error=0.000313518
#  fSumw[10][59]=-0.000258321, x=120, y=0.334286, error=0.000236447
#  fSumw[11][59]=0.000299975, x=130, y=0.334286, error=0.000277542
#  fSumw[12][59]=8.66254e-06, x=140, y=0.334286, error=8.66254e-06
#  fSumw[13][59]=0, x=150, y=0.334286, error=0
#  fSumw[14][59]=8.79806e-05, x=160, y=0.334286, error=3.6515e-05
#  fSumw[0][60]=0, x=20, y=0.34, error=0
#  fSumw[1][60]=0, x=30, y=0.34, error=0
#  fSumw[2][60]=0, x=40, y=0.34, error=0
#  fSumw[3][60]=0.000314718, x=50, y=0.34, error=0.000297392
#  fSumw[4][60]=0.000571757, x=60, y=0.34, error=0.000404591
#  fSumw[5][60]=0, x=70, y=0.34, error=0
#  fSumw[6][60]=1.56224e-05, x=80, y=0.34, error=9.02891e-06
#  fSumw[7][60]=0.000437502, x=90, y=0.34, error=0.000366806
#  fSumw[8][60]=0.000398913, x=100, y=0.34, error=0.000361275
#  fSumw[9][60]=-1.20592e-05, x=110, y=0.34, error=4.95542e-05
#  fSumw[10][60]=-4.25825e-05, x=120, y=0.34, error=4.25825e-05
#  fSumw[11][60]=-5.19967e-06, x=130, y=0.34, error=2.92405e-05
#  fSumw[12][60]=1.57246e-05, x=140, y=0.34, error=5.59092e-05
#  fSumw[13][60]=4.49793e-05, x=150, y=0.34, error=4.49793e-05
#  fSumw[14][60]=-1.97993e-05, x=160, y=0.34, error=5.9107e-05
#  fSumw[0][61]=0, x=20, y=0.345714, error=0
#  fSumw[1][61]=0, x=30, y=0.345714, error=0
#  fSumw[2][61]=0, x=40, y=0.345714, error=0
#  fSumw[3][61]=4.52536e-05, x=50, y=0.345714, error=4.52536e-05
#  fSumw[4][61]=0.000139549, x=60, y=0.345714, error=0.000199147
#  fSumw[5][61]=1.26353e-05, x=70, y=0.345714, error=4.23114e-05
#  fSumw[6][61]=-0.000237848, x=80, y=0.345714, error=0.000248575
#  fSumw[7][61]=1.26177e-05, x=90, y=0.345714, error=3.4099e-05
#  fSumw[8][61]=1.35876e-06, x=100, y=0.345714, error=3.67119e-05
#  fSumw[9][61]=2.66799e-05, x=110, y=0.345714, error=2.20302e-05
#  fSumw[10][61]=0, x=120, y=0.345714, error=0
#  fSumw[11][61]=0, x=130, y=0.345714, error=0
#  fSumw[12][61]=-0.000192569, x=140, y=0.345714, error=0.000230131
#  fSumw[13][61]=1.16581e-05, x=150, y=0.345714, error=1.16581e-05
#  fSumw[14][61]=0.000450977, x=160, y=0.345714, error=0.000310982
#  fSumw[0][62]=0, x=20, y=0.351429, error=0
#  fSumw[1][62]=0.000216355, x=30, y=0.351429, error=0.000216355
#  fSumw[2][62]=0, x=40, y=0.351429, error=0
#  fSumw[3][62]=7.8372e-06, x=50, y=0.351429, error=7.8372e-06
#  fSumw[4][62]=8.76459e-06, x=60, y=0.351429, error=2.83971e-05
#  fSumw[5][62]=0.000227657, x=70, y=0.351429, error=0.000219017
#  fSumw[6][62]=0.000326375, x=80, y=0.351429, error=0.000281007
#  fSumw[7][62]=-0.000198135, x=90, y=0.351429, error=0.000282625
#  fSumw[8][62]=7.23815e-05, x=100, y=0.351429, error=4.1796e-05
#  fSumw[9][62]=0.000172584, x=110, y=0.351429, error=0.000196736
#  fSumw[10][62]=0.000235456, x=120, y=0.351429, error=0.000233541
#  fSumw[11][62]=0.000324024, x=130, y=0.351429, error=0.000299091
#  fSumw[12][62]=6.28418e-06, x=140, y=0.351429, error=6.28418e-06
#  fSumw[13][62]=-1.71253e-05, x=150, y=0.351429, error=1.85873e-05
#  fSumw[14][62]=5.39477e-05, x=160, y=0.351429, error=3.79911e-05
#  fSumw[0][63]=0, x=20, y=0.357143, error=0
#  fSumw[1][63]=0, x=30, y=0.357143, error=0
#  fSumw[2][63]=0, x=40, y=0.357143, error=0
#  fSumw[3][63]=4.9664e-05, x=50, y=0.357143, error=4.9664e-05
#  fSumw[4][63]=-0.000166725, x=60, y=0.357143, error=0.00018026
#  fSumw[5][63]=5.93319e-05, x=70, y=0.357143, error=5.09067e-05
#  fSumw[6][63]=-0.000330085, x=80, y=0.357143, error=0.000352029
#  fSumw[7][63]=0.000191829, x=90, y=0.357143, error=0.000675792
#  fSumw[8][63]=-0.000142504, x=100, y=0.357143, error=0.000376399
#  fSumw[9][63]=9.61338e-06, x=110, y=0.357143, error=9.61338e-06
#  fSumw[10][63]=-1.16118e-05, x=120, y=0.357143, error=1.16118e-05
#  fSumw[11][63]=6.87478e-05, x=130, y=0.357143, error=5.5015e-05
#  fSumw[12][63]=2.14081e-05, x=140, y=0.357143, error=2.12974e-05
#  fSumw[13][63]=0, x=150, y=0.357143, error=0
#  fSumw[14][63]=-0.000395371, x=160, y=0.357143, error=0.000407305
#  fSumw[0][64]=0, x=20, y=0.362857, error=0
#  fSumw[1][64]=0, x=30, y=0.362857, error=0
#  fSumw[2][64]=0, x=40, y=0.362857, error=0
#  fSumw[3][64]=-0.000150339, x=50, y=0.362857, error=0.000200511
#  fSumw[4][64]=0.000260402, x=60, y=0.362857, error=0.000241941
#  fSumw[5][64]=0.000197642, x=70, y=0.362857, error=0.000197642
#  fSumw[6][64]=-2.86132e-05, x=80, y=0.362857, error=5.17868e-05
#  fSumw[7][64]=1.58618e-05, x=90, y=0.362857, error=5.76718e-05
#  fSumw[8][64]=-3.78219e-05, x=100, y=0.362857, error=5.07709e-05
#  fSumw[9][64]=3.50596e-06, x=110, y=0.362857, error=4.53568e-05
#  fSumw[10][64]=2.21096e-05, x=120, y=0.362857, error=1.56378e-05
#  fSumw[11][64]=1.26152e-05, x=130, y=0.362857, error=9.19565e-06
#  fSumw[12][64]=4.00702e-05, x=140, y=0.362857, error=3.05989e-05
#  fSumw[13][64]=0.000169585, x=150, y=0.362857, error=0.000216323
#  fSumw[14][64]=0.000611113, x=160, y=0.362857, error=0.000411331
#  fSumw[0][65]=0, x=20, y=0.368571, error=0
#  fSumw[1][65]=0, x=30, y=0.368571, error=0
#  fSumw[2][65]=2.75845e-05, x=40, y=0.368571, error=2.75845e-05
#  fSumw[3][65]=0.0003903, x=50, y=0.368571, error=0.000281014
#  fSumw[4][65]=0.000302923, x=60, y=0.368571, error=0.000286181
#  fSumw[5][65]=3.14689e-05, x=70, y=0.368571, error=2.98418e-05
#  fSumw[6][65]=0.000403768, x=80, y=0.368571, error=0.000301868
#  fSumw[7][65]=7.94901e-06, x=90, y=0.368571, error=0.000347635
#  fSumw[8][65]=-0.000190885, x=100, y=0.368571, error=0.000220817
# ...
#  fSumw[12][332]=0, x=140, y=1.89429, error=0
#  fSumw[13][332]=0, x=150, y=1.89429, error=0
#  fSumw[14][332]=1.18074e-05, x=160, y=1.89429, error=1.18074e-05
#  fSumw[0][333]=0.00114849, x=20, y=1.9, error=0.000531867
#  fSumw[1][333]=0.00202003, x=30, y=1.9, error=0.000829816
#  fSumw[2][333]=0.000206319, x=40, y=1.9, error=0.000589816
#  fSumw[3][333]=0.000441695, x=50, y=1.9, error=0.000309619
#  fSumw[4][333]=0.000232935, x=60, y=1.9, error=0.000272619
#  fSumw[5][333]=7.45279e-06, x=70, y=1.9, error=7.45279e-06
#  fSumw[6][333]=-0.000423778, x=80, y=1.9, error=0.000406344
#  fSumw[7][333]=0, x=90, y=1.9, error=0
#  fSumw[8][333]=-0.000285314, x=100, y=1.9, error=0.000260833
#  fSumw[9][333]=7.10658e-06, x=110, y=1.9, error=7.10658e-06
#  fSumw[10][333]=0, x=120, y=1.9, error=0
#  fSumw[11][333]=3.95682e-05, x=130, y=1.9, error=3.95682e-05
#  fSumw[12][333]=0, x=140, y=1.9, error=0
#  fSumw[13][333]=-7.39577e-06, x=150, y=1.9, error=7.39577e-06
#  fSumw[14][333]=0, x=160, y=1.9, error=0
#  fSumw[0][334]=0.000146529, x=20, y=1.90571, error=0.000615466
#  fSumw[1][334]=0.000440547, x=30, y=1.90571, error=0.00074081
#  fSumw[2][334]=0.000503015, x=40, y=1.90571, error=0.000362401
#  fSumw[3][334]=-0.000198713, x=50, y=1.90571, error=0.000270269
#  fSumw[4][334]=7.30256e-05, x=60, y=1.90571, error=4.02981e-05
#  fSumw[5][334]=-0.000343778, x=70, y=1.90571, error=0.000313789
#  fSumw[6][334]=0, x=80, y=1.90571, error=0
#  fSumw[7][334]=-7.86005e-06, x=90, y=1.90571, error=2.33052e-05
#  fSumw[8][334]=-5.95678e-06, x=100, y=1.90571, error=5.95678e-06
#  fSumw[9][334]=6.58143e-06, x=110, y=1.90571, error=6.58143e-06
#  fSumw[10][334]=0, x=120, y=1.90571, error=0
#  fSumw[11][334]=0, x=130, y=1.90571, error=0
#  fSumw[12][334]=0, x=140, y=1.90571, error=0
#  fSumw[13][334]=0, x=150, y=1.90571, error=0
#  fSumw[14][334]=0, x=160, y=1.90571, error=0
#  fSumw[0][335]=0.000695694, x=20, y=1.91143, error=0.000748223
#  fSumw[1][335]=0.00127124, x=30, y=1.91143, error=0.00055409
#  fSumw[2][335]=-7.64789e-05, x=40, y=1.91143, error=0.000642076
#  fSumw[3][335]=0.000364787, x=50, y=1.91143, error=0.000212255
#  fSumw[4][335]=1.38401e-05, x=60, y=1.91143, error=2.53034e-05
#  fSumw[5][335]=-0.000308188, x=70, y=1.91143, error=0.000315735
#  fSumw[6][335]=0.000162476, x=80, y=1.91143, error=0.000156057
#  fSumw[7][335]=-3.48626e-05, x=90, y=1.91143, error=3.48626e-05
#  fSumw[8][335]=1.60858e-05, x=100, y=1.91143, error=1.14012e-05
#  fSumw[9][335]=0, x=110, y=1.91143, error=0
#  fSumw[10][335]=0, x=120, y=1.91143, error=0
#  fSumw[11][335]=0, x=130, y=1.91143, error=0
#  fSumw[12][335]=0, x=140, y=1.91143, error=0
#  fSumw[13][335]=0, x=150, y=1.91143, error=0
#  fSumw[14][335]=0, x=160, y=1.91143, error=0
#  fSumw[0][336]=0.00163677, x=20, y=1.91714, error=0.000653588
#  fSumw[1][336]=0.00126965, x=30, y=1.91714, error=0.000872035
#  fSumw[2][336]=0.00138727, x=40, y=1.91714, error=0.000578379
#  fSumw[3][336]=0.000751901, x=50, y=1.91714, error=0.000424799
#  fSumw[4][336]=-1.04692e-05, x=60, y=1.91714, error=3.6726e-05
#  fSumw[5][336]=8.42393e-06, x=70, y=1.91714, error=8.42393e-06
#  fSumw[6][336]=5.92476e-06, x=80, y=1.91714, error=5.92476e-06
#  fSumw[7][336]=0.000280693, x=90, y=1.91714, error=0.000280693
#  fSumw[8][336]=0, x=100, y=1.91714, error=0
#  fSumw[9][336]=0, x=110, y=1.91714, error=0
#  fSumw[10][336]=1.06464e-05, x=120, y=1.91714, error=1.06464e-05
#  fSumw[11][336]=0, x=130, y=1.91714, error=0
#  fSumw[12][336]=0, x=140, y=1.91714, error=0
#  fSumw[13][336]=1.09926e-05, x=150, y=1.91714, error=1.09926e-05
#  fSumw[14][336]=0, x=160, y=1.91714, error=0
#  fSumw[0][337]=-0.000373958, x=20, y=1.92286, error=0.000576258
#  fSumw[1][337]=0.00160881, x=30, y=1.92286, error=0.000721099
#  fSumw[2][337]=0.00108997, x=40, y=1.92286, error=0.000586846
#  fSumw[3][337]=0.000387349, x=50, y=1.92286, error=0.000339941
#  fSumw[4][337]=-0.000334489, x=60, y=1.92286, error=0.000320107
#  fSumw[5][337]=0.000310364, x=70, y=1.92286, error=0.000259056
#  fSumw[6][337]=0.000265611, x=80, y=1.92286, error=0.00022498
#  fSumw[7][337]=1.2225e-05, x=90, y=1.92286, error=1.2225e-05
#  fSumw[8][337]=0.000278961, x=100, y=1.92286, error=0.00026153
#  fSumw[9][337]=0, x=110, y=1.92286, error=0
#  fSumw[10][337]=0, x=120, y=1.92286, error=0
#  fSumw[11][337]=1.25749e-05, x=130, y=1.92286, error=1.25749e-05
#  fSumw[12][337]=0, x=140, y=1.92286, error=0
#  fSumw[13][337]=0, x=150, y=1.92286, error=0
#  fSumw[14][337]=0, x=160, y=1.92286, error=0
#  fSumw[0][338]=0.00106638, x=20, y=1.92857, error=0.000527083
#  fSumw[1][338]=0.00210926, x=30, y=1.92857, error=0.000707564
#  fSumw[2][338]=0.00086313, x=40, y=1.92857, error=0.000621107
#  fSumw[3][338]=0.000476471, x=50, y=1.92857, error=0.000324324
#  fSumw[4][338]=6.94516e-05, x=60, y=1.92857, error=7.21026e-05
#  fSumw[5][338]=0, x=70, y=1.92857, error=0
#  fSumw[6][338]=2.21829e-05, x=80, y=1.92857, error=1.56945e-05
#  fSumw[7][338]=5.38368e-06, x=90, y=1.92857, error=5.38368e-06
#  fSumw[8][338]=0, x=100, y=1.92857, error=0
#  fSumw[9][338]=0, x=110, y=1.92857, error=0
#  fSumw[10][338]=0, x=120, y=1.92857, error=0
#  fSumw[11][338]=0, x=130, y=1.92857, error=0
#  fSumw[12][338]=0, x=140, y=1.92857, error=0
#  fSumw[13][338]=0, x=150, y=1.92857, error=0
#  fSumw[14][338]=0, x=160, y=1.92857, error=0
#  fSumw[0][339]=1.01603e-05, x=20, y=1.93429, error=0.00035304
#  fSumw[1][339]=0.00277218, x=30, y=1.93429, error=0.000936572
#  fSumw[2][339]=-0.000111197, x=40, y=1.93429, error=0.000205937
#  fSumw[3][339]=9.9439e-05, x=50, y=1.93429, error=0.000356678
#  fSumw[4][339]=8.91586e-05, x=60, y=1.93429, error=4.46006e-05
#  fSumw[5][339]=0.000119185, x=70, y=1.93429, error=6.0834e-05
#  fSumw[6][339]=-2.5854e-06, x=80, y=1.93429, error=1.17116e-05
#  fSumw[7][339]=4.72232e-06, x=90, y=1.93429, error=4.72232e-06
#  fSumw[8][339]=0, x=100, y=1.93429, error=0
#  fSumw[9][339]=1.80097e-05, x=110, y=1.93429, error=1.80097e-05
#  fSumw[10][339]=0, x=120, y=1.93429, error=0
#  fSumw[11][339]=-7.46382e-06, x=130, y=1.93429, error=7.46382e-06
#  fSumw[12][339]=0, x=140, y=1.93429, error=0
#  fSumw[13][339]=4.92251e-05, x=150, y=1.93429, error=4.92251e-05
#  fSumw[14][339]=7.1025e-05, x=160, y=1.93429, error=5.17322e-05
#  fSumw[0][340]=0.000286702, x=20, y=1.94, error=0.000566335
#  fSumw[1][340]=0.000814119, x=30, y=1.94, error=0.000792886
#  fSumw[2][340]=0.00140802, x=40, y=1.94, error=0.000536633
#  fSumw[3][340]=0.000370017, x=50, y=1.94, error=0.000267537
#  fSumw[4][340]=8.37231e-05, x=60, y=1.94, error=5.1739e-05
#  fSumw[5][340]=0, x=70, y=1.94, error=0
#  fSumw[6][340]=-0.000617254, x=80, y=1.94, error=0.000442401
#  fSumw[7][340]=0, x=90, y=1.94, error=0
#  fSumw[8][340]=0, x=100, y=1.94, error=0
#  fSumw[9][340]=1.19155e-05, x=110, y=1.94, error=1.19155e-05
#  fSumw[10][340]=0, x=120, y=1.94, error=0
#  fSumw[11][340]=0, x=130, y=1.94, error=0
#  fSumw[12][340]=0, x=140, y=1.94, error=0
#  fSumw[13][340]=0, x=150, y=1.94, error=0
#  fSumw[14][340]=0.000209902, x=160, y=1.94, error=0.000209902
#  fSumw[0][341]=0.00056199, x=20, y=1.94571, error=0.000706641
#  fSumw[1][341]=0.000790302, x=30, y=1.94571, error=0.000631233
#  fSumw[2][341]=0.00170323, x=40, y=1.94571, error=0.000760488
#  fSumw[3][341]=0.000316379, x=50, y=1.94571, error=0.000238741
#  fSumw[4][341]=0.000334253, x=60, y=1.94571, error=0.00027824
#  fSumw[5][341]=5.62426e-05, x=70, y=1.94571, error=3.64941e-05
#  fSumw[6][341]=4.61075e-06, x=80, y=1.94571, error=4.61075e-06
#  fSumw[7][341]=-3.0999e-05, x=90, y=1.94571, error=3.78584e-05
#  fSumw[8][341]=-0.000284692, x=100, y=1.94571, error=0.000284692
#  fSumw[9][341]=0, x=110, y=1.94571, error=0
#  fSumw[10][341]=0, x=120, y=1.94571, error=0
#  fSumw[11][341]=0, x=130, y=1.94571, error=0
#  fSumw[12][341]=0, x=140, y=1.94571, error=0
#  fSumw[13][341]=2.81283e-05, x=150, y=1.94571, error=2.81283e-05
#  fSumw[14][341]=0, x=160, y=1.94571, error=0
#  fSumw[0][342]=0.000296887, x=20, y=1.95143, error=0.0002898
#  fSumw[1][342]=0.0021367, x=30, y=1.95143, error=0.000785012
#  fSumw[2][342]=3.51493e-05, x=40, y=1.95143, error=0.000450583
#  fSumw[3][342]=-0.000104984, x=50, y=1.95143, error=0.000227389
#  fSumw[4][342]=-4.83982e-05, x=60, y=1.95143, error=8.26727e-05
#  fSumw[5][342]=0.000332975, x=70, y=1.95143, error=0.000276505
#  fSumw[6][342]=8.5835e-06, x=80, y=1.95143, error=8.5835e-06
#  fSumw[7][342]=3.50375e-05, x=90, y=1.95143, error=2.96969e-05
#  fSumw[8][342]=0, x=100, y=1.95143, error=0
#  fSumw[9][342]=0, x=110, y=1.95143, error=0
#  fSumw[10][342]=4.72834e-06, x=120, y=1.95143, error=4.72834e-06
#  fSumw[11][342]=0, x=130, y=1.95143, error=0
#  fSumw[12][342]=0, x=140, y=1.95143, error=0
#  fSumw[13][342]=0, x=150, y=1.95143, error=0
#  fSumw[14][342]=3.89819e-06, x=160, y=1.95143, error=3.89819e-06
#  fSumw[0][343]=0.000117135, x=20, y=1.95714, error=0.000520062
#  fSumw[1][343]=0.00283495, x=30, y=1.95714, error=0.000972614
#  fSumw[2][343]=0.000287619, x=40, y=1.95714, error=0.00042405
#  fSumw[3][343]=0.000308096, x=50, y=1.95714, error=0.000227767
#  fSumw[4][343]=0.000158584, x=60, y=1.95714, error=8.18223e-05
#  fSumw[5][343]=0.000228518, x=70, y=1.95714, error=0.00025829
#  fSumw[6][343]=4.27986e-06, x=80, y=1.95714, error=8.39443e-06
#  fSumw[7][343]=5.79125e-05, x=90, y=1.95714, error=4.6015e-05
#  fSumw[8][343]=1.76045e-05, x=100, y=1.95714, error=1.32802e-05
#  fSumw[9][343]=5.99091e-06, x=110, y=1.95714, error=5.99091e-06
#  fSumw[10][343]=0, x=120, y=1.95714, error=0
#  fSumw[11][343]=0, x=130, y=1.95714, error=0
#  fSumw[12][343]=0, x=140, y=1.95714, error=0
#  fSumw[13][343]=0, x=150, y=1.95714, error=0
#  fSumw[14][343]=0, x=160, y=1.95714, error=0
#  fSumw[0][344]=0.000960477, x=20, y=1.96286, error=0.000434104
#  fSumw[1][344]=0.000508661, x=30, y=1.96286, error=0.000654101
#  fSumw[2][344]=0.00247913, x=40, y=1.96286, error=0.000810143
#  fSumw[3][344]=0.000201294, x=50, y=1.96286, error=8.655e-05
#  fSumw[4][344]=8.93931e-05, x=60, y=1.96286, error=5.08385e-05
#  fSumw[5][344]=1.27944e-05, x=70, y=1.96286, error=6.81082e-05
#  fSumw[6][344]=6.71865e-05, x=80, y=1.96286, error=3.69704e-05
#  fSumw[7][344]=-3.00666e-05, x=90, y=1.96286, error=5.77068e-05
#  fSumw[8][344]=5.24541e-06, x=100, y=1.96286, error=5.24541e-06
#  fSumw[9][344]=-3.11102e-05, x=110, y=1.96286, error=3.11102e-05
#  fSumw[10][344]=0, x=120, y=1.96286, error=0
#  fSumw[11][344]=0, x=130, y=1.96286, error=0
#  fSumw[12][344]=0, x=140, y=1.96286, error=0
#  fSumw[13][344]=0, x=150, y=1.96286, error=0
#  fSumw[14][344]=0, x=160, y=1.96286, error=0
#  fSumw[0][345]=0.000468099, x=20, y=1.96857, error=0.000450203
#  fSumw[1][345]=0.00100226, x=30, y=1.96857, error=0.000575778
#  fSumw[2][345]=0.000691174, x=40, y=1.96857, error=0.000656292
#  fSumw[3][345]=1.70378e-05, x=50, y=1.96857, error=0.000449539
#  fSumw[4][345]=0.000108131, x=60, y=1.96857, error=0.000100374
#  fSumw[5][345]=0.000265331, x=70, y=1.96857, error=0.000265852
#  fSumw[6][345]=3.28421e-05, x=80, y=1.96857, error=2.66031e-05
#  fSumw[7][345]=0, x=90, y=1.96857, error=0
#  fSumw[8][345]=0, x=100, y=1.96857, error=0
#  fSumw[9][345]=1.61278e-05, x=110, y=1.96857, error=1.61278e-05
#  fSumw[10][345]=0, x=120, y=1.96857, error=0
#  fSumw[11][345]=0, x=130, y=1.96857, error=0
#  fSumw[12][345]=0, x=140, y=1.96857, error=0
#  fSumw[13][345]=0, x=150, y=1.96857, error=0
#  fSumw[14][345]=0, x=160, y=1.96857, error=0
#  fSumw[0][346]=4.11243e-05, x=20, y=1.97429, error=0.000410324
#  fSumw[1][346]=0.000359481, x=30, y=1.97429, error=0.000531668
#  fSumw[2][346]=0.000822468, x=40, y=1.97429, error=0.000434282
#  fSumw[3][346]=8.26868e-05, x=50, y=1.97429, error=4.79902e-05
#  fSumw[4][346]=0.000276135, x=60, y=1.97429, error=0.000203407
#  fSumw[5][346]=0, x=70, y=1.97429, error=0
#  fSumw[6][346]=-2.65826e-05, x=80, y=1.97429, error=3.52608e-05
#  fSumw[7][346]=1.23145e-05, x=90, y=1.97429, error=1.23145e-05
#  fSumw[8][346]=7.76854e-06, x=100, y=1.97429, error=7.76854e-06
#  fSumw[9][346]=0, x=110, y=1.97429, error=0
#  fSumw[10][346]=0, x=120, y=1.97429, error=0
#  fSumw[11][346]=0, x=130, y=1.97429, error=0
#  fSumw[12][346]=0, x=140, y=1.97429, error=0
#  fSumw[13][346]=0, x=150, y=1.97429, error=0
#  fSumw[14][346]=0, x=160, y=1.97429, error=0
#  fSumw[0][347]=0.000400757, x=20, y=1.98, error=0.000365616
#  fSumw[1][347]=0.00234163, x=30, y=1.98, error=0.000856672
#  fSumw[2][347]=0.00063444, x=40, y=1.98, error=0.0006738
#  fSumw[3][347]=0.000385767, x=50, y=1.98, error=0.000329174
#  fSumw[4][347]=6.56661e-05, x=60, y=1.98, error=3.8397e-05
#  fSumw[5][347]=-7.02891e-06, x=70, y=1.98, error=7.02891e-06
#  fSumw[6][347]=0, x=80, y=1.98, error=0
#  fSumw[7][347]=7.82539e-06, x=90, y=1.98, error=7.82539e-06
#  fSumw[8][347]=0, x=100, y=1.98, error=0
#  fSumw[9][347]=0, x=110, y=1.98, error=0
#  fSumw[10][347]=0, x=120, y=1.98, error=0
#  fSumw[11][347]=0, x=130, y=1.98, error=0
#  fSumw[12][347]=0, x=140, y=1.98, error=0
#  fSumw[13][347]=0, x=150, y=1.98, error=0
#  fSumw[14][347]=0, x=160, y=1.98, error=0
#  fSumw[0][348]=0.00119664, x=20, y=1.98571, error=0.00056207
#  fSumw[1][348]=0.000718393, x=30, y=1.98571, error=0.000424356
#  fSumw[2][348]=0.000134379, x=40, y=1.98571, error=0.000339869
#  fSumw[3][348]=0.000295834, x=50, y=1.98571, error=0.000230358
#  fSumw[4][348]=0.000235341, x=60, y=1.98571, error=0.000193421
#  fSumw[5][348]=8.86248e-05, x=70, y=1.98571, error=4.35777e-05
#  fSumw[6][348]=8.51718e-05, x=80, y=1.98571, error=6.11447e-05
#  fSumw[7][348]=0, x=90, y=1.98571, error=0
#  fSumw[8][348]=0, x=100, y=1.98571, error=0
#  fSumw[9][348]=0, x=110, y=1.98571, error=0
#  fSumw[10][348]=0, x=120, y=1.98571, error=0
#  fSumw[11][348]=0, x=130, y=1.98571, error=0
#  fSumw[12][348]=0, x=140, y=1.98571, error=0
#  fSumw[13][348]=7.62709e-06, x=150, y=1.98571, error=7.62709e-06
#  fSumw[14][348]=7.71821e-06, x=160, y=1.98571, error=7.71821e-06
#  fSumw[0][349]=0.00048531, x=20, y=1.99143, error=0.000477281
#  fSumw[1][349]=0.00170569, x=30, y=1.99143, error=0.000713776
#  fSumw[2][349]=0.000591167, x=40, y=1.99143, error=0.00062177
#  fSumw[3][349]=0.000329339, x=50, y=1.99143, error=0.00017981
#  fSumw[4][349]=5.55284e-05, x=60, y=1.99143, error=3.079e-05
#  fSumw[5][349]=0, x=70, y=1.99143, error=0
#  fSumw[6][349]=0, x=80, y=1.99143, error=0
#  fSumw[7][349]=3.14971e-05, x=90, y=1.99143, error=3.14971e-05
#  fSumw[8][349]=0.000226127, x=100, y=1.99143, error=0.000189194
#  fSumw[9][349]=0, x=110, y=1.99143, error=0
#  fSumw[10][349]=0, x=120, y=1.99143, error=0
#  fSumw[11][349]=0, x=130, y=1.99143, error=0
#  fSumw[12][349]=0, x=140, y=1.99143, error=0
#  fSumw[13][349]=0, x=150, y=1.99143, error=0
#  fSumw[14][349]=0, x=160, y=1.99143, error=0
#  fSumw[0][350]=0.00106998, x=20, y=1.99714, error=0.000554479
#  fSumw[1][350]=0.000995932, x=30, y=1.99714, error=0.000526164
#  fSumw[2][350]=0.000705247, x=40, y=1.99714, error=0.000446978
#  fSumw[3][350]=-9.94459e-05, x=50, y=1.99714, error=0.000198401
#  fSumw[4][350]=0.000225582, x=60, y=1.99714, error=0.000206184
#  fSumw[5][350]=0, x=70, y=1.99714, error=0
#  fSumw[6][350]=3.2638e-05, x=80, y=1.99714, error=3.11247e-05
#  fSumw[7][350]=0, x=90, y=1.99714, error=0
#  fSumw[8][350]=1.05377e-05, x=100, y=1.99714, error=1.98204e-05
#  fSumw[9][350]=0, x=110, y=1.99714, error=0
#  fSumw[10][350]=0, x=120, y=1.99714, error=0
#  fSumw[11][350]=0, x=130, y=1.99714, error=0
#  fSumw[12][350]=0, x=140, y=1.99714, error=0
#  fSumw[13][350]=0, x=150, y=1.99714, error=0
#  fSumw[14][350]=0, x=160, y=1.99714, error=0
#  fSumw[0][351]=0.238475, x=20, y=2.00286, error=0.00987792
#  fSumw[1][351]=0.0789514, x=30, y=2.00286, error=0.00611447
#  fSumw[2][351]=0.0332207, x=40, y=2.00286, error=0.0037982
#  fSumw[3][351]=0.0138519, x=50, y=2.00286, error=0.00231951
#  fSumw[4][351]=0.006245, x=60, y=2.00286, error=0.00140946
#  fSumw[5][351]=0.00360737, x=70, y=2.00286, error=0.00125503
#  fSumw[6][351]=0.00148054, x=80, y=2.00286, error=0.00102773
#  fSumw[7][351]=0.00167252, x=90, y=2.00286, error=0.000736125
#  fSumw[8][351]=0.000422564, x=100, y=2.00286, error=0.000513532
#  fSumw[9][351]=0.000945302, x=110, y=2.00286, error=0.00042626
#  fSumw[10][351]=-3.66033e-05, x=120, y=2.00286, error=0.000456763
#  fSumw[11][351]=0.00049943, x=130, y=2.00286, error=0.000327042
#  fSumw[12][351]=-7.02245e-05, x=140, y=2.00286, error=0.00021921
#  fSumw[13][351]=-0.000295319, x=150, y=2.00286, error=0.00032802
#  fSumw[14][351]=0.000526406, x=160, y=2.00286, error=0.000349541

# %%
def fit_resp(hist, pt_do, pt_up, method):
    # build fitting pdf
    x       = ROOT.RooRealVar("x", " ", 0, 2)
    mu      = ROOT.RooRealVar("mu",   " ",  hist.GetBinCenter(hist.GetMaximumBin()), 0.95, 1.05)
    sigma   = ROOT.RooRealVar("sigma",  " ", hist.GetStdDev(), 0.0, 0.5)
    alpha1  = ROOT.RooRealVar("alpha1", " ", 1,   1e-1,   3)
    alpha2  = ROOT.RooRealVar("alpha2", " ", 1,   1e-1,   3)
    n1      = ROOT.RooRealVar("n1",     " ", 80,    1,     200)
    n2      = ROOT.RooRealVar("n2",     " ", 80,    1,     200)
    pdf     = ROOT.RooCrystalBall("dcb", "dcb", x, mu, sigma, alpha1, n1, alpha2, n2)
    
    # histogram to be fitted
    dh = ROOT.RooDataHist("dh", "dh", x, ROOT.RooFit.Import(hist))
    x.setRange("fitRange", 0.65, 1.35)
    for i in range(10):
        results = pdf.fitTo(
            dh, 
            ROOT.RooFit.Minimizer("Minuit2", "minimize"),
            ROOT.RooFit.Range("fitRange"),
            ROOT.RooFit.Save(1), ROOT.RooFit.Strategy(2),
            ROOT.RooFit.SumW2Error(1), 
            ROOT.RooFit.PrintLevel(1)
        )
        if results.status() == 0:
            print(color.YELLOW + "Fitting succeed!" + color.END)
            break
    if results.status() != 0:
        print(color.RED + "Fitting failed after 10 trials!" + color.END)
        
    # visualization
    canv = ROOT.TCanvas("canv", "", 800, 650)
    canv.cd()
    canv.SetRightMargin(0.04)
    canv.SetTopMargin(0.075)
    canv.SetLeftMargin(0.14)
    canv.SetBottomMargin(0.14)

    xframe = x.frame(0.65, 1.35)
    dh.plotOn(
        xframe,
        RooFit.Name("hist"),
        # RooFit.Binning(nbins),
        RooFit.MarkerStyle(ROOT.kFullCircle), RooFit.MarkerSize(1.2),
        RooFit.LineWidth(2)
    )
    pdf.plotOn(
        xframe,
        RooFit.Name("pdf"),
        # RooFit.NormRange("NormRange"),
        RooFit.LineColor(ROOT.kRed - 4), RooFit.LineWidth(2)
    )
    dh.plotOn(
        xframe,
        RooFit.Name("hist"),
        # RooFit.Binning(nbins),
        RooFit.MarkerStyle(ROOT.kFullCircle), RooFit.MarkerSize(1.2),
        RooFit.LineWidth(2)
    )
    xframe.SetTitle("")
    xframe.GetXaxis().SetTitleSize(0.047)
    xframe.GetXaxis().SetLabelSize(0.046)
    xframe.GetXaxis().SetTitleOffset(1.24)
    xframe.GetXaxis().SetLabelOffset(0.012)
    xframe.GetXaxis().SetTitle("p^{Reco}_{T} / p^{True}_{T}")
    # xframe.GetYaxis().SetTitle("Events / 0.005")
    xframe.GetYaxis().SetTitleSize(0.047)
    xframe.GetYaxis().SetLabelSize(0.046)
    xframe.GetYaxis().SetTitleOffset(1.4)
    xframe.SetMaximum(xframe.GetMaximum() * 1.5)
    xframe.SetMinimum(0)
    xframe.Draw()
    
    leg = ROOT.TLegend(0.17, 0.64, 0.45, 0.76)
    leg.SetTextFont(42)
    leg.SetTextSize(0.04)
    leg.SetFillColor(0)
    leg.SetLineColor(0)
    leg.AddEntry(xframe.findObject("hist"), "Simulation", "LE1P")
    leg.AddEntry(xframe.findObject("pdf"), "DCB", "l")
    leg.Draw("same")

    var1 = results.floatParsFinal().find("mu")
    var2 = results.floatParsFinal().find("sigma")
    ltx = ROOT.TLatex()
    ltx.SetNDC()
    ltx.SetTextFont(42)
    ltx.SetTextSize(0.045)
    ltx.DrawLatex(0.58, 0.86, " #mu = %.4f #pm %.4f" %(var1.getValV(), var1.getError()))
    ltx.DrawLatex(0.58, 0.81, " #sigma = %.4f #pm %.4f" %(var2.getValV(), var2.getError()))
    
    region = "ECAL Barrrel" if iBE == 0 else "ECAL Endcap"
    ltx.DrawLatex(0.18, 0.58, "%d < p^{true}_{T} < %d GeV" %(pt_do, pt_up))
    ltx.DrawLatex(0.18, 0.5, region)
    
    CMS_lumi(canv, 5, 10, "", 2017, True, "Simulation Preliminary", "H #rightarrow #gamma* #gamma #rightarrow ee#gamma", "")
    canv.Update()
    canv.RedrawAxis()

    reg_ext = "EB" if iBE == 0 else "EE"
    directory = "../plots/validation/resp_fit/{}".format(reg_ext)
    if not os.path.exists(directory):
        os.makedirs(directory)
    canv.Print("{}/respFit_pt_{}_{}To{}GeV.pdf".format(directory, method, int(pt_do), int(pt_up)))
    canv.Close()
    
    return results

# %%
x_mu, y_mu, xerr_mu, yerr_mu = [], [], [], []
x_width, y_width, xerr_width, yerr_width = [], [], [], []
for i in range(hist2D_XGB.GetNbinsX()):
# for i in range(1):
    pt_do = hist2D_XGB.GetXaxis().GetBinLowEdge(i+1) 
    pt_up = hist2D_XGB.GetXaxis().GetBinUpEdge(i+1)
    print(color.GREEN + "[INFO] Perform the fitting in range [%d, %d]" %(int(pt_do), int(pt_up)) + color.END)
    histName_XGB = "hist1D_XGB_{}To{}".format(pt_do, pt_up)
    hist_XGB = hist2D_XGB.ProjectionY(histName_XGB, i+1, i+1).Clone()
    fitRes = fit_resp(hist_XGB, pt_do, pt_up, "XGB")
    fitRes.Print("V")
    
    x_mu.append(pt_do+(pt_up-pt_do)/2)
    y_mu.append(fitRes.floatParsFinal().find("mu").getValV())
    xerr_mu.append((pt_up-pt_do)/2)
    yerr_mu.append(fitRes.floatParsFinal().find("mu").getError())
    
    sigma_ave = fitRes.floatParsFinal().find("sigma").getValV()
    sigma_ave_err = fitRes.floatParsFinal().find("sigma").getError()
    x_width.append(pt_do+(pt_up-pt_do)/2)
    y_width.append(sigma_ave)
    xerr_width.append((pt_up-pt_do)/2)
    yerr_width.append(sigma_ave_err)
    
mu_err_XGB = ROOT.TGraphErrors(hist2D_XGB.GetNbinsX(), np.array(x_mu), np.array(y_mu), np.array(xerr_mu), np.array(yerr_mu)) 
width_err_XGB = ROOT.TGraphErrors(hist2D_XGB.GetNbinsX(), np.array(x_width), np.array(y_width), np.array(xerr_width), np.array(yerr_width)) 
width_err_XGB.Print()
# Out:
# [INFO] Perform the fitting in range [25, 35]
# Fitting succeed!
# [INFO] Perform the fitting in range [35, 45]
# Fitting succeed!
# [INFO] Perform the fitting in range [45, 55]
# Fitting succeed!
# [INFO] Perform the fitting in range [55, 65]
# Fitting succeed!
# [INFO] Perform the fitting in range [65, 75]
# Fitting succeed!
# [INFO] Perform the fitting in range [75, 85]
# Fitting succeed!
# [INFO] Perform the fitting in range [85, 95]
# Fitting succeed!
# [INFO] Perform the fitting in range [95, 105]
# Fitting succeed!
# [INFO] Perform the fitting in range [105, 115]
# Fitting succeed!
# [INFO] Perform the fitting in range [115, 125]
# Fitting succeed!
# [INFO] Perform the fitting in range [125, 135]
# Fitting succeed!
# [INFO] Perform the fitting in range [135, 145]
# Fitting succeed!
# [INFO] Perform the fitting in range [145, 155]
# Fitting succeed!
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-7.32034) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1.43954	alpha2=1.77489	mu=1.00969	n1=198.902	n2=1.23494	sigma=0.035594
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.654286, x0=mu=1.00969, sigmaL=sigma=0.035594, sigmaR=sigma=0.035594, alphaL=alpha1=1.43954, nL=n1=198.902, alphaR=alpha2=1.77489, nR=n2=1.23494
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.654286, x0=mu=1.00969, sigmaL=sigma=0.035594, sigmaR=sigma=0.035594, alphaL=alpha1=1.43954, nL=n1=198.902, alphaR=alpha2=1.77489, nR=n2=1.23494
#      p.d.f value is Not-a-Number @ x=x=0.66, x0=mu=1.00969, sigmaL=sigma=0.035594, sigmaR=sigma=0.035594, alphaL=alpha1=1.43954, nL=n1=198.902, alphaR=alpha2=1.77489, nR=n2=1.23494
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.66, x0=mu=1.00969, sigmaL=sigma=0.035594, sigmaR=sigma=0.035594, alphaL=alpha1=1.43954, nL=n1=198.902, alphaR=alpha2=1.77489, nR=n2=1.23494
#      p.d.f value is Not-a-Number @ x=x=0.665714, x0=mu=1.00969, sigmaL=sigma=0.035594, sigmaR=sigma=0.035594, alphaL=alpha1=1.43954, nL=n1=198.902, alphaR=alpha2=1.77489, nR=n2=1.23494
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.665714, x0=mu=1.00969, sigmaL=sigma=0.035594, sigmaR=sigma=0.035594, alphaL=alpha1=1.43954, nL=n1=198.902, alphaR=alpha2=1.77489, nR=n2=1.23494
#      p.d.f value is Not-a-Number @ x=x=0.671429, x0=mu=1.00969, sigmaL=sigma=0.035594, sigmaR=sigma=0.035594, alphaL=alpha1=1.43954, nL=n1=198.902, alphaR=alpha2=1.77489, nR=n2=1.23494
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.671429, x0=mu=1.00969, sigmaL=sigma=0.035594, sigmaR=sigma=0.035594, alphaL=alpha1=1.43954, nL=n1=198.902, alphaR=alpha2=1.77489, nR=n2=1.23494
#      p.d.f value is Not-a-Number @ x=x=0.677143, x0=mu=1.00969, sigmaL=sigma=0.035594, sigmaR=sigma=0.035594, alphaL=alpha1=1.43954, nL=n1=198.902, alphaR=alpha2=1.77489, nR=n2=1.23494
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.677143, x0=mu=1.00969, sigmaL=sigma=0.035594, sigmaR=sigma=0.035594, alphaL=alpha1=1.43954, nL=n1=198.902, alphaR=alpha2=1.77489, nR=n2=1.23494
#      p.d.f value is Not-a-Number @ x=x=0.682857, x0=mu=1.00969, sigmaL=sigma=0.035594, sigmaR=sigma=0.035594, alphaL=alpha1=1.43954, nL=n1=198.902, alphaR=alpha2=1.77489, nR=n2=1.23494
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.682857, x0=mu=1.00969, sigmaL=sigma=0.035594, sigmaR=sigma=0.035594, alphaL=alpha1=1.43954, nL=n1=198.902, alphaR=alpha2=1.77489, nR=n2=1.23494
#     ... (remaining 166 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1.43954,alpha2 = 1.77489,mu = 1.00969,n1 = 198.902,n2 = 1.23494,sigma = 0.035594)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.654286), !jacList=(), !facList=(), !func=dcb=-nan/0.111642, !sumCat=()
#
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -12.5501, estimated distance to minimum: 1.15486e-06
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.7266e+00 +/-  4.69e-02  <none>
#                 alpha2    1.0000e+00    1.9031e+00 +/-  5.93e-02  <none>
#                     mu    1.0029e+00    1.0068e+00 +/-  3.07e-04  <none>
#                     n1    8.0000e+01    3.0902e+00 +/-  2.77e-01  <none>
#                     n2    8.0000e+01    1.4945e+00 +/-  1.38e-01  <none>
#                  sigma    1.2467e-01    3.2816e-02 +/-  3.08e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -25.3587, estimated distance to minimum: 1.71266e-06
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.7687e+00 +/-  2.77e-02  <none>
#                 alpha2    1.0000e+00    1.9876e+00 +/-  3.11e-02  <none>
#                     mu    1.0029e+00    1.0033e+00 +/-  1.91e-04  <none>
#                     n1    8.0000e+01    1.8035e+00 +/-  7.90e-02  <none>
#                     n2    8.0000e+01    1.3247e+00 +/-  6.34e-02  <none>
#                  sigma    9.8297e-02    2.9835e-02 +/-  1.82e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -41.8592, estimated distance to minimum: 2.99114e-06
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.9549e+00 +/-  2.75e-02  <none>
#                 alpha2    1.0000e+00    1.9465e+00 +/-  2.06e-02  <none>
#                     mu    1.0029e+00    1.0019e+00 +/-  1.38e-04  <none>
#                     n1    8.0000e+01    1.4528e+00 +/-  5.68e-02  <none>
#                     n2    8.0000e+01    1.5414e+00 +/-  5.08e-02  <none>
#                  sigma    7.0975e-02    2.7171e-02 +/-  1.29e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-44.8878) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1	alpha2=1	mu=0.997143	n1=7.86223	n2=153.826	sigma=0.0230384
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1,alpha2 = 1,mu = 0.997143,n1 = 7.86223,n2 = 153.826,sigma = 0.0230384)
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.654286, x0=mu=0.997143, sigmaL=sigma=0.0230384, sigmaR=sigma=0.0230384, alphaL=alpha1=1, nL=n1=7.86223, alphaR=alpha2=1, nR=n2=153.826
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.66, x0=mu=0.997143, sigmaL=sigma=0.0230384, sigmaR=sigma=0.0230384, alphaL=alpha1=1, nL=n1=7.86223, alphaR=alpha2=1, nR=n2=153.826
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.665714, x0=mu=0.997143, sigmaL=sigma=0.0230384, sigmaR=sigma=0.0230384, alphaL=alpha1=1, nL=n1=7.86223, alphaR=alpha2=1, nR=n2=153.826
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.671429, x0=mu=0.997143, sigmaL=sigma=0.0230384, sigmaR=sigma=0.0230384, alphaL=alpha1=1, nL=n1=7.86223, alphaR=alpha2=1, nR=n2=153.826
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.677143, x0=mu=0.997143, sigmaL=sigma=0.0230384, sigmaR=sigma=0.0230384, alphaL=alpha1=1, nL=n1=7.86223, alphaR=alpha2=1, nR=n2=153.826
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.682857, x0=mu=0.997143, sigmaL=sigma=0.0230384, sigmaR=sigma=0.0230384, alphaL=alpha1=1, nL=n1=7.86223, alphaR=alpha2=1, nR=n2=153.826
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.688571, x0=mu=0.997143, sigmaL=sigma=0.0230384, sigmaR=sigma=0.0230384, alphaL=alpha1=1, nL=n1=7.86223, alphaR=alpha2=1, nR=n2=153.826
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.694286, x0=mu=0.997143, sigmaL=sigma=0.0230384, sigmaR=sigma=0.0230384, alphaL=alpha1=1, nL=n1=7.86223, alphaR=alpha2=1, nR=n2=153.826
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.7, x0=mu=0.997143, sigmaL=sigma=0.0230384, sigmaR=sigma=0.0230384, alphaL=alpha1=1, nL=n1=7.86223, alphaR=alpha2=1, nR=n2=153.826
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.705714, x0=mu=0.997143, sigmaL=sigma=0.0230384, sigmaR=sigma=0.0230384, alphaL=alpha1=1, nL=n1=7.86223, alphaR=alpha2=1, nR=n2=153.826
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.711429, x0=mu=0.997143, sigmaL=sigma=0.0230384, sigmaR=sigma=0.0230384, alphaL=alpha1=1, nL=n1=7.86223, alphaR=alpha2=1, nR=n2=153.826
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.717143, x0=mu=0.997143, sigmaL=sigma=0.0230384, sigmaR=sigma=0.0230384, alphaL=alpha1=1, nL=n1=7.86223, alphaR=alpha2=1, nR=n2=153.826
#     ... (remaining 169 messages suppressed)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.654286), !jacList=(), !facList=(), !func=dcb=0.000203861/0.0708037, !sumCat=()
#
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -57.0273, estimated distance to minimum: 2.44826e-06
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.9019e+00 +/-  5.76e-02  <none>
#                 alpha2    1.0000e+00    1.9925e+00 +/-  4.58e-02  <none>
#                     mu    9.9714e-01    9.9886e-01 +/-  1.32e-04  <none>
#                     n1    8.0000e+01    1.6465e+00 +/-  1.15e-01  <none>
#                     n2    8.0000e+01    2.0843e+00 +/-  1.20e-01  <none>
#                  sigma    5.7405e-02    2.3954e-02 +/-  2.26e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -34.2707, estimated distance to minimum: 1.59167e-06
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.9701e+00 +/-  2.35e-02  <none>
#                 alpha2    1.0000e+00    2.1394e+00 +/-  3.26e-02  <none>
#                     mu    9.9714e-01    9.9635e-01 +/-  1.30e-04  <none>
#                     n1    8.0000e+01    1.5485e+00 +/-  5.44e-02  <none>
#                     n2    8.0000e+01    1.7459e+00 +/-  8.60e-02  <none>
#                  sigma    5.6806e-02    2.2912e-02 +/-  1.12e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -17.9546, estimated distance to minimum: 6.59496e-07
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.8730e+00 +/-  3.66e-02  <none>
#                 alpha2    1.0000e+00    2.0288e+00 +/-  4.71e-02  <none>
#                     mu    9.9714e-01    9.9657e-01 +/-  1.86e-04  <none>
#                     n1    8.0000e+01    1.7987e+00 +/-  9.31e-02  <none>
#                     n2    8.0000e+01    1.8049e+00 +/-  1.20e-01  <none>
#                  sigma    5.8441e-02    2.1542e-02 +/-  1.69e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (345.645) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=2.80649	alpha2=0.748373	mu=0.98579	n1=32.3576	n2=138.11	sigma=0.00241674
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 2.80649,alpha2 = 0.748373,mu = 0.98579,n1 = 32.3576,n2 = 138.11,sigma = 0.00241674)
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.654286, x0=mu=0.98579, sigmaL=sigma=0.00241674, sigmaR=sigma=0.00241674, alphaL=alpha1=2.80649, nL=n1=32.3576, alphaR=alpha2=0.748373, nR=n2=138.11
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.66, x0=mu=0.98579, sigmaL=sigma=0.00241674, sigmaR=sigma=0.00241674, alphaL=alpha1=2.80649, nL=n1=32.3576, alphaR=alpha2=0.748373, nR=n2=138.11
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.665714, x0=mu=0.98579, sigmaL=sigma=0.00241674, sigmaR=sigma=0.00241674, alphaL=alpha1=2.80649, nL=n1=32.3576, alphaR=alpha2=0.748373, nR=n2=138.11
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.671429, x0=mu=0.98579, sigmaL=sigma=0.00241674, sigmaR=sigma=0.00241674, alphaL=alpha1=2.80649, nL=n1=32.3576, alphaR=alpha2=0.748373, nR=n2=138.11
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.677143, x0=mu=0.98579, sigmaL=sigma=0.00241674, sigmaR=sigma=0.00241674, alphaL=alpha1=2.80649, nL=n1=32.3576, alphaR=alpha2=0.748373, nR=n2=138.11
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.682857, x0=mu=0.98579, sigmaL=sigma=0.00241674, sigmaR=sigma=0.00241674, alphaL=alpha1=2.80649, nL=n1=32.3576, alphaR=alpha2=0.748373, nR=n2=138.11
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.688571, x0=mu=0.98579, sigmaL=sigma=0.00241674, sigmaR=sigma=0.00241674, alphaL=alpha1=2.80649, nL=n1=32.3576, alphaR=alpha2=0.748373, nR=n2=138.11
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.694286, x0=mu=0.98579, sigmaL=sigma=0.00241674, sigmaR=sigma=0.00241674, alphaL=alpha1=2.80649, nL=n1=32.3576, alphaR=alpha2=0.748373, nR=n2=138.11
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.7, x0=mu=0.98579, sigmaL=sigma=0.00241674, sigmaR=sigma=0.00241674, alphaL=alpha1=2.80649, nL=n1=32.3576, alphaR=alpha2=0.748373, nR=n2=138.11
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.705714, x0=mu=0.98579, sigmaL=sigma=0.00241674, sigmaR=sigma=0.00241674, alphaL=alpha1=2.80649, nL=n1=32.3576, alphaR=alpha2=0.748373, nR=n2=138.11
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.711429, x0=mu=0.98579, sigmaL=sigma=0.00241674, sigmaR=sigma=0.00241674, alphaL=alpha1=2.80649, nL=n1=32.3576, alphaR=alpha2=0.748373, nR=n2=138.11
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.717143, x0=mu=0.98579, sigmaL=sigma=0.00241674, sigmaR=sigma=0.00241674, alphaL=alpha1=2.80649, nL=n1=32.3576, alphaR=alpha2=0.748373, nR=n2=138.11
#     ... (remaining 175 messages suppressed)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.654286), !jacList=(), !facList=(), !func=dcb=4.21113e-38/0.369697, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (345.645) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=0.850255	alpha2=1.17296	mu=0.990208	n1=120.7	n2=93.3214	sigma=0.00147199
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 0.850255,alpha2 = 1.17296,mu = 0.990208,n1 = 120.7,n2 = 93.3214,sigma = 0.00147199)
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.654286, x0=mu=0.990208, sigmaL=sigma=0.00147199, sigmaR=sigma=0.00147199, alphaL=alpha1=0.850255, nL=n1=120.7, alphaR=alpha2=1.17296, nR=n2=93.3214
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.66, x0=mu=0.990208, sigmaL=sigma=0.00147199, sigmaR=sigma=0.00147199, alphaL=alpha1=0.850255, nL=n1=120.7, alphaR=alpha2=1.17296, nR=n2=93.3214
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.665714, x0=mu=0.990208, sigmaL=sigma=0.00147199, sigmaR=sigma=0.00147199, alphaL=alpha1=0.850255, nL=n1=120.7, alphaR=alpha2=1.17296, nR=n2=93.3214
#
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -11.055, estimated distance to minimum: 8.63481e-07
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.9829e+00 +/-  4.28e-02  <none>
#                 alpha2    1.0000e+00    2.0475e+00 +/-  4.74e-02  <none>
#                     mu    9.9714e-01    9.9672e-01 +/-  2.19e-04  <none>
#                     n1    8.0000e+01    1.5162e+00 +/-  9.29e-02  <none>
#                     n2    8.0000e+01    1.6442e+00 +/-  1.12e-01  <none>
#                  sigma    6.3444e-02    2.0389e-02 +/-  1.85e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -7.47151, estimated distance to minimum: 9.63271e-07
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    2.0047e+00 +/-  5.46e-02  <none>
#                 alpha2    1.0000e+00    2.0717e+00 +/-  5.76e-02  <none>
#                     mu    9.9714e-01    9.9642e-01 +/-  2.58e-04  <none>
#                     n1    8.0000e+01    1.5380e+00 +/-  1.20e-01  <none>
#                     n2    8.0000e+01    1.6341e+00 +/-  1.40e-01  <none>
#                  sigma    5.5880e-02    1.9934e-02 +/-  2.15e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.78141) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1	alpha2=1	mu=0.997143	n1=142.909	n2=80	sigma=0.0192389
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.654286, x0=mu=0.997143, sigmaL=sigma=0.0192389, sigmaR=sigma=0.0192389, alphaL=alpha1=1, nL=n1=142.909, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.66, x0=mu=0.997143, sigmaL=sigma=0.0192389, sigmaR=sigma=0.0192389, alphaL=alpha1=1, nL=n1=142.909, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.665714, x0=mu=0.997143, sigmaL=sigma=0.0192389, sigmaR=sigma=0.0192389, alphaL=alpha1=1, nL=n1=142.909, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.671429, x0=mu=0.997143, sigmaL=sigma=0.0192389, sigmaR=sigma=0.0192389, alphaL=alpha1=1, nL=n1=142.909, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.677143, x0=mu=0.997143, sigmaL=sigma=0.0192389, sigmaR=sigma=0.0192389, alphaL=alpha1=1, nL=n1=142.909, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.682857, x0=mu=0.997143, sigmaL=sigma=0.0192389, sigmaR=sigma=0.0192389, alphaL=alpha1=1, nL=n1=142.909, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.688571, x0=mu=0.997143, sigmaL=sigma=0.0192389, sigmaR=sigma=0.0192389, alphaL=alpha1=1, nL=n1=142.909, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.694286, x0=mu=0.997143, sigmaL=sigma=0.0192389, sigmaR=sigma=0.0192389, alphaL=alpha1=1, nL=n1=142.909, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.7, x0=mu=0.997143, sigmaL=sigma=0.0192389, sigmaR=sigma=0.0192389, alphaL=alpha1=1, nL=n1=142.909, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.705714, x0=mu=0.997143, sigmaL=sigma=0.0192389, sigmaR=sigma=0.0192389, alphaL=alpha1=1, nL=n1=142.909, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.711429, x0=mu=0.997143, sigmaL=sigma=0.0192389, sigmaR=sigma=0.0192389, alphaL=alpha1=1, nL=n1=142.909, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.717143, x0=mu=0.997143, sigmaL=sigma=0.0192389, sigmaR=sigma=0.0192389, alphaL=alpha1=1, nL=n1=142.909, alphaR=alpha2=1, nR=n2=80
#     ... (remaining 45 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1,alpha2 = 1,mu = 0.997143,n1 = 142.909,n2 = 80,sigma = 0.0192389)
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-3.78141) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=2.97699	alpha2=0.241357	mu=1.04615	n1=1.00285	n2=187.973	sigma=0.498271
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.654286, x0=mu=1.04615, sigmaL=sigma=0.498271, sigmaR=sigma=0.498271, alphaL=alpha1=2.97699, nL=n1=1.00285, alphaR=alpha2=0.241357, nR=n2=187.973
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.66, x0=mu=1.04615, sigmaL=sigma=0.498271, sigmaR=sigma=0.498271, alphaL=alpha1=2.97699, nL=n1=1.00285, alphaR=alpha2=0.241357, nR=n2=187.973
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.665714, x0=mu=1.04615, sigmaL=sigma=0.498271, sigmaR=sigma=0.498271, alphaL=alpha1=2.97699, nL=n1=1.00285, alphaR=alpha2=0.241357, nR=n2=187.973
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.671429, x0=mu=1.04615, sigmaL=sigma=0.498271, sigmaR=sigma=0.498271, alphaL=alpha1=2.97699, nL=n1=1.00285, alphaR=alpha2=0.241357, nR=n2=187.973
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.677143, x0=mu=1.04615, sigmaL=sigma=0.498271, sigmaR=sigma=0.498271, alphaL=alpha1=2.97699, nL=n1=1.00285, alphaR=alpha2=0.241357, nR=n2=187.973
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.682857, x0=mu=1.04615, sigmaL=sigma=0.498271, sigmaR=sigma=0.498271, alphaL=alpha1=2.97699, nL=n1=1.00285, alphaR=alpha2=0.241357, nR=n2=187.973
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.688571, x0=mu=1.04615, sigmaL=sigma=0.498271, sigmaR=sigma=0.498271, alphaL=alpha1=2.97699, nL=n1=1.00285, alphaR=alpha2=0.241357, nR=n2=187.973
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.694286, x0=mu=1.04615, sigmaL=sigma=0.498271, sigmaR=sigma=0.498271, alphaL=alpha1=2.97699, nL=n1=1.00285, alphaR=alpha2=0.241357, nR=n2=187.973
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.7, x0=mu=1.04615, sigmaL=sigma=0.498271, sigmaR=sigma=0.498271, alphaL=alpha1=2.97699, nL=n1=1.00285, alphaR=alpha2=0.241357, nR=n2=187.973
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.705714, x0=mu=1.04615, sigmaL=sigma=0.498271, sigmaR=sigma=0.498271, alphaL=alpha1=2.97699, nL=n1=1.00285, alphaR=alpha2=0.241357, nR=n2=187.973
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.711429, x0=mu=1.04615, sigmaL=sigma=0.498271, sigmaR=sigma=0.498271, alphaL=alpha1=2.97699, nL=n1=1.00285, alphaR=alpha2=0.241357, nR=n2=187.973
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.717143, x0=mu=1.04615, sigmaL=sigma=0.498271, sigmaR=sigma=0.498271, alphaL=alpha1=2.97699, nL=n1=1.00285, alphaR=alpha2=0.241357, nR=n2=187.973
#     ... (remaining 144 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 2.97699,alpha2 = 0.241357,mu = 1.04615,n1 = 1.00285,n2 = 187.973,sigma = 0.498271)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.654286), !jacList=(), !facList=(), !func=dcb=0.733992/0.061366, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (4.40014) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1.89299	alpha2=0.221314	mu=0.997771	n1=5.32491	n2=192.274	sigma=0.0121715
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.654286, x0=mu=0.997771, sigmaL=sigma=0.0121715, sigmaR=sigma=0.0121715, alphaL=alpha1=1.89299, nL=n1=5.32491, alphaR=alpha2=0.221314, nR=n2=192.274
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.66, x0=mu=0.997771, sigmaL=sigma=0.0121715, sigmaR=sigma=0.0121715, alphaL=alpha1=1.89299, nL=n1=5.32491, alphaR=alpha2=0.221314, nR=n2=192.274
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.665714, x0=mu=0.997771, sigmaL=sigma=0.0121715, sigmaR=sigma=0.0121715, alphaL=alpha1=1.89299, nL=n1=5.32491, alphaR=alpha2=0.221314, nR=n2=192.274
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.671429, x0=mu=0.997771, sigmaL=sigma=0.0121715, sigmaR=sigma=0.0121715, alphaL=alpha1=1.89299, nL=n1=5.32491, alphaR=alpha2=0.221314, nR=n2=192.274
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.677143, x0=mu=0.997771, sigmaL=sigma=0.0121715, sigmaR=sigma=0.0121715, alphaL=alpha1=1.89299, nL=n1=5.32491, alphaR=alpha2=0.221314, nR=n2=192.274
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.682857, x0=mu=0.997771, sigmaL=sigma=0.0121715, sigmaR=sigma=0.0121715, alphaL=alpha1=1.89299, nL=n1=5.32491, alphaR=alpha2=0.221314, nR=n2=192.274
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.688571, x0=mu=0.997771, sigmaL=sigma=0.0121715, sigmaR=sigma=0.0121715, alphaL=alpha1=1.89299, nL=n1=5.32491, alphaR=alpha2=0.221314, nR=n2=192.274
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.694286, x0=mu=0.997771, sigmaL=sigma=0.0121715, sigmaR=sigma=0.0121715, alphaL=alpha1=1.89299, nL=n1=5.32491, alphaR=alpha2=0.221314, nR=n2=192.274
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.7, x0=mu=0.997771, sigmaL=sigma=0.0121715, sigmaR=sigma=0.0121715, alphaL=alpha1=1.89299, nL=n1=5.32491, alphaR=alpha2=0.221314, nR=n2=192.274
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.705714, x0=mu=0.997771, sigmaL=sigma=0.0121715, sigmaR=sigma=0.0121715, alphaL=alpha1=1.89299, nL=n1=5.32491, alphaR=alpha2=0.221314, nR=n2=192.274
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.711429, x0=mu=0.997771, sigmaL=sigma=0.0121715, sigmaR=sigma=0.0121715, alphaL=alpha1=1.89299, nL=n1=5.32491, alphaR=alpha2=0.221314, nR=n2=192.274
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.717143, x0=mu=0.997771, sigmaL=sigma=0.0121715, sigmaR=sigma=0.0121715, alphaL=alpha1=1.89299, nL=n1=5.32491, alphaR=alpha2=0.221314, nR=n2=192.274
#     ... (remaining 173 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1.89299,alpha2 = 0.221314,mu = 0.997771,n1 = 5.32491,n2 = 192.274,sigma = 0.0121715)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.654286), !jacList=(), !facList=(), !func=dcb=6.53622e-07/0.0669891, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (4.40014) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1.50506	alpha2=0.557064	mu=0.997631	n1=4.64558	n2=133.362	sigma=0.0143177
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.654286, x0=mu=0.997631, sigmaL=sigma=0.0143177, sigmaR=sigma=0.0143177, alphaL=alpha1=1.50506, nL=n1=4.64558, alphaR=alpha2=0.557064, nR=n2=133.362
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.66, x0=mu=0.997631, sigmaL=sigma=0.0143177, sigmaR=sigma=0.0143177, alphaL=alpha1=1.50506, nL=n1=4.64558, alphaR=alpha2=0.557064, nR=n2=133.362
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.665714, x0=mu=0.997631, sigmaL=sigma=0.0143177, sigmaR=sigma=0.0143177, alphaL=alpha1=1.50506, nL=n1=4.64558, alphaR=alpha2=0.557064, nR=n2=133.362
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.671429, x0=mu=0.997631, sigmaL=sigma=0.0143177, sigmaR=sigma=0.0143177, alphaL=alpha1=1.50506, nL=n1=4.64558, alphaR=alpha2=0.557064, nR=n2=133.362
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.677143, x0=mu=0.997631, sigmaL=sigma=0.0143177, sigmaR=sigma=0.0143177, alphaL=alpha1=1.50506, nL=n1=4.64558, alphaR=alpha2=0.557064, nR=n2=133.362
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.682857, x0=mu=0.997631, sigmaL=sigma=0.0143177, sigmaR=sigma=0.0143177, alphaL=alpha1=1.50506, nL=n1=4.64558, alphaR=alpha2=0.557064, nR=n2=133.362
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.688571, x0=mu=0.997631, sigmaL=sigma=0.0143177, sigmaR=sigma=0.0143177, alphaL=alpha1=1.50506, nL=n1=4.64558, alphaR=alpha2=0.557064, nR=n2=133.362
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.694286, x0=mu=0.997631, sigmaL=sigma=0.0143177, sigmaR=sigma=0.0143177, alphaL=alpha1=1.50506, nL=n1=4.64558, alphaR=alpha2=0.557064, nR=n2=133.362
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.7, x0=mu=0.997631, sigmaL=sigma=0.0143177, sigmaR=sigma=0.0143177, alphaL=alpha1=1.50506, nL=n1=4.64558, alphaR=alpha2=0.557064, nR=n2=133.362
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.705714, x0=mu=0.997631, sigmaL=sigma=0.0143177, sigmaR=sigma=0.0143177, alphaL=alpha1=1.50506, nL=n1=4.64558, alphaR=alpha2=0.557064, nR=n2=133.362
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.711429, x0=mu=0.997631, sigmaL=sigma=0.0143177, sigmaR=sigma=0.0143177, alphaL=alpha1=1.50506, nL=n1=4.64558, alphaR=alpha2=0.557064, nR=n2=133.362
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.717143, x0=mu=0.997631, sigmaL=sigma=0.0143177, sigmaR=sigma=0.0143177, alphaL=alpha1=1.50506, nL=n1=4.64558, alphaR=alpha2=0.557064, nR=n2=133.362
#     ... (remaining 172 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1.50506,alpha2 = 0.557064,mu = 0.997631,n1 = 4.64558,n2 = 133.362,sigma = 0.0143177)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.654286), !jacList=(), !facList=(), !func=dcb=1.7497e-05/-nan, !sumCat=()
#
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# ...
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (47.8739) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1	alpha2=1	mu=0.997143	n1=152.851	n2=80	sigma=0.0184732
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.654286, x0=mu=0.997143, sigmaL=sigma=0.0184732, sigmaR=sigma=0.0184732, alphaL=alpha1=1, nL=n1=152.851, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.654286, x0=mu=0.997143, sigmaL=sigma=0.0184732, sigmaR=sigma=0.0184732, alphaL=alpha1=1, nL=n1=152.851, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.66, x0=mu=0.997143, sigmaL=sigma=0.0184732, sigmaR=sigma=0.0184732, alphaL=alpha1=1, nL=n1=152.851, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.66, x0=mu=0.997143, sigmaL=sigma=0.0184732, sigmaR=sigma=0.0184732, alphaL=alpha1=1, nL=n1=152.851, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.665714, x0=mu=0.997143, sigmaL=sigma=0.0184732, sigmaR=sigma=0.0184732, alphaL=alpha1=1, nL=n1=152.851, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.665714, x0=mu=0.997143, sigmaL=sigma=0.0184732, sigmaR=sigma=0.0184732, alphaL=alpha1=1, nL=n1=152.851, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.671429, x0=mu=0.997143, sigmaL=sigma=0.0184732, sigmaR=sigma=0.0184732, alphaL=alpha1=1, nL=n1=152.851, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.671429, x0=mu=0.997143, sigmaL=sigma=0.0184732, sigmaR=sigma=0.0184732, alphaL=alpha1=1, nL=n1=152.851, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.677143, x0=mu=0.997143, sigmaL=sigma=0.0184732, sigmaR=sigma=0.0184732, alphaL=alpha1=1, nL=n1=152.851, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.677143, x0=mu=0.997143, sigmaL=sigma=0.0184732, sigmaR=sigma=0.0184732, alphaL=alpha1=1, nL=n1=152.851, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.682857, x0=mu=0.997143, sigmaL=sigma=0.0184732, sigmaR=sigma=0.0184732, alphaL=alpha1=1, nL=n1=152.851, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.682857, x0=mu=0.997143, sigmaL=sigma=0.0184732, sigmaR=sigma=0.0184732, alphaL=alpha1=1, nL=n1=152.851, alphaR=alpha2=1, nR=n2=80
#     ... (remaining 169 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1,alpha2 = 1,mu = 0.997143,n1 = 152.851,n2 = 80,sigma = 0.0184732)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.654286), !jacList=(), !facList=(), !func=dcb=-nan/0.0590602, !sumCat=()
#
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -2.83493, estimated distance to minimum: 1.1582e-06
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    2.2198e+00 +/-  5.93e-02  <none>
#                 alpha2    1.0000e+00    2.0338e+00 +/-  8.25e-02  <none>
#                     mu    9.9714e-01    9.9651e-01 +/-  3.84e-04  <none>
#                     n1    8.0000e+01    1.1274e+00 +/-  4.44e-02  <none>
#                     n2    8.0000e+01    1.5852e+00 +/-  1.85e-01  <none>
#                  sigma    6.4619e-02    1.8365e-02 +/-  3.12e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -2.02816, estimated distance to minimum: 7.66741e-07
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    2.3142e+00 +/-  9.05e-02  <none>
#                 alpha2    1.0000e+00    1.8535e+00 +/-  1.13e-01  <none>
#                     mu    1.0029e+00    9.9653e-01 +/-  4.54e-04  <none>
#                     n1    8.0000e+01    1.1510e+00 +/-  1.39e-01  <none>
#                     n2    8.0000e+01    1.7479e+00 +/-  2.50e-01  <none>
#                  sigma    5.4574e-02    1.7359e-02 +/-  3.64e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.10905) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1	alpha2=1	mu=0.997143	n1=80	n2=80	sigma=2.15104e-05
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1,alpha2 = 1,mu = 0.997143,n1 = 80,n2 = 80,sigma = 2.15104e-05)
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.654286, x0=mu=0.997143, sigmaL=sigma=2.15104e-05, sigmaR=sigma=2.15104e-05, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.66, x0=mu=0.997143, sigmaL=sigma=2.15104e-05, sigmaR=sigma=2.15104e-05, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.665714, x0=mu=0.997143, sigmaL=sigma=2.15104e-05, sigmaR=sigma=2.15104e-05, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.671429, x0=mu=0.997143, sigmaL=sigma=2.15104e-05, sigmaR=sigma=2.15104e-05, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.677143, x0=mu=0.997143, sigmaL=sigma=2.15104e-05, sigmaR=sigma=2.15104e-05, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.682857, x0=mu=0.997143, sigmaL=sigma=2.15104e-05, sigmaR=sigma=2.15104e-05, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.688571, x0=mu=0.997143, sigmaL=sigma=2.15104e-05, sigmaR=sigma=2.15104e-05, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.694286, x0=mu=0.997143, sigmaL=sigma=2.15104e-05, sigmaR=sigma=2.15104e-05, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.7, x0=mu=0.997143, sigmaL=sigma=2.15104e-05, sigmaR=sigma=2.15104e-05, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.705714, x0=mu=0.997143, sigmaL=sigma=2.15104e-05, sigmaR=sigma=2.15104e-05, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.711429, x0=mu=0.997143, sigmaL=sigma=2.15104e-05, sigmaR=sigma=2.15104e-05, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.717143, x0=mu=0.997143, sigmaL=sigma=2.15104e-05, sigmaR=sigma=2.15104e-05, alphaL=alpha1=1, nL=n1=80, alphaR=alpha2=1, nR=n2=80
#     ... (remaining 58 messages suppressed)
#
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -1.62189, estimated distance to minimum: 1.86928e-06
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.5608e+00 +/-  1.10e-01  <none>
#                 alpha2    1.0000e+00    2.0146e+00 +/-  1.26e-01  <none>
#                     mu    9.9714e-01    9.9746e-01 +/-  5.18e-04  <none>
#                     n1    8.0000e+01    2.4277e+00 +/-  3.53e-01  <none>
#                     n2    8.0000e+01    1.3925e+00 +/-  1.46e-01  <none>
#                  sigma    6.2399e-02    1.5872e-02 +/-  5.43e-04  <none>
#
# x[0]=30, y[0]=0.0328157, ex[0]=5, ey[0]=0.000307579
# x[1]=40, y[1]=0.0298355, ex[1]=5, ey[1]=0.000182252
# x[2]=50, y[2]=0.0271709, ex[2]=5, ey[2]=0.000129023
# x[3]=60, y[3]=0.0239537, ex[3]=5, ey[3]=0.000226404
# x[4]=70, y[4]=0.0229117, ex[4]=5, ey[4]=0.000112443
# x[5]=80, y[5]=0.0215424, ex[5]=5, ey[5]=0.000169442
# x[6]=90, y[6]=0.020389, ex[6]=5, ey[6]=0.000185066
# x[7]=100, y[7]=0.0199345, ex[7]=5, ey[7]=0.000215098
# x[8]=110, y[8]=0.019056, ex[8]=5, ey[8]=0.000242958
# x[9]=120, y[9]=0.0186539, ex[9]=5, ey[9]=0.000557065
# x[10]=130, y[10]=0.018365, ex[10]=5, ey[10]=0.00031178
# x[11]=140, y[11]=0.0173588, ex[11]=5, ey[11]=0.000364224
# x[12]=150, y[12]=0.0158723, ex[12]=5, ey[12]=0.000542966
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_XGB_25To35GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_XGB_35To45GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_XGB_45To55GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_XGB_55To65GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_XGB_65To75GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_XGB_75To85GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_XGB_85To95GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_XGB_95To105GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_XGB_105To115GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_XGB_115To125GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_XGB_125To135GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_XGB_135To145GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_XGB_145To155GeV.pdf has been created

# %%
x_mu_egm, y_mu_egm, xerr_mu_egm, yerr_mu_egm = [], [], [], []
x_width_egm, y_width_egm, xerr_width_egm, yerr_width_egm = [], [], [], []
for i in range(hist2D_EGM.GetNbinsX()):
    pt_do = hist2D_EGM.GetXaxis().GetBinLowEdge(i+1) 
    pt_up = hist2D_EGM.GetXaxis().GetBinUpEdge(i+1)
    print(color.GREEN + "[INFO] Perform the fitting in range [%d, %d]" %(int(pt_do), int(pt_up)) + color.END)
    histName_EGM = "hist1D_EGM_{}To{}".format(pt_do, pt_up) 
    hist_EGM = hist2D_EGM.ProjectionY(histName_EGM, i+1, i+1).Clone()
    fitRes = fit_resp(hist_EGM, pt_do, pt_up, "EGM")
    fitRes.Print("V")
    
    x_mu_egm.append(pt_do+(pt_up-pt_do)/2)
    y_mu_egm.append(fitRes.floatParsFinal().find("mu").getValV())
    xerr_mu_egm.append((pt_up-pt_do)/2)
    yerr_mu_egm.append(fitRes.floatParsFinal().find("mu").getError())
    
    sigma_ave = fitRes.floatParsFinal().find("sigma").getValV()
    sigma_ave_err = fitRes.floatParsFinal().find("sigma").getError()
    x_width_egm.append(pt_do+(pt_up-pt_do)/2)
    y_width_egm.append(sigma_ave)
    xerr_width_egm.append((pt_up-pt_do)/2)
    yerr_width_egm.append(sigma_ave_err)
    
mu_err_EGM = ROOT.TGraphErrors(hist2D_EGM.GetNbinsX(), np.array(x_mu_egm), np.array(y_mu_egm), np.array(xerr_mu_egm), np.array(yerr_mu_egm)) 
width_err_EGM = ROOT.TGraphErrors(hist2D_EGM.GetNbinsX(), np.array(x_width_egm), np.array(y_width_egm), np.array(xerr_width_egm), np.array(yerr_width_egm)) 
width_err_EGM.Print()
# Out:
# [INFO] Perform the fitting in range [25, 35]
# Fitting succeed!
# [INFO] Perform the fitting in range [35, 45]
# Fitting succeed!
# [INFO] Perform the fitting in range [45, 55]
# Fitting succeed!
# [INFO] Perform the fitting in range [55, 65]
# Fitting succeed!
# [INFO] Perform the fitting in range [65, 75]
# Fitting succeed!
# [INFO] Perform the fitting in range [75, 85]
# Fitting succeed!
# [INFO] Perform the fitting in range [85, 95]
# Fitting succeed!
# [INFO] Perform the fitting in range [95, 105]
# Fitting succeed!
# [INFO] Perform the fitting in range [105, 115]
# Fitting succeed!
# [INFO] Perform the fitting in range [115, 125]
# Fitting succeed!
# [INFO] Perform the fitting in range [125, 135]
# Fitting succeed!
# [INFO] Perform the fitting in range [135, 145]
# Fitting succeed!
# [INFO] Perform the fitting in range [145, 155]
# Fitting succeed!
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-6.68615) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1	alpha2=1	mu=0.98	n1=145.251	n2=80	sigma=0.0303825
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1,alpha2 = 1,mu = 0.98,n1 = 145.251,n2 = 80,sigma = 0.0303825)
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.654286, x0=mu=0.98, sigmaL=sigma=0.0303825, sigmaR=sigma=0.0303825, alphaL=alpha1=1, nL=n1=145.251, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.654286, x0=mu=0.98, sigmaL=sigma=0.0303825, sigmaR=sigma=0.0303825, alphaL=alpha1=1, nL=n1=145.251, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.66, x0=mu=0.98, sigmaL=sigma=0.0303825, sigmaR=sigma=0.0303825, alphaL=alpha1=1, nL=n1=145.251, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.66, x0=mu=0.98, sigmaL=sigma=0.0303825, sigmaR=sigma=0.0303825, alphaL=alpha1=1, nL=n1=145.251, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.665714, x0=mu=0.98, sigmaL=sigma=0.0303825, sigmaR=sigma=0.0303825, alphaL=alpha1=1, nL=n1=145.251, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.665714, x0=mu=0.98, sigmaL=sigma=0.0303825, sigmaR=sigma=0.0303825, alphaL=alpha1=1, nL=n1=145.251, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.671429, x0=mu=0.98, sigmaL=sigma=0.0303825, sigmaR=sigma=0.0303825, alphaL=alpha1=1, nL=n1=145.251, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.671429, x0=mu=0.98, sigmaL=sigma=0.0303825, sigmaR=sigma=0.0303825, alphaL=alpha1=1, nL=n1=145.251, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.677143, x0=mu=0.98, sigmaL=sigma=0.0303825, sigmaR=sigma=0.0303825, alphaL=alpha1=1, nL=n1=145.251, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.677143, x0=mu=0.98, sigmaL=sigma=0.0303825, sigmaR=sigma=0.0303825, alphaL=alpha1=1, nL=n1=145.251, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.682857, x0=mu=0.98, sigmaL=sigma=0.0303825, sigmaR=sigma=0.0303825, alphaL=alpha1=1, nL=n1=145.251, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.682857, x0=mu=0.98, sigmaL=sigma=0.0303825, sigmaR=sigma=0.0303825, alphaL=alpha1=1, nL=n1=145.251, alphaR=alpha2=1, nR=n2=80
#     ... (remaining 164 messages suppressed)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.654286), !jacList=(), !facList=(), !func=dcb=-nan/0.0953122, !sumCat=()
#
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -10.2815, estimated distance to minimum: 6.38486e-07
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.3088e+00 +/-  4.10e-02  <none>
#                 alpha2    1.0000e+00    2.1446e+00 +/-  4.14e-02  <none>
#                     mu    9.8000e-01    9.7744e-01 +/-  4.62e-04  <none>
#                     n1    8.0000e+01    1.0558e+01 +/-  2.04e+00  <none>
#                     n2    8.0000e+01    1.0062e+00 +/-  6.60e-02  <none>
#                  sigma    1.3420e-01    4.6371e-02 +/-  4.80e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.85377) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1	alpha2=1	mu=0.985714	n1=4.34992	n2=149.485	sigma=0.0401765
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.654286, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=149.485
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.66, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=149.485
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.665714, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=149.485
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.671429, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=149.485
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.677143, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=149.485
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.682857, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=149.485
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.688571, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=149.485
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.694286, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=149.485
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.7, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=149.485
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.705714, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=149.485
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.711429, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=149.485
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.717143, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=149.485
#     ... (remaining 168 messages suppressed)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.654286), !jacList=(), !facList=(), !func=dcb=0.00851162/0.126848, !sumCat=()
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1,alpha2 = 1,mu = 0.985714,n1 = 4.34992,n2 = 149.485,sigma = 0.0401765)
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.85377) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1	alpha2=1	mu=0.985714	n1=4.34992	n2=169.994	sigma=0.0401765
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.654286, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=169.994
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.66, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=169.994
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.665714, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=169.994
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.671429, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=169.994
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.677143, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=169.994
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.682857, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=169.994
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.688571, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=169.994
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.694286, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=169.994
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.7, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=169.994
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.705714, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=169.994
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.711429, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=169.994
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.717143, x0=mu=0.985714, sigmaL=sigma=0.0401765, sigmaR=sigma=0.0401765, alphaL=alpha1=1, nL=n1=4.34992, alphaR=alpha2=1, nR=n2=169.994
#     ... (remaining 168 messages suppressed)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.654286), !jacList=(), !facList=(), !func=dcb=0.00851162/-nan, !sumCat=()
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1,alpha2 = 1,mu = 0.985714,n1 = 4.34992,n2 = 169.994,sigma = 0.0401765)
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-1.85377) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=0.93658	alpha2=2.17348	mu=0.986532	n1=5.02511	n2=178.423	sigma=0.0275014
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.654286, x0=mu=0.986532, sigmaL=sigma=0.0275014, sigmaR=sigma=0.0275014, alphaL=alpha1=0.93658, nL=n1=5.02511, alphaR=alpha2=2.17348, nR=n2=178.423
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.66, x0=mu=0.986532, sigmaL=sigma=0.0275014, sigmaR=sigma=0.0275014, alphaL=alpha1=0.93658, nL=n1=5.02511, alphaR=alpha2=2.17348, nR=n2=178.423
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.665714, x0=mu=0.986532, sigmaL=sigma=0.0275014, sigmaR=sigma=0.0275014, alphaL=alpha1=0.93658, nL=n1=5.02511, alphaR=alpha2=2.17348, nR=n2=178.423
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.671429, x0=mu=0.986532, sigmaL=sigma=0.0275014, sigmaR=sigma=0.0275014, alphaL=alpha1=0.93658, nL=n1=5.02511, alphaR=alpha2=2.17348, nR=n2=178.423
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.677143, x0=mu=0.986532, sigmaL=sigma=0.0275014, sigmaR=sigma=0.0275014, alphaL=alpha1=0.93658, nL=n1=5.02511, alphaR=alpha2=2.17348, nR=n2=178.423
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.682857, x0=mu=0.986532, sigmaL=sigma=0.0275014, sigmaR=sigma=0.0275014, alphaL=alpha1=0.93658, nL=n1=5.02511, alphaR=alpha2=2.17348, nR=n2=178.423
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.688571, x0=mu=0.986532, sigmaL=sigma=0.0275014, sigmaR=sigma=0.0275014, alphaL=alpha1=0.93658, nL=n1=5.02511, alphaR=alpha2=2.17348, nR=n2=178.423
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.694286, x0=mu=0.986532, sigmaL=sigma=0.0275014, sigmaR=sigma=0.0275014, alphaL=alpha1=0.93658, nL=n1=5.02511, alphaR=alpha2=2.17348, nR=n2=178.423
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.7, x0=mu=0.986532, sigmaL=sigma=0.0275014, sigmaR=sigma=0.0275014, alphaL=alpha1=0.93658, nL=n1=5.02511, alphaR=alpha2=2.17348, nR=n2=178.423
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.705714, x0=mu=0.986532, sigmaL=sigma=0.0275014, sigmaR=sigma=0.0275014, alphaL=alpha1=0.93658, nL=n1=5.02511, alphaR=alpha2=2.17348, nR=n2=178.423
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.711429, x0=mu=0.986532, sigmaL=sigma=0.0275014, sigmaR=sigma=0.0275014, alphaL=alpha1=0.93658, nL=n1=5.02511, alphaR=alpha2=2.17348, nR=n2=178.423
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.717143, x0=mu=0.986532, sigmaL=sigma=0.0275014, sigmaR=sigma=0.0275014, alphaL=alpha1=0.93658, nL=n1=5.02511, alphaR=alpha2=2.17348, nR=n2=178.423
#     ... (remaining 165 messages suppressed)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.654286), !jacList=(), !facList=(), !func=dcb=0.00227277/0.125743, !sumCat=()
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 0.93658,alpha2 = 2.17348,mu = 0.986532,n1 = 5.02511,n2 = 178.423,sigma = 0.0275014)
#
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -21.1538, estimated distance to minimum: 9.99857e-07
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.4010e+00 +/-  2.44e-02  <none>
#                 alpha2    1.0000e+00    2.1099e+00 +/-  2.13e-02  <none>
#                     mu    9.8571e-01    9.8348e-01 +/-  2.68e-04  <none>
#                     n1    8.0000e+01    2.7695e+00 +/-  1.40e-01  <none>
#                     n2    8.0000e+01    1.0175e+00 +/-  3.80e-02  <none>
#                  sigma    1.0815e-01    3.9538e-02 +/-  2.43e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-11.3122) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1.07907	alpha2=1.15374	mu=1.01688	n1=45.5703	n2=139.689	sigma=0.00153962
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1.07907,alpha2 = 1.15374,mu = 1.01688,n1 = 45.5703,n2 = 139.689,sigma = 0.00153962)
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=1.08286, x0=mu=1.01688, sigmaL=sigma=0.00153962, sigmaR=sigma=0.00153962, alphaL=alpha1=1.07907, nL=n1=45.5703, alphaR=alpha2=1.15374, nR=n2=139.689
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=1.08857, x0=mu=1.01688, sigmaL=sigma=0.00153962, sigmaR=sigma=0.00153962, alphaL=alpha1=1.07907, nL=n1=45.5703, alphaR=alpha2=1.15374, nR=n2=139.689
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=1.09429, x0=mu=1.01688, sigmaL=sigma=0.00153962, sigmaR=sigma=0.00153962, alphaL=alpha1=1.07907, nL=n1=45.5703, alphaR=alpha2=1.15374, nR=n2=139.689
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=1.1, x0=mu=1.01688, sigmaL=sigma=0.00153962, sigmaR=sigma=0.00153962, alphaL=alpha1=1.07907, nL=n1=45.5703, alphaR=alpha2=1.15374, nR=n2=139.689
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=1.10571, x0=mu=1.01688, sigmaL=sigma=0.00153962, sigmaR=sigma=0.00153962, alphaL=alpha1=1.07907, nL=n1=45.5703, alphaR=alpha2=1.15374, nR=n2=139.689
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=1.11143, x0=mu=1.01688, sigmaL=sigma=0.00153962, sigmaR=sigma=0.00153962, alphaL=alpha1=1.07907, nL=n1=45.5703, alphaR=alpha2=1.15374, nR=n2=139.689
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=1.11714, x0=mu=1.01688, sigmaL=sigma=0.00153962, sigmaR=sigma=0.00153962, alphaL=alpha1=1.07907, nL=n1=45.5703, alphaR=alpha2=1.15374, nR=n2=139.689
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=1.12286, x0=mu=1.01688, sigmaL=sigma=0.00153962, sigmaR=sigma=0.00153962, alphaL=alpha1=1.07907, nL=n1=45.5703, alphaR=alpha2=1.15374, nR=n2=139.689
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=1.12857, x0=mu=1.01688, sigmaL=sigma=0.00153962, sigmaR=sigma=0.00153962, alphaL=alpha1=1.07907, nL=n1=45.5703, alphaR=alpha2=1.15374, nR=n2=139.689
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=1.13429, x0=mu=1.01688, sigmaL=sigma=0.00153962, sigmaR=sigma=0.00153962, alphaL=alpha1=1.07907, nL=n1=45.5703, alphaR=alpha2=1.15374, nR=n2=139.689
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=1.14, x0=mu=1.01688, sigmaL=sigma=0.00153962, sigmaR=sigma=0.00153962, alphaL=alpha1=1.07907, nL=n1=45.5703, alphaR=alpha2=1.15374, nR=n2=139.689
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=1.14571, x0=mu=1.01688, sigmaL=sigma=0.00153962, sigmaR=sigma=0.00153962, alphaL=alpha1=1.07907, nL=n1=45.5703, alphaR=alpha2=1.15374, nR=n2=139.689
#     ... (remaining 37 messages suppressed)
#
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -35.9422, estimated distance to minimum: 7.70701e-07
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.4364e+00 +/-  2.00e-02  <none>
#                 alpha2    1.0000e+00    2.0251e+00 +/-  2.47e-02  <none>
#                     mu    9.9714e-01    9.8835e-01 +/-  1.85e-04  <none>
#                     n1    8.0000e+01    2.6579e+00 +/-  9.58e-02  <none>
#                     n2    8.0000e+01    1.3444e+00 +/-  5.53e-02  <none>
#                  sigma    8.1468e-02    3.3819e-02 +/-  1.78e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-39.4248) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1.02901	alpha2=1.16126	mu=0.991544	n1=4.9756	n2=153.751	sigma=0.0281044
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.654286, x0=mu=0.991544, sigmaL=sigma=0.0281044, sigmaR=sigma=0.0281044, alphaL=alpha1=1.02901, nL=n1=4.9756, alphaR=alpha2=1.16126, nR=n2=153.751
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.66, x0=mu=0.991544, sigmaL=sigma=0.0281044, sigmaR=sigma=0.0281044, alphaL=alpha1=1.02901, nL=n1=4.9756, alphaR=alpha2=1.16126, nR=n2=153.751
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.665714, x0=mu=0.991544, sigmaL=sigma=0.0281044, sigmaR=sigma=0.0281044, alphaL=alpha1=1.02901, nL=n1=4.9756, alphaR=alpha2=1.16126, nR=n2=153.751
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.671429, x0=mu=0.991544, sigmaL=sigma=0.0281044, sigmaR=sigma=0.0281044, alphaL=alpha1=1.02901, nL=n1=4.9756, alphaR=alpha2=1.16126, nR=n2=153.751
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.677143, x0=mu=0.991544, sigmaL=sigma=0.0281044, sigmaR=sigma=0.0281044, alphaL=alpha1=1.02901, nL=n1=4.9756, alphaR=alpha2=1.16126, nR=n2=153.751
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.682857, x0=mu=0.991544, sigmaL=sigma=0.0281044, sigmaR=sigma=0.0281044, alphaL=alpha1=1.02901, nL=n1=4.9756, alphaR=alpha2=1.16126, nR=n2=153.751
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.688571, x0=mu=0.991544, sigmaL=sigma=0.0281044, sigmaR=sigma=0.0281044, alphaL=alpha1=1.02901, nL=n1=4.9756, alphaR=alpha2=1.16126, nR=n2=153.751
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.694286, x0=mu=0.991544, sigmaL=sigma=0.0281044, sigmaR=sigma=0.0281044, alphaL=alpha1=1.02901, nL=n1=4.9756, alphaR=alpha2=1.16126, nR=n2=153.751
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.7, x0=mu=0.991544, sigmaL=sigma=0.0281044, sigmaR=sigma=0.0281044, alphaL=alpha1=1.02901, nL=n1=4.9756, alphaR=alpha2=1.16126, nR=n2=153.751
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.705714, x0=mu=0.991544, sigmaL=sigma=0.0281044, sigmaR=sigma=0.0281044, alphaL=alpha1=1.02901, nL=n1=4.9756, alphaR=alpha2=1.16126, nR=n2=153.751
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.711429, x0=mu=0.991544, sigmaL=sigma=0.0281044, sigmaR=sigma=0.0281044, alphaL=alpha1=1.02901, nL=n1=4.9756, alphaR=alpha2=1.16126, nR=n2=153.751
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.717143, x0=mu=0.991544, sigmaL=sigma=0.0281044, sigmaR=sigma=0.0281044, alphaL=alpha1=1.02901, nL=n1=4.9756, alphaR=alpha2=1.16126, nR=n2=153.751
#     ... (remaining 169 messages suppressed)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.654286), !jacList=(), !facList=(), !func=dcb=0.00162394/0.0718702, !sumCat=()
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1.02901,alpha2 = 1.16126,mu = 0.991544,n1 = 4.9756,n2 = 153.751,sigma = 0.0281044)
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-39.4248) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1.18128	alpha2=1.14603	mu=0.990232	n1=2.02383	n2=198.351	sigma=0.0256842
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.654286, x0=mu=0.990232, sigmaL=sigma=0.0256842, sigmaR=sigma=0.0256842, alphaL=alpha1=1.18128, nL=n1=2.02383, alphaR=alpha2=1.14603, nR=n2=198.351
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.66, x0=mu=0.990232, sigmaL=sigma=0.0256842, sigmaR=sigma=0.0256842, alphaL=alpha1=1.18128, nL=n1=2.02383, alphaR=alpha2=1.14603, nR=n2=198.351
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.665714, x0=mu=0.990232, sigmaL=sigma=0.0256842, sigmaR=sigma=0.0256842, alphaL=alpha1=1.18128, nL=n1=2.02383, alphaR=alpha2=1.14603, nR=n2=198.351
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.671429, x0=mu=0.990232, sigmaL=sigma=0.0256842, sigmaR=sigma=0.0256842, alphaL=alpha1=1.18128, nL=n1=2.02383, alphaR=alpha2=1.14603, nR=n2=198.351
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.677143, x0=mu=0.990232, sigmaL=sigma=0.0256842, sigmaR=sigma=0.0256842, alphaL=alpha1=1.18128, nL=n1=2.02383, alphaR=alpha2=1.14603, nR=n2=198.351
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.682857, x0=mu=0.990232, sigmaL=sigma=0.0256842, sigmaR=sigma=0.0256842, alphaL=alpha1=1.18128, nL=n1=2.02383, alphaR=alpha2=1.14603, nR=n2=198.351
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.688571, x0=mu=0.990232, sigmaL=sigma=0.0256842, sigmaR=sigma=0.0256842, alphaL=alpha1=1.18128, nL=n1=2.02383, alphaR=alpha2=1.14603, nR=n2=198.351
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.694286, x0=mu=0.990232, sigmaL=sigma=0.0256842, sigmaR=sigma=0.0256842, alphaL=alpha1=1.18128, nL=n1=2.02383, alphaR=alpha2=1.14603, nR=n2=198.351
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.7, x0=mu=0.990232, sigmaL=sigma=0.0256842, sigmaR=sigma=0.0256842, alphaL=alpha1=1.18128, nL=n1=2.02383, alphaR=alpha2=1.14603, nR=n2=198.351
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.705714, x0=mu=0.990232, sigmaL=sigma=0.0256842, sigmaR=sigma=0.0256842, alphaL=alpha1=1.18128, nL=n1=2.02383, alphaR=alpha2=1.14603, nR=n2=198.351
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.711429, x0=mu=0.990232, sigmaL=sigma=0.0256842, sigmaR=sigma=0.0256842, alphaL=alpha1=1.18128, nL=n1=2.02383, alphaR=alpha2=1.14603, nR=n2=198.351
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.717143, x0=mu=0.990232, sigmaL=sigma=0.0256842, sigmaR=sigma=0.0256842, alphaL=alpha1=1.18128, nL=n1=2.02383, alphaR=alpha2=1.14603, nR=n2=198.351
#     ... (remaining 170 messages suppressed)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.654286), !jacList=(), !facList=(), !func=dcb=0.00750486/0.0907711, !sumCat=()
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1.18128,alpha2 = 1.14603,mu = 0.990232,n1 = 2.02383,n2 = 198.351,sigma = 0.0256842)
#
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -49.3422, estimated distance to minimum: 2.7521e-06
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.5366e+00 +/-  1.83e-02  <none>
#                 alpha2    1.0000e+00    2.0478e+00 +/-  3.41e-02  <none>
#                     mu    9.9143e-01    9.9044e-01 +/-  1.40e-04  <none>
#                     n1    8.0000e+01    2.2624e+00 +/-  6.69e-02  <none>
#                     n2    8.0000e+01    1.9585e+00 +/-  1.03e-01  <none>
#                  sigma    6.8133e-02    3.0138e-02 +/-  1.45e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (66.6173) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1	alpha2=1	mu=0.997143	n1=153.314	n2=80	sigma=0.0264118
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.654286, x0=mu=0.997143, sigmaL=sigma=0.0264118, sigmaR=sigma=0.0264118, alphaL=alpha1=1, nL=n1=153.314, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.654286, x0=mu=0.997143, sigmaL=sigma=0.0264118, sigmaR=sigma=0.0264118, alphaL=alpha1=1, nL=n1=153.314, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.66, x0=mu=0.997143, sigmaL=sigma=0.0264118, sigmaR=sigma=0.0264118, alphaL=alpha1=1, nL=n1=153.314, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.66, x0=mu=0.997143, sigmaL=sigma=0.0264118, sigmaR=sigma=0.0264118, alphaL=alpha1=1, nL=n1=153.314, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.665714, x0=mu=0.997143, sigmaL=sigma=0.0264118, sigmaR=sigma=0.0264118, alphaL=alpha1=1, nL=n1=153.314, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.665714, x0=mu=0.997143, sigmaL=sigma=0.0264118, sigmaR=sigma=0.0264118, alphaL=alpha1=1, nL=n1=153.314, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.671429, x0=mu=0.997143, sigmaL=sigma=0.0264118, sigmaR=sigma=0.0264118, alphaL=alpha1=1, nL=n1=153.314, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.671429, x0=mu=0.997143, sigmaL=sigma=0.0264118, sigmaR=sigma=0.0264118, alphaL=alpha1=1, nL=n1=153.314, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.677143, x0=mu=0.997143, sigmaL=sigma=0.0264118, sigmaR=sigma=0.0264118, alphaL=alpha1=1, nL=n1=153.314, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.677143, x0=mu=0.997143, sigmaL=sigma=0.0264118, sigmaR=sigma=0.0264118, alphaL=alpha1=1, nL=n1=153.314, alphaR=alpha2=1, nR=n2=80
#      p.d.f value is Not-a-Number @ x=x=0.682857, x0=mu=0.997143, sigmaL=sigma=0.0264118, sigmaR=sigma=0.0264118, alphaL=alpha1=1, nL=n1=153.314, alphaR=alpha2=1, nR=n2=80
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.682857, x0=mu=0.997143, sigmaL=sigma=0.0264118, sigmaR=sigma=0.0264118, alphaL=alpha1=1, nL=n1=153.314, alphaR=alpha2=1, nR=n2=80
#     ... (remaining 168 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1,alpha2 = 1,mu = 0.997143,n1 = 153.314,n2 = 80,sigma = 0.0264118)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.654286), !jacList=(), !facList=(), !func=dcb=-nan/0.0840269, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (83.6335) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1.31609	alpha2=1.66857	mu=0.979228	n1=1.14678	n2=164.931	sigma=0.0123243
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.654286, x0=mu=0.979228, sigmaL=sigma=0.0123243, sigmaR=sigma=0.0123243, alphaL=alpha1=1.31609, nL=n1=1.14678, alphaR=alpha2=1.66857, nR=n2=164.931
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.66, x0=mu=0.979228, sigmaL=sigma=0.0123243, sigmaR=sigma=0.0123243, alphaL=alpha1=1.31609, nL=n1=1.14678, alphaR=alpha2=1.66857, nR=n2=164.931
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.665714, x0=mu=0.979228, sigmaL=sigma=0.0123243, sigmaR=sigma=0.0123243, alphaL=alpha1=1.31609, nL=n1=1.14678, alphaR=alpha2=1.66857, nR=n2=164.931
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.671429, x0=mu=0.979228, sigmaL=sigma=0.0123243, sigmaR=sigma=0.0123243, alphaL=alpha1=1.31609, nL=n1=1.14678, alphaR=alpha2=1.66857, nR=n2=164.931
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.677143, x0=mu=0.979228, sigmaL=sigma=0.0123243, sigmaR=sigma=0.0123243, alphaL=alpha1=1.31609, nL=n1=1.14678, alphaR=alpha2=1.66857, nR=n2=164.931
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.682857, x0=mu=0.979228, sigmaL=sigma=0.0123243, sigmaR=sigma=0.0123243, alphaL=alpha1=1.31609, nL=n1=1.14678, alphaR=alpha2=1.66857, nR=n2=164.931
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.688571, x0=mu=0.979228, sigmaL=sigma=0.0123243, sigmaR=sigma=0.0123243, alphaL=alpha1=1.31609, nL=n1=1.14678, alphaR=alpha2=1.66857, nR=n2=164.931
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.694286, x0=mu=0.979228, sigmaL=sigma=0.0123243, sigmaR=sigma=0.0123243, alphaL=alpha1=1.31609, nL=n1=1.14678, alphaR=alpha2=1.66857, nR=n2=164.931
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.7, x0=mu=0.979228, sigmaL=sigma=0.0123243, sigmaR=sigma=0.0123243, alphaL=alpha1=1.31609, nL=n1=1.14678, alphaR=alpha2=1.66857, nR=n2=164.931
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.705714, x0=mu=0.979228, sigmaL=sigma=0.0123243, sigmaR=sigma=0.0123243, alphaL=alpha1=1.31609, nL=n1=1.14678, alphaR=alpha2=1.66857, nR=n2=164.931
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.711429, x0=mu=0.979228, sigmaL=sigma=0.0123243, sigmaR=sigma=0.0123243, alphaL=alpha1=1.31609, nL=n1=1.14678, alphaR=alpha2=1.66857, nR=n2=164.931
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.717143, x0=mu=0.979228, sigmaL=sigma=0.0123243, sigmaR=sigma=0.0123243, alphaL=alpha1=1.31609, nL=n1=1.14678, alphaR=alpha2=1.66857, nR=n2=164.931
#     ... (remaining 173 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1.31609,alpha2 = 1.66857,mu = 0.979228,n1 = 1.14678,n2 = 164.931,sigma = 0.0123243)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.654286), !jacList=(), !facList=(), !func=dcb=0.00859299/0.0174344, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (83.6335) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=1.90514	alpha2=2.24784	mu=1.03198	n1=118.998	n2=68.439	sigma=3.32738e-05
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.654286, x0=mu=1.03198, sigmaL=sigma=3.32738e-05, sigmaR=sigma=3.32738e-05, alphaL=alpha1=1.90514, nL=n1=118.998, alphaR=alpha2=2.24784, nR=n2=68.439
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.66, x0=mu=1.03198, sigmaL=sigma=3.32738e-05, sigmaR=sigma=3.32738e-05, alphaL=alpha1=1.90514, nL=n1=118.998, alphaR=alpha2=2.24784, nR=n2=68.439
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.665714, x0=mu=1.03198, sigmaL=sigma=3.32738e-05, sigmaR=sigma=3.32738e-05, alphaL=alpha1=1.90514, nL=n1=118.998, alphaR=alpha2=2.24784, nR=n2=68.439
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.671429, x0=mu=1.03198, sigmaL=sigma=3.32738e-05, sigmaR=sigma=3.32738e-05, alphaL=alpha1=1.90514, nL=n1=118.998, alphaR=alpha2=2.24784, nR=n2=68.439
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.677143, x0=mu=1.03198, sigmaL=sigma=3.32738e-05, sigmaR=sigma=3.32738e-05, alphaL=alpha1=1.90514, nL=n1=118.998, alphaR=alpha2=2.24784, nR=n2=68.439
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.682857, x0=mu=1.03198, sigmaL=sigma=3.32738e-05, sigmaR=sigma=3.32738e-05, alphaL=alpha1=1.90514, nL=n1=118.998, alphaR=alpha2=2.24784, nR=n2=68.439
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.688571, x0=mu=1.03198, sigmaL=sigma=3.32738e-05, sigmaR=sigma=3.32738e-05, alphaL=alpha1=1.90514, nL=n1=118.998, alphaR=alpha2=2.24784, nR=n2=68.439
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.694286, x0=mu=1.03198, sigmaL=sigma=3.32738e-05, sigmaR=sigma=3.32738e-05, alphaL=alpha1=1.90514, nL=n1=118.998, alphaR=alpha2=2.24784, nR=n2=68.439
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.7, x0=mu=1.03198, sigmaL=sigma=3.32738e-05, sigmaR=sigma=3.32738e-05, alphaL=alpha1=1.90514, nL=n1=118.998, alphaR=alpha2=2.24784, nR=n2=68.439
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.705714, x0=mu=1.03198, sigmaL=sigma=3.32738e-05, sigmaR=sigma=3.32738e-05, alphaL=alpha1=1.90514, nL=n1=118.998, alphaR=alpha2=2.24784, nR=n2=68.439
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.711429, x0=mu=1.03198, sigmaL=sigma=3.32738e-05, sigmaR=sigma=3.32738e-05, alphaL=alpha1=1.90514, nL=n1=118.998, alphaR=alpha2=2.24784, nR=n2=68.439
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.717143, x0=mu=1.03198, sigmaL=sigma=3.32738e-05, sigmaR=sigma=3.32738e-05, alphaL=alpha1=1.90514, nL=n1=118.998, alphaR=alpha2=2.24784, nR=n2=68.439
#     ... (remaining 55 messages suppressed)
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 1.90514,alpha2 = 2.24784,mu = 1.03198,n1 = 118.998,n2 = 68.439,sigma = 3.32738e-05)
#
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -30.5643, estimated distance to minimum: 1.32769e-06
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.5459e+00 +/-  2.24e-02  <none>
#                 alpha2    1.0000e+00    2.1342e+00 +/-  3.19e-02  <none>
#                     mu    9.9714e-01    9.9215e-01 +/-  1.65e-04  <none>
#                     n1    8.0000e+01    2.2706e+00 +/-  8.11e-02  <none>
#                     n2    8.0000e+01    1.6745e+00 +/-  8.89e-02  <none>
#                  sigma    6.6257e-02    2.7055e-02 +/-  1.51e-04  <none>
#
# [#0] WARNING:InputArguments -- The parameter 'sigma' with range [0, 0.5] of the RooCrystalBall 'dcb' exceeds the safe range of (0, inf). Advise to limit its range.
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fitRange' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) constructing test statistic for sub-range named fitRange
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'NormalizationRangeForfitRange' created with bounds [0,2]
# [#1] INFO:Eval -- RooRealVar::setRange(x) new range named 'fit_nll_dcb_dh' created with bounds [0.65,1.35]
# [#1] INFO:Fitting -- RooAbsOptTestStatistic::ctor(nll_dcb_dh) fixing interpretation of coefficients of any RooAddPdf to full domain of observables
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: activating const optimization
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (-4.18671) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=0.647709	alpha2=1.26938	mu=0.978541	n1=170.5	n2=56.138	sigma=0.245
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 0.647709,alpha2 = 1.26938,mu = 0.978541,n1 = 170.5,n2 = 56.138,sigma = 0.245)
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      p.d.f value is Not-a-Number @ x=x=0.654286, x0=mu=0.978541, sigmaL=sigma=0.245, sigmaR=sigma=0.245, alphaL=alpha1=0.647709, nL=n1=170.5, alphaR=alpha2=1.26938, nR=n2=56.138
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.654286, x0=mu=0.978541, sigmaL=sigma=0.245, sigmaR=sigma=0.245, alphaL=alpha1=0.647709, nL=n1=170.5, alphaR=alpha2=1.26938, nR=n2=56.138
# ...
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.66, x0=mu=0.95099, sigmaL=sigma=0.383725, sigmaR=sigma=0.383725, alphaL=alpha1=0.596146, nL=n1=158.945, alphaR=alpha2=2.42896, nR=n2=132.818
#      p.d.f value is Not-a-Number @ x=x=0.665714, x0=mu=0.95099, sigmaL=sigma=0.383725, sigmaR=sigma=0.383725, alphaL=alpha1=0.596146, nL=n1=158.945, alphaR=alpha2=2.42896, nR=n2=132.818
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.665714, x0=mu=0.95099, sigmaL=sigma=0.383725, sigmaR=sigma=0.383725, alphaL=alpha1=0.596146, nL=n1=158.945, alphaR=alpha2=2.42896, nR=n2=132.818
#      p.d.f value is Not-a-Number @ x=x=0.671429, x0=mu=0.95099, sigmaL=sigma=0.383725, sigmaR=sigma=0.383725, alphaL=alpha1=0.596146, nL=n1=158.945, alphaR=alpha2=2.42896, nR=n2=132.818
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.671429, x0=mu=0.95099, sigmaL=sigma=0.383725, sigmaR=sigma=0.383725, alphaL=alpha1=0.596146, nL=n1=158.945, alphaR=alpha2=2.42896, nR=n2=132.818
#      p.d.f value is Not-a-Number @ x=x=0.677143, x0=mu=0.95099, sigmaL=sigma=0.383725, sigmaR=sigma=0.383725, alphaL=alpha1=0.596146, nL=n1=158.945, alphaR=alpha2=2.42896, nR=n2=132.818
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.677143, x0=mu=0.95099, sigmaL=sigma=0.383725, sigmaR=sigma=0.383725, alphaL=alpha1=0.596146, nL=n1=158.945, alphaR=alpha2=2.42896, nR=n2=132.818
#      p.d.f value is Not-a-Number @ x=x=0.682857, x0=mu=0.95099, sigmaL=sigma=0.383725, sigmaR=sigma=0.383725, alphaL=alpha1=0.596146, nL=n1=158.945, alphaR=alpha2=2.42896, nR=n2=132.818
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.682857, x0=mu=0.95099, sigmaL=sigma=0.383725, sigmaR=sigma=0.383725, alphaL=alpha1=0.596146, nL=n1=158.945, alphaR=alpha2=2.42896, nR=n2=132.818
#     ... (remaining 123 messages suppressed)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.654286), !jacList=(), !facList=(), !func=dcb=-nan/0.065881, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (20.2782) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=0.176996	alpha2=2.30492	mu=0.951779	n1=3.50971	n2=175.696	sigma=0.0022185
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 0.176996,alpha2 = 2.30492,mu = 0.951779,n1 = 3.50971,n2 = 175.696,sigma = 0.0022185)
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.654286, x0=mu=0.951779, sigmaL=sigma=0.0022185, sigmaR=sigma=0.0022185, alphaL=alpha1=0.176996, nL=n1=3.50971, alphaR=alpha2=2.30492, nR=n2=175.696
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.66, x0=mu=0.951779, sigmaL=sigma=0.0022185, sigmaR=sigma=0.0022185, alphaL=alpha1=0.176996, nL=n1=3.50971, alphaR=alpha2=2.30492, nR=n2=175.696
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.665714, x0=mu=0.951779, sigmaL=sigma=0.0022185, sigmaR=sigma=0.0022185, alphaL=alpha1=0.176996, nL=n1=3.50971, alphaR=alpha2=2.30492, nR=n2=175.696
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.671429, x0=mu=0.951779, sigmaL=sigma=0.0022185, sigmaR=sigma=0.0022185, alphaL=alpha1=0.176996, nL=n1=3.50971, alphaR=alpha2=2.30492, nR=n2=175.696
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.677143, x0=mu=0.951779, sigmaL=sigma=0.0022185, sigmaR=sigma=0.0022185, alphaL=alpha1=0.176996, nL=n1=3.50971, alphaR=alpha2=2.30492, nR=n2=175.696
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.682857, x0=mu=0.951779, sigmaL=sigma=0.0022185, sigmaR=sigma=0.0022185, alphaL=alpha1=0.176996, nL=n1=3.50971, alphaR=alpha2=2.30492, nR=n2=175.696
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.688571, x0=mu=0.951779, sigmaL=sigma=0.0022185, sigmaR=sigma=0.0022185, alphaL=alpha1=0.176996, nL=n1=3.50971, alphaR=alpha2=2.30492, nR=n2=175.696
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.694286, x0=mu=0.951779, sigmaL=sigma=0.0022185, sigmaR=sigma=0.0022185, alphaL=alpha1=0.176996, nL=n1=3.50971, alphaR=alpha2=2.30492, nR=n2=175.696
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.7, x0=mu=0.951779, sigmaL=sigma=0.0022185, sigmaR=sigma=0.0022185, alphaL=alpha1=0.176996, nL=n1=3.50971, alphaR=alpha2=2.30492, nR=n2=175.696
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.705714, x0=mu=0.951779, sigmaL=sigma=0.0022185, sigmaR=sigma=0.0022185, alphaL=alpha1=0.176996, nL=n1=3.50971, alphaR=alpha2=2.30492, nR=n2=175.696
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.711429, x0=mu=0.951779, sigmaL=sigma=0.0022185, sigmaR=sigma=0.0022185, alphaL=alpha1=0.176996, nL=n1=3.50971, alphaR=alpha2=2.30492, nR=n2=175.696
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.717143, x0=mu=0.951779, sigmaL=sigma=0.0022185, sigmaR=sigma=0.0022185, alphaL=alpha1=0.176996, nL=n1=3.50971, alphaR=alpha2=2.30492, nR=n2=175.696
#     ... (remaining 179 messages suppressed)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.654286), !jacList=(), !facList=(), !func=dcb=0.00074352/0.322483, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (20.2782) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=0.288722	alpha2=2.57799	mu=1.01923	n1=3.67692	n2=183.462	sigma=0.000572678
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 0.288722,alpha2 = 2.57799,mu = 1.01923,n1 = 3.67692,n2 = 183.462,sigma = 0.000572678)
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.654286, x0=mu=1.01923, sigmaL=sigma=0.000572678, sigmaR=sigma=0.000572678, alphaL=alpha1=0.288722, nL=n1=3.67692, alphaR=alpha2=2.57799, nR=n2=183.462
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.66, x0=mu=1.01923, sigmaL=sigma=0.000572678, sigmaR=sigma=0.000572678, alphaL=alpha1=0.288722, nL=n1=3.67692, alphaR=alpha2=2.57799, nR=n2=183.462
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.665714, x0=mu=1.01923, sigmaL=sigma=0.000572678, sigmaR=sigma=0.000572678, alphaL=alpha1=0.288722, nL=n1=3.67692, alphaR=alpha2=2.57799, nR=n2=183.462
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.671429, x0=mu=1.01923, sigmaL=sigma=0.000572678, sigmaR=sigma=0.000572678, alphaL=alpha1=0.288722, nL=n1=3.67692, alphaR=alpha2=2.57799, nR=n2=183.462
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.677143, x0=mu=1.01923, sigmaL=sigma=0.000572678, sigmaR=sigma=0.000572678, alphaL=alpha1=0.288722, nL=n1=3.67692, alphaR=alpha2=2.57799, nR=n2=183.462
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.682857, x0=mu=1.01923, sigmaL=sigma=0.000572678, sigmaR=sigma=0.000572678, alphaL=alpha1=0.288722, nL=n1=3.67692, alphaR=alpha2=2.57799, nR=n2=183.462
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.688571, x0=mu=1.01923, sigmaL=sigma=0.000572678, sigmaR=sigma=0.000572678, alphaL=alpha1=0.288722, nL=n1=3.67692, alphaR=alpha2=2.57799, nR=n2=183.462
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.694286, x0=mu=1.01923, sigmaL=sigma=0.000572678, sigmaR=sigma=0.000572678, alphaL=alpha1=0.288722, nL=n1=3.67692, alphaR=alpha2=2.57799, nR=n2=183.462
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.7, x0=mu=1.01923, sigmaL=sigma=0.000572678, sigmaR=sigma=0.000572678, alphaL=alpha1=0.288722, nL=n1=3.67692, alphaR=alpha2=2.57799, nR=n2=183.462
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.705714, x0=mu=1.01923, sigmaL=sigma=0.000572678, sigmaR=sigma=0.000572678, alphaL=alpha1=0.288722, nL=n1=3.67692, alphaR=alpha2=2.57799, nR=n2=183.462
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.711429, x0=mu=1.01923, sigmaL=sigma=0.000572678, sigmaR=sigma=0.000572678, alphaL=alpha1=0.288722, nL=n1=3.67692, alphaR=alpha2=2.57799, nR=n2=183.462
#      getLogVal() top-level p.d.f evaluates to NaN @ x=x=0.717143, x0=mu=1.01923, sigmaL=sigma=0.000572678, sigmaR=sigma=0.000572678, alphaL=alpha1=0.288722, nL=n1=3.67692, alphaR=alpha2=2.57799, nR=n2=183.462
#     ... (remaining 167 messages suppressed)
# RooRealIntegral::dcb_Int[x][ Int dcbd[Ana](x) ]
#      function value is NAN @ !sumList=(), !intList=(), !anaList=(x = 0.654286), !jacList=(), !facList=(), !func=dcb=5.04423e-07/0.374014, !sumCat=()
#
# RooMinimizerFcn: Minimized function has error status.
# Returning maximum FCN so far (20.2782) to force MIGRAD to back out of this region. Error log follows.
# Parameter values: 	alpha1=2.71024	alpha2=1.2944	mu=0.992014	n1=164.109	n2=1.59338	sigma=4.92343e-06
# RooNLLVar::nll_dcb_dh[ paramSet=(alpha1,alpha2,mu,n1,n2,sigma) ]
#      function value is NAN @ paramSet=(alpha1 = 2.71024,alpha2 = 1.2944,mu = 0.992014,n1 = 164.109,n2 = 1.59338,sigma = 4.92343e-06)
# RooCrystalBall::dcb[ x=x x0=mu sigmaL=sigma sigmaR=sigma alphaL=alpha1 nL=n1 alphaR=alpha2 nR=n2 ]
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.654286, x0=mu=0.992014, sigmaL=sigma=4.92343e-06, sigmaR=sigma=4.92343e-06, alphaL=alpha1=2.71024, nL=n1=164.109, alphaR=alpha2=1.2944, nR=n2=1.59338
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.66, x0=mu=0.992014, sigmaL=sigma=4.92343e-06, sigmaR=sigma=4.92343e-06, alphaL=alpha1=2.71024, nL=n1=164.109, alphaR=alpha2=1.2944, nR=n2=1.59338
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.665714, x0=mu=0.992014, sigmaL=sigma=4.92343e-06, sigmaR=sigma=4.92343e-06, alphaL=alpha1=2.71024, nL=n1=164.109, alphaR=alpha2=1.2944, nR=n2=1.59338
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.671429, x0=mu=0.992014, sigmaL=sigma=4.92343e-06, sigmaR=sigma=4.92343e-06, alphaL=alpha1=2.71024, nL=n1=164.109, alphaR=alpha2=1.2944, nR=n2=1.59338
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.677143, x0=mu=0.992014, sigmaL=sigma=4.92343e-06, sigmaR=sigma=4.92343e-06, alphaL=alpha1=2.71024, nL=n1=164.109, alphaR=alpha2=1.2944, nR=n2=1.59338
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.682857, x0=mu=0.992014, sigmaL=sigma=4.92343e-06, sigmaR=sigma=4.92343e-06, alphaL=alpha1=2.71024, nL=n1=164.109, alphaR=alpha2=1.2944, nR=n2=1.59338
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.688571, x0=mu=0.992014, sigmaL=sigma=4.92343e-06, sigmaR=sigma=4.92343e-06, alphaL=alpha1=2.71024, nL=n1=164.109, alphaR=alpha2=1.2944, nR=n2=1.59338
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.694286, x0=mu=0.992014, sigmaL=sigma=4.92343e-06, sigmaR=sigma=4.92343e-06, alphaL=alpha1=2.71024, nL=n1=164.109, alphaR=alpha2=1.2944, nR=n2=1.59338
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.7, x0=mu=0.992014, sigmaL=sigma=4.92343e-06, sigmaR=sigma=4.92343e-06, alphaL=alpha1=2.71024, nL=n1=164.109, alphaR=alpha2=1.2944, nR=n2=1.59338
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.705714, x0=mu=0.992014, sigmaL=sigma=4.92343e-06, sigmaR=sigma=4.92343e-06, alphaL=alpha1=2.71024, nL=n1=164.109, alphaR=alpha2=1.2944, nR=n2=1.59338
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.711429, x0=mu=0.992014, sigmaL=sigma=4.92343e-06, sigmaR=sigma=4.92343e-06, alphaL=alpha1=2.71024, nL=n1=164.109, alphaR=alpha2=1.2944, nR=n2=1.59338
#      getLogVal() top-level p.d.f evaluates to zero @ x=x=0.717143, x0=mu=0.992014, sigmaL=sigma=4.92343e-06, sigmaR=sigma=4.92343e-06, alphaL=alpha1=2.71024, nL=n1=164.109, alphaR=alpha2=1.2944, nR=n2=1.59338
#     ... (remaining 50 messages suppressed)
#
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(dcb) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minization -- RooMinimizer::optimizeConst: deactivating const optimization
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f was fitted in a subrange and no explicit Range() and NormRange() was specified. Plotting / normalising in fit range. To override, do one of the following
# 	- Clear the automatic fit range attribute: <pdf>.setStringAttribute("fitrange", nullptr);
# 	- Explicitly specify the plotting range: Range("<rangeName>").
# 	- Explicitly specify where to compute the normalisation: NormRange("<rangeName>").
# 	The default (full) range can be denoted with Range("") / NormRange("").
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) only plotting range 'fit_nll_dcb_dh'
# [#1] INFO:Plotting -- RooAbsPdf::plotOn(dcb) p.d.f. curve is normalized using explicit choice of ranges 'fit_nll_dcb_dh'
# [#1] INFO:InputArguments -- RooAbsData::plotOn(dh) INFO: dataset has non-integer weights, auto-selecting SumW2 errors instead of Poisson errors
#
#   RooFitResult: minimized FCN value: -1.50555, estimated distance to minimum: 1.57012e-06
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0 HESSE=0
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 alpha1    1.0000e+00    1.5235e+00 +/-  1.13e-01  <none>
#                 alpha2    1.0000e+00    2.0801e+00 +/-  8.26e-02  <none>
#                     mu    9.9714e-01    9.9921e-01 +/-  6.10e-04  <none>
#                     n1    8.0000e+01    2.4703e+00 +/-  4.09e-01  <none>
#                     n2    8.0000e+01    1.2900e+00 +/-  1.38e-01  <none>
#                  sigma    6.9008e-02    1.8699e-02 +/-  5.24e-04  <none>
#
# x[0]=30, y[0]=0.0463715, ex[0]=5, ey[0]=0.000479726
# x[1]=40, y[1]=0.0395384, ex[1]=5, ey[1]=0.00024306
# x[2]=50, y[2]=0.0338186, ex[2]=5, ey[2]=0.000177558
# x[3]=60, y[3]=0.0301382, ex[3]=5, ey[3]=0.000145325
# x[4]=70, y[4]=0.027055, ex[4]=5, ey[4]=0.000151351
# x[5]=80, y[5]=0.0256749, ex[5]=5, ey[5]=0.000220279
# x[6]=90, y[6]=0.0234794, ex[6]=5, ey[6]=0.000266853
# x[7]=100, y[7]=0.0231251, ex[7]=5, ey[7]=0.000280374
# x[8]=110, y[8]=0.0221933, ex[8]=5, ey[8]=0.000429556
# x[9]=120, y[9]=0.0213909, ex[9]=5, ey[9]=0.00037037
# x[10]=130, y[10]=0.0207406, ex[10]=5, ey[10]=0.000414092
# x[11]=140, y[11]=0.0196823, ex[11]=5, ey[11]=0.000465912
# x[12]=150, y[12]=0.0186988, ex[12]=5, ey[12]=0.000523577
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_EGM_25To35GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_EGM_35To45GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_EGM_45To55GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_EGM_55To65GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_EGM_65To75GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_EGM_75To85GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_EGM_85To95GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_EGM_95To105GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_EGM_105To115GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_EGM_115To125GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_EGM_125To135GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_EGM_135To145GeV.pdf has been created
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_fit/EE/respFit_pt_EGM_145To155GeV.pdf has been created

# %%
c1 = ROOT.TCanvas("c1", "", 800, 800)
c1.cd()

pad1 = ROOT.TPad("pad1", " ", 0, 0.3, 1, 1.0)
pad1.SetBottomMargin(0.03)
pad1.SetTopMargin(0.09)
pad1.SetRightMargin(0.05)
pad1.SetLeftMargin(0.14)
pad1.Draw()
pad1.cd()

mu_err_XGB.GetXaxis().SetTitle("")
mu_err_XGB.GetYaxis().SetTitle("#LT p^{Reco}_{T} / p^{True}_{T} #GT")
mu_err_XGB.GetYaxis().SetRangeUser(0.97, 1.03)
mu_err_XGB.GetYaxis().SetNdivisions(506)
mu_err_XGB.GetYaxis().SetTickSize(0.03)
mu_err_XGB.GetYaxis().SetTitleSize(0.06)
mu_err_XGB.GetYaxis().SetLabelSize(0.06)
mu_err_XGB.GetYaxis().SetTitleOffset(1.15)

mu_err_XGB.GetXaxis().SetRangeUser(25, 155)
mu_err_XGB.GetXaxis().SetTickSize(0.03)
mu_err_XGB.GetXaxis().SetTitleSize(0.06)
mu_err_XGB.GetXaxis().SetLabelSize(0.05)
mu_err_XGB.GetXaxis().SetLabelOffset(0.1)
mu_err_XGB.GetXaxis().SetTitleOffset(1)
mu_err_XGB.SetMarkerColor(ROOT.TColor.GetColor("#CC4054"))
mu_err_XGB.SetMarkerSize(1.4)
mu_err_XGB.SetMarkerStyle(20)
mu_err_XGB.SetLineColor(ROOT.TColor.GetColor("#CC4054"))
mu_err_XGB.SetLineWidth(2)
mu_err_XGB.Draw("AP")

mu_err_EGM.SetMarkerColor(ROOT.TColor.GetColor("#202020"))
mu_err_EGM.SetMarkerSize(1.4)
mu_err_EGM.SetMarkerStyle(20)
mu_err_EGM.SetLineColor(ROOT.TColor.GetColor("#202020"))
mu_err_EGM.SetLineWidth(2)

l = ROOT.TLine(25, 1, 155, 1)
l.SetLineStyle(2)
l.SetLineColor(1)
l.Draw()

mu_err_EGM.Draw("P same")
mu_err_XGB.Draw("P same")

region = "ECAL Barrrel" if iBE == 0 else "ECAL Endcap"
leg = ROOT.TLegend(0.53, 0.66, 0.88, 0.86)
leg.SetHeader(region)
leg.SetTextFont(42)
leg.SetTextSize(0.05)
leg.SetFillColor(0)
leg.SetLineColor(0)
leg.AddEntry(mu_err_XGB, "dedicated regression", "LE1P")
leg.AddEntry(mu_err_EGM, "standard regression", "LE1P")
leg.Draw("same")

CMS_lumi(pad1, 5, 10, "", 2017, True, "Simulation Preliminary", "H #rightarrow #gamma* #gamma #rightarrow ee#gamma", "")
c1.cd()

pad2 = ROOT.TPad("pad2", "", 0, 0, 1, 0.3)
pad2.SetGridy()
pad2.SetRightMargin(0.05)
pad2.SetLeftMargin(0.14)
pad2.SetTopMargin(0.06)
pad2.SetBottomMargin(0.43)
pad2.Draw()
pad2.cd()

nPoints = mu_err_XGB.GetN()
ratio_err = ROOT.TGraphErrors(nPoints)
for i in range(nPoints):
    xp = mu_err_XGB.GetPointX(i)
    yp = mu_err_XGB.GetPointY(i)/mu_err_EGM.GetPointY(i)
    xp_err = mu_err_XGB.GetErrorX(i)
    yp_err = yp * np.sqrt(pow(mu_err_XGB.GetErrorY(i)/mu_err_XGB.GetPointY(i), 2) + pow(mu_err_EGM.GetErrorY(i)/mu_err_EGM.GetPointY(i), 2))
    
    ratio_err.SetPoint(i, xp, yp)
    ratio_err.SetPointError(i, xp_err, yp_err)

ratio_err.SetName("")
ratio_err.SetTitle("")
ratio_err.GetXaxis().SetTitle("p^{True}_{T} [GeV]")
ratio_err.GetYaxis().SetTitle("Ratio")
ratio_err.GetYaxis().SetRangeUser(0.97 , 1.03)

ratio_err.SetMarkerColor(ROOT.TColor.GetColor("#202020"))
ratio_err.SetMarkerSize(1.4)
ratio_err.SetMarkerStyle(20)
ratio_err.SetLineColor(ROOT.TColor.GetColor("#202020"))
ratio_err.SetLineWidth(2)

ratio_err.GetXaxis().SetRangeUser(25, 155)
ratio_err.GetXaxis().SetTickSize(0.03 * (7/3.))
ratio_err.GetXaxis().SetTitleSize(0.16)
ratio_err.GetXaxis().SetTitleOffset(1.2)
ratio_err.GetXaxis().SetLabelSize(0.06  * (7/3.))
ratio_err.GetXaxis().SetLabelOffset(0.05)
ratio_err.GetYaxis().SetTitleSize(0.13)
ratio_err.GetYaxis().SetTitleOffset(0.22 * (7/3.))
ratio_err.GetYaxis().SetLabelSize(0.06  * (7/3.))
ratio_err.GetYaxis().SetNdivisions(502)
ratio_err.Draw("AP")

c1.Draw()

# %%
reg_ext = "EB" if iBE == 0 else "EE"
directory = "../plots/validation/resp_mu"
if not os.path.exists(directory):
    os.makedirs(directory)

c1.Print("{}/respMu_pt_{}.pdf".format(directory, reg_ext))
c1.Close()
# Out:
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_mu/respMu_pt_EE.pdf has been created

# %%
c1 = ROOT.TCanvas("c1", "", 800, 800)
c1.cd()

pad1 = ROOT.TPad("pad1", " ", 0, 0.3, 1, 1.0)
pad1.SetBottomMargin(0.03)
pad1.SetTopMargin(0.09)
pad1.SetRightMargin(0.05)
pad1.SetLeftMargin(0.14)
pad1.Draw()
pad1.cd()

width_err_XGB.GetXaxis().SetTitle("")
width_err_XGB.GetYaxis().SetTitle("#sigma_{p^{Reco}_{T} / p^{True}_{T}}")
width_err_XGB.GetYaxis().SetRangeUser(0, 0.06)
width_err_XGB.GetYaxis().SetNdivisions(506)
width_err_XGB.GetYaxis().SetTickSize(0.03)
width_err_XGB.GetYaxis().SetTitleSize(0.06)
width_err_XGB.GetYaxis().SetLabelSize(0.06)
width_err_XGB.GetYaxis().SetTitleOffset(1.15)

width_err_XGB.GetXaxis().SetRangeUser(25, 155)
width_err_XGB.GetXaxis().SetTickSize(0.03)
width_err_XGB.GetXaxis().SetTitleSize(0.06)
width_err_XGB.GetXaxis().SetLabelSize(0.05)
width_err_XGB.GetXaxis().SetLabelOffset(0.1)
width_err_XGB.GetXaxis().SetTitleOffset(1)
width_err_XGB.SetMarkerColor(ROOT.TColor.GetColor("#CC4054"))
width_err_XGB.SetMarkerSize(1.4)
width_err_XGB.SetMarkerStyle(20)
width_err_XGB.SetLineColor(ROOT.TColor.GetColor("#CC4054"))
width_err_XGB.SetLineWidth(2)
width_err_XGB.Draw("AP")

width_err_EGM.SetMarkerColor(ROOT.TColor.GetColor("#202020"))
width_err_EGM.SetMarkerSize(1.4)
width_err_EGM.SetMarkerStyle(20)
width_err_EGM.SetLineColor(ROOT.TColor.GetColor("#202020"))
width_err_EGM.SetLineWidth(2)

# l = ROOT.TLine(25, 1, 155, 1)
# l.SetLineStyle(2)
# l.SetLineColor(1)
# l.Draw()
    
width_err_EGM.Draw("P same")
width_err_XGB.Draw("P same")

region = "ECAL Barrrel" if iBE == 0 else "ECAL Endcap"
leg = ROOT.TLegend(0.53, 0.66, 0.88, 0.86)
leg.SetHeader(region)
leg.SetTextFont(42)
leg.SetTextSize(0.05)
leg.SetFillColor(0)
leg.SetLineColor(0)
leg.AddEntry(mu_err_XGB, "dedicated regression", "LE1P")
leg.AddEntry(mu_err_EGM, "standard regression", "LE1P")
leg.Draw("same")

CMS_lumi(pad1, 5, 10, "", 2017, True, "Simulation Preliminary", "H #rightarrow #gamma* #gamma #rightarrow ee#gamma", "")
c1.cd()

pad2 = ROOT.TPad("pad2", "", 0, 0, 1, 0.3)
pad2.SetGridy()
pad2.SetRightMargin(0.05)
pad2.SetLeftMargin(0.14)
pad2.SetTopMargin(0.06)
pad2.SetBottomMargin(0.43)
pad2.Draw()
pad2.cd()

nPoints = width_err_XGB.GetN()
ratio_err = ROOT.TGraphErrors(nPoints)
for i in range(nPoints):
    xp = width_err_XGB.GetPointX(i)
    yp = width_err_XGB.GetPointY(i)/width_err_EGM.GetPointY(i)
    xp_err = width_err_XGB.GetErrorX(i)
    yp_err = yp * np.sqrt(pow(width_err_XGB.GetErrorY(i)/width_err_XGB.GetPointY(i), 2) + pow(width_err_EGM.GetErrorY(i)/width_err_EGM.GetPointY(i), 2))
    
    ratio_err.SetPoint(i, xp, yp)
    ratio_err.SetPointError(i, xp_err, yp_err)

ratio_err.SetName("")
ratio_err.SetTitle("")
ratio_err.GetXaxis().SetTitle("p^{True}_{T} [GeV]")
ratio_err.GetYaxis().SetTitle("Ratio")
ratio_err.GetYaxis().SetRangeUser(0.4 , 1.6)

ratio_err.SetMarkerColor(ROOT.TColor.GetColor("#202020"))
ratio_err.SetMarkerSize(1.4)
ratio_err.SetMarkerStyle(20)
ratio_err.SetLineColor(ROOT.TColor.GetColor("#202020"))
ratio_err.SetLineWidth(2)

ratio_err.GetXaxis().SetRangeUser(25, 155)
ratio_err.GetXaxis().SetTickSize(0.03 * (7/3.))
ratio_err.GetXaxis().SetTitleSize(0.16)
ratio_err.GetXaxis().SetTitleOffset(1.2)
ratio_err.GetXaxis().SetLabelSize(0.06  * (7/3.))
ratio_err.GetXaxis().SetLabelOffset(0.05)
ratio_err.GetYaxis().SetTitleSize(0.13)
ratio_err.GetYaxis().SetTitleOffset(0.22 * (7/3.))
ratio_err.GetYaxis().SetLabelSize(0.06  * (7/3.))
ratio_err.GetYaxis().SetNdivisions(502)
ratio_err.Draw("AP")

c1.Draw()

# %%
reg_ext = "EB" if iBE == 0 else "EE"
directory = "../plots/validation/resp_width"
if not os.path.exists(directory):
    os.makedirs(directory)
c1.Print("{}/respWidth_pt_{}.pdf".format(directory, reg_ext))
c1.Close()
# Out:
# Info in <TCanvas::Print>: pdf file ../plots/validation/resp_width/respWidth_pt_EE.pdf has been created
